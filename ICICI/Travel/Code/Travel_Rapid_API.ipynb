# %%
credentials = {
                
                    "rapidapi_key":"48eab417d3msh71be3d50835a24cp1e73a7jsn6eab1f0f0e2d",
                    "rapidapi_host":"skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
                    "rapidapi_host2":"travel-advisory.p.rapidapi.com",
                    "rapidapi_host3":"referential.p.rapidapi.com",
                    "rapidapi_host4":"travel-hacking-tool.p.rapidapi.com",
                    "rapidapi_host5":"location-api.p.rapidapi.com",
                    "rapidapi_host6":"iatacodes-iatacodes-v1.p.rapidapi.com",
                    "rapidapi_host7":"currency-converter5.p.rapidapi.com",
                    "rapidapi_host8":"currency-converter13.p.rapidapi.com",
                    "rapidapi_host9":"currencyscoop.p.rapidapi.com"
        
}

# %%
# !pip install selenium
# Out:
# Error processing line 7 of c:\users\gopin\anaconda3\lib\site-packages\pywin32.pth:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\gopin\anaconda3\lib\site-packages (from selenium) (1.25.11)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
#   Traceback (most recent call last):
#     File "c:\users\gopin\anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys 
import time
import re
# Out:
# C:\Users\gopin\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\gopin\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\gopin\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# using rest_id

# %%
class rapid_Skyscanner_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/IN/USD/en-IND/"
        self.base_url1 = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/reference/v1.0/countries/en-US"
        self.base_url2 = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/IN/USD/en-US/DEL-sky/"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def query_places(self,querystring):
        self.querystring = querystring
        self.search_url = self.base_url

        self.params = {
            'query' : "{}".format(self.querystring)
            }

        self.response = requests.get(self.search_url,headers=self.headers,params=self.params)
        print(self.response.url)
        return self.response.json()
    
    def list_markets(self):
        
        self.search_url1 = self.base_url1

        self.response = requests.get(self.search_url1,headers=self.headers)
        print(self.response.url)
        return self.response.json()
    
    def browse_quotes(self,location,outbound_date,inbound_date):
        self.location = location
        self.outbound_date = outbound_date
        self.inbound_date = inbound_date
        self.search_url = self.base_url2 + location + '/' + outbound_date
        
        self.params = {
            'inboundpartialdate' : "{}".format(self.inbound_date)
            }

        self.response = requests.get(self.search_url,headers=self.headers,params=self.params)
        print(self.response.url)
        return self.response.json()
    
    def getplacedetails(self,jsonObj):
        
        if 'code' in jsonObj.keys():
            
            return 'Location Not Found/Invalid Request'
        
        else:        
            return jsonObj
    
    def getmarketsdetails(self,jsonObj):
        
        if 'code' in jsonObj.keys():
            
            return 'Location Not Found/Invalid Request'
        
        else:        
            return jsonObj
    
    def getpricedetails(self,jsonObj):
        
        if 'code' in jsonObj.keys():
            
            return 'Location Not Found/Invalid Request'
        
        else:        
            return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_Skyscanner_Api(credentials['rapidapi_key'],credentials['rapidapi_host'])
    v = app.query_places('El Arish')
    Location_Details = app.getplacedetails(v)
# Out:
# https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/IN/USD/en-IND/?query=El+Arish

# %%
Location_Details
# Out:
# {'Places': []}

# %%
if __name__ == '__main__':
    app = rapid_Skyscanner_Api(credentials['rapidapi_key'],credentials['rapidapi_host'])
    v = app.list_markets()
    Market_Details = app.getmarketsdetails(v)
# Out:
# https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/reference/v1.0/countries/en-US

# %%
Market_Details
# Out:
# {'Countries': [{'Code': 'AD', 'Name': 'Andorra'},
#   {'Code': 'AE', 'Name': 'United Arab Emirates'},
#   {'Code': 'AF', 'Name': 'Afghanistan'},
#   {'Code': 'AG', 'Name': 'Antigua and Barbuda'},
#   {'Code': 'AI', 'Name': 'Anguilla'},
#   {'Code': 'AL', 'Name': 'Albania'},
#   {'Code': 'AM', 'Name': 'Armenia'},
#   {'Code': 'AO', 'Name': 'Angola'},
#   {'Code': 'AQ', 'Name': 'Antarctica'},
#   {'Code': 'AR', 'Name': 'Argentina'},
#   {'Code': 'AS', 'Name': 'American Samoa'},
#   {'Code': 'AT', 'Name': 'Austria'},
#   {'Code': 'AU', 'Name': 'Australia'},
#   {'Code': 'AW', 'Name': 'Aruba'},
#   {'Code': 'AZ', 'Name': 'Azerbaijan'},
#   {'Code': 'BA', 'Name': 'Bosnia and Herzegovina'},
#   {'Code': 'BB', 'Name': 'Barbados'},
#   {'Code': 'BD', 'Name': 'Bangladesh'},
#   {'Code': 'BE', 'Name': 'Belgium'},
#   {'Code': 'BF', 'Name': 'Burkina Faso'},
#   {'Code': 'BG', 'Name': 'Bulgaria'},
#   {'Code': 'BH', 'Name': 'Bahrain'},
#   {'Code': 'BI', 'Name': 'Burundi'},
#   {'Code': 'BJ', 'Name': 'Benin'},
#   {'Code': 'BL', 'Name': 'Saint Barthelemy'},
#   {'Code': 'BM', 'Name': 'Bermuda'},
#   {'Code': 'BN', 'Name': 'Brunei'},
#   {'Code': 'BO', 'Name': 'Bolivia'},
#   {'Code': 'BQ', 'Name': 'Caribbean Netherlands'},
#   {'Code': 'BR', 'Name': 'Brazil'},
#   {'Code': 'BS', 'Name': 'Bahamas'},
#   {'Code': 'BT', 'Name': 'Bhutan'},
#   {'Code': 'BW', 'Name': 'Botswana'},
#   {'Code': 'BY', 'Name': 'Belarus'},
#   {'Code': 'BZ', 'Name': 'Belize'},
#   {'Code': 'CA', 'Name': 'Canada'},
#   {'Code': 'CC', 'Name': 'Cocos (Keeling) Islands'},
#   {'Code': 'CD', 'Name': 'DR Congo'},
#   {'Code': 'CF', 'Name': 'Central African Republic'},
#   {'Code': 'CG', 'Name': 'Congo'},
#   {'Code': 'CH', 'Name': 'Switzerland'},
#   {'Code': 'CI', 'Name': 'Ivory Coast'},
#   {'Code': 'CK', 'Name': 'Cook Islands'},
#   {'Code': 'CL', 'Name': 'Chile'},
#   {'Code': 'CM', 'Name': 'Cameroon'},
#   {'Code': 'CN', 'Name': 'China'},
#   {'Code': 'CO', 'Name': 'Colombia'},
#   {'Code': 'CR', 'Name': 'Costa Rica'},
#   {'Code': 'CU', 'Name': 'Cuba'},
#   {'Code': 'CV', 'Name': 'Cape Verde'},
#   {'Code': 'CW', 'Name': 'Curacao'},
#   {'Code': 'CX', 'Name': 'Christmas Island'},
#   {'Code': 'CY', 'Name': 'Cyprus'},
#   {'Code': 'CZ', 'Name': 'Czech Republic'},
#   {'Code': 'DE', 'Name': 'Germany'},
#   {'Code': 'DJ', 'Name': 'Djibouti'},
#   {'Code': 'DK', 'Name': 'Denmark'},
#   {'Code': 'DM', 'Name': 'Dominica'},
#   {'Code': 'DO', 'Name': 'Dominican Republic'},
#   {'Code': 'DZ', 'Name': 'Algeria'},
#   {'Code': 'EC', 'Name': 'Ecuador'},
#   {'Code': 'EE', 'Name': 'Estonia'},
#   {'Code': 'EG', 'Name': 'Egypt'},
#   {'Code': 'ER', 'Name': 'Eritrea'},
#   {'Code': 'ES', 'Name': 'Spain'},
#   {'Code': 'ET', 'Name': 'Ethiopia'},
#   {'Code': 'FI', 'Name': 'Finland'},
#   {'Code': 'FJ', 'Name': 'Fiji'},
#   {'Code': 'FK', 'Name': 'Falkland Islands'},
#   {'Code': 'FM', 'Name': 'Micronesia'},
#   {'Code': 'FO', 'Name': 'Faroe Islands'},
#   {'Code': 'FR', 'Name': 'France'},
#   {'Code': 'GA', 'Name': 'Gabon'},
#   {'Code': 'GD', 'Name': 'Grenada'},
#   {'Code': 'GE', 'Name': 'Georgia'},
#   {'Code': 'GF', 'Name': 'French Guiana'},
#   {'Code': 'GG', 'Name': 'Guernsey'},
#   {'Code': 'GH', 'Name': 'Ghana'},
#   {'Code': 'GI', 'Name': 'Gibraltar'},
#   {'Code': 'GL', 'Name': 'Greenland'},
#   {'Code': 'GM', 'Name': 'Gambia'},
#   {'Code': 'GN', 'Name': 'Guinea'},
#   {'Code': 'GP', 'Name': 'Guadeloupe'},
#   {'Code': 'GQ', 'Name': 'Equatorial Guinea'},
#   {'Code': 'GR', 'Name': 'Greece'},
#   {'Code': 'GS', 'Name': 'South Georgia & South Sandwich Islands'},
#   {'Code': 'GT', 'Name': 'Guatemala'},
#   {'Code': 'GU', 'Name': 'Guam'},
#   {'Code': 'GW', 'Name': 'Guinea-Bissau'},
#   {'Code': 'GY', 'Name': 'Guyana'},
#   {'Code': 'HK', 'Name': 'Hong Kong'},
#   {'Code': 'HN', 'Name': 'Honduras'},
#   {'Code': 'HR', 'Name': 'Croatia'},
#   {'Code': 'HT', 'Name': 'Haiti'},
#   {'Code': 'HU', 'Name': 'Hungary'},
#   {'Code': 'ID', 'Name': 'Indonesia'},
#   {'Code': 'IE', 'Name': 'Ireland'},
#   {'Code': 'IL', 'Name': 'Israel'},
#   {'Code': 'IN', 'Name': 'India'},
#   {'Code': 'IQ', 'Name': 'Iraq'},
#   {'Code': 'IR', 'Name': 'Iran'},
#   {'Code': 'IS', 'Name': 'Iceland'},
#   {'Code': 'IT', 'Name': 'Italy'},
#   {'Code': 'JM', 'Name': 'Jamaica'},
#   {'Code': 'JO', 'Name': 'Jordan'},
#   {'Code': 'JP', 'Name': 'Japan'},
#   {'Code': 'KE', 'Name': 'Kenya'},
#   {'Code': 'KG', 'Name': 'Kyrgyzstan'},
#   {'Code': 'KH', 'Name': 'Cambodia'},
#   {'Code': 'KI', 'Name': 'Kiribati'},
#   {'Code': 'KM', 'Name': 'Comoros'},
#   {'Code': 'KN', 'Name': 'Saint Kitts and Nevis'},
#   {'Code': 'KO', 'Name': 'Kosovo'},
#   {'Code': 'KP', 'Name': 'North Korea'},
#   {'Code': 'KR', 'Name': 'South Korea'},
#   {'Code': 'KW', 'Name': 'Kuwait'},
#   {'Code': 'KY', 'Name': 'Cayman Islands'},
#   {'Code': 'KZ', 'Name': 'Kazakhstan'},
#   {'Code': 'LA', 'Name': 'Laos'},
#   {'Code': 'LB', 'Name': 'Lebanon'},
#   {'Code': 'LC', 'Name': 'Saint Lucia'},
#   {'Code': 'LI', 'Name': 'Liechtenstein'},
#   {'Code': 'LK', 'Name': 'Sri Lanka'},
#   {'Code': 'LR', 'Name': 'Liberia'},
#   {'Code': 'LS', 'Name': 'Lesotho'},
#   {'Code': 'LT', 'Name': 'Lithuania'},
#   {'Code': 'LU', 'Name': 'Luxembourg'},
#   {'Code': 'LV', 'Name': 'Latvia'},
#   {'Code': 'LY', 'Name': 'Libya'},
#   {'Code': 'MA', 'Name': 'Morocco'},
#   {'Code': 'MC', 'Name': 'Monaco'},
#   {'Code': 'MD', 'Name': 'Moldova'},
#   {'Code': 'ME', 'Name': 'Montenegro'},
#   {'Code': 'MG', 'Name': 'Madagascar'},
#   {'Code': 'MH', 'Name': 'Marshall Islands'},
#   {'Code': 'MK', 'Name': 'Republic of Macedonia'},
#   {'Code': 'ML', 'Name': 'Mali'},
#   {'Code': 'MM', 'Name': 'Myanmar'},
#   {'Code': 'MN', 'Name': 'Mongolia'},
#   {'Code': 'MO', 'Name': 'Macau'},
#   {'Code': 'MP', 'Name': 'Northern Mariana Islands'},
#   {'Code': 'MQ', 'Name': 'Martinique'},
#   {'Code': 'MR', 'Name': 'Mauritania'},
#   {'Code': 'MS', 'Name': 'Montserrat'},
#   {'Code': 'MT', 'Name': 'Malta'},
#   {'Code': 'MU', 'Name': 'Mauritius'},
#   {'Code': 'MV', 'Name': 'Maldives'},
#   {'Code': 'MW', 'Name': 'Malawi'},
#   {'Code': 'MX', 'Name': 'Mexico'},
#   {'Code': 'MY', 'Name': 'Malaysia'},
#   {'Code': 'MZ', 'Name': 'Mozambique'},
#   {'Code': 'NA', 'Name': 'Namibia'},
#   {'Code': 'NC', 'Name': 'New Caledonia'},
#   {'Code': 'NE', 'Name': 'Niger'},
#   {'Code': 'NG', 'Name': 'Nigeria'},
#   {'Code': 'NI', 'Name': 'Nicaragua'},
#   {'Code': 'NL', 'Name': 'Netherlands'},
#   {'Code': 'NO', 'Name': 'Norway'},
#   {'Code': 'NP', 'Name': 'Nepal'},
#   {'Code': 'NR', 'Name': 'Nauru'},
#   {'Code': 'NU', 'Name': 'Niue'},
#   {'Code': 'NZ', 'Name': 'New Zealand'},
#   {'Code': 'OM', 'Name': 'Oman'},
#   {'Code': 'PA', 'Name': 'Panama'},
#   {'Code': 'PE', 'Name': 'Peru'},
#   {'Code': 'PF', 'Name': 'French Polynesia'},
#   {'Code': 'PG', 'Name': 'Papua New Guinea'},
#   {'Code': 'PH', 'Name': 'Philippines'},
#   {'Code': 'PK', 'Name': 'Pakistan'},
#   {'Code': 'PL', 'Name': 'Poland'},
#   {'Code': 'PM', 'Name': 'St. Pierre and Miquelon'},
#   {'Code': 'PR', 'Name': 'Puerto Rico'},
#   {'Code': 'PT', 'Name': 'Portugal'},
#   {'Code': 'PW', 'Name': 'Palau'},
#   {'Code': 'PY', 'Name': 'Paraguay'},
#   {'Code': 'QA', 'Name': 'Qatar'},
#   {'Code': 'RE', 'Name': 'Reunion'},
#   {'Code': 'RO', 'Name': 'Romania'},
#   {'Code': 'RS', 'Name': 'Serbia'},
#   {'Code': 'RU', 'Name': 'Russia'},
#   {'Code': 'RW', 'Name': 'Rwanda'},
#   {'Code': 'SA', 'Name': 'Saudi Arabia'},
#   {'Code': 'SB', 'Name': 'Solomon Islands'},
#   {'Code': 'SC', 'Name': 'Seychelles'},
#   {'Code': 'SD', 'Name': 'Sudan'},
#   {'Code': 'SE', 'Name': 'Sweden'},
#   {'Code': 'SG', 'Name': 'Singapore'},
#   {'Code': 'SH', 'Name': 'St. Helena'},
#   {'Code': 'SI', 'Name': 'Slovenia'},
#   {'Code': 'SK', 'Name': 'Slovakia'},
#   {'Code': 'SL', 'Name': 'Sierra Leone'},
#   {'Code': 'SN', 'Name': 'Senegal'},
#   {'Code': 'SO', 'Name': 'Somalia'},
#   {'Code': 'SR', 'Name': 'Suriname'},
#   {'Code': 'SS', 'Name': 'South Sudan'},
#   {'Code': 'ST', 'Name': 'Sao Tome and Principe'},
#   {'Code': 'SV', 'Name': 'El Salvador'},
#   {'Code': 'SX', 'Name': 'St Maarten'},
#   {'Code': 'SY', 'Name': 'Syria'},
#   {'Code': 'SZ', 'Name': 'Swaziland'},
#   {'Code': 'TC', 'Name': 'Turks and Caicos Islands'},
#   {'Code': 'TD', 'Name': 'Chad'},
#   {'Code': 'TG', 'Name': 'Togo'},
#   {'Code': 'TH', 'Name': 'Thailand'},
#   {'Code': 'TJ', 'Name': 'Tajikistan'},
#   {'Code': 'TL', 'Name': 'East Timor'},
#   {'Code': 'TM', 'Name': 'Turkmenistan'},
#   {'Code': 'TN', 'Name': 'Tunisia'},
#   {'Code': 'TO', 'Name': 'Tonga'},
#   {'Code': 'TR', 'Name': 'Turkey'},
#   {'Code': 'TT', 'Name': 'Trinidad and Tobago'},
#   {'Code': 'TV', 'Name': 'Tuvalu'},
#   {'Code': 'TW', 'Name': 'Taiwan'},
#   {'Code': 'TZ', 'Name': 'Tanzania'},
#   {'Code': 'UA', 'Name': 'Ukraine'},
#   {'Code': 'UG', 'Name': 'Uganda'},
#   {'Code': 'UK', 'Name': 'United Kingdom'},
#   {'Code': 'US', 'Name': 'United States'},
#   {'Code': 'UY', 'Name': 'Uruguay'},
#   {'Code': 'UZ', 'Name': 'Uzbekistan'},
#   {'Code': 'VA', 'Name': 'Vatican City'},
#   {'Code': 'VC', 'Name': 'Saint Vincent and the Grenadines'},
#   {'Code': 'VE', 'Name': 'Venezuela'},
#   {'Code': 'VG', 'Name': 'British Virgin Islands'},
#   {'Code': 'VI', 'Name': 'US Virgin Islands'},
#   {'Code': 'VN', 'Name': 'Vietnam'},
#   {'Code': 'VU', 'Name': 'Vanuatu'},
#   {'Code': 'WF', 'Name': 'Wallis and Futuna Islands'},
#   {'Code': 'WS', 'Name': 'Samoa'},
#   {'Code': 'YE', 'Name': 'Yemen'},
#   {'Code': 'YT', 'Name': 'Mayotte'},
#   {'Code': 'ZA', 'Name': 'South Africa'},
#   {'Code': 'ZM', 'Name': 'Zambia'},
#   {'Code': 'ZW', 'Name': 'Zimbabwe'}]}

# %%
if __name__ == '__main__':
    app = rapid_Skyscanner_Api(credentials['rapidapi_key'],credentials['rapidapi_host'])
    v = app.browse_quotes('ACA-sky','2021','2021')
    Price_Details = app.getpricedetails(v)
# Out:
# https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/IN/USD/en-US/DEL-sky/ACA-sky/2021?inboundpartialdate=2021

# %%
Price_Details
# Out:
# {'Quotes': [],
#  'Carriers': [],
#  'Places': [],
#  'Currencies': [{'Code': 'USD',
#    'Symbol': '$',
#    'ThousandsSeparator': ',',
#    'DecimalSeparator': '.',
#    'SymbolOnLeft': True,
#    'SpaceBetweenAmountAndSymbol': False,
#    'RoundingCoefficient': 0,
#    'DecimalDigits': 2}]}

# %%
class rapid_TravelAdvisory_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://www.travel-advisory.info/api"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def Travel_Advisory(self):
        
        self.search_url = self.base_url

        self.response = requests.get(self.search_url,headers=self.headers)
        print(self.response.url)
        return self.response.json()
    
    def getTravelAdvisorydetails(self,jsonObj):
        
        if 'code' in jsonObj.keys():
            
            return 'Location Not Found/Invalid Request'
        
        else:        
            return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_TravelAdvisory_Api(credentials['rapidapi_key'],credentials['rapidapi_host2'])
    v = app.Travel_Advisory()
    TravelAdvisorydetails = app.getTravelAdvisorydetails(v)
# Out:
# https://www.travel-advisory.info/api

# %%
TravelAdvisorydetails
# Out:
# {'api_status': {'request': {'item': 'not specified'},
#   'reply': {'cache': 'cached',
#    'code': 200,
#    'status': 'ok',
#    'note': 'The api works, we could fetch countries.',
#    'count': 238}},
#  'data': {'AD': {'iso_alpha2': 'AD',
#    'name': 'Andorra',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Andorra has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Andorra.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/andorra'}},
#   'AE': {'iso_alpha2': 'AE',
#    'name': 'United Arab Emirates',
#    'continent': 'AS',
#    'advisory': {'score': 3.6,
#     'sources_active': 7,
#     'message': 'United Arab Emirates has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to United Arab Emirates.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/united-arab-emirates'}},
#   'AF': {'iso_alpha2': 'AF',
#    'name': 'Afghanistan',
#    'continent': 'AS',
#    'advisory': {'score': 5,
#     'sources_active': 10,
#     'message': 'Afghanistan has a current risk level of 5 (out of 5). We advise: It is not safe to travel Afghanistan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/afghanistan'}},
#   'AG': {'iso_alpha2': 'AG',
#    'name': 'Antigua and Barbuda',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Antigua and Barbuda has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Antigua and Barbuda.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/antigua-and-barbuda'}},
#   'AI': {'iso_alpha2': 'AI',
#    'name': 'Anguilla',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Anguilla has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Anguilla.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/anguilla'}},
#   'AL': {'iso_alpha2': 'AL',
#    'name': 'Albania',
#    'continent': 'EU',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Albania has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Albania.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/albania'}},
#   'AM': {'iso_alpha2': 'AM',
#    'name': 'Armenia',
#    'continent': 'AS',
#    'advisory': {'score': 4.3,
#     'sources_active': 7,
#     'message': 'Armenia has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to Armenia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/armenia'}},
#   'AO': {'iso_alpha2': 'AO',
#    'name': 'Angola',
#    'continent': 'AF',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Angola has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Angola.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/angola'}},
#   'AR': {'iso_alpha2': 'AR',
#    'name': 'Argentina',
#    'continent': 'SA',
#    'advisory': {'score': 3.9,
#     'sources_active': 8,
#     'message': 'Argentina has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to Argentina.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/argentina'}},
#   'AS': {'iso_alpha2': 'AS',
#    'name': 'American Samoa',
#    'continent': 'OC',
#    'advisory': {'score': 4,
#     'sources_active': 1,
#     'message': 'American Samoa has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to American Samoa.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/american-samoa'}},
#   'AT': {'iso_alpha2': 'AT',
#    'name': 'Austria',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Austria has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Austria.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/austria'}},
#   'AU': {'iso_alpha2': 'AU',
#    'name': 'Australia',
#    'continent': 'OC',
#    'advisory': {'score': 3.3,
#     'sources_active': 6,
#     'message': 'Australia has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Australia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/australia'}},
#   'AW': {'iso_alpha2': 'AW',
#    'name': 'Aruba',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 2,
#     'message': 'Aruba has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Aruba.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/aruba'}},
#   'AZ': {'iso_alpha2': 'AZ',
#    'name': 'Azerbaijan',
#    'continent': 'AS',
#    'advisory': {'score': 4,
#     'sources_active': 8,
#     'message': 'Azerbaijan has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Azerbaijan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/azerbaijan'}},
#   'BA': {'iso_alpha2': 'BA',
#    'name': 'Bosnia and Herzegovina',
#    'continent': 'EU',
#    'advisory': {'score': 4,
#     'sources_active': 6,
#     'message': 'Bosnia and Herzegovina has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Bosnia and Herzegovina.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bosnia-and-herzegovina'}},
#   'BB': {'iso_alpha2': 'BB',
#    'name': 'Barbados',
#    'continent': 'NA',
#    'advisory': {'score': 3.5,
#     'sources_active': 4,
#     'message': 'Barbados has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Barbados.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/barbados'}},
#   'BD': {'iso_alpha2': 'BD',
#    'name': 'Bangladesh',
#    'continent': 'AS',
#    'advisory': {'score': 3.8,
#     'sources_active': 8,
#     'message': 'Bangladesh has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Bangladesh.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bangladesh'}},
#   'BE': {'iso_alpha2': 'BE',
#    'name': 'Belgium',
#    'continent': 'EU',
#    'advisory': {'score': 3.5,
#     'sources_active': 8,
#     'message': 'Belgium has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Belgium.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/belgium'}},
#   'BF': {'iso_alpha2': 'BF',
#    'name': 'Burkina Faso',
#    'continent': 'AF',
#    'advisory': {'score': 3.9,
#     'sources_active': 8,
#     'message': 'Burkina Faso has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to Burkina Faso.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/burkina-faso'}},
#   'BG': {'iso_alpha2': 'BG',
#    'name': 'Bulgaria',
#    'continent': 'EU',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Bulgaria has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Bulgaria.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bulgaria'}},
#   'BH': {'iso_alpha2': 'BH',
#    'name': 'Bahrain',
#    'continent': 'AS',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Bahrain has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Bahrain.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bahrain'}},
#   'BI': {'iso_alpha2': 'BI',
#    'name': 'Burundi',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 6,
#     'message': 'Burundi has a current risk level of 5 (out of 5). We advise: It is not safe to travel Burundi.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/burundi'}},
#   'BJ': {'iso_alpha2': 'BJ',
#    'name': 'Benin',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 4,
#     'message': 'Benin has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Benin.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/benin'}},
#   'BL': {'iso_alpha2': 'BL',
#    'name': 'Saint Barthélemy',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 1,
#     'message': 'Saint Barthélemy has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Saint Barthélemy.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/saint-barthelemy'}},
#   'BM': {'iso_alpha2': 'BM',
#    'name': 'Bermuda',
#    'continent': 'NA',
#    'advisory': {'score': 3.3,
#     'sources_active': 3,
#     'message': 'Bermuda has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Bermuda.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bermuda'}},
#   'BN': {'iso_alpha2': 'BN',
#    'name': 'Brunei',
#    'continent': 'AS',
#    'advisory': {'score': 3.4,
#     'sources_active': 5,
#     'message': 'Brunei has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Brunei.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/brunei'}},
#   'BO': {'iso_alpha2': 'BO',
#    'name': 'Bolivia',
#    'continent': 'SA',
#    'advisory': {'score': 3.7,
#     'sources_active': 6,
#     'message': 'Bolivia has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Bolivia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bolivia'}},
#   'BR': {'iso_alpha2': 'BR',
#    'name': 'Brazil',
#    'continent': 'SA',
#    'advisory': {'score': 3.9,
#     'sources_active': 9,
#     'message': 'Brazil has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to Brazil.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/brazil'}},
#   'BS': {'iso_alpha2': 'BS',
#    'name': 'Bahamas',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 4,
#     'message': 'Bahamas has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Bahamas.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bahamas'}},
#   'BT': {'iso_alpha2': 'BT',
#    'name': 'Bhutan',
#    'continent': 'AS',
#    'advisory': {'score': 4,
#     'sources_active': 5,
#     'message': 'Bhutan has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Bhutan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/bhutan'}},
#   'BW': {'iso_alpha2': 'BW',
#    'name': 'Botswana',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Botswana has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Botswana.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/botswana'}},
#   'BY': {'iso_alpha2': 'BY',
#    'name': 'Belarus',
#    'continent': 'EU',
#    'advisory': {'score': 4,
#     'sources_active': 6,
#     'message': 'Belarus has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Belarus.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/belarus'}},
#   'BZ': {'iso_alpha2': 'BZ',
#    'name': 'Belize',
#    'continent': 'NA',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Belize has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Belize.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/belize'}},
#   'CA': {'iso_alpha2': 'CA',
#    'name': 'Canada',
#    'continent': 'NA',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Canada has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Canada.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/canada'}},
#   'CC': {'iso_alpha2': 'CC',
#    'name': 'Cocos Islands',
#    'continent': 'SA',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Cocos Islands has a current risk level of 0 (out of 5). We advise: Travelling Cocos Islands is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cocos-islands'}},
#   'CD': {'iso_alpha2': 'CD',
#    'name': 'Democratic Republic of the Congo',
#    'continent': 'AF',
#    'advisory': {'score': 3.9,
#     'sources_active': 8,
#     'message': 'Democratic Republic of the Congo has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to Democratic Republic of the Congo.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/democratic-republic-of-the-congo'}},
#   'CF': {'iso_alpha2': 'CF',
#    'name': 'Central African Republic',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 8,
#     'message': 'Central African Republic has a current risk level of 5 (out of 5). We advise: It is not safe to travel Central African Republic.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/central-african-republic'}},
#   'CG': {'iso_alpha2': 'CG',
#    'name': 'Republic of the Congo',
#    'continent': 'AF',
#    'advisory': {'score': 3.3,
#     'sources_active': 4,
#     'message': 'Republic of the Congo has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Republic of the Congo.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/republic-of-the-congo'}},
#   'CH': {'iso_alpha2': 'CH',
#    'name': 'Switzerland',
#    'continent': 'EU',
#    'advisory': {'score': 4,
#     'sources_active': 5,
#     'message': 'Switzerland has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Switzerland.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/switzerland'}},
#   'CI': {'iso_alpha2': 'CI',
#    'name': 'Ivory Coast',
#    'continent': 'AF',
#    'advisory': {'score': 3.6,
#     'sources_active': 7,
#     'message': 'Ivory Coast has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Ivory Coast.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/ivory-coast'}},
#   'CK': {'iso_alpha2': 'CK',
#    'name': 'Cook Islands',
#    'continent': 'OC',
#    'advisory': {'score': 4.5,
#     'sources_active': 2,
#     'message': 'Cook Islands has a current risk level of 4.5 (out of 5). We advise: It is not safe to travel Cook Islands.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cook-islands'}},
#   'CL': {'iso_alpha2': 'CL',
#    'name': 'Chile',
#    'continent': 'SA',
#    'advisory': {'score': 3.9,
#     'sources_active': 8,
#     'message': 'Chile has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to Chile.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/chile'}},
#   'CM': {'iso_alpha2': 'CM',
#    'name': 'Cameroon',
#    'continent': 'AF',
#    'advisory': {'score': 3.4,
#     'sources_active': 7,
#     'message': 'Cameroon has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Cameroon.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cameroon'}},
#   'CN': {'iso_alpha2': 'CN',
#    'name': 'China',
#    'continent': 'AS',
#    'advisory': {'score': 4,
#     'sources_active': 9,
#     'message': 'China has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to China.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/china'}},
#   'CO': {'iso_alpha2': 'CO',
#    'name': 'Colombia',
#    'continent': 'SA',
#    'advisory': {'score': 3.6,
#     'sources_active': 7,
#     'message': 'Colombia has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Colombia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/colombia'}},
#   'CR': {'iso_alpha2': 'CR',
#    'name': 'Costa Rica',
#    'continent': 'NA',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Costa Rica has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Costa Rica.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/costa-rica'}},
#   'CU': {'iso_alpha2': 'CU',
#    'name': 'Cuba',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 5,
#     'message': 'Cuba has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Cuba.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cuba'}},
#   'CV': {'iso_alpha2': 'CV',
#    'name': 'Cape Verde',
#    'continent': 'AF',
#    'advisory': {'score': 3.5,
#     'sources_active': 4,
#     'message': 'Cape Verde has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Cape Verde.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cape-verde'}},
#   'CX': {'iso_alpha2': 'CX',
#    'name': 'Christmas Island',
#    'continent': 'OC',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Christmas Island has a current risk level of 0 (out of 5). We advise: Travelling Christmas Island is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/christmas-island'}},
#   'CY': {'iso_alpha2': 'CY',
#    'name': 'Cyprus',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Cyprus has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Cyprus.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cyprus'}},
#   'CZ': {'iso_alpha2': 'CZ',
#    'name': 'Czech Republic',
#    'continent': 'EU',
#    'advisory': {'score': 4,
#     'sources_active': 7,
#     'message': 'Czech Republic has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Czech Republic.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/czech-republic'}},
#   'DE': {'iso_alpha2': 'DE',
#    'name': 'Germany',
#    'continent': 'EU',
#    'advisory': {'score': 3.5,
#     'sources_active': 8,
#     'message': 'Germany has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Germany.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/germany'}},
#   'DJ': {'iso_alpha2': 'DJ',
#    'name': 'Djibouti',
#    'continent': 'AF',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Djibouti has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Djibouti.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/djibouti'}},
#   'DK': {'iso_alpha2': 'DK',
#    'name': 'Denmark',
#    'continent': 'EU',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Denmark has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Denmark.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/denmark'}},
#   'DM': {'iso_alpha2': 'DM',
#    'name': 'Dominica',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Dominica has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Dominica.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/dominica'}},
#   'DO': {'iso_alpha2': 'DO',
#    'name': 'Dominican Republic',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 5,
#     'message': 'Dominican Republic has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Dominican Republic.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/dominican-republic'}},
#   'DZ': {'iso_alpha2': 'DZ',
#    'name': 'Algeria',
#    'continent': 'AF',
#    'advisory': {'score': 3.4,
#     'sources_active': 10,
#     'message': 'Algeria has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Algeria.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/algeria'}},
#   'EC': {'iso_alpha2': 'EC',
#    'name': 'Ecuador',
#    'continent': 'SA',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Ecuador has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Ecuador.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/ecuador'}},
#   'EE': {'iso_alpha2': 'EE',
#    'name': 'Estonia',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 6,
#     'message': 'Estonia has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Estonia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/estonia'}},
#   'EG': {'iso_alpha2': 'EG',
#    'name': 'Egypt',
#    'continent': 'AF',
#    'advisory': {'score': 3.6,
#     'sources_active': 10,
#     'message': 'Egypt has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Egypt.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/egypt'}},
#   'EH': {'iso_alpha2': 'EH',
#    'name': 'Western Sahara',
#    'continent': 'AF',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Western Sahara has a current risk level of 0 (out of 5). We advise: Travelling Western Sahara is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/western-sahara'}},
#   'ER': {'iso_alpha2': 'ER',
#    'name': 'Eritrea',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 7,
#     'message': 'Eritrea has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Eritrea.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/eritrea'}},
#   'ES': {'iso_alpha2': 'ES',
#    'name': 'Spain',
#    'continent': 'EU',
#    'advisory': {'score': 3.5,
#     'sources_active': 8,
#     'message': 'Spain has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Spain.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/spain'}},
#   'ET': {'iso_alpha2': 'ET',
#    'name': 'Ethiopia',
#    'continent': 'AF',
#    'advisory': {'score': 3.4,
#     'sources_active': 9,
#     'message': 'Ethiopia has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Ethiopia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/ethiopia'}},
#   'FI': {'iso_alpha2': 'FI',
#    'name': 'Finland',
#    'continent': 'EU',
#    'advisory': {'score': 4.2,
#     'sources_active': 5,
#     'message': 'Finland has a current risk level of 4.2 (out of 5). We advise: Please reconsider your need to travel to Finland.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/finland'}},
#   'FJ': {'iso_alpha2': 'FJ',
#    'name': 'Fiji',
#    'continent': 'OC',
#    'advisory': {'score': 3.4,
#     'sources_active': 5,
#     'message': 'Fiji has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Fiji.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/fiji'}},
#   'FK': {'iso_alpha2': 'FK',
#    'name': 'Falkland Islands',
#    'continent': 'SA',
#    'advisory': {'score': 4,
#     'sources_active': 1,
#     'message': 'Falkland Islands has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Falkland Islands.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/falkland-islands'}},
#   'FM': {'iso_alpha2': 'FM',
#    'name': 'Micronesia',
#    'continent': 'OC',
#    'advisory': {'score': 2,
#     'sources_active': 1,
#     'message': 'Micronesia has a current risk level of 2 (out of 5). We advise: Travelling Micronesia is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/micronesia'}},
#   'FO': {'iso_alpha2': 'FO',
#    'name': 'Faroe Islands',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Faroe Islands has a current risk level of 0 (out of 5). We advise: Travelling Faroe Islands is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/faroe-islands'}},
#   'FR': {'iso_alpha2': 'FR',
#    'name': 'France',
#    'continent': 'EU',
#    'advisory': {'score': 3.6,
#     'sources_active': 8,
#     'message': 'France has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to France.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/france'}},
#   'GA': {'iso_alpha2': 'GA',
#    'name': 'Gabon',
#    'continent': 'AF',
#    'advisory': {'score': 4.3,
#     'sources_active': 4,
#     'message': 'Gabon has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to Gabon.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/gabon'}},
#   'GB': {'iso_alpha2': 'GB',
#    'name': 'United Kingdom',
#    'continent': 'EU',
#    'advisory': {'score': 3.5,
#     'sources_active': 8,
#     'message': 'United Kingdom has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to United Kingdom.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/united-kingdom'}},
#   'GD': {'iso_alpha2': 'GD',
#    'name': 'Grenada',
#    'continent': 'NA',
#    'advisory': {'score': 3.3,
#     'sources_active': 3,
#     'message': 'Grenada has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Grenada.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/grenada'}},
#   'GE': {'iso_alpha2': 'GE',
#    'name': 'Georgia',
#    'continent': 'AS',
#    'advisory': {'score': 3.6,
#     'sources_active': 5,
#     'message': 'Georgia has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Georgia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/georgia'}},
#   'GF': {'iso_alpha2': 'GF',
#    'name': 'French Guiana',
#    'continent': 'SA',
#    'advisory': {'score': 4,
#     'sources_active': 2,
#     'message': 'French Guiana has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to French Guiana.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/french-guiana'}},
#   'GG': {'iso_alpha2': 'GG',
#    'name': 'Guernsey',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Guernsey has a current risk level of 0 (out of 5). We advise: Travelling Guernsey is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/guernsey'}},
#   'GH': {'iso_alpha2': 'GH',
#    'name': 'Ghana',
#    'continent': 'AF',
#    'advisory': {'score': 4.2,
#     'sources_active': 5,
#     'message': 'Ghana has a current risk level of 4.2 (out of 5). We advise: Please reconsider your need to travel to Ghana.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/ghana'}},
#   'GI': {'iso_alpha2': 'GI',
#    'name': 'Gibraltar',
#    'continent': 'EU',
#    'advisory': {'score': 4,
#     'sources_active': 1,
#     'message': 'Gibraltar has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Gibraltar.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/gibraltar'}},
#   'GL': {'iso_alpha2': 'GL',
#    'name': 'Greenland',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 1,
#     'message': 'Greenland has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Greenland.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/greenland'}},
#   'GM': {'iso_alpha2': 'GM',
#    'name': 'Gambia',
#    'continent': 'AF',
#    'advisory': {'score': 3.6,
#     'sources_active': 5,
#     'message': 'Gambia has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Gambia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/gambia'}},
#   'GN': {'iso_alpha2': 'GN',
#    'name': 'Guinea',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Guinea has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Guinea.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/guinea'}},
#   'GP': {'iso_alpha2': 'GP',
#    'name': 'Guadeloupe',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 2,
#     'message': 'Guadeloupe has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Guadeloupe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/guadeloupe'}},
#   'GQ': {'iso_alpha2': 'GQ',
#    'name': 'Equatorial Guinea',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Equatorial Guinea has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Equatorial Guinea.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/equatorial-guinea'}},
#   'GR': {'iso_alpha2': 'GR',
#    'name': 'Greece',
#    'continent': 'EU',
#    'advisory': {'score': 3.6,
#     'sources_active': 7,
#     'message': 'Greece has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Greece.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/greece'}},
#   'GS': {'iso_alpha2': 'GS',
#    'name': 'South Georgia and the South Sandwich Islands',
#    'continent': 'AN',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'South Georgia and the South Sandwich Islands has a current risk level of 0 (out of 5). We advise: Travelling South Georgia and the South Sandwich Islands is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/south-georgia-and-the-south-sandwich-islands'}},
#   'GT': {'iso_alpha2': 'GT',
#    'name': 'Guatemala',
#    'continent': 'NA',
#    'advisory': {'score': 3.7,
#     'sources_active': 6,
#     'message': 'Guatemala has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Guatemala.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/guatemala'}},
#   'GU': {'iso_alpha2': 'GU',
#    'name': 'Guam',
#    'continent': 'OC',
#    'advisory': {'score': 4.5,
#     'sources_active': 2,
#     'message': 'Guam has a current risk level of 4.5 (out of 5). We advise: It is not safe to travel Guam.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/guam'}},
#   'GW': {'iso_alpha2': 'GW',
#    'name': 'Guinea-Bissau',
#    'continent': 'AF',
#    'advisory': {'score': 3.3,
#     'sources_active': 3,
#     'message': 'Guinea-Bissau has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Guinea-Bissau.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/guinea-bissau'}},
#   'GY': {'iso_alpha2': 'GY',
#    'name': 'Guyana',
#    'continent': 'SA',
#    'advisory': {'score': 4,
#     'sources_active': 5,
#     'message': 'Guyana has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Guyana.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/guyana'}},
#   'HK': {'iso_alpha2': 'HK',
#    'name': 'Hong Kong',
#    'continent': 'AS',
#    'advisory': {'score': 3.7,
#     'sources_active': 6,
#     'message': 'Hong Kong has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Hong Kong.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/hong-kong'}},
#   'HN': {'iso_alpha2': 'HN',
#    'name': 'Honduras',
#    'continent': 'NA',
#    'advisory': {'score': 3.8,
#     'sources_active': 6,
#     'message': 'Honduras has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Honduras.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/honduras'}},
#   'HR': {'iso_alpha2': 'HR',
#    'name': 'Croatia',
#    'continent': 'EU',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Croatia has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Croatia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/croatia'}},
#   'HT': {'iso_alpha2': 'HT',
#    'name': 'Haiti',
#    'continent': 'NA',
#    'advisory': {'score': 4.4,
#     'sources_active': 7,
#     'message': 'Haiti has a current risk level of 4.4 (out of 5). We advise: Please reconsider your need to travel to Haiti.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/haiti'}},
#   'HU': {'iso_alpha2': 'HU',
#    'name': 'Hungary',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 6,
#     'message': 'Hungary has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Hungary.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/hungary'}},
#   'ID': {'iso_alpha2': 'ID',
#    'name': 'Indonesia',
#    'continent': 'AS',
#    'advisory': {'score': 4,
#     'sources_active': 8,
#     'message': 'Indonesia has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Indonesia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/indonesia'}},
#   'IE': {'iso_alpha2': 'IE',
#    'name': 'Ireland',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Ireland has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Ireland.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/ireland'}},
#   'IL': {'iso_alpha2': 'IL',
#    'name': 'Israel',
#    'continent': 'AS',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Israel has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Israel.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/israel'}},
#   'IM': {'iso_alpha2': 'IM',
#    'name': 'Isle of Man',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Isle of Man has a current risk level of 0 (out of 5). We advise: Travelling Isle of Man is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/isle-of-man'}},
#   'IN': {'iso_alpha2': 'IN',
#    'name': 'India',
#    'continent': 'AS',
#    'advisory': {'score': 3.9,
#     'sources_active': 8,
#     'message': 'India has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to India.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/india'}},
#   'IQ': {'iso_alpha2': 'IQ',
#    'name': 'Iraq',
#    'continent': 'AS',
#    'advisory': {'score': 4.7,
#     'sources_active': 9,
#     'message': 'Iraq has a current risk level of 4.7 (out of 5). We advise: It is not safe to travel Iraq.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/iraq'}},
#   'IR': {'iso_alpha2': 'IR',
#    'name': 'Iran',
#    'continent': 'AS',
#    'advisory': {'score': 4.6,
#     'sources_active': 7,
#     'message': 'Iran has a current risk level of 4.6 (out of 5). We advise: It is not safe to travel Iran.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/iran'}},
#   'IS': {'iso_alpha2': 'IS',
#    'name': 'Iceland',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 6,
#     'message': 'Iceland has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Iceland.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/iceland'}},
#   'IT': {'iso_alpha2': 'IT',
#    'name': 'Italy',
#    'continent': 'EU',
#    'advisory': {'score': 3.7,
#     'sources_active': 9,
#     'message': 'Italy has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Italy.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/italy'}},
#   'JE': {'iso_alpha2': 'JE',
#    'name': 'Jersey',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Jersey has a current risk level of 0 (out of 5). We advise: Travelling Jersey is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/jersey'}},
#   'JM': {'iso_alpha2': 'JM',
#    'name': 'Jamaica',
#    'continent': 'NA',
#    'advisory': {'score': 3.7,
#     'sources_active': 6,
#     'message': 'Jamaica has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Jamaica.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/jamaica'}},
#   'JO': {'iso_alpha2': 'JO',
#    'name': 'Jordan',
#    'continent': 'AS',
#    'advisory': {'score': 3.6,
#     'sources_active': 7,
#     'message': 'Jordan has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Jordan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/jordan'}},
#   'JP': {'iso_alpha2': 'JP',
#    'name': 'Japan',
#    'continent': 'AS',
#    'advisory': {'score': 3.5,
#     'sources_active': 8,
#     'message': 'Japan has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Japan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/japan'}},
#   'KE': {'iso_alpha2': 'KE',
#    'name': 'Kenya',
#    'continent': 'AF',
#    'advisory': {'score': 3.4,
#     'sources_active': 9,
#     'message': 'Kenya has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Kenya.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/kenya'}},
#   'KG': {'iso_alpha2': 'KG',
#    'name': 'Kyrgyzstan',
#    'continent': 'AS',
#    'advisory': {'score': 3.4,
#     'sources_active': 5,
#     'message': 'Kyrgyzstan has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Kyrgyzstan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/kyrgyzstan'}},
#   'KH': {'iso_alpha2': 'KH',
#    'name': 'Cambodia',
#    'continent': 'AS',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Cambodia has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Cambodia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cambodia'}},
#   'KI': {'iso_alpha2': 'KI',
#    'name': 'Kiribati',
#    'continent': 'OC',
#    'advisory': {'score': 4,
#     'sources_active': 2,
#     'message': 'Kiribati has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Kiribati.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/kiribati'}},
#   'KM': {'iso_alpha2': 'KM',
#    'name': 'Comoros',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Comoros has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Comoros.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/comoros'}},
#   'KN': {'iso_alpha2': 'KN',
#    'name': 'Saint Kitts and Nevis',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Saint Kitts and Nevis has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Saint Kitts and Nevis.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/saint-kitts-and-nevis'}},
#   'KP': {'iso_alpha2': 'KP',
#    'name': 'North Korea',
#    'continent': 'AS',
#    'advisory': {'score': 4.3,
#     'sources_active': 6,
#     'message': 'North Korea has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to North Korea.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/north-korea'}},
#   'KR': {'iso_alpha2': 'KR',
#    'name': 'South Korea',
#    'continent': 'AS',
#    'advisory': {'score': 3.3,
#     'sources_active': 6,
#     'message': 'South Korea has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling South Korea.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/south-korea'}},
#   'KW': {'iso_alpha2': 'KW',
#    'name': 'Kuwait',
#    'continent': 'AS',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Kuwait has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Kuwait.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/kuwait'}},
#   'KY': {'iso_alpha2': 'KY',
#    'name': 'Cayman Islands',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Cayman Islands has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Cayman Islands.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/cayman-islands'}},
#   'KZ': {'iso_alpha2': 'KZ',
#    'name': 'Kazakhstan',
#    'continent': 'AS',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Kazakhstan has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Kazakhstan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/kazakhstan'}},
#   'LA': {'iso_alpha2': 'LA',
#    'name': 'Laos',
#    'continent': 'AS',
#    'advisory': {'score': 3.6,
#     'sources_active': 5,
#     'message': 'Laos has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Laos.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/laos'}},
#   'LB': {'iso_alpha2': 'LB',
#    'name': 'Lebanon',
#    'continent': 'AS',
#    'advisory': {'score': 3.4,
#     'sources_active': 10,
#     'message': 'Lebanon has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Lebanon.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/lebanon'}},
#   'LC': {'iso_alpha2': 'LC',
#    'name': 'Saint Lucia',
#    'continent': 'NA',
#    'advisory': {'score': 3.3,
#     'sources_active': 3,
#     'message': 'Saint Lucia has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Saint Lucia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/saint-lucia'}},
#   'LI': {'iso_alpha2': 'LI',
#    'name': 'Liechtenstein',
#    'continent': 'EU',
#    'advisory': {'score': 3.5,
#     'sources_active': 4,
#     'message': 'Liechtenstein has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Liechtenstein.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/liechtenstein'}},
#   'LK': {'iso_alpha2': 'LK',
#    'name': 'Sri Lanka',
#    'continent': 'AS',
#    'advisory': {'score': 3.6,
#     'sources_active': 8,
#     'message': 'Sri Lanka has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Sri Lanka.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/sri-lanka'}},
#   'LR': {'iso_alpha2': 'LR',
#    'name': 'Liberia',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Liberia has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Liberia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/liberia'}},
#   'LS': {'iso_alpha2': 'LS',
#    'name': 'Lesotho',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Lesotho has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Lesotho.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/lesotho'}},
#   'LT': {'iso_alpha2': 'LT',
#    'name': 'Lithuania',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 6,
#     'message': 'Lithuania has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Lithuania.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/lithuania'}},
#   'LU': {'iso_alpha2': 'LU',
#    'name': 'Luxembourg',
#    'continent': 'EU',
#    'advisory': {'score': 3.5,
#     'sources_active': 4,
#     'message': 'Luxembourg has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Luxembourg.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/luxembourg'}},
#   'LV': {'iso_alpha2': 'LV',
#    'name': 'Latvia',
#    'continent': 'EU',
#    'advisory': {'score': 3.8,
#     'sources_active': 6,
#     'message': 'Latvia has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Latvia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/latvia'}},
#   'LY': {'iso_alpha2': 'LY',
#    'name': 'Libya',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 9,
#     'message': 'Libya has a current risk level of 5 (out of 5). We advise: It is not safe to travel Libya.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/libya'}},
#   'MA': {'iso_alpha2': 'MA',
#    'name': 'Morocco',
#    'continent': 'AF',
#    'advisory': {'score': 3.4,
#     'sources_active': 8,
#     'message': 'Morocco has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Morocco.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/morocco'}},
#   'MC': {'iso_alpha2': 'MC',
#    'name': 'Monaco',
#    'continent': 'EU',
#    'advisory': {'score': 3.3,
#     'sources_active': 3,
#     'message': 'Monaco has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Monaco.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/monaco'}},
#   'MD': {'iso_alpha2': 'MD',
#    'name': 'Moldova',
#    'continent': 'EU',
#    'advisory': {'score': 3.6,
#     'sources_active': 5,
#     'message': 'Moldova has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Moldova.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/moldova'}},
# ...
#    'name': 'Sierra Leone',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Sierra Leone has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Sierra Leone.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/sierra-leone'}},
#   'SM': {'iso_alpha2': 'SM',
#    'name': 'San Marino',
#    'continent': 'EU',
#    'advisory': {'score': 4.5,
#     'sources_active': 2,
#     'message': 'San Marino has a current risk level of 4.5 (out of 5). We advise: It is not safe to travel San Marino.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/san-marino'}},
#   'SN': {'iso_alpha2': 'SN',
#    'name': 'Senegal',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 6,
#     'message': 'Senegal has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Senegal.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/senegal'}},
#   'SO': {'iso_alpha2': 'SO',
#    'name': 'Somalia',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 8,
#     'message': 'Somalia has a current risk level of 5 (out of 5). We advise: It is not safe to travel Somalia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/somalia'}},
#   'SR': {'iso_alpha2': 'SR',
#    'name': 'Suriname',
#    'continent': 'SA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Suriname has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Suriname.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/suriname'}},
#   'SS': {'iso_alpha2': 'SS',
#    'name': 'South Sudan',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 4,
#     'message': 'South Sudan has a current risk level of 5 (out of 5). We advise: It is not safe to travel South Sudan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/south-sudan'}},
#   'ST': {'iso_alpha2': 'ST',
#    'name': 'Sao Tome and Principe',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Sao Tome and Principe has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Sao Tome and Principe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/sao-tome-and-principe'}},
#   'SV': {'iso_alpha2': 'SV',
#    'name': 'El Salvador',
#    'continent': 'NA',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'El Salvador has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to El Salvador.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/el-salvador'}},
#   'SY': {'iso_alpha2': 'SY',
#    'name': 'Syria',
#    'continent': 'AS',
#    'advisory': {'score': 5,
#     'sources_active': 9,
#     'message': 'Syria has a current risk level of 5 (out of 5). We advise: It is not safe to travel Syria.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/syria'}},
#   'SZ': {'iso_alpha2': 'SZ',
#    'name': 'Swaziland',
#    'continent': 'AF',
#    'advisory': {'score': 3.3,
#     'sources_active': 3,
#     'message': 'Swaziland has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Swaziland.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/swaziland'}},
#   'TC': {'iso_alpha2': 'TC',
#    'name': 'Turks and Caicos Islands',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Turks and Caicos Islands has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Turks and Caicos Islands.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/turks-and-caicos-islands'}},
#   'TD': {'iso_alpha2': 'TD',
#    'name': 'Chad',
#    'continent': 'AF',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Chad has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Chad.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/chad'}},
#   'TG': {'iso_alpha2': 'TG',
#    'name': 'Togo',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'Togo has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Togo.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/togo'}},
#   'TH': {'iso_alpha2': 'TH',
#    'name': 'Thailand',
#    'continent': 'AS',
#    'advisory': {'score': 3.3,
#     'sources_active': 7,
#     'message': 'Thailand has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Thailand.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/thailand'}},
#   'TJ': {'iso_alpha2': 'TJ',
#    'name': 'Tajikistan',
#    'continent': 'AS',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Tajikistan has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Tajikistan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/tajikistan'}},
#   'TL': {'iso_alpha2': 'TL',
#    'name': 'East Timor',
#    'continent': 'OC',
#    'advisory': {'score': 3.7,
#     'sources_active': 6,
#     'message': 'East Timor has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to East Timor.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/east-timor'}},
#   'TM': {'iso_alpha2': 'TM',
#    'name': 'Turkmenistan',
#    'continent': 'AS',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Turkmenistan has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Turkmenistan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/turkmenistan'}},
#   'TN': {'iso_alpha2': 'TN',
#    'name': 'Tunisia',
#    'continent': 'AF',
#    'advisory': {'score': 3.4,
#     'sources_active': 9,
#     'message': 'Tunisia has a current risk level of 3.4 (out of 5). We advise: Use some caution when travelling Tunisia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/tunisia'}},
#   'TO': {'iso_alpha2': 'TO',
#    'name': 'Tonga',
#    'continent': 'OC',
#    'advisory': {'score': 4.3,
#     'sources_active': 3,
#     'message': 'Tonga has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to Tonga.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/tonga'}},
#   'TR': {'iso_alpha2': 'TR',
#    'name': 'Turkey',
#    'continent': 'AS',
#    'advisory': {'score': 3.8,
#     'sources_active': 9,
#     'message': 'Turkey has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Turkey.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/turkey'}},
#   'TT': {'iso_alpha2': 'TT',
#    'name': 'Trinidad and Tobago',
#    'continent': 'NA',
#    'advisory': {'score': 3.7,
#     'sources_active': 6,
#     'message': 'Trinidad and Tobago has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Trinidad and Tobago.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/trinidad-and-tobago'}},
#   'TV': {'iso_alpha2': 'TV',
#    'name': 'Tuvalu',
#    'continent': 'OC',
#    'advisory': {'score': 4,
#     'sources_active': 2,
#     'message': 'Tuvalu has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Tuvalu.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/tuvalu'}},
#   'TW': {'iso_alpha2': 'TW',
#    'name': 'Taiwan',
#    'continent': 'AS',
#    'advisory': {'score': 3,
#     'sources_active': 4,
#     'message': 'Taiwan has a current risk level of 3 (out of 5). We advise: Use some caution when travelling Taiwan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/taiwan'}},
#   'TZ': {'iso_alpha2': 'TZ',
#    'name': 'Tanzania',
#    'continent': 'AF',
#    'advisory': {'score': 3.6,
#     'sources_active': 7,
#     'message': 'Tanzania has a current risk level of 3.6 (out of 5). We advise: Please reconsider your need to travel to Tanzania.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/tanzania'}},
#   'UA': {'iso_alpha2': 'UA',
#    'name': 'Ukraine',
#    'continent': 'EU',
#    'advisory': {'score': 3.7,
#     'sources_active': 10,
#     'message': 'Ukraine has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Ukraine.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/ukraine'}},
#   'UG': {'iso_alpha2': 'UG',
#    'name': 'Uganda',
#    'continent': 'AF',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Uganda has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Uganda.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/uganda'}},
#   'US': {'iso_alpha2': 'US',
#    'name': 'United States',
#    'continent': 'NA',
#    'advisory': {'score': 3,
#     'sources_active': 5,
#     'message': 'United States has a current risk level of 3 (out of 5). We advise: Use some caution when travelling United States.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/united-states'}},
#   'UY': {'iso_alpha2': 'UY',
#    'name': 'Uruguay',
#    'continent': 'SA',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Uruguay has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Uruguay.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/uruguay'}},
#   'UZ': {'iso_alpha2': 'UZ',
#    'name': 'Uzbekistan',
#    'continent': 'AS',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Uzbekistan has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Uzbekistan.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/uzbekistan'}},
#   'VA': {'iso_alpha2': 'VA',
#    'name': 'Vatican',
#    'continent': 'EU',
#    'advisory': {'score': 5,
#     'sources_active': 1,
#     'message': 'Vatican has a current risk level of 5 (out of 5). We advise: It is not safe to travel Vatican.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/vatican'}},
#   'VC': {'iso_alpha2': 'VC',
#    'name': 'Saint Vincent and the Grenadines',
#    'continent': 'NA',
#    'advisory': {'score': 3,
#     'sources_active': 2,
#     'message': 'Saint Vincent and the Grenadines has a current risk level of 3 (out of 5). We advise: Use some caution when travelling Saint Vincent and the Grenadines.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/saint-vincent-and-the-grenadines'}},
#   'VE': {'iso_alpha2': 'VE',
#    'name': 'Venezuela',
#    'continent': 'SA',
#    'advisory': {'score': 4.4,
#     'sources_active': 9,
#     'message': 'Venezuela has a current risk level of 4.4 (out of 5). We advise: Please reconsider your need to travel to Venezuela.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/venezuela'}},
#   'VG': {'iso_alpha2': 'VG',
#    'name': 'British Virgin Islands',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 3,
#     'message': 'British Virgin Islands has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to British Virgin Islands.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/british-virgin-islands'}},
#   'VI': {'iso_alpha2': 'VI',
#    'name': 'U.S. Virgin Islands',
#    'continent': 'NA',
#    'advisory': {'score': 4,
#     'sources_active': 2,
#     'message': 'U.S. Virgin Islands has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to U.S. Virgin Islands.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/us-virgin-islands'}},
#   'VN': {'iso_alpha2': 'VN',
#    'name': 'Vietnam',
#    'continent': 'AS',
#    'advisory': {'score': 3.5,
#     'sources_active': 6,
#     'message': 'Vietnam has a current risk level of 3.5 (out of 5). We advise: Please reconsider your need to travel to Vietnam.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/vietnam'}},
#   'VU': {'iso_alpha2': 'VU',
#    'name': 'Vanuatu',
#    'continent': 'OC',
#    'advisory': {'score': 4.3,
#     'sources_active': 3,
#     'message': 'Vanuatu has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to Vanuatu.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/vanuatu'}},
#   'WF': {'iso_alpha2': 'WF',
#    'name': 'Wallis and Futuna',
#    'continent': 'OC',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Wallis and Futuna has a current risk level of 0 (out of 5). We advise: Travelling Wallis and Futuna is (relatively) safe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/wallis-and-futuna'}},
#   'WS': {'iso_alpha2': 'WS',
#    'name': 'Samoa',
#    'continent': 'OC',
#    'advisory': {'score': 4.3,
#     'sources_active': 4,
#     'message': 'Samoa has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to Samoa.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/samoa'}},
#   'XK': {'iso_alpha2': 'XK',
#    'name': 'Kosovo',
#    'continent': 'EU',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Kosovo has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Kosovo.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/kosovo'}},
#   'YE': {'iso_alpha2': 'YE',
#    'name': 'Yemen',
#    'continent': 'AS',
#    'advisory': {'score': 5,
#     'sources_active': 9,
#     'message': 'Yemen has a current risk level of 5 (out of 5). We advise: It is not safe to travel Yemen.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/yemen'}},
#   'YT': {'iso_alpha2': 'YT',
#    'name': 'Mayotte',
#    'continent': 'AF',
#    'advisory': {'score': 4,
#     'sources_active': 2,
#     'message': 'Mayotte has a current risk level of 4 (out of 5). We advise: Please reconsider your need to travel to Mayotte.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/mayotte'}},
#   'ZA': {'iso_alpha2': 'ZA',
#    'name': 'South Africa',
#    'continent': 'AF',
#    'advisory': {'score': 3.9,
#     'sources_active': 8,
#     'message': 'South Africa has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to South Africa.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/south-africa'}},
#   'ZM': {'iso_alpha2': 'ZM',
#    'name': 'Zambia',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 5,
#     'message': 'Zambia has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Zambia.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/zambia'}},
#   'ZW': {'iso_alpha2': 'ZW',
#    'name': 'Zimbabwe',
#    'continent': 'AF',
#    'advisory': {'score': 3.7,
#     'sources_active': 6,
#     'message': 'Zimbabwe has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Zimbabwe.',
#     'updated': '2020-11-18 08:28:13',
#     'source': 'https://www.travel-advisory.info/zimbabwe'}}}}

# %%
class rapid_referential_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://referential.p.rapidapi.com/v1/city"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def browse_cities(self,fields,iso_a2,sort,order,lang):
        self.fields = fields
        self.iso_a2 = iso_a2
        self.sort = sort
        self.order = order
        self.lang = lang
        
        self.search_url = self.base_url
        
        self.params = {
            'fields' : "{}".format(self.fields),
            'iso_a2' : "{}".format(self.iso_a2),
            'sort' : "{}".format(self.sort),
            'order' : "{}".format(self.order),
            'lang' : "{}".format(self.lang)
            
            }

        self.response = requests.get(self.search_url,headers=self.headers,params=self.params)
        print(self.response.url)
        return self.response.json()
    
    def getcitydetails(self,jsonObj):
        
        if 'code' in jsonObj[0].keys():
            
            return 'Invalid Request'
        
        else:        
            return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_referential_Api(credentials['rapidapi_key'],credentials['rapidapi_host3'])
    v = app.browse_cities('iso_a2,state_code,state_hasc,timezone,timezone_offset','us','population','desc','en')
    City_Details = app.getcitydetails(v)
# Out:
# https://referential.p.rapidapi.com/v1/city?fields=iso_a2%2Cstate_code%2Cstate_hasc%2Ctimezone%2Ctimezone_offset&iso_a2=us&sort=population&order=desc&lang=en

# %%
City_Details
# Out:
# [{'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'New York City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'NEW YORK|US-NY'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Los Angeles',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'LOS ANGELES|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Chicago',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'CHICAGO|US-IL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Miami',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'MIAMI|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-PA',
#   'value': 'Philadelphia',
#   'iso_a2': 'US',
#   'state_hasc': 'US.PA',
#   'key': 'PHILADELPHIA|US-PA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Dallas',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'DALLAS|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-GA',
#   'value': 'Atlanta',
#   'iso_a2': 'US',
#   'state_hasc': 'US.GA',
#   'key': 'ATLANTA|US-GA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Boston',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'BOSTON|US-MA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-DC',
#   'value': 'Washington',
#   'iso_a2': 'US',
#   'state_hasc': 'US.DC',
#   'key': 'WASHINGTON|US-DC'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Detroit',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'DETROIT|US-MI'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Phoenix',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'PHOENIX|US-AZ'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'San Francisco',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SAN FRANCISCO|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Seattle',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'SEATTLE|US-WA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'San Diego',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SAN DIEGO|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MN',
#   'value': 'Minneapolis',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MN',
#   'key': 'MINNEAPOLIS|US-MN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Tampa',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'TAMPA|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MD',
#   'value': 'Baltimore',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MD',
#   'key': 'BALTIMORE|US-MD'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MO',
#   'value': 'St. Louis',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MO',
#   'key': 'ST. LOUIS|US-MO'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Fort Lauderdale',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'FORT LAUDERDALE|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Long Beach',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'LONG BEACH|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Cleveland',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'CLEVELAND|US-OH'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-OR',
#   'value': 'Portland',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OR',
#   'key': 'PORTLAND|US-OR'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-NV',
#   'value': 'Las Vegas',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NV',
#   'key': 'LAS VEGAS|US-NV'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'San Bernardino',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SAN BERNARDINO|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'San Jose',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SAN JOSE|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Cincinnati',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'CINCINNATI|US-OH'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Sacramento',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SACRAMENTO|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Oakland',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'OAKLAND|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Virginia Beach',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'VIRGINIA BEACH|US-VA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'San Antonio',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'SAN ANTONIO|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MO',
#   'value': 'Kansas City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MO',
#   'key': 'KANSAS CITY|US-MO'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Fort Worth',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'FT. WORTH|US-TX'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'Indianapolis',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'INDIANAPOLIS|US-IN'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'Milwaukee',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'MILWAUKEE|US-WI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Orlando',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'ORLANDO|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-RI',
#   'value': 'Providence',
#   'iso_a2': 'US',
#   'state_hasc': 'US.RI',
#   'key': 'PROVIDENCE|US-RI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Columbus',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'COLUMBUS|US-OH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'West Palm Beach',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'WEST PALM BEACH|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Raleigh',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'RALEIGH|US-NC'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Austin',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'AUSTIN|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AL',
#   'value': 'Birmingham',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AL',
#   'key': 'BIRMINGHAM|US-AL'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Mesa',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'MESA|US-AZ'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TN',
#   'value': 'Memphis',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'MEMPHIS|US-TN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Norfolk',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'NORFOLK|US-VA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-CT',
#   'value': 'Bridgeport',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CT',
#   'key': 'BRIDGEPORT|US-CT'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Buffalo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'BUFFALO|US-NY'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-UT',
#   'value': 'Salt Lake City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.UT',
#   'key': 'SALT LAKE CITY|US-UT'},
#  {'timezone': 'America/Kentucky/Louisville',
#   'state_code': 'US-KY',
#   'value': 'Louisville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KY',
#   'key': 'LOUISVILLE|US-KY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-CT',
#   'value': 'Hartford',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CT',
#   'key': 'HARTFORD|US-CT'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Richmond',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'RICHMOND|US-VA'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-NM',
#   'value': 'Albuquerque',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NM',
#   'key': 'ALBUQUERQUE|US-NM'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-NE',
#   'value': 'Omaha',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NE',
#   'key': 'OMAHA|US-NE'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TN',
#   'value': 'Nashville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'NASHVILLE|US-TN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Albany',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'ALBANY|US-NY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-CT',
#   'value': 'New Haven',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CT',
#   'key': 'NEW HAVEN|US-CT'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Tucson',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'TUCSON|US-AZ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'St. Petersburg',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'ST. PETERSBURG|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-OK',
#   'value': 'Oklahoma City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OK',
#   'key': 'OKLAHOMA CITY|US-OK'},
#  {'timezone': 'Pacific/Honolulu',
#   'state_code': 'US-HI',
#   'value': 'Honolulu',
#   'iso_a2': 'US',
#   'state_hasc': 'US.HI',
#   'key': 'HONOLULU|US-HI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-LA',
#   'value': 'New Orleans',
#   'iso_a2': 'US',
#   'state_hasc': 'US.LA',
#   'key': 'NEW ORLEANS|US-LA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Dayton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'DAYTON|US-OH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Rochester',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'ROCHESTER|US-NY'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-TX',
#   'value': 'El Paso',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'EL PASO|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-CT',
#   'value': 'Stamford',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CT',
#   'key': 'STAMFORD|US-CT'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MN',
#   'value': 'Saint Paul',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MN',
#   'key': 'ST. PAUL|US-MN'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Arlington',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'ARLINGTON|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Lowell',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'LOWELL|US-MA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Tacoma',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'TACOMA|US-WA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Akron',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'AKRON|US-OH'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Denver',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'DENVER|US-CO'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Syracuse',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'SYRACUSE|US-NY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-TN',
#   'value': 'Knoxville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'KNOXVILLE|US-TN'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Pasadena',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'PASADENA|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'San Mateo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SAN MATEO|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Fresno',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'FRESNO|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Oceanside',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'OCEANSIDE|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IN',
#   'value': 'Gary',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'GARY|US-IN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Sarasota',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'SARASOTA|US-FL'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Aurora',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'AURORA|US-CO'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-KY',
#   'value': 'Covington',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KY',
#   'key': 'COVINGTON|US-KY'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Joliet',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'JOLIET|US-IL'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Grand Rapids',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'GRAND RAPIDS|US-MI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-PA',
#   'value': 'Harrisburg',
#   'iso_a2': 'US',
#   'state_hasc': 'US.PA',
#   'key': 'HARRISBURG|US-PA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Vancouver',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'VANCOUVER|US-WA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-KS',
#   'value': 'Kansas City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KS',
#   'key': 'KANSAS CITY|US-KS'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Glendale',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'GLENDALE|US-AZ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-PA',
#   'value': 'Allentown',
#   'iso_a2': 'US',
#   'state_hasc': 'US.PA',
#   'key': 'ALLENTOWN|US-PA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Berkeley',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'BERKELEY|US-CA'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Colorado Springs',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'COLORADO SPRINGS|US-CO'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Everett',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'EVERETT|US-WA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Toledo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'TOLEDO|US-OH'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Bakersfield',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'BAKERSFIELD|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Laredo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'LAREDO|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-LA',
#   'value': 'Baton Rouge',
#   'iso_a2': 'US',
#   'state_hasc': 'US.LA',
#   'key': 'BATON ROUGE|US-LA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Springfield',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'SPRINGFIELD|US-MA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Charleston',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
#   'key': 'CHARLESTON|US-SC'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Miami Beach',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'MIAMI BEACH|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-KS',
#   'value': 'Wichita',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KS',
#   'key': 'WICHITA|US-KS'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Columbia',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
#   'key': 'COLUMBIA|US-SC'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MO',
#   'value': 'Columbia',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MO',
#   'key': 'COLUMBIA|US-MO'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-LA',
#   'value': 'Metairie',
#   'iso_a2': 'US',
#   'state_hasc': 'US.LA',
#   'key': 'METAIRIE|US-LA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Palm Springs',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'PALM SPRINGS|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Elgin',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'ELGIN|US-IL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Greensboro',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'GREENSBORO|US-NC'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IA',
#   'value': 'Des Moines',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IA',
#   'key': 'DES MOINES|US-IA'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-UT',
#   'value': 'Ogden',
#   'iso_a2': 'US',
#   'state_hasc': 'US.UT',
#   'key': 'OGDEN|US-UT'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Hampton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'HAMPTON|US-VA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NJ',
#   'value': 'Trenton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NJ',
#   'key': 'TRENTON|US-NJ'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Mcallen',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'MCALLEN|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MO',
#   'value': 'St. Charles',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MO',
#   'key': 'ST. CHARLES|US-MO'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-UT',
#   'value': 'Provo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.UT',
#   'key': 'PROVO|US-UT'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Greenville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
#   'key': 'GREENVILLE|US-SC'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Anaheim',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ANAHEIM|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Aurora',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'AURORA|US-IL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Evanston',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'EVANSTON|US-IL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Spokane',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'SPOKANE|US-WA'},
#  {'timezone': 'America/Boise',
#   'state_code': 'US-ID',
#   'value': 'Boise',
#   'iso_a2': 'US',
#   'state_hasc': 'US.ID',
#   'key': 'BOISE|US-ID'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Salem',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'SALEM|US-MA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Sanford',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'SANFORD|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-NV',
#   'value': 'Reno',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NV',
#   'key': 'RENO|US-NV'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'Madison',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'MADISON|US-WI'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Modesto',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'MODESTO|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Youngstown',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'YOUNGSTOWN|US-OH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Durham',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'DURHAM|US-NC'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'Fort Wayne',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'FORT WAYNE|US-IN'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Riverside',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'RIVERSIDE|US-CA'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Flint',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'FLINT|US-MI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-KY',
#   'value': 'Ironville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KY',
#   'key': 'IRONVILLE|US-KY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-KY',
#   'value': 'Meads',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KY',
#   'key': 'MEADS|US-KY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Worcester',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'WORCESTER|US-MA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TN',
#   'value': 'Bartlett',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'BARLETT|US-TN'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-NV',
#   'value': 'Henderson',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NV',
#   'key': 'HENDERSON|US-NV'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Plano',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'PLANO|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Winston-Salem',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'WINSTON-SALEM|US-NC'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NJ',
#   'value': 'Newark',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NJ',
#   'key': 'NEWARK|US-NJ'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Lansing',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'LANSING|US-MI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Corpus Christi',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'CORPUS CHRISTI|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AR',
#   'value': 'Little Rock',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AR',
#   'key': 'LITTLE ROCK|US-AR'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Ann Arbor',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'ANN ARBOR|US-MI'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Chula Vista',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'CHULA VISTA|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Melbourne',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'MELBOURNE|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-KY',
#   'value': 'Lexington',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KY',
#   'key': 'LEXINGTON|US-KY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-GA',
#   'value': 'Augusta',
#   'iso_a2': 'US',
#   'state_hasc': 'US.GA',
#   'key': 'AUGUSTA|US-GA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Naples',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'NAPLES|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MN',
#   'value': 'Lakeville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MN',
#   'key': 'LAKEVILLE|US-MN'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Chandler',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'CHANDLER|US-AZ'},
#  {'timezone': 'America/Juneau',
#   'state_code': 'US-AK',
#   'value': 'Anchorage',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AK',
#   'key': 'ANCHORAGE|US-AK'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Canton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'CANTON|US-OH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-TN',
#   'value': 'Chattanooga',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'CHATTANOOGA|US-TN'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Irvine',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'IRVINE|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Rockford',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'ROCKFORD|US-IL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IA',
#   'value': 'Davenport',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IA',
#   'key': 'DAVENPORT|US-IA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AL',
#   'value': 'Mobile',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AL',
#   'key': 'MOBILE|US-AL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MS',
#   'value': 'Jackson',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MS',
#   'key': 'JACKSON|US-MS'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Coral Springs',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'CORAL SPRINGS|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'Waukesha',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'WAUKESHA|US-WI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-LA',
#   'value': 'Shreveport',
#   'iso_a2': 'US',
#   'state_hasc': 'US.LA',
#   'key': 'SHREVEPORT|US-LA'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Gilbert',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'GILBERT|US-AZ'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-NE',
#   'value': 'Lincoln',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NE',
#   'key': 'LINCOLN|US-NE'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-OR',
#   'value': 'Eugene',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OR',
#   'key': 'EUGENE|US-OR'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Fayetteville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'FAYETTEVILLE|US-NC'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'South Bend',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'SOUTH BEND|US-IN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Hialeah',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'HIALEAH|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Garland',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'GARLAND|US-TX'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Scottsdale',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'SCOTTSDALE|US-AZ'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Irving',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'IRVING|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-NV',
#   'value': 'North Las Vegas',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NV',
#   'key': 'NORTH LAS VEGAS|US-NV'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-FL',
#   'value': 'Pensacola',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'PENSACOLA|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Fremont',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'FREMONT|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Santa Rosa',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SANTA ROSA|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-OR',
#   'value': 'Salem',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OR',
#   'key': 'SALEM|US-OR'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Fort Collins',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'FORT COLLINS|US-CO'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Fort Pierce',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'FORT PIERCE|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Kissimmee',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'KISSIMMEE|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-NV',
#   'value': 'Paradise',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NV',
#   'key': 'PARADISE|US-NV'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Tallahassee',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'TALLAHASSEE|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-PA',
#   'value': 'York',
#   'iso_a2': 'US',
#   'state_hasc': 'US.PA',
#   'key': 'YORK|US-PA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-GA',
#   'value': 'Columbus',
#   'iso_a2': 'US',
#   'state_hasc': 'US.GA',
#   'key': 'COLUMBUS|US-GA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Daytona Beach',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'DAYTONA BEACH|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Jamaica',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'JAMAICA|US-NY'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Lubbock',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'LUBBOCK|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AL',
#   'value': 'Huntsville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AL',
#   'key': 'HUNTSVILLE|US-AL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MO',
#   'value': 'Springfield',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MO',
#   'key': 'SPRINGFIELD|US-MO'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Maryvale',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'MARYVALE|US-AZ'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Fontana',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'FONTANA|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Oxnard',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'OXNARD|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Moreno Valley',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'MORENO VALLEY|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'Appleton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'APPLETON|US-WI'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Huntington Beach',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'HUNTINGTON BEACH|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Glendale',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'GLENDALE|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Waukegan',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'WAUKEGAN|US-IL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'Green Bay',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'GREEN BAY|US-WI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AL',
#   'value': 'Montgomery',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AL',
#   'key': 'MONTGOMERY|US-AL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Roanoke',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'ROANOKE|US-VA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NH',
#   'value': 'Manchester',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NH',
#   'key': 'MANCHESTER|US-NH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Gainesville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'GAINESVILLE|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-NV',
#   'value': 'Sunrise Manor',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NV',
#   'key': 'SUNRISE MANOR|US-NV'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Fort Myers',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'FT. MYERS|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Grand Prairie',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'GRAND PRAIRIE|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-KS',
#   'value': 'Overland Park',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KS',
#   'key': 'OVERLAND PARK|US-KS'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Kalamazoo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'KALAMAZOO|US-MI'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Santa Clarita',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SANTA CLARITA|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Amarillo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'AMARILLO|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Santa Barbara',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SANTA BARBARA|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Brownsville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'BROWNSVILLE|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-GA',
#   'value': 'Savannah',
#   'iso_a2': 'US',
#   'state_hasc': 'US.GA',
#   'key': 'SAVANNAH|US-GA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'East Flatbush',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'EAST FLATBUSH|US-NY'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-NV',
#   'value': 'Spring Valley',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NV',
#   'key': 'SPRING VALLEY|US-NV'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-PA',
#   'value': 'Erie',
#   'iso_a2': 'US',
#   'state_hasc': 'US.PA',
#   'key': 'ERIE|US-PA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Denton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'DENTON|US-TX'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Tempe',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'TEMPE|US-AZ'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Garden Grove',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'GARDEN GROVE|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Rancho Cucamonga',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'RANCHO CUCAMONGA|US-CA'},
#  {'timezone': 'Pacific/Honolulu',
#   'state_code': 'US-HI',
#   'value': 'Wahiawa',
#   'iso_a2': 'US',
#   'state_hasc': 'US.HI',
#   'key': 'WAHIAWA|US-HI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IN',
#   'value': 'Evansville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'EVANSVILLE|US-IN'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Peoria',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'PEORIA|US-IL'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Peoria',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'PEORIA|US-AZ'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Ontario',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ONTARIO|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Poughkeepsie',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'POUGHKEEPSIE|US-NY'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IA',
#   'value': 'Cedar Rapids',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IA',
#   'key': 'CEDAR RAPIDS|US-IA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Waco',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'WACO|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Elk Grove',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ELK GROVE|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Pembroke Pines',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'PEMBROKE PINES|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Rock Island',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'ROCK ISLAND|US-IL'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Deer Valley',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'DEER VALLEY|US-AZ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Port Saint Lucie',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'PORT SAINT LUCIE|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Corona',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'CORONA|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-ND',
#   'value': 'Fargo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.ND',
#   'key': 'FARGO|US-ND'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-DE',
#   'value': 'Wilmington',
#   'iso_a2': 'US',
#   'state_hasc': 'US.DE',
#   'key': 'WILMINGTON|US-DE'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Wilmington',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'WILMINGTON|US-NC'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Lancaster',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'LANCASTER|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Cary',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'CARY|US-NC'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-PA',
#   'value': 'Wilkes-Barre',
#   'iso_a2': 'US',
#   'state_hasc': 'US.PA',
#   'key': 'WILKES BARRE|US-PA'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Tempe Junction',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'TEMPE JUNCTION|US-AZ'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Palmdale',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'PALMDALE|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Hayward',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'HAYWARD|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-LA',
#   'value': 'Lafayette',
#   'iso_a2': 'US',
#   'state_hasc': 'US.LA',
#   'key': 'LAFAYETTE|US-LA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Olympia',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'OLYMPIA|US-WA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Salinas',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SALINAS|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-PA',
#   'value': 'Scranton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.PA',
#   'key': 'SCRANTON|US-PA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-SD',
#   'value': 'Sioux Falls',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SD',
#   'key': 'SIOUX FALLS|US-SD'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Frisco',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'FRISCO|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-TN',
#   'value': 'East Chattanooga',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'EAST CHATTANOOGA|US-TN'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Pomona',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'POMONA|US-CA'},
#  {'timezone': 'America/Toronto',
#   'state_code': 'US-NY',
#   'value': 'Niagara Falls',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'NIAGARA FALLS|US-NY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Washington Heights',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'WASHINGTON HEIGHTS|US-NY'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Lakewood',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'LAKEWOOD|US-CO'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Sunnyvale',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SUNNYVALE|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AR',
#   'value': 'Fayetteville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AR',
#   'key': 'FAYETTEVILLE|US-AR'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Escondido',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ESCONDIDO|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NJ',
#   'value': 'Paterson',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NJ',
#   'key': 'PATERSON|US-NJ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Astoria',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'ASTORIA|US-NY'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Edinburg',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'EDINBURG|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Coral Gables',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'CORAL GABLES|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'National City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'NATIONAL CITY|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Hollywood',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'HOLLYWOOD|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Schenectady',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'SCHENECTADY|US-NY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Borough Park',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'BOROUGH PARK|US-NY'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'Elkhart',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'ELKHART|US-IN'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Torrance',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'TORRANCE|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Valencia',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'VALENCIA|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Santa Cruz',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SANTA CRUZ|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MO',
#   'value': 'Independence',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MO',
#   'key': 'INDEPENDENCE|US-MO'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'East Hampton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'EAST HAMPTON|US-VA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Naperville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'NAPERVILLE|US-IL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Bryan',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'BRYAN|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Vallejo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'VALLEJO|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Mesquite',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'MESQUITE|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Pasadena',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'PASADENA|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Urbana',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'URBANA|US-IL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Belleville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'BELLEVILLE|US-IL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Asheville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'ASHEVILLE|US-NC'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-LA',
#   'value': 'Metairie Terrace',
#   'iso_a2': 'US',
#   'state_hasc': 'US.LA',
#   'key': 'METAIRIE TERRACE|US-LA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Ocala',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'OCALA|US-FL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Fullerton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'FULLERTON|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Binghamton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'BINGHAMTON|US-NY'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Bellevue',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'BELLEVUE|US-WA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Killeen',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'KILLEEN|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Miramar',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'MIRAMAR|US-FL'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-UT',
#   'value': 'West Valley City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.UT',
#   'key': 'WEST VALLEY CITY|US-UT'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'New Bedford',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'NEW BEDFORD|US-MA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-ME',
#   'value': 'Portland',
#   'iso_a2': 'US',
#   'state_hasc': 'US.ME',
#   'key': 'PORTLAND|US-ME'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Springfield',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'SPRINGFIELD|US-IL'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Warren',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'WARREN|US-MI'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'Lafayette',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'LAFAYETTE|US-IN'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Thornton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'THORNTON|US-CO'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Carrollton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'CARROLLTON|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Fredericksburg',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'FREDERICKSBURG|US-VA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TN',
#   'value': 'Clarksville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'CLARKSVILLE|US-TN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Cape Coral',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'CAPE CORAL|US-FL'},
#  {'timezone': 'America/Boise',
#   'state_code': 'US-ID',
#   'value': 'Caldwell',
#   'iso_a2': 'US',
#   'state_hasc': 'US.ID',
#   'key': 'CALDWELL|US-ID'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-KS',
#   'value': 'Topeka',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KS',
#   'key': 'TOPEKA|US-KS'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Sterling Heights',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'STERLING HEIGHTS|US-MI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'Racine',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'RACINE|US-WI'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Roseville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ROSEVILLE|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Thousand Oaks',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'THOUSAND OAKS|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Bloomington',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'BLOOMINGTON|US-IL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Concord',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'CONCORD|US-CA'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Surprise',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'SURPRISE|US-AZ'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Alhambra',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'ALHAMBRA|US-AZ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Alexandria',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'ALEXANDRIA|US-VA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Kent',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'KENT|US-WA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Bremerton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'BREMERTON|US-WA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Simi Valley',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SIMI VALLEY|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'East Los Angeles',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'EAST LOS ANGELES|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Santa Clara',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SANTA CLARA|US-CA'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Greeley',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'GREELEY|US-CO'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Monterey',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'MONTEREY|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Spartanburg',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
# ...
#   'state_code': 'US-FL',
#   'value': 'The Hammocks',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'THE HAMMOCKS|US-FL'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Buckeye',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'BUCKEYE|US-AZ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Sumter',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
#   'key': 'SUMTER|US-SC'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Flagami',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'FLAGAMI|US-FL'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Catalina Foothills',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'CATALINA FOOTHILLS|US-AZ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Lakewood',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'LAKEWOOD|US-OH'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MS',
#   'value': 'Biloxi',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MS',
#   'key': 'BILOXI|US-MS'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'North La Crosse',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'NORTH LA CROSSE|US-WI'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Burien',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'BURIEN|US-WA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'South Peabody',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'SOUTH PEABODY|US-MA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-ME',
#   'value': 'Bangor',
#   'iso_a2': 'US',
#   'state_hasc': 'US.ME',
#   'key': 'BANGOR|US-ME'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Aliso Viejo',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ALISO VIEJO|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Poway',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'POWAY|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MN',
#   'value': 'Edina',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MN',
#   'key': 'EDINA|US-MN'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MN',
#   'value': 'Minnetonka Mills',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MN',
#   'key': 'MINNETONKA MILLS|US-MN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-GA',
#   'value': 'Stonecrest',
#   'iso_a2': 'US',
#   'state_hasc': 'US.GA',
#   'key': 'STONECREST|US-GA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Cerritos',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'CERRITOS|US-CA'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Redford',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'REDFORD|US-MI'},
#  {'timezone': 'Pacific/Honolulu',
#   'state_code': 'US-HI',
#   'value': 'East Honolulu',
#   'iso_a2': 'US',
#   'state_hasc': 'US.HI',
#   'key': 'EAST HONOLULU|US-HI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Sunnyside',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'SUNNYSIDE|US-NY'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Downers Grove',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'DOWNERS GROVE|US-IL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Azusa',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'AZUSA|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Leesburg',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'LEESBURG|US-FL'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-CO',
#   'value': 'Parker',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CO',
#   'key': 'PARKER|US-CO'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'La Mirada',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'LA MIRADA|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-OR',
#   'value': 'Aloha',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OR',
#   'key': 'ALOHA|US-OR'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Myrtle Beach',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
#   'key': 'MYRTLE BEACH|US-SC'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Bedford',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'BEDFORD|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Rancho Santa Margarita',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'RANCHO SANTA MARGARITA|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Cypress',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'CYPRESS|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-ID',
#   'value': 'Lewiston',
#   'iso_a2': 'US',
#   'state_hasc': 'US.ID',
#   'key': 'LEWISTON|US-ID'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-UT',
#   'value': 'Murray',
#   'iso_a2': 'US',
#   'state_hasc': 'US.UT',
#   'key': 'MURRAY|US-UT'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Cuyahoga Falls',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'CUYAHOGA FALLS|US-OH'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Rowland Heights',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ROWLAND HEIGHTS|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Covina',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'COVINA|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TN',
#   'value': 'Collierville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'COLLIERVILLE|US-TN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Summerville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
#   'key': 'SUMMERVILLE|US-SC'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Lancaster',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'LANCASTER|US-OH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Middletown',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'MIDDLETOWN|US-OH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MD',
#   'value': 'Aspen Hill',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MD',
#   'key': 'ASPEN HILL|US-MD'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-GA',
#   'value': 'Dunwoody',
#   'iso_a2': 'US',
#   'state_hasc': 'US.GA',
#   'key': 'DUNWOODY|US-GA'},
#  {'timezone': 'America/Phoenix',
#   'state_code': 'US-AZ',
#   'value': 'Maricopa',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AZ',
#   'key': 'MARICOPA|US-AZ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Palm Coast',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'PALM COAST|US-FL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Cedar Hill',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'CEDAR HILL|US-TX'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'East Lansing',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'EAST LANSING|US-MI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Apopka',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'APOPKA|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Maspeth',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'MASPETH|US-NY'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MD',
#   'value': 'Wheaton',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MD',
#   'key': 'WHEATON|US-MD'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'Mishawaka',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'MISHAWAKA|US-IN'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Portage',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'PORTAGE|US-MI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NJ',
#   'value': 'West Orange',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NJ',
#   'key': 'WEST ORANGE|US-NJ'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Mclean',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'MCLEAN|US-VA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-KS',
#   'value': 'Salina',
#   'iso_a2': 'US',
#   'state_hasc': 'US.KS',
#   'key': 'SALINA|US-KS'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Ceres',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'CERES|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MO',
#   'value': 'Chesterfield',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MO',
#   'key': 'CHESTERFIELD|US-MO'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'Lawrence',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'LAWRENCE|US-IN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MD',
#   'value': 'Bel Air South',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MD',
#   'key': 'BEL AIR SOUTH|US-MD'},
#  {'timezone': 'Pacific/Honolulu',
#   'state_code': 'US-HI',
#   'value': 'Pearl City',
#   'iso_a2': 'US',
#   'state_hasc': 'US.HI',
#   'key': 'PEARL CITY|US-HI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Euclid',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'EUCLID|US-OH'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-OK',
#   'value': 'Stillwater',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OK',
#   'key': 'STILLWATER|US-OK'},
#  {'timezone': 'America/Detroit',
#   'state_code': 'US-MI',
#   'value': 'Roseville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MI',
#   'key': 'ROSEVILLE|US-MI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-WI',
#   'value': 'Wauwatosa',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WI',
#   'key': 'WAUWATOSA|US-WI'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Goldsboro',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'GOLDSBORO|US-NC'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Florin',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'FLORIN|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Glenview',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'GLENVIEW|US-IL'},
#  {'timezone': 'America/Boise',
#   'state_code': 'US-ID',
#   'value': 'Twin Falls',
#   'iso_a2': 'US',
#   'state_hasc': 'US.ID',
#   'key': 'TWIN FALLS|US-ID'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Methuen',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'METHUEN|US-MA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Quincy',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'QUINCY|US-IL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-FL',
#   'value': 'Country Club',
#   'iso_a2': 'US',
#   'state_hasc': 'US.FL',
#   'key': 'COUNTRY CLUB|US-FL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-GA',
#   'value': 'Brunswick',
#   'iso_a2': 'US',
#   'state_hasc': 'US.GA',
#   'key': 'BRUNSWICK|US-GA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AL',
#   'value': 'Madison',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AL',
#   'key': 'MADISON|US-AL'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'San Jacinto',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'SAN JACINTO|US-CA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Mentor',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'MENTOR|US-OH'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-UT',
#   'value': 'Draper',
#   'iso_a2': 'US',
#   'state_hasc': 'US.UT',
#   'key': 'DRAPER|US-UT'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-CT',
#   'value': 'Middletown',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CT',
#   'key': 'MIDDLETOWN|US-CT'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Wylie',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'WYLIE|US-TX'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TN',
#   'value': 'Smyrna',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TN',
#   'key': 'SMYRNA|US-TN'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Lincoln',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'LINCOLN|US-CA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Lacey',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'LACEY|US-WA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Beavercreek',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'BEAVERCREEK|US-OH'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Pittsfield',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'PITTSFIELD|US-MA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-SC',
#   'value': 'Aiken',
#   'iso_a2': 'US',
#   'state_hasc': 'US.SC',
#   'key': 'AIKEN|US-SC'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-OR',
#   'value': 'Grants Pass',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OR',
#   'key': 'GRANTS PASS|US-OR'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Kannapolis',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'KANNAPOLIS|US-NC'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-OK',
#   'value': 'Enid',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OK',
#   'key': 'ENID|US-OK'},
#  {'timezone': 'America/Denver',
#   'state_code': 'US-NM',
#   'value': 'Roswell',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NM',
#   'key': 'ROSWELL|US-NM'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-MA',
#   'value': 'Everett',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MA',
#   'key': 'EVERETT|US-MA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-RI',
#   'value': 'Newport',
#   'iso_a2': 'US',
#   'state_hasc': 'US.RI',
#   'key': 'NEWPORT|US-RI'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-IL',
#   'value': 'Elmhurst',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IL',
#   'key': 'ELMHURST|US-IL'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-VA',
#   'value': 'Danville',
#   'iso_a2': 'US',
#   'state_hasc': 'US.VA',
#   'key': 'DANVILLE|US-VA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'New Braunfels',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'NEW BRAUNFELS|US-TX'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'City Of Sammamish',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'CITY OF SAMMAMISH|US-WA'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-CA',
#   'value': 'Antelope',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CA',
#   'key': 'ANTELOPE|US-CA'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-TX',
#   'value': 'Keller',
#   'iso_a2': 'US',
#   'state_hasc': 'US.TX',
#   'key': 'KELLER|US-TX'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NY',
#   'value': 'Jamestown',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NY',
#   'key': 'JAMESTOWN|US-NY'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-NE',
#   'value': 'Grand Island',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NE',
#   'key': 'GRAND ISLAND|US-NE'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-NC',
#   'value': 'Apex',
#   'iso_a2': 'US',
#   'state_hasc': 'US.NC',
#   'key': 'APEX|US-NC'},
#  {'timezone': 'America/Indiana/Indianapolis',
#   'state_code': 'US-IN',
#   'value': 'West Lafayette',
#   'iso_a2': 'US',
#   'state_hasc': 'US.IN',
#   'key': 'WEST LAFAYETTE|US-IN'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-AL',
#   'value': 'Florence',
#   'iso_a2': 'US',
#   'state_hasc': 'US.AL',
#   'key': 'FLORENCE|US-AL'},
#  {'timezone': 'America/Chicago',
#   'state_code': 'US-MN',
#   'value': 'Saint Louis Park',
#   'iso_a2': 'US',
#   'state_hasc': 'US.MN',
#   'key': 'SAINT LOUIS PARK|US-MN'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-CT',
#   'value': 'Enfield',
#   'iso_a2': 'US',
#   'state_hasc': 'US.CT',
#   'key': 'ENFIELD|US-CT'},
#  {'timezone': 'America/Los_Angeles',
#   'state_code': 'US-WA',
#   'value': 'Walla Walla',
#   'iso_a2': 'US',
#   'state_hasc': 'US.WA',
#   'key': 'WALLA WALLA|US-WA'},
#  {'timezone': 'America/New_York',
#   'state_code': 'US-OH',
#   'value': 'Dublin',
#   'iso_a2': 'US',
#   'state_hasc': 'US.OH',
#   'key': 'DUBLIN|US-OH'}]

# %%
class rapid_TravelHacking_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://travel-hacking-tool.p.rapidapi.com/api/airports/"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def AirportList(self):
        
        self.search_url = self.base_url

        self.response = requests.get(self.search_url,headers=self.headers)
        print(self.response.url)
        return self.response.json()
    
    def getAirportListdetails(self,jsonObj):
        
        return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_TravelHacking_Api(credentials['rapidapi_key'],credentials['rapidapi_host4'])
    v = app.AirportList()
    AirportList = app.getAirportListdetails(v)
# Out:
# https://travel-hacking-tool.p.rapidapi.com/api/airports/

# %%
AirportList
# Out:
# [{'code': 'AAA',
#   'name': 'Anaa',
#   'latitude': -17.05,
#   'longitude': -145.41667,
#   'time_zone': 'Pacific/Tahiti',
#   'city_code': 'AAA',
#   'country': 'PF'},
#  {'code': 'AAB',
#   'name': 'Arrabury',
#   'latitude': -26.7,
#   'longitude': 141.04167,
#   'time_zone': 'Australia/Brisbane',
#   'city_code': 'AAB',
#   'country': 'AU'},
#  {'code': 'AAC',
#   'name': 'El Arish International Airport',
#   'latitude': 31.133333,
#   'longitude': 33.75,
#   'time_zone': 'Africa/Cairo',
#   'city_code': 'AAC',
#   'country': 'EG'},
#  {'code': 'AAD',
#   'name': 'Adado',
#   'latitude': 17.5927778,
#   'longitude': 33.9591667,
#   'time_zone': 'Africa/Khartoum',
#   'city_code': 'AAD',
#   'country': 'SD'},
#  {'code': 'AAE',
#   'name': 'Les Salines Airport',
#   'latitude': 36.821392,
#   'longitude': 7.811857,
#   'time_zone': 'Africa/Algiers',
#   'city_code': 'AAE',
#   'country': 'DZ'},
#  {'code': 'AAF',
#   'name': 'Apalachicola Regional',
#   'latitude': 29.733334,
#   'longitude': -84.98333,
#   'time_zone': 'America/New_York',
#   'city_code': 'AAF',
#   'country': 'US'},
#  {'code': 'AAG',
#   'name': 'Arapoti',
#   'latitude': -24.103611,
#   'longitude': -49.79,
#   'time_zone': 'America/Sao_Paulo',
#   'city_code': 'AAG',
#   'country': 'BR'},
#  {'code': 'AAH',
#   'name': 'Aachen/Merzbruck',
#   'latitude': 50.75,
#   'longitude': 6.133333,
#   'time_zone': 'Europe/Berlin',
#   'city_code': 'AAH',
#   'country': 'DE'},
#  {'code': 'AAI',
#   'name': 'Arraias',
#   'latitude': -12.916667,
#   'longitude': -46.933334,
#   'time_zone': 'America/Araguaina',
#   'city_code': 'AAI',
#   'country': 'BR'},
#  {'code': 'AAJ',
#   'name': 'Cayana Airstrip',
#   'latitude': 3.9,
#   'longitude': -55.36667,
#   'time_zone': 'America/Paramaribo',
#   'city_code': 'AAJ',
#   'country': 'SR'},
#  {'code': 'AAK',
#   'name': 'Aranuka',
#   'latitude': 0.166667,
#   'longitude': 173.58333,
#   'time_zone': 'Pacific/Tarawa',
#   'city_code': 'AAK',
#   'country': 'KI'},
#  {'code': 'AAL',
#   'name': 'Aalborg Airport',
#   'latitude': 57.08655,
#   'longitude': 9.872241,
#   'time_zone': 'Europe/Copenhagen',
#   'city_code': 'AAL',
#   'country': 'DK'},
#  {'code': 'AAM',
#   'name': 'Mala Mala',
#   'latitude': -24.8,
#   'longitude': 31.533333,
#   'time_zone': 'Africa/Johannesburg',
#   'city_code': 'AAM',
#   'country': 'ZA'},
#  {'code': 'AAN',
#   'name': 'Al Ain Airport',
#   'latitude': 24.260231,
#   'longitude': 55.616627,
#   'time_zone': 'Asia/Dubai',
#   'city_code': 'AAN',
#   'country': 'AE'},
#  {'code': 'AAO',
#   'name': 'Anaco',
#   'latitude': 9.431944,
#   'longitude': -64.46389,
#   'time_zone': 'America/Caracas',
#   'city_code': 'AAO',
#   'country': 'VE'},
#  {'code': 'AAP',
#   'name': 'Andrau Airpark',
#   'latitude': 29.833332,
#   'longitude': -95.666664,
#   'time_zone': 'America/Chicago',
#   'city_code': 'HOU',
#   'country': 'US'},
#  {'code': 'AAQ',
#   'name': 'Anapa Airport',
#   'latitude': 44.9,
#   'longitude': 37.316666,
#   'time_zone': 'Europe/Moscow',
#   'city_code': 'AAQ',
#   'country': 'RU'},
#  {'code': 'AAR',
#   'name': 'Aarhus Airport',
#   'latitude': 56.30823,
#   'longitude': 10.626351,
#   'time_zone': 'Europe/Copenhagen',
#   'city_code': 'AAR',
#   'country': 'DK'},
#  {'code': 'AAS',
#   'name': 'Apalapsili',
#   'latitude': -3.916667,
#   'longitude': 139.25,
#   'time_zone': 'Asia/Jayapura',
#   'city_code': 'AAS',
#   'country': 'ID'},
#  {'code': 'AAT',
#   'name': 'Altay Airport',
#   'latitude': 47.750362,
#   'longitude': 88.08444,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'AAT',
#   'country': 'CN'},
#  {'code': 'AAU',
#   'name': 'Asau',
#   'latitude': -13.458333,
#   'longitude': -172.6,
#   'time_zone': 'Pacific/Apia',
#   'city_code': 'AAU',
#   'country': 'WS'},
#  {'code': 'AAV',
#   'name': 'Allah Valley',
#   'latitude': 6.333333,
#   'longitude': 124.76667,
#   'time_zone': 'Asia/Manila',
#   'city_code': 'AAV',
#   'country': 'PH'},
#  {'code': 'AAW',
#   'name': 'Abbottabad',
#   'latitude': 34.2,
#   'longitude': 73.25,
#   'time_zone': 'Asia/Karachi',
#   'city_code': 'AAW',
#   'country': 'PK'},
#  {'code': 'AAX',
#   'name': 'Araxa Airport',
#   'latitude': -19.568056,
#   'longitude': -46.92917,
#   'time_zone': 'America/Sao_Paulo',
#   'city_code': 'AAX',
#   'country': 'BR'},
#  {'code': 'AAY',
#   'name': 'Al Ghaydah',
#   'latitude': 16.19596,
#   'longitude': 52.173256,
#   'time_zone': 'Asia/Aden',
#   'city_code': 'AAY',
#   'country': 'YE'},
#  {'code': 'AAZ',
#   'name': 'Quetzaltenango',
#   'latitude': 14.87,
#   'longitude': -91.5,
#   'time_zone': 'America/Guatemala',
#   'city_code': 'AAZ',
#   'country': 'GT'},
#  {'code': 'ABA',
#   'name': 'Abakan Airport',
#   'latitude': 53.716667,
#   'longitude': 91.5,
#   'time_zone': 'Asia/Krasnoyarsk',
#   'city_code': 'ABA',
#   'country': 'RU'},
#  {'code': 'ABB',
#   'name': 'Asaba International Airport',
#   'latitude': 51.666668,
#   'longitude': -1.283333,
#   'time_zone': 'Africa/Lagos',
#   'city_code': 'ABB',
#   'country': 'NG'},
#  {'code': 'ABC',
#   'name': 'Los Llanos',
#   'latitude': 38.948334,
#   'longitude': -1.863333,
#   'time_zone': 'Europe/Madrid',
#   'city_code': 'ABC',
#   'country': 'ES'},
#  {'code': 'ABD',
#   'name': 'Abadan Airport',
#   'latitude': 30.363905,
#   'longitude': 48.226597,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'ABD',
#   'country': 'IR'},
#  {'code': 'ABE',
#   'name': 'Lehigh Valley International Airport',
#   'latitude': 40.651573,
#   'longitude': -75.434364,
#   'time_zone': 'America/New_York',
#   'city_code': 'ABE',
#   'country': 'US'},
#  {'code': 'ABF',
#   'name': 'Abaiang',
#   'latitude': 1.670833,
#   'longitude': 173.30417,
#   'time_zone': 'Pacific/Tarawa',
#   'city_code': 'ABF',
#   'country': 'KI'},
#  {'code': 'ABG',
#   'name': 'Abingdon',
#   'latitude': -17.666668,
#   'longitude': 143.2,
#   'time_zone': 'Australia/Brisbane',
#   'city_code': 'ABG',
#   'country': 'AU'},
#  {'code': 'ABH',
#   'name': 'Alpha',
#   'latitude': -23.65,
#   'longitude': 146.63333,
#   'time_zone': 'Australia/Brisbane',
#   'city_code': 'ABH',
#   'country': 'AU'},
#  {'code': 'ABI',
#   'name': 'Abilene Regional Airport',
#   'latitude': 32.409443,
#   'longitude': -99.679726,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ABI',
#   'country': 'US'},
#  {'code': 'ABJ',
#   'name': 'Felix Houphouet Boigny Airport',
#   'latitude': 5.254879,
#   'longitude': -3.933015,
#   'time_zone': 'Africa/Abidjan',
#   'city_code': 'ABJ',
#   'country': 'CI'},
#  {'code': 'ABK',
#   'name': 'Kabri Dar',
#   'latitude': 6.733889,
#   'longitude': 44.26611,
#   'time_zone': 'Africa/Addis_Ababa',
#   'city_code': 'ABK',
#   'country': 'ET'},
#  {'code': 'ABL',
#   'name': 'Ambler Airport',
#   'latitude': 67.0875,
#   'longitude': -157.84584,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'ABL',
#   'country': 'US'},
#  {'code': 'ABM',
#   'name': 'Northern Peninsula Airport',
#   'latitude': -10.942619,
#   'longitude': 142.45033,
#   'time_zone': 'Australia/Brisbane',
#   'city_code': 'ABM',
#   'country': 'AU'},
#  {'code': 'ABN',
#   'name': 'Albina',
#   'latitude': 5.5,
#   'longitude': -54.083332,
#   'time_zone': 'America/Paramaribo',
#   'city_code': 'ABN',
#   'country': 'SR'},
#  {'code': 'ABO',
#   'name': 'Aboisso',
#   'latitude': 5.433333,
#   'longitude': -3.216667,
#   'time_zone': 'Africa/Abidjan',
#   'city_code': 'ABO',
#   'country': 'CI'},
#  {'code': 'ABP',
#   'name': 'Atkamba',
#   'latitude': -6.066667,
#   'longitude': 141.1,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'ABP',
#   'country': 'PG'},
#  {'code': 'ABQ',
#   'name': 'Albuquerque International Sunport',
#   'latitude': 35.049625,
#   'longitude': -106.617195,
#   'time_zone': 'America/Denver',
#   'city_code': 'ABQ',
#   'country': 'US'},
#  {'code': 'ABR',
#   'name': 'Aberdeen Municipal Airport',
#   'latitude': 45.4525,
#   'longitude': -98.42611,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ABR',
#   'country': 'US'},
#  {'code': 'ABS',
#   'name': 'Abu Simbel',
#   'latitude': 22.367567,
#   'longitude': 31.609774,
#   'time_zone': 'Africa/Cairo',
#   'city_code': 'ABS',
#   'country': 'EG'},
#  {'code': 'ABT',
#   'name': 'Al-Aqiq Airport',
#   'latitude': 20.29401,
#   'longitude': 41.64002,
#   'time_zone': 'Asia/Riyadh',
#   'city_code': 'ABT',
#   'country': 'SA'},
#  {'code': 'ABU',
#   'name': 'Haliwen Airport',
#   'latitude': -9.133333,
#   'longitude': 124.88333,
#   'time_zone': 'Asia/Makassar',
#   'city_code': 'ABU',
#   'country': 'ID'},
#  {'code': 'ABV',
#   'name': 'Nnamdi Azikiwe International Airport',
#   'latitude': 9.004614,
#   'longitude': 7.270447,
#   'time_zone': 'Africa/Lagos',
#   'city_code': 'ABV',
#   'country': 'NG'},
#  {'code': 'ABW',
#   'name': 'Abau',
#   'latitude': -10.183333,
#   'longitude': 148.7,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'ABW',
#   'country': 'PG'},
#  {'code': 'ABX',
#   'name': 'Albury Airport',
#   'latitude': -36.069626,
#   'longitude': 146.95453,
#   'time_zone': 'Australia/Sydney',
#   'city_code': 'ABX',
#   'country': 'AU'},
#  {'code': 'ABY',
#   'name': 'Southwest Georgia Regional Airport',
#   'latitude': 31.532223,
#   'longitude': -84.19611,
#   'time_zone': 'America/New_York',
#   'city_code': 'ABY',
#   'country': 'US'},
#  {'code': 'ABZ',
#   'name': 'Aberdeen International Airport',
#   'latitude': 57.200253,
#   'longitude': -2.204186,
#   'time_zone': 'Europe/London',
#   'city_code': 'ABZ',
#   'country': 'GB'},
#  {'code': 'ACA',
#   'name': 'Acapulco International Airport',
#   'latitude': 16.762403,
#   'longitude': -99.75459,
#   'time_zone': 'America/Mexico_City',
#   'city_code': 'ACA',
#   'country': 'MX'},
#  {'code': 'ACB',
#   'name': 'Antrim County',
#   'latitude': 44.983334,
#   'longitude': -85.21667,
#   'time_zone': 'America/Detroit',
#   'city_code': 'ACB',
#   'country': 'US'},
#  {'code': 'ACC',
#   'name': 'Kotoka International Airport',
#   'latitude': 5.60737,
#   'longitude': -0.171769,
#   'time_zone': 'Africa/Accra',
#   'city_code': 'ACC',
#   'country': 'GH'},
#  {'code': 'ACD',
#   'name': 'Acandi',
#   'latitude': 8.516667,
#   'longitude': -77.3,
#   'time_zone': 'America/Bogota',
#   'city_code': 'ACD',
#   'country': 'CO'},
#  {'code': 'ACE',
#   'name': 'Lanzarote Airport',
#   'latitude': 28.950668,
#   'longitude': -13.609059,
#   'time_zone': 'Atlantic/Canary',
#   'city_code': 'ACE',
#   'country': 'ES'},
#  {'code': 'ACH',
#   'name': 'Altenrhein Airport',
#   'latitude': 47.483334,
#   'longitude': 9.566667,
#   'time_zone': 'Europe/Zurich',
#   'city_code': 'ACH',
#   'country': 'CH'},
#  {'code': 'ACI',
#   'name': 'Alderney Airport',
#   'latitude': 49.709347,
#   'longitude': -2.215369,
#   'time_zone': 'Europe/Guernsey',
#   'city_code': 'ACI',
#   'country': 'GB'},
#  {'code': 'ACJ',
#   'name': 'Anuradhapura',
#   'latitude': 8.35,
#   'longitude': 80.38333,
#   'time_zone': 'Asia/Colombo',
#   'city_code': 'ACJ',
#   'country': 'LK'},
#  {'code': 'ACK',
#   'name': 'Nantucket Memorial Airport',
#   'latitude': 41.256668,
#   'longitude': -70.05972,
#   'time_zone': 'America/New_York',
#   'city_code': 'ACK',
#   'country': 'US'},
#  {'code': 'ACL',
#   'name': 'Aguaclara',
#   'latitude': 4.75,
#   'longitude': -73.0,
#   'time_zone': 'America/Bogota',
#   'city_code': 'ACL',
#   'country': 'CO'},
#  {'code': 'ACM',
#   'name': 'Arica',
#   'latitude': -2.0,
#   'longitude': -71.833336,
#   'time_zone': 'America/Bogota',
#   'city_code': 'ACM',
#   'country': 'CO'},
#  {'code': 'ACN',
#   'name': 'International',
#   'latitude': 29.3,
#   'longitude': -100.916664,
#   'time_zone': 'America/Matamoros',
#   'city_code': 'ACN',
#   'country': 'MX'},
#  {'code': 'ACP',
#   'name': 'Sahand',
#   'latitude': 37.347244,
#   'longitude': 46.145115,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'ACP',
#   'country': 'IR'},
#  {'code': 'ACR',
#   'name': 'Araracuara',
#   'latitude': -0.383333,
#   'longitude': -72.3,
#   'time_zone': 'America/Bogota',
#   'city_code': 'ACR',
#   'country': 'CO'},
#  {'code': 'ACS',
#   'name': 'Achinsk',
#   'latitude': 56.266666,
#   'longitude': 90.566666,
#   'time_zone': 'Asia/Krasnoyarsk',
#   'city_code': 'ACS',
#   'country': 'RU'},
#  {'code': 'ACT',
#   'name': 'Waco Municipal Airport',
#   'latitude': 31.609133,
#   'longitude': -97.22321,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ACT',
#   'country': 'US'},
#  {'code': 'ACU',
#   'name': 'Achutupo',
#   'latitude': 9.576389,
#   'longitude': -79.72444,
#   'time_zone': 'America/Panama',
#   'city_code': 'ACU',
#   'country': 'PA'},
#  {'code': 'ACV',
#   'name': 'Arcata-Eureka Airport',
#   'latitude': 40.970913,
#   'longitude': -124.106926,
#   'time_zone': 'America/Los_Angeles',
#   'city_code': 'ACV',
#   'country': 'US'},
#  {'code': 'ACX',
#   'name': 'Xingyi Airport',
#   'latitude': 25.085556,
#   'longitude': 104.95944,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'ACX',
#   'country': 'CN'},
#  {'code': 'ACY',
#   'name': 'Atlantic City International Airport',
#   'latitude': 39.450703,
#   'longitude': -74.572235,
#   'time_zone': 'America/New_York',
#   'city_code': 'AIY',
#   'country': 'US'},
#  {'code': 'ACZ',
#   'name': 'Zabol Airport',
#   'latitude': 31.087694,
#   'longitude': 61.542244,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'ACZ',
#   'country': 'IR'},
#  {'code': 'ADA',
#   'name': 'Adana Airport',
#   'latitude': 36.98503,
#   'longitude': 35.29736,
#   'time_zone': 'Europe/Istanbul',
#   'city_code': 'ADA',
#   'country': 'TR'},
#  {'code': 'ADB',
#   'name': 'Izmir Adnan Menderes Airport',
#   'latitude': 38.294403,
#   'longitude': 27.147594,
#   'time_zone': 'Europe/Istanbul',
#   'city_code': 'IZM',
#   'country': 'TR'},
#  {'code': 'ADC',
#   'name': 'Andakombe',
#   'latitude': -7.133333,
#   'longitude': 145.73334,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'ADC',
#   'country': 'PG'},
#  {'code': 'ADD',
#   'name': 'Addis Ababa Bole International Airport',
#   'latitude': 8.983759,
#   'longitude': 38.7959,
#   'time_zone': 'Africa/Addis_Ababa',
#   'city_code': 'ADD',
#   'country': 'ET'},
#  {'code': 'ADE',
#   'name': 'International',
#   'latitude': 12.826116,
#   'longitude': 45.037537,
#   'time_zone': 'Asia/Aden',
#   'city_code': 'ADE',
#   'country': 'YE'},
#  {'code': 'ADF',
#   'name': 'Adiyaman Airport',
#   'latitude': 37.75,
#   'longitude': 38.266666,
#   'time_zone': 'Europe/Istanbul',
#   'city_code': 'ADF',
#   'country': 'TR'},
#  {'code': 'ADG',
#   'name': 'Lenawee County',
#   'latitude': 41.9,
#   'longitude': -84.03333,
#   'time_zone': 'America/Detroit',
#   'city_code': 'ADG',
#   'country': 'US'},
#  {'code': 'ADH',
#   'name': 'Aldan',
#   'latitude': 58.6,
#   'longitude': 125.4,
#   'time_zone': 'Asia/Yakutsk',
#   'city_code': 'ADH',
#   'country': 'RU'},
#  {'code': 'ADI',
#   'name': 'Arandis',
#   'latitude': -22.4,
#   'longitude': 15.0,
#   'time_zone': 'Africa/Windhoek',
#   'city_code': 'ADI',
#   'country': 'NA'},
#  {'code': 'ADJ',
#   'name': 'Marka International Airport',
#   'latitude': 31.97533,
#   'longitude': 35.98277,
#   'time_zone': 'Asia/Amman',
#   'city_code': 'AMM',
#   'country': 'JO'},
#  {'code': 'ADK',
#   'name': 'Adak Island Ns',
#   'latitude': 51.88278,
#   'longitude': -176.64473,
#   'time_zone': 'America/Adak',
#   'city_code': 'ADK',
#   'country': 'US'},
#  {'code': 'ADL',
#   'name': 'Adelaide Airport',
#   'latitude': -34.938175,
#   'longitude': 138.53735,
#   'time_zone': 'Australia/Adelaide',
#   'city_code': 'ADL',
#   'country': 'AU'},
#  {'code': 'ADM',
#   'name': 'Ardmore Municipal Airport',
#   'latitude': 34.303055,
#   'longitude': -97.01945,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ADM',
#   'country': 'US'},
#  {'code': 'ADN',
#   'name': 'Andes',
#   'latitude': 5.666667,
#   'longitude': -75.933334,
#   'time_zone': 'America/Bogota',
#   'city_code': 'ADN',
#   'country': 'CO'},
#  {'code': 'ADO',
#   'name': 'Andamooka',
#   'latitude': -31.016666,
#   'longitude': 137.15,
#   'time_zone': 'Australia/Adelaide',
#   'city_code': 'ADO',
#   'country': 'AU'},
#  {'code': 'ADP',
#   'name': 'Ampara',
#   'latitude': 7.336389,
#   'longitude': 81.625275,
#   'time_zone': 'Asia/Colombo',
#   'city_code': 'ADP',
#   'country': 'LK'},
#  {'code': 'ADQ',
#   'name': 'Kodiak Benny Benson State Airport',
#   'latitude': 57.755276,
#   'longitude': -152.51297,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'ADQ',
#   'country': 'US'},
#  {'code': 'ADR',
#   'name': 'Andrews',
#   'latitude': 33.45,
#   'longitude': -79.566666,
#   'time_zone': 'America/New_York',
#   'city_code': 'ADR',
#   'country': 'US'},
#  {'code': 'ADS',
#   'name': 'Addison Airport',
#   'latitude': 32.783333,
#   'longitude': -97.3,
#   'time_zone': 'America/Chicago',
#   'city_code': 'DFW',
#   'country': 'US'},
#  {'code': 'ADT',
#   'name': 'Ada Municipal',
#   'latitude': 34.8,
#   'longitude': -96.666664,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ADT',
#   'country': 'US'},
#  {'code': 'ADU',
#   'name': 'Ardabil Airport',
#   'latitude': 38.323826,
#   'longitude': 48.42125,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'ADU',
#   'country': 'IR'},
#  {'code': 'ADV',
#   'name': 'El Daein',
#   'latitude': 11.4023,
#   'longitude': 26.1168,
#   'time_zone': 'Africa/Khartoum',
#   'city_code': 'ADV',
#   'country': 'SD'},
#  {'code': 'ADW',
#   'name': 'Andrews AFB',
#   'latitude': 38.816666,
#   'longitude': -76.86667,
#   'time_zone': 'America/New_York',
#   'city_code': 'ADW',
#   'country': 'US'},
#  {'code': 'ADX',
#   'name': 'Leuchars',
#   'latitude': 56.36667,
#   'longitude': -2.866667,
#   'time_zone': 'Europe/London',
#   'city_code': 'ADX',
#   'country': 'GB'},
#  {'code': 'ADY',
#   'name': 'Alldays',
#   'latitude': -22.666668,
#   'longitude': 29.05,
#   'time_zone': 'Africa/Johannesburg',
#   'city_code': 'ADY',
#   'country': 'ZA'},
#  {'code': 'ADZ',
#   'name': 'Gustavo Rojas Pinilla Airport',
#   'latitude': 12.586047,
#   'longitude': -81.70221,
#   'time_zone': 'America/Bogota',
#   'city_code': 'ADZ',
#   'country': 'CO'},
#  {'code': 'AEA',
#   'name': 'Abemama Atoll',
#   'latitude': 0.483333,
#   'longitude': 173.85,
#   'time_zone': 'Pacific/Tarawa',
#   'city_code': 'AEA',
#   'country': 'KI'},
#  {'code': 'AEB',
#   'name': 'Youjiang',
#   'latitude': 23.71947,
#   'longitude': 106.96777,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'AEB',
#   'country': 'CN'},
#  {'code': 'AED',
#   'name': 'Aleneva',
#   'latitude': 58.033333,
#   'longitude': -152.9,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'AED',
#   'country': 'US'},
#  {'code': 'AEE',
#   'name': 'Adareil',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'time_zone': 'Africa/Juba',
#   'city_code': 'AEE',
#   'country': 'SS'},
#  {'code': 'AEG',
#   'name': 'Aek Godang',
#   'latitude': 1.399722,
#   'longitude': 99.416664,
#   'time_zone': 'Asia/Jakarta',
#   'city_code': 'AEG',
#   'country': 'ID'},
#  {'code': 'AEH',
#   'name': 'Abéché',
#   'latitude': 13.851389,
#   'longitude': 20.850834,
#   'time_zone': 'Africa/Ndjamena',
#   'city_code': 'AEH',
#   'country': 'TD'},
#  {'code': 'AEI',
#   'name': 'Algeciras',
#   'latitude': 36.1289,
#   'longitude': -5.441301,
#   'time_zone': 'Europe/Madrid',
#   'city_code': 'AEI',
#   'country': 'ES'},
#  {'code': 'AEK',
#   'name': 'Aseki',
#   'latitude': -7.366667,
#   'longitude': 146.28334,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AEK',
#   'country': 'PG'},
#  {'code': 'AEL',
#   'name': 'Albert Lea',
#   'latitude': 43.65,
#   'longitude': -93.36667,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AEL',
#   'country': 'US'},
#  {'code': 'AEM',
#   'name': 'Amgu',
#   'latitude': 45.841667,
#   'longitude': 137.678333,
#   'time_zone': 'Asia/Vladivostok',
#   'city_code': 'AEM',
#   'country': 'RU'},
#  {'code': 'AEO',
#   'name': 'Aioun El Atrouss',
#   'latitude': 16.709167,
#   'longitude': -9.635556,
#   'time_zone': 'Africa/Nouakchott',
#   'city_code': 'AEO',
#   'country': 'MR'},
#  {'code': 'AEP',
#   'name': 'Jorge Newbery Airport',
#   'latitude': -34.55622,
#   'longitude': -58.41667,
#   'time_zone': 'America/Argentina/Buenos_Aires',
#   'city_code': 'BUE',
#   'country': 'AR'},
#  {'code': 'AEQ',
#   'name': 'Ar Horqin Airport',
#   'latitude': 43.87042,
#   'longitude': 120.15958,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'AEQ',
#   'country': 'CN'},
#  {'code': 'AER',
#   'name': 'Sochi International Airport',
#   'latitude': 43.44884,
#   'longitude': 39.941105,
#   'time_zone': 'Europe/Moscow',
#   'city_code': 'AER',
#   'country': 'RU'},
#  {'code': 'AES',
#   'name': 'Vigra Alesund Airport',
#   'latitude': 62.559643,
#   'longitude': 6.116605,
#   'time_zone': 'Europe/Oslo',
#   'city_code': 'AES',
#   'country': 'NO'},
#  {'code': 'AET',
#   'name': 'Allakaket',
#   'latitude': 66.56167,
#   'longitude': -152.65834,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'AET',
#   'country': 'US'},
#  {'code': 'AEU',
#   'name': 'Abu Musa',
#   'latitude': 25.8875,
#   'longitude': 55.041668,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'AEU',
#   'country': 'IR'},
#  {'code': 'AEX',
#   'name': 'Alexandria International Airport',
#   'latitude': 31.321268,
#   'longitude': -92.53958,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AEX',
#   'country': 'US'},
#  {'code': 'AEY',
#   'name': 'Akureyri Airport',
#   'latitude': 65.654564,
#   'longitude': -18.075068,
#   'time_zone': 'Atlantic/Reykjavik',
#   'city_code': 'AEY',
#   'country': 'IS'},
#  {'code': 'AFA',
#   'name': 'San Rafael Airport',
#   'latitude': -34.58917,
#   'longitude': -68.40056,
#   'time_zone': 'America/Argentina/Mendoza',
#   'city_code': 'AFA',
#   'country': 'AR'},
#  {'code': 'AFD',
#   'name': 'Port Alfred',
#   'latitude': -33.583332,
#   'longitude': 26.883333,
#   'time_zone': 'Africa/Johannesburg',
#   'city_code': 'AFD',
#   'country': 'ZA'},
#  {'code': 'AFF',
#   'name': 'USAF Academy Airstrip',
#   'latitude': 38.833332,
#   'longitude': -104.7,
#   'time_zone': 'America/Denver',
#   'city_code': 'COS',
#   'country': 'US'},
#  {'code': 'AFI',
#   'name': 'Amalfi',
#   'latitude': 6.916667,
#   'longitude': -75.066666,
#   'time_zone': 'America/Bogota',
#   'city_code': 'AFI',
#   'country': 'CO'},
#  {'code': 'AFK',
#   'name': 'Kondavattavan Tank',
#   'latitude': 40.668888,
#   'longitude': -96.00694,
#   'time_zone': 'Asia/Colombo',
#   'city_code': 'ADP',
#   'country': 'LK'},
#  {'code': 'AFL',
#   'name': 'Alta Floresta Airport',
#   'latitude': -9.872456,
#   'longitude': -56.104767,
#   'time_zone': 'America/Cuiaba',
#   'city_code': 'AFL',
#   'country': 'BR'},
#  {'code': 'AFN',
#   'name': 'Municipal',
#   'latitude': 42.833332,
#   'longitude': -72.066666,
#   'time_zone': 'America/New_York',
#   'city_code': 'AFN',
#   'country': 'US'},
#  {'code': 'AFO',
#   'name': 'Municipal',
#   'latitude': 42.733334,
#   'longitude': -110.933334,
#   'time_zone': 'America/Denver',
#   'city_code': 'AFO',
#   'country': 'US'},
#  {'code': 'AFR',
#   'name': 'Afore',
#   'latitude': -9.133333,
#   'longitude': 148.38333,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AFR',
#   'country': 'PG'},
#  {'code': 'AFS',
#   'name': 'Zarafshan',
#   'latitude': 41.61361,
#   'longitude': 64.233055,
#   'time_zone': 'Asia/Samarkand',
#   'city_code': 'AFS',
#   'country': 'UZ'},
#  {'code': 'AFT',
#   'name': 'Afutara Aerodrome',
#   'latitude': -9.2,
#   'longitude': 160.85,
#   'time_zone': 'Pacific/Guadalcanal',
#   'city_code': 'AFT',
#   'country': 'SB'},
#  {'code': 'AFW',
#   'name': 'Fort Worth Alliance Airport',
#   'latitude': 32.986668,
#   'longitude': -97.316666,
#   'time_zone': 'America/Chicago',
#   'city_code': 'DFW',
#   'country': 'US'},
#  {'code': 'AFY',
#   'name': 'Afyon',
#   'latitude': 38.733334,
#   'longitude': 30.6,
#   'time_zone': 'Europe/Istanbul',
#   'city_code': 'AFY',
#   'country': 'TR'},
#  {'code': 'AFZ',
#   'name': 'Sabzevar',
#   'latitude': 36.171513,
#   'longitude': 57.60332,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'AFZ',
#   'country': 'IR'},
#  {'code': 'AGA',
#   'name': 'Agadir Al Massira Airport',
#   'latitude': 30.378326,
#   'longitude': -9.555895,
#   'time_zone': 'Africa/Casablanca',
#   'city_code': 'AGA',
#   'country': 'MA'},
#  {'code': 'AGB',
#   'name': 'Augsburg Airport',
#   'latitude': 48.425278,
#   'longitude': 10.931667,
#   'time_zone': 'Europe/Berlin',
#   'city_code': 'MUC',
#   'country': 'DE'},
#  {'code': 'AGC',
#   'name': 'Allegheny County Airport',
#   'latitude': 40.35472,
#   'longitude': -79.93,
#   'time_zone': 'America/New_York',
#   'city_code': 'PIT',
#   'country': 'US'},
#  {'code': 'AGD',
#   'name': 'Anggi',
#   'latitude': -1.383333,
#   'longitude': 133.86667,
#   'time_zone': 'Asia/Jayapura',
#   'city_code': 'AGD',
#   'country': 'ID'},
#  {'code': 'AGE',
#   'name': 'Flugplatz',
#   'latitude': 53.783333,
#   'longitude': 7.916667,
#   'time_zone': 'Europe/Berlin',
#   'city_code': 'AGE',
#   'country': 'DE'},
#  {'code': 'AGF',
#   'name': 'La Garenne Airport',
#   'latitude': 44.17361,
#   'longitude': 0.598611,
#   'time_zone': 'Europe/Paris',
#   'city_code': 'AGF',
#   'country': 'FR'},
#  {'code': 'AGG',
#   'name': 'Angoram',
#   'latitude': -4.168611,
#   'longitude': 144.07388,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AGG',
#   'country': 'PG'},
#  {'code': 'AGH',
#   'name': 'Angelholm Helsingborg Airport',
#   'latitude': 56.293056,
#   'longitude': 12.8625,
#   'time_zone': 'Europe/Stockholm',
#   'city_code': 'AGH',
#   'country': 'SE'},
#  {'code': 'AGI',
#   'name': 'Wageningen',
#   'latitude': 5.833333,
#   'longitude': -56.833332,
#   'time_zone': 'America/Paramaribo',
#   'city_code': 'AGI',
#   'country': 'SR'},
#  {'code': 'AGJ',
#   'name': 'Aguni',
#   'latitude': 26.589722,
#   'longitude': 127.23805,
#   'time_zone': 'Asia/Tokyo',
#   'city_code': 'AGJ',
#   'country': 'JP'},
#  {'code': 'AGK',
#   'name': 'Kagua',
#   'latitude': -6.403333,
#   'longitude': 143.84666,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AGK',
#   'country': 'PG'},
#  {'code': 'AGL',
#   'name': 'Wanigela',
#   'latitude': -9.340278,
#   'longitude': 149.15527,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AGL',
#   'country': 'PG'},
#  {'code': 'AGM',
#   'name': 'Tasiilaq',
#   'latitude': 65.6,
#   'longitude': -37.683334,
#   'time_zone': 'America/Godthab',
#   'city_code': 'AGM',
#   'country': 'GL'},
#  {'code': 'AGN',
#   'name': 'Angoon',
#   'latitude': 57.503887,
#   'longitude': -134.58333,
#   'time_zone': 'America/Juneau',
#   'city_code': 'AGN',
#   'country': 'US'},
#  {'code': 'AGO',
#   'name': 'Municipal',
#   'latitude': 33.266666,
#   'longitude': -93.23333,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AGO',
#   'country': 'US'},
#  {'code': 'AGP',
#   'name': 'Malaga Airport',
#   'latitude': 36.675182,
#   'longitude': -4.489616,
#   'time_zone': 'Europe/Madrid',
#   'city_code': 'AGP',
#   'country': 'ES'},
#  {'code': 'AGQ',
#   'name': 'Agrinion',
#   'latitude': 38.604168,
#   'longitude': 21.351944,
#   'time_zone': 'Europe/Athens',
#   'city_code': 'AGQ',
#   'country': 'GR'},
#  {'code': 'AGR',
#   'name': 'Kheria',
#   'latitude': 27.158333,
#   'longitude': 77.962776,
#   'time_zone': 'Asia/Kolkata',
#   'city_code': 'AGR',
#   'country': 'IN'},
#  {'code': 'AGS',
#   'name': 'Augusta Regional Airport',
#   'latitude': 33.373665,
#   'longitude': -81.973434,
#   'time_zone': 'America/New_York',
#   'city_code': 'AGS',
#   'country': 'US'},
#  {'code': 'AGT',
#   'name': 'Alejo Garcia Airport',
#   'latitude': -25.5,
#   'longitude': -54.833332,
#   'time_zone': 'America/Asuncion',
#   'city_code': 'AGT',
#   'country': 'PY'},
#  {'code': 'AGU',
#   'name': 'Aguascalients International Airport',
#   'latitude': 21.701416,
#   'longitude': -102.31374,
#   'time_zone': 'America/Mexico_City',
#   'city_code': 'AGU',
#   'country': 'MX'},
#  {'code': 'AGV',
#   'name': 'Acarigua',
#   'latitude': 9.552222,
#   'longitude': -69.23333,
#   'time_zone': 'America/Caracas',
#   'city_code': 'AGV',
#   'country': 'VE'},
#  {'code': 'AGW',
#   'name': 'Agnew',
#   'latitude': -12.15,
#   'longitude': 142.15,
#   'time_zone': 'Australia/Brisbane',
#   'city_code': 'AGW',
#   'country': 'AU'},
#  {'code': 'AGX',
#   'name': 'Agatti Island Airport',
#   'latitude': 10.828967,
#   'longitude': 72.17987,
#   'time_zone': 'Asia/Kolkata',
#   'city_code': 'AGX',
#   'country': 'IN'},
#  {'code': 'AGZ',
#   'name': 'Aggeneys',
#   'latitude': -29.05,
#   'longitude': 18.85,
#   'time_zone': 'Africa/Johannesburg',
#   'city_code': 'AGZ',
#   'country': 'ZA'},
#  {'code': 'AHA',
#   'name': 'Naha AFB',
#   'latitude': 26.2,
#   'longitude': 127.65,
#   'time_zone': 'Asia/Tokyo',
#   'city_code': 'OKA',
#   'country': 'JP'},
#  {'code': 'AHB',
#   'name': 'Abha Regional Airport',
#   'latitude': 18.23429,
#   'longitude': 42.657574,
#   'time_zone': 'Asia/Riyadh',
#   'city_code': 'AHB',
#   'country': 'SA'},
#  {'code': 'AHC',
#   'name': 'Amedee AAF',
#   'latitude': 40.15,
#   'longitude': -120.13333,
#   'time_zone': 'America/Los_Angeles',
#   'city_code': 'AHC',
#   'country': 'US'},
#  {'code': 'AHD',
#   'name': 'Downtown',
#   'latitude': 34.166668,
#   'longitude': -97.13333,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ADM',
#   'country': 'US'},
#  {'code': 'AHE',
#   'name': 'Ahe Airport',
#   'latitude': -14.428056,
#   'longitude': -146.25694,
#   'time_zone': 'Pacific/Tahiti',
#   'city_code': 'AHE',
#   'country': 'PF'},
#  {'code': 'AHF',
#   'name': 'Municipal',
#   'latitude': 40.3,
#   'longitude': -99.9,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AHF',
#   'country': 'US'},
#  {'code': 'AHH',
#   'name': 'Municipal',
#   'latitude': 45.3,
#   'longitude': -92.35,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AHH',
#   'country': 'US'},
#  {'code': 'AHI',
#   'name': 'Amahai',
#   'latitude': -3.333333,
#   'longitude': 128.91667,
#   'time_zone': 'Asia/Jayapura',
#   'city_code': 'AHI',
#   'country': 'ID'},
#  {'code': 'AHJ',
#   'name': 'Hongyuan Airport',
#   'latitude': 32.53154,
#   'longitude': 102.35224,
#   'time_zone': 'Asia/Chongqing',
#   'city_code': 'AHJ',
#   'country': 'CN'},
#  {'code': 'AHL',
#   'name': 'Aishalton',
#   'latitude': 2.483333,
#   'longitude': -59.316666,
#   'time_zone': 'America/Guyana',
#   'city_code': 'AHL',
#   'country': 'GY'},
#  {'code': 'AHM',
#   'name': 'Sumner Parker Field',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'time_zone': 'America/Los_Angeles',
#   'city_code': 'AHM',
#   'country': 'US'},
#  {'code': 'AHN',
#   'name': 'Athens-Ben Epps',
#   'latitude': 33.95195,
#   'longitude': -83.32472,
#   'time_zone': 'America/New_York',
#   'city_code': 'AHN',
#   'country': 'US'},
#  {'code': 'AHO',
#   'name': 'Alghero-Fertilia Airport',
#   'latitude': 40.630405,
#   'longitude': 8.295891,
#   'time_zone': 'Europe/Rome',
#   'city_code': 'AHO',
#   'country': 'IT'},
#  {'code': 'AHS',
#   'name': 'Ahuas',
#   'latitude': 15.441667,
#   'longitude': -84.425,
#   'time_zone': 'America/Tegucigalpa',
#   'city_code': 'AHS',
#   'country': 'HN'},
#  {'code': 'AHT',
#   'name': 'Amchitka',
#   'latitude': 51.5,
#   'longitude': 179.0,
#   'time_zone': 'America/Adak',
#   'city_code': 'AHT',
#   'country': 'US'},
#  {'code': 'AHU',
#   'name': 'Charif Al Idrissi Airport',
#   'latitude': 35.17972,
#   'longitude': -3.836944,
#   'time_zone': 'Africa/Casablanca',
#   'city_code': 'AHU',
#   'country': 'MA'},
#  {'code': 'AHW',
#   'name': 'Saih Rawl',
#   'latitude': 31.34292,
#   'longitude': 48.74668,
#   'time_zone': 'Asia/Muscat',
#   'city_code': 'AHW',
#   'country': 'OM'},
#  {'code': 'AHY',
#   'name': 'Ambatolahy',
#   'latitude': -20.016666,
#   'longitude': 45.533333,
#   'time_zone': 'Indian/Antananarivo',
#   'city_code': 'AHY',
#   'country': 'MG'},
#  {'code': 'AHZ',
#   'name': 'Alpe D Huez',
#   'latitude': 45.083332,
#   'longitude': 6.083333,
#   'time_zone': 'Europe/Paris',
#   'city_code': 'AHZ',
#   'country': 'FR'},
#  {'code': 'AIA',
#   'name': 'Alliance Airport',
#   'latitude': 42.051666,
#   'longitude': -102.80666,
#   'time_zone': 'America/Denver',
#   'city_code': 'AIA',
#   'country': 'US'},
#  {'code': 'AIB',
#   'name': 'Anita Bay',
#   'latitude': 56.233334,
#   'longitude': -132.38333,
#   'time_zone': 'America/Sitka',
#   'city_code': 'AIB',
#   'country': 'US'},
#  {'code': 'AIC',
#   'name': 'Airok',
#   'latitude': 7.5,
#   'longitude': 170.83333,
#   'time_zone': 'Pacific/Majuro',
#   'city_code': 'AIC',
#   'country': 'MH'},
#  {'code': 'AID',
#   'name': 'Municipal',
#   'latitude': 40.166668,
#   'longitude': -85.683334,
#   'time_zone': 'America/Indiana/Indianapolis',
#   'city_code': 'AID',
#   'country': 'US'},
#  {'code': 'AIE',
#   'name': 'Aiome',
#   'latitude': -5.166667,
#   'longitude': 144.66667,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AIE',
#   'country': 'PG'},
#  {'code': 'AIF',
#   'name': 'Assis',
#   'latitude': -22.666668,
#   'longitude': -50.416668,
#   'time_zone': 'America/Sao_Paulo',
#   'city_code': 'AIF',
#   'country': 'BR'},
#  {'code': 'AIG',
#   'name': 'Yalinga',
#   'latitude': 6.516667,
#   'longitude': 23.25,
#   'time_zone': 'Africa/Bangui',
#   'city_code': 'AIG',
#   'country': 'CF'},
#  {'code': 'AIH',
#   'name': 'Aiambak',
#   'latitude': -7.348611,
#   'longitude': 141.26639,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AIH',
#   'country': 'PG'},
#  {'code': 'AII',
#   'name': 'Alisabieh',
#   'latitude': 11.15,
#   'longitude': 42.716667,
#   'time_zone': 'Africa/Djibouti',
#   'city_code': 'AII',
#   'country': 'DJ'},
#  {'code': 'AIK',
#   'name': 'Municipal',
#   'latitude': 33.566666,
#   'longitude': -81.71667,
#   'time_zone': 'America/New_York',
#   'city_code': 'AIK',
#   'country': 'US'},
#  {'code': 'AIL',
#   'name': 'Ailigandi',
#   'latitude': 9.25,
#   'longitude': -78.083336,
#   'time_zone': 'America/Panama',
#   'city_code': 'AIL',
#   'country': 'PA'},
#  {'code': 'AIM',
#   'name': 'Ailuk Island',
#   'latitude': 10.2,
#   'longitude': 169.98334,
#   'time_zone': 'Pacific/Majuro',
#   'city_code': 'AIM',
#   'country': 'MH'},
#  {'code': 'AIN',
#   'name': 'Wainwright',
#   'latitude': 70.63333,
#   'longitude': -160.03334,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'AIN',
#   'country': 'US'},
#  {'code': 'AIO',
#   'name': 'Municipal',
#   'latitude': 41.4,
#   'longitude': -95.01667,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AIO',
#   'country': 'US'},
#  {'code': 'AIP',
#   'name': 'Ailinglapalap Island',
#   'latitude': 7.266667,
#   'longitude': 168.81667,
#   'time_zone': 'Pacific/Majuro',
#   'city_code': 'AIP',
#   'country': 'MH'},
#  {'code': 'AIR',
#   'name': 'Aripuana',
#   'latitude': -10.25,
#   'longitude': -59.38333,
#   'time_zone': 'America/Cuiaba',
#   'city_code': 'AIR',
#   'country': 'BR'},
#  {'code': 'AIS',
#   'name': 'Arorae Island',
#   'latitude': -2.65,
#   'longitude': 176.83333,
#   'time_zone': 'Pacific/Tarawa',
#   'city_code': 'AIS',
#   'country': 'KI'},
#  {'code': 'AIT',
#   'name': 'Aitutaki Airport',
#   'latitude': -18.829443,
#   'longitude': -159.767,
#   'time_zone': 'Pacific/Rarotonga',
#   'city_code': 'AIT',
#   'country': 'CK'},
#  {'code': 'AIU',
#   'name': 'Atiu Island',
#   'latitude': -20.033333,
#   'longitude': -158.1,
#   'time_zone': 'Pacific/Rarotonga',
#   'city_code': 'AIU',
#   'country': 'CK'},
#  {'code': 'AIV',
#   'name': 'George Downer',
#   'latitude': 33.13333,
#   'longitude': -88.15,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AIV',
#   'country': 'US'},
#  {'code': 'AIW',
#   'name': 'Ai-ais',
#   'latitude': -27.983334,
#   'longitude': 17.583332,
#   'time_zone': 'Africa/Windhoek',
#   'city_code': 'AIW',
#   'country': 'NA'},
#  {'code': 'AIY',
#   'name': 'Bader Field',
#   'latitude': 39.36,
#   'longitude': -74.45722,
#   'time_zone': 'America/New_York',
#   'city_code': 'AIY',
#   'country': 'US'},
#  {'code': 'AIZ',
#   'name': 'Lee C Fine Memorial',
#   'latitude': 38.09833,
#   'longitude': -92.54722,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AIZ',
#   'country': 'US'},
#  {'code': 'AJA',
#   'name': 'Ajaccio Napoleon Bonaparte Airport',
#   'latitude': 41.91987,
#   'longitude': 8.794013,
#   'time_zone': 'Europe/Paris',
#   'city_code': 'AJA',
#   'country': 'FR'},
#  {'code': 'AJF',
#   'name': 'Jouf Airport',
#   'latitude': 29.788668,
#   'longitude': 40.101486,
#   'time_zone': 'Asia/Riyadh',
#   'city_code': 'AJF',
#   'country': 'SA'},
#  {'code': 'AJI',
#   'name': 'Agri Airport',
#   'latitude': 39.65,
#   'longitude': 43.025,
#   'time_zone': 'Europe/Istanbul',
#   'city_code': 'AJI',
#   'country': 'TR'},
#  {'code': 'AJJ',
#   'name': 'Akjoujt',
#   'latitude': 19.730556,
#   'longitude': -14.374444,
#   'time_zone': 'Africa/Nouakchott',
#   'city_code': 'AJJ',
#   'country': 'MR'},
#  {'code': 'AJK',
#   'name': 'Araak',
#   'latitude': 34.13333,
#   'longitude': 49.833332,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'AJK',
#   'country': 'IR'},
#  {'code': 'AJL',
#   'name': 'Aizawl Airport',
#   'latitude': 23.838985,
#   'longitude': 92.62482,
#   'time_zone': 'Asia/Kolkata',
#   'city_code': 'AJL',
#   'country': 'IN'},
#  {'code': 'AJN',
#   'name': 'Ouani',
#   'latitude': -12.126389,
#   'longitude': 44.42972,
#   'time_zone': 'Indian/Comoro',
#   'city_code': 'AJN',
#   'country': 'KM'},
#  {'code': 'AJR',
#   'name': 'Arvidsjaur Airport',
#   'latitude': 65.59139,
#   'longitude': 19.285557,
#   'time_zone': 'Europe/Stockholm',
#   'city_code': 'AJR',
#   'country': 'SE'},
#  {'code': 'AJS',
#   'name': 'Abreojos',
#   'latitude': 26.833332,
#   'longitude': -113.666664,
#   'time_zone': 'America/Mazatlan',
#   'city_code': 'AJS',
#   'country': 'MX'},
#  {'code': 'AJU',
#   'name': 'Aracaju Airport',
#   'latitude': -10.987206,
#   'longitude': -37.072792,
#   'time_zone': 'America/Maceio',
#   'city_code': 'AJU',
#   'country': 'BR'},
#  {'code': 'AJY',
#   'name': 'Agades',
#   'latitude': 16.964167,
#   'longitude': 7.993056,
#   'time_zone': 'Africa/Niamey',
#   'city_code': 'AJY',
#   'country': 'NE'},
#  {'code': 'AKA',
#   'name': 'Ankang',
#   'latitude': 32.7091,
#   'longitude': 108.936,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'AKA',
#   'country': 'CN'},
#  {'code': 'AKB',
#   'name': 'Atka',
#   'latitude': 52.21722,
#   'longitude': -174.20084,
#   'time_zone': 'America/Adak',
#   'city_code': 'AKB',
#   'country': 'US'},
#  {'code': 'AKC',
#   'name': 'Fulton International',
#   'latitude': 41.04,
#   'longitude': -81.46778,
#   'time_zone': 'America/New_York',
#   'city_code': 'CAK',
#   'country': 'US'},
#  {'code': 'AKD',
#   'name': 'Akola',
#   'latitude': 20.666668,
#   'longitude': 77.083336,
#   'time_zone': 'Asia/Kolkata',
#   'city_code': 'AKD',
#   'country': 'IN'},
#  {'code': 'AKE',
#   'name': 'Akieni',
#   'latitude': -1.172222,
#   'longitude': 13.916667,
#   'time_zone': 'Africa/Libreville',
#   'city_code': 'AKE',
#   'country': 'GA'},
#  {'code': 'AKF',
#   'name': 'Kufrah',
#   'latitude': 24.2,
#   'longitude': 23.333332,
#   'time_zone': 'Africa/Tripoli',
#   'city_code': 'AKF',
#   'country': 'LY'},
#  {'code': 'AKG',
#   'name': 'Anguganak',
#   'latitude': -3.633333,
#   'longitude': 142.01666,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AKG',
#   'country': 'PG'},
#  {'code': 'AKH',
#   'name': 'Prince Sultan Air Base',
#   'latitude': 24.063334,
#   'longitude': 47.580555,
#   'time_zone': 'Asia/Riyadh',
#   'city_code': 'AKH',
#   'country': 'SA'},
#  {'code': 'AKI',
#   'name': 'Akiak',
#   'latitude': 60.905556,
#   'longitude': -161.22333,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'AKI',
#   'country': 'US'},
#  {'code': 'AKJ',
#   'name': 'Asahikawa Airport',
#   'latitude': 43.67109,
#   'longitude': 142.45454,
#   'time_zone': 'Asia/Tokyo',
#   'city_code': 'AKJ',
#   'country': 'JP'},
#  {'code': 'AKK',
#   'name': 'Akhiok SPB',
#   'latitude': 56.944443,
#   'longitude': -154.16667,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'AKK',
#   'country': 'US'},
#  {'code': 'AKL',
#   'name': 'Auckland Airport',
#   'latitude': -37.004787,
#   'longitude': 174.78352,
#   'time_zone': 'Pacific/Auckland',
#   'city_code': 'AKL',
#   'country': 'NZ'},
#  {'code': 'AKM',
#   'name': 'Zakouma',
#   'latitude': 10.883333,
#   'longitude': 19.816668,
#   'time_zone': 'Africa/Ndjamena',
#   'city_code': 'AKM',
#   'country': 'TD'},
#  {'code': 'AKN',
#   'name': 'King Salmon Airport',
#   'latitude': 58.68274,
#   'longitude': -156.66902,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'AKN',
#   'country': 'US'},
#  {'code': 'AKO',
#   'name': 'Colorado Plains Regional Airport',
#   'latitude': 40.166668,
#   'longitude': -103.21667,
#   'time_zone': 'America/Denver',
#   'city_code': 'AKO',
#   'country': 'US'},
#  {'code': 'AKP',
#   'name': 'Anaktuvuk',
#   'latitude': 68.1375,
#   'longitude': -151.74,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'AKP',
#   'country': 'US'},
#  {'code': 'AKQ',
#   'name': 'Gunung Batin',
#   'latitude': -4.616667,
#   'longitude': 105.23333,
#   'time_zone': 'Asia/Jakarta',
#   'city_code': 'AKQ',
#   'country': 'ID'},
#  {'code': 'AKR',
#   'name': 'Akure',
#   'latitude': 7.25,
#   'longitude': 5.083333,
#   'time_zone': 'Africa/Lagos',
#   'city_code': 'AKR',
#   'country': 'NG'},
#  {'code': 'AKS',
#   'name': "Gwaunaru'u",
#   'latitude': -8.697778,
#   'longitude': 160.68083,
#   'time_zone': 'Pacific/Guadalcanal',
#   'city_code': 'AKS',
#   'country': 'SB'},
#  {'code': 'AKT',
#   'name': 'Raf Akrotiri',
#   'latitude': 34.583332,
#   'longitude': 32.983334,
#   'time_zone': 'Asia/Nicosia',
#   'city_code': 'AKT',
#   'country': 'CY'},
#  {'code': 'AKU',
#   'name': 'Aksu Airport',
#   'latitude': 41.259983,
#   'longitude': 80.29262,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'AKU',
#   'country': 'CN'},
#  {'code': 'AKV',
#   'name': 'Akulivik',
#   'latitude': 60.733334,
#   'longitude': -78.583336,
#   'time_zone': 'America/Montreal',
#   'city_code': 'AKV',
#   'country': 'CA'},
#  {'code': 'AKW',
#   'name': 'Aghajari',
#   'latitude': 30.75,
#   'longitude': 49.683334,
#   'time_zone': 'Asia/Tehran',
#   'city_code': 'AKW',
#   'country': 'IR'},
#  {'code': 'AKX',
#   'name': 'Aktyubinsk Airport',
#   'latitude': 50.249336,
#   'longitude': 57.211403,
#   'time_zone': 'Asia/Aqtobe',
#   'city_code': 'AKX',
#   'country': 'KZ'},
#  {'code': 'AKY',
#   'name': 'Civil Airport',
#   'latitude': 20.130278,
#   'longitude': 92.88028,
#   'time_zone': 'Asia/Rangoon',
#   'city_code': 'AKY',
#   'country': 'MM'},
#  {'code': 'ALA',
#   'name': 'Almaty Airport',
#   'latitude': 43.346653,
#   'longitude': 77.01145,
#   'time_zone': 'Asia/Almaty',
#   'city_code': 'ALA',
#   'country': 'KZ'},
#  {'code': 'ALB',
#   'name': 'Albany International Airport',
#   'latitude': 42.745277,
#   'longitude': -73.809555,
#   'time_zone': 'America/New_York',
#   'city_code': 'ALB',
#   'country': 'US'},
#  {'code': 'ALC',
#   'name': 'Alicante-Elche Airport',
#   'latitude': 38.287098,
#   'longitude': -0.557381,
#   'time_zone': 'Europe/Madrid',
#   'city_code': 'ALC',
#   'country': 'ES'},
#  {'code': 'ALD',
#   'name': 'Alerta',
#   'latitude': -11.683333,
#   'longitude': -69.333336,
#   'time_zone': 'America/Lima',
#   'city_code': 'ALD',
#   'country': 'PE'},
#  {'code': 'ALE',
#   'name': 'Alpine',
#   'latitude': 30.416668,
#   'longitude': -103.75,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ALE',
#   'country': 'US'},
#  {'code': 'ALF',
#   'name': 'Alta Airport',
#   'latitude': 69.977165,
#   'longitude': 23.355808,
#   'time_zone': 'Europe/Oslo',
#   'city_code': 'ALF',
#   'country': 'NO'},
#  {'code': 'ALG',
#   'name': 'Houari Boumediene Airport',
#   'latitude': 36.70058,
#   'longitude': 3.21167,
#   'time_zone': 'Africa/Algiers',
#   'city_code': 'ALG',
#   'country': 'DZ'},
#  {'code': 'ALH',
#   'name': 'Albany Airport',
#   'latitude': -34.944996,
#   'longitude': 117.804,
#   'time_zone': 'Australia/Perth',
#   'city_code': 'ALH',
#   'country': 'AU'},
#  {'code': 'ALI',
#   'name': 'International',
#   'latitude': 27.75,
#   'longitude': -98.066666,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ALI',
#   'country': 'US'},
#  {'code': 'ALJ',
#   'name': 'Kortdoorn',
#   'latitude': -28.567223,
#   'longitude': 16.536388,
#   'time_zone': 'Africa/Johannesburg',
#   'city_code': 'ALJ',
#   'country': 'ZA'},
#  {'code': 'ALK',
#   'name': 'Asela',
#   'latitude': 7.966667,
#   'longitude': 39.11667,
#   'time_zone': 'Africa/Addis_Ababa',
#   'city_code': 'ALK',
#   'country': 'ET'},
#  {'code': 'ALL',
#   'name': 'Albenga',
#   'latitude': 44.05,
#   'longitude': 8.216667,
#   'time_zone': 'Europe/Rome',
#   'city_code': 'ALL',
#   'country': 'IT'},
#  {'code': 'ALM',
#   'name': 'Municipal',
#   'latitude': 32.845833,
#   'longitude': -105.985275,
#   'time_zone': 'America/Denver',
#   'city_code': 'ALM',
#   'country': 'US'},
#  {'code': 'ALN',
#   'name': 'Alton',
#   'latitude': 38.891666,
#   'longitude': -90.04833,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ALN',
#   'country': 'US'},
#  {'code': 'ALO',
#   'name': 'Waterloo Airport',
#   'latitude': 42.55611,
#   'longitude': -92.39972,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ALO',
#   'country': 'US'},
#  {'code': 'ALP',
#   'name': 'Nejrab',
#   'latitude': 36.185352,
#   'longitude': 37.227074,
#   'time_zone': 'Asia/Damascus',
#   'city_code': 'ALP',
#   'country': 'SY'},
#  {'code': 'ALQ',
#   'name': 'Federal',
#   'latitude': -29.799723,
#   'longitude': -55.763332,
#   'time_zone': 'America/Sao_Paulo',
#   'city_code': 'ALQ',
#   'country': 'BR'},
#  {'code': 'ALR',
#   'name': 'Alexandra',
#   'latitude': -45.21389,
#   'longitude': 169.36945,
#   'time_zone': 'Pacific/Auckland',
#   'city_code': 'ALR',
#   'country': 'NZ'},
#  {'code': 'ALS',
#   'name': 'Alamosa Municipal Airport',
#   'latitude': 37.43667,
#   'longitude': -105.86667,
#   'time_zone': 'America/Denver',
#   'city_code': 'ALS',
#   'country': 'US'},
#  {'code': 'ALT',
#   'name': 'Alenquer',
#   'latitude': -1.933333,
#   'longitude': -54.766666,
#   'time_zone': 'America/Santarem',
#   'city_code': 'ALT',
#   'country': 'BR'},
#  {'code': 'ALU',
#   'name': 'Alula',
#   'latitude': 11.966667,
#   'longitude': 50.8,
#   'time_zone': 'Africa/Mogadishu',
#   'city_code': 'ALU',
#   'country': 'SO'},
#  {'code': 'ALW',
#   'name': 'Walla Walla Airport',
#   'latitude': 46.094723,
#   'longitude': -118.291115,
#   'time_zone': 'America/Los_Angeles',
#   'city_code': 'ALW',
#   'country': 'US'},
#  {'code': 'ALX',
#   'name': 'Thomas C Russell Field',
#   'latitude': 32.933334,
#   'longitude': -85.95,
#   'time_zone': 'America/Chicago',
#   'city_code': 'ALX',
#   'country': 'US'},
#  {'code': 'ALY',
#   'name': 'El Nohza',
#   'latitude': 31.192545,
#   'longitude': 29.953058,
#   'time_zone': 'Africa/Cairo',
#   'city_code': 'ALY',
#   'country': 'EG'},
#  {'code': 'ALZ',
#   'name': 'Alitak SPB',
#   'latitude': 56.895832,
#   'longitude': -154.24583,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'ALZ',
#   'country': 'US'},
#  {'code': 'AMA',
#   'name': 'Rick Husband Amarillo International Airport',
#   'latitude': 35.218273,
#   'longitude': -101.70513,
#   'time_zone': 'America/Chicago',
#   'city_code': 'AMA',
#   'country': 'US'},
#  {'code': 'AMB',
#   'name': 'Ambilobe',
#   'latitude': -13.183333,
#   'longitude': 48.983334,
#   'time_zone': 'Indian/Antananarivo',
#   'city_code': 'AMB',
#   'country': 'MG'},
#  {'code': 'AMC',
#   'name': 'Am Timan',
#   'latitude': 11.033333,
#   'longitude': 20.283333,
#   'time_zone': 'Africa/Ndjamena',
#   'city_code': 'AMC',
#   'country': 'TD'},
#  {'code': 'AMD',
#   'name': 'Ahmedabad Airport',
#   'latitude': 23.06639,
#   'longitude': 72.62417,
#   'time_zone': 'Asia/Kolkata',
#   'city_code': 'AMD',
#   'country': 'IN'},
#  {'code': 'AME',
#   'name': 'Alto Molocue',
#   'latitude': -15.833333,
#   'longitude': 37.583332,
#   'time_zone': 'Africa/Maputo',
#   'city_code': 'AME',
#   'country': 'MZ'},
#  {'code': 'AMF',
#   'name': 'Ama',
#   'latitude': -4.166667,
#   'longitude': 141.66667,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AMF',
#   'country': 'PG'},
#  {'code': 'AMG',
#   'name': 'Amboin',
#   'latitude': -4.616667,
#   'longitude': 143.7,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AMG',
#   'country': 'PG'},
#  {'code': 'AMH',
#   'name': 'Arba Mintch Airport',
#   'latitude': 6.036111,
#   'longitude': 37.576942,
#   'time_zone': 'Africa/Addis_Ababa',
#   'city_code': 'AMH',
#   'country': 'ET'},
#  {'code': 'AMI',
#   'name': 'Selaparang',
#   'latitude': -8.563165,
#   'longitude': 116.10237,
#   'time_zone': 'Asia/Makassar',
#   'city_code': 'AMI',
#   'country': 'ID'},
#  {'code': 'AMJ',
#   'name': 'Almenara',
#   'latitude': -16.183332,
#   'longitude': -40.683334,
#   'time_zone': 'America/Sao_Paulo',
#   'city_code': 'AMJ',
#   'country': 'BR'},
#  {'code': 'AMK',
#   'name': 'Animas Airpark',
#   'latitude': 37.15,
#   'longitude': -107.75,
#   'time_zone': 'America/Denver',
#   'city_code': 'DRO',
#   'country': 'US'},
#  {'code': 'AML',
#   'name': 'Puerto Armuellas',
#   'latitude': 8.266667,
#   'longitude': -82.86667,
#   'time_zone': 'America/Panama',
#   'city_code': 'AML',
#   'country': 'PA'},
#  {'code': 'AMM',
#   'name': 'Queen Alia International Airport',
#   'latitude': 31.722534,
#   'longitude': 35.98932,
#   'time_zone': 'Asia/Amman',
#   'city_code': 'AMM',
#   'country': 'JO'},
#  {'code': 'AMN',
#   'name': 'Gratiot Community',
#   'latitude': 43.38333,
#   'longitude': -84.65,
#   'time_zone': 'America/Detroit',
#   'city_code': 'AMN',
#   'country': 'US'},
#  {'code': 'AMO',
#   'name': 'Mao',
#   'latitude': 14.116667,
#   'longitude': 15.316667,
#   'time_zone': 'Africa/Ndjamena',
#   'city_code': 'AMO',
#   'country': 'TD'},
#  {'code': 'AMP',
#   'name': 'Ampanihy',
#   'latitude': -24.7,
#   'longitude': 44.733334,
#   'time_zone': 'Indian/Antananarivo',
#   'city_code': 'AMP',
#   'country': 'MG'},
#  {'code': 'AMQ',
#   'name': 'Pattimura Airport',
#   'latitude': -3.704996,
#   'longitude': 128.08888,
#   'time_zone': 'Asia/Jayapura',
#   'city_code': 'AMQ',
#   'country': 'ID'},
#  {'code': 'AMR',
#   'name': 'Arno',
#   'latitude': 7.033333,
#   'longitude': 171.23334,
#   'time_zone': 'Europe/Madrid',
#   'city_code': 'AMR',
#   'country': 'ES'},
#  {'code': 'AMS',
#   'name': 'Amsterdam Airport Schiphol',
#   'latitude': 52.30907,
#   'longitude': 4.763385,
#   'time_zone': 'Europe/Amsterdam',
#   'city_code': 'AMS',
#   'country': 'NL'},
#  {'code': 'AMT',
#   'name': 'Amata',
#   'latitude': -26.766666,
#   'longitude': 132.03334,
#   'time_zone': 'Australia/Adelaide',
#   'city_code': 'AMT',
#   'country': 'AU'},
#  {'code': 'AMU',
#   'name': 'Amanab',
#   'latitude': -3.516667,
#   'longitude': 141.15,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'AMU',
#   'country': 'PG'},
#  {'code': 'AMV',
#   'name': 'Amderma',
#   'latitude': 69.76667,
#   'longitude': 61.55,
#   'time_zone': 'Europe/Moscow',
#   'city_code': 'AMV',
#   'country': 'RU'},
#  {'code': 'AMW',
#   'name': 'Ames',
#   'latitude': 41.994167,
#   'longitude': -93.61833,
#   'time_zone': 'America/Chicago',
# ...
#   'country': 'FR'},
#  {'code': 'BOE',
#   'name': 'Boundji',
#   'latitude': -1.033333,
#   'longitude': 15.383333,
#   'time_zone': 'Africa/Brazzaville',
#   'city_code': 'BOE',
#   'country': 'CG'},
#  {'code': 'BOF',
#   'name': 'Bolling AFB',
#   'latitude': 38.9,
#   'longitude': -77.03333,
#   'time_zone': 'America/New_York',
#   'city_code': 'WAS',
#   'country': 'US'},
#  {'code': 'BOG',
#   'name': 'El Dorado International Airport',
#   'latitude': 4.698602,
#   'longitude': -74.143135,
#   'time_zone': 'America/Bogota',
#   'city_code': 'BOG',
#   'country': 'CO'},
#  {'code': 'BOH',
#   'name': 'Bournemouth Airport',
#   'latitude': 50.77827,
#   'longitude': -1.832476,
#   'time_zone': 'Europe/London',
#   'city_code': 'BOH',
#   'country': 'GB'},
#  {'code': 'BOI',
#   'name': 'Boise Air Terminal (Gowen Field)',
#   'latitude': 43.569263,
#   'longitude': -116.22193,
#   'time_zone': 'America/Boise',
#   'city_code': 'BOI',
#   'country': 'US'},
#  {'code': 'BOJ',
#   'name': 'Bourgas Airport',
#   'latitude': 42.416668,
#   'longitude': 27.283333,
#   'time_zone': 'Europe/Sofia',
#   'city_code': 'BOJ',
#   'country': 'BG'},
#  {'code': 'BOK',
#   'name': 'Brookings State',
#   'latitude': 42.05,
#   'longitude': -124.28333,
#   'time_zone': 'America/Los_Angeles',
#   'city_code': 'BOK',
#   'country': 'US'},
#  {'code': 'BOL',
#   'name': 'Ballykelly',
#   'latitude': 55.0,
#   'longitude': -7.0,
#   'time_zone': 'Europe/London',
#   'city_code': 'BOL',
#   'country': 'GB'},
#  {'code': 'BOM',
#   'name': 'Chhatrapati Shivaji International Airport',
#   'latitude': 19.095509,
#   'longitude': 72.87497,
#   'time_zone': 'Asia/Kolkata',
#   'city_code': 'BOM',
#   'country': 'IN'},
#  {'code': 'BON',
#   'name': 'Flamingo International Airport',
#   'latitude': 12.133403,
#   'longitude': -68.27687,
#   'time_zone': 'America/Kralendijk',
#   'city_code': 'BON',
#   'country': 'BQ'},
#  {'code': 'BOO',
#   'name': 'Bodo Airport',
#   'latitude': 67.27262,
#   'longitude': 14.367839,
#   'time_zone': 'Europe/Oslo',
#   'city_code': 'BOO',
#   'country': 'NO'},
#  {'code': 'BOP',
#   'name': 'Bouar',
#   'latitude': 6.0,
#   'longitude': 15.666667,
#   'time_zone': 'Africa/Bangui',
#   'city_code': 'BOP',
#   'country': 'CF'},
#  {'code': 'BOQ',
#   'name': 'Boku',
#   'latitude': -6.533333,
#   'longitude': 155.35,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BOQ',
#   'country': 'PG'},
#  {'code': 'BOS',
#   'name': 'Logan International Airport',
#   'latitude': 42.36646,
#   'longitude': -71.02018,
#   'time_zone': 'America/New_York',
#   'city_code': 'BOS',
#   'country': 'US'},
#  {'code': 'BOT',
#   'name': 'Boset',
#   'latitude': -7.233333,
#   'longitude': 141.08333,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BOT',
#   'country': 'PG'},
#  {'code': 'BOU',
#   'name': 'Bourges',
#   'latitude': 47.15,
#   'longitude': 2.416667,
#   'time_zone': 'Europe/Paris',
#   'city_code': 'BOU',
#   'country': 'FR'},
#  {'code': 'BOV',
#   'name': 'Boang',
#   'latitude': -3.366667,
#   'longitude': 153.33333,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BOV',
#   'country': 'PG'},
#  {'code': 'BOW',
#   'name': 'Bartow',
#   'latitude': 27.9,
#   'longitude': -81.833336,
#   'time_zone': 'America/New_York',
#   'city_code': 'BOW',
#   'country': 'US'},
#  {'code': 'BOX',
#   'name': 'Borroloola',
#   'latitude': -16.066668,
#   'longitude': 136.28334,
#   'time_zone': 'Australia/Darwin',
#   'city_code': 'BOX',
#   'country': 'AU'},
#  {'code': 'BOY',
#   'name': 'Borgo',
#   'latitude': 11.163611,
#   'longitude': -4.324444,
#   'time_zone': 'Africa/Ouagadougou',
#   'city_code': 'BOY',
#   'country': 'BF'},
#  {'code': 'BOZ',
#   'name': 'Bozoum',
#   'latitude': 6.416667,
#   'longitude': 16.583332,
#   'time_zone': 'Africa/Bangui',
#   'city_code': 'BOZ',
#   'country': 'CF'},
#  {'code': 'BPA',
#   'name': 'Grumman',
#   'latitude': 40.733334,
#   'longitude': -73.48333,
#   'time_zone': 'America/New_York',
#   'city_code': 'BPA',
#   'country': 'US'},
#  {'code': 'BPB',
#   'name': 'Boridi',
#   'latitude': -9.133333,
#   'longitude': 147.53334,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BPB',
#   'country': 'PG'},
#  {'code': 'BPC',
#   'name': 'Bamenda',
#   'latitude': 5.916667,
#   'longitude': 10.15,
#   'time_zone': 'Africa/Douala',
#   'city_code': 'BPC',
#   'country': 'CM'},
#  {'code': 'BPD',
#   'name': 'Bapi',
#   'latitude': -7.75,
#   'longitude': 147.01666,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BPD',
#   'country': 'PG'},
#  {'code': 'BPE',
#   'name': 'Qinhuangdao Beidaihe Airport',
#   'latitude': 24.0,
#   'longitude': 96.0,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'SHP',
#   'country': 'CN'},
#  {'code': 'BPF',
#   'name': 'Batuna Aerodrome',
#   'latitude': -8.55,
#   'longitude': 158.11667,
#   'time_zone': 'Pacific/Guadalcanal',
#   'city_code': 'BPF',
#   'country': 'SB'},
#  {'code': 'BPG',
#   'name': 'Barra Do Garcas',
#   'latitude': -15.85,
#   'longitude': -52.38333,
#   'time_zone': 'America/Cuiaba',
#   'city_code': 'BPG',
#   'country': 'BR'},
#  {'code': 'BPH',
#   'name': 'Bislig',
#   'latitude': 8.196667,
#   'longitude': 126.32111,
#   'time_zone': 'Asia/Manila',
#   'city_code': 'BPH',
#   'country': 'PH'},
#  {'code': 'BPI',
#   'name': 'Big Piney-marbleton',
#   'latitude': 42.533333,
#   'longitude': -110.11667,
#   'time_zone': 'America/Denver',
#   'city_code': 'BPI',
#   'country': 'US'},
#  {'code': 'BPK',
#   'name': 'Biangabip',
#   'latitude': -5.529722,
#   'longitude': 141.74973,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BPK',
#   'country': 'PG'},
#  {'code': 'BPL',
#   'name': 'Bole Airport',
#   'latitude': 44.904232,
#   'longitude': 82.024185,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'BPL',
#   'country': 'CN'},
#  {'code': 'BPM',
#   'name': 'Begumpet',
#   'latitude': 17.449114,
#   'longitude': 78.47183,
#   'time_zone': 'Asia/Kolkata',
#   'city_code': 'HYD',
#   'country': 'IN'},
#  {'code': 'BPN',
#   'name': 'Sultan Aji Muhamad Sulaiman Airport',
#   'latitude': -1.260623,
#   'longitude': 116.90082,
#   'time_zone': 'Asia/Makassar',
#   'city_code': 'BPN',
#   'country': 'ID'},
#  {'code': 'BPO',
#   'name': "Bo'ao Railway Station",
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'BPO',
#   'country': 'CN'},
#  {'code': 'BPS',
#   'name': 'Porto Seguro Airport',
#   'latitude': -16.441158,
#   'longitude': -39.081097,
#   'time_zone': 'America/Bahia',
#   'city_code': 'BPS',
#   'country': 'BR'},
#  {'code': 'BPT',
#   'name': 'Jefferson County Airport',
#   'latitude': 29.950832,
#   'longitude': -94.02,
#   'time_zone': 'America/Chicago',
#   'city_code': 'BPT',
#   'country': 'US'},
#  {'code': 'BPU',
#   'name': 'Beppu',
#   'latitude': 33.25,
#   'longitude': 131.5,
#   'time_zone': 'Asia/Tokyo',
#   'city_code': 'BPU',
#   'country': 'JP'},
#  {'code': 'BPX',
#   'name': 'Bangda Airport',
#   'latitude': 30.555834,
#   'longitude': 97.10667,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'BPX',
#   'country': 'CN'},
#  {'code': 'BPY',
#   'name': 'Besalampy',
#   'latitude': -16.75,
#   'longitude': 44.483334,
#   'time_zone': 'Indian/Antananarivo',
#   'city_code': 'BPY',
#   'country': 'MG'},
#  {'code': 'BQA',
#   'name': 'Baler',
#   'latitude': 15.0,
#   'longitude': 121.083336,
#   'time_zone': 'Asia/Manila',
#   'city_code': 'BQA',
#   'country': 'PH'},
#  {'code': 'BQB',
#   'name': 'Bussellton',
#   'latitude': -33.716667,
#   'longitude': 115.25,
#   'time_zone': 'Australia/Perth',
#   'city_code': 'BQB',
#   'country': 'AU'},
#  {'code': 'BQD',
#   'name': 'Brindisi Railway Station',
#   'latitude': 40.6361753,
#   'longitude': 17.9389909,
#   'time_zone': 'Europe/Rome',
#   'city_code': 'BDS',
#   'country': 'IT'},
#  {'code': 'BQE',
#   'name': 'Bubaque',
#   'latitude': 11.3,
#   'longitude': -15.85,
#   'time_zone': 'Africa/Bissau',
#   'city_code': 'BQE',
#   'country': 'GW'},
#  {'code': 'BQG',
#   'name': 'Bogorodskoye',
#   'latitude': 52.378334,
#   'longitude': 140.44833,
#   'time_zone': 'Asia/Vladivostok',
#   'city_code': 'BQG',
#   'country': 'RU'},
#  {'code': 'BQH',
#   'name': 'Biggin Hill',
#   'latitude': 51.333332,
#   'longitude': 0.033333,
#   'time_zone': 'Europe/London',
#   'city_code': 'LON',
#   'country': 'GB'},
#  {'code': 'BQI',
#   'name': 'Bagani',
#   'latitude': -18.118055,
#   'longitude': 21.629723,
#   'time_zone': 'Africa/Windhoek',
#   'city_code': 'BQI',
#   'country': 'NA'},
#  {'code': 'BQJ',
#   'name': 'Batagay',
#   'latitude': 67.655,
#   'longitude': 134.641667,
#   'time_zone': 'Asia/Vladivostok',
#   'city_code': 'BQJ',
#   'country': 'RU'},
#  {'code': 'BQK',
#   'name': 'Glynco Jetport',
#   'latitude': 31.166668,
#   'longitude': -81.48333,
#   'time_zone': 'America/New_York',
#   'city_code': 'SSI',
#   'country': 'US'},
#  {'code': 'BQL',
#   'name': 'Boulia',
#   'latitude': -22.9,
#   'longitude': 139.9,
#   'time_zone': 'Australia/Brisbane',
#   'city_code': 'BQL',
#   'country': 'AU'},
#  {'code': 'BQN',
#   'name': 'Rafael Hernandez Airport',
#   'latitude': 18.495832,
#   'longitude': -67.13,
#   'time_zone': 'America/Puerto_Rico',
#   'city_code': 'BQN',
#   'country': 'PR'},
#  {'code': 'BQO',
#   'name': 'Bouna',
#   'latitude': 9.266667,
#   'longitude': -3.0,
#   'time_zone': 'Africa/Abidjan',
#   'city_code': 'BQO',
#   'country': 'CI'},
#  {'code': 'BQQ',
#   'name': 'Barra',
#   'latitude': -11.083333,
#   'longitude': -43.13333,
#   'time_zone': 'America/Bahia',
#   'city_code': 'BQQ',
#   'country': 'BR'},
#  {'code': 'BQS',
#   'name': 'Blagoveschensk Airport',
#   'latitude': 50.416668,
#   'longitude': 127.4,
#   'time_zone': 'Asia/Yakutsk',
#   'city_code': 'BQS',
#   'country': 'RU'},
#  {'code': 'BQT',
#   'name': 'Brest Airport',
#   'latitude': 52.11667,
#   'longitude': 23.883333,
#   'time_zone': 'Europe/Minsk',
#   'city_code': 'BQT',
#   'country': 'BY'},
#  {'code': 'BQU',
#   'name': 'J. F. Mitchell',
#   'latitude': 12.986667,
#   'longitude': -61.264168,
#   'time_zone': 'America/St_Vincent',
#   'city_code': 'BQU',
#   'country': 'VC'},
#  {'code': 'BQV',
#   'name': 'Bartlett SPB',
#   'latitude': 58.416668,
#   'longitude': -135.73334,
#   'time_zone': 'America/Juneau',
#   'city_code': 'GST',
#   'country': 'US'},
#  {'code': 'BQW',
#   'name': 'Balgo Hills',
#   'latitude': -20.183332,
#   'longitude': 127.8,
#   'time_zone': 'Australia/Perth',
#   'city_code': 'BQW',
#   'country': 'AU'},
#  {'code': 'BRA',
#   'name': 'Barreiras Airport',
#   'latitude': -12.073056,
#   'longitude': -45.00833,
#   'time_zone': 'America/Bahia',
#   'city_code': 'BRA',
#   'country': 'BR'},
#  {'code': 'BRB',
#   'name': 'Barreirinhas',
#   'latitude': -2.910626,
#   'longitude': -57.11111,
#   'time_zone': 'America/Fortaleza',
#   'city_code': 'BRB',
#   'country': 'BR'},
#  {'code': 'BRC',
#   'name': 'San Carlos de Bariloche International Airport',
#   'latitude': -41.145966,
#   'longitude': -71.16109,
#   'time_zone': 'America/Argentina/Salta',
#   'city_code': 'BRC',
#   'country': 'AR'},
#  {'code': 'BRD',
#   'name': 'Crow Wing County Airport',
#   'latitude': 46.39722,
#   'longitude': -94.1375,
#   'time_zone': 'America/Chicago',
#   'city_code': 'BRD',
#   'country': 'US'},
#  {'code': 'BRE',
#   'name': 'Bremen Airport',
#   'latitude': 53.05297,
#   'longitude': 8.785352,
#   'time_zone': 'Europe/Berlin',
#   'city_code': 'BRE',
#   'country': 'DE'},
#  {'code': 'BRF',
#   'name': 'Bradford',
#   'latitude': 53.8,
#   'longitude': -1.75,
#   'time_zone': 'Europe/London',
#   'city_code': 'LBA',
#   'country': 'GB'},
#  {'code': 'BRG',
#   'name': 'Municipal',
#   'latitude': 37.11667,
#   'longitude': -82.833336,
#   'time_zone': 'America/New_York',
#   'city_code': 'BRG',
#   'country': 'US'},
#  {'code': 'BRH',
#   'name': 'Brahman',
#   'latitude': -5.7,
#   'longitude': 145.36667,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BRH',
#   'country': 'PG'},
#  {'code': 'BRI',
#   'name': 'Palese Airport',
#   'latitude': 41.13388,
#   'longitude': 16.76391,
#   'time_zone': 'Europe/Rome',
#   'city_code': 'BRI',
#   'country': 'IT'},
#  {'code': 'BRJ',
#   'name': 'Bright',
#   'latitude': -36.7,
#   'longitude': 146.93333,
#   'time_zone': 'Australia/Melbourne',
#   'city_code': 'BRJ',
#   'country': 'AU'},
#  {'code': 'BRK',
#   'name': 'Bourke',
#   'latitude': -30.083332,
#   'longitude': 145.93333,
#   'time_zone': 'Australia/Sydney',
#   'city_code': 'BRK',
#   'country': 'AU'},
#  {'code': 'BRL',
#   'name': 'Burlington Airport',
#   'latitude': 40.78611,
#   'longitude': -91.12334,
#   'time_zone': 'America/Chicago',
#   'city_code': 'BRL',
#   'country': 'US'},
#  {'code': 'BRM',
#   'name': 'Barquisimeto Airport',
#   'latitude': 10.046267,
#   'longitude': -69.35984,
#   'time_zone': 'America/Caracas',
#   'city_code': 'BRM',
#   'country': 'VE'},
#  {'code': 'BRN',
#   'name': 'Bern Airport',
#   'latitude': 46.911728,
#   'longitude': 7.50356,
#   'time_zone': 'Europe/Zurich',
#   'city_code': 'BRN',
#   'country': 'CH'},
#  {'code': 'BRO',
#   'name': 'South Padre Island International Airport',
#   'latitude': 25.90889,
#   'longitude': -97.42333,
#   'time_zone': 'America/Chicago',
#   'city_code': 'BRO',
#   'country': 'US'},
#  {'code': 'BRP',
#   'name': 'Biaru',
#   'latitude': -7.533333,
#   'longitude': 146.7,
#   'time_zone': 'Pacific/Port_Moresby',
#   'city_code': 'BRP',
#   'country': 'PG'},
#  {'code': 'BRQ',
#   'name': 'Turany Airport',
#   'latitude': 49.15,
#   'longitude': 16.7,
#   'time_zone': 'Europe/Prague',
#   'city_code': 'BRQ',
#   'country': 'CZ'},
#  {'code': 'BRR',
#   'name': 'North Bay Airport',
#   'latitude': 57.023335,
#   'longitude': -7.440278,
#   'time_zone': 'Europe/London',
#   'city_code': 'BRR',
#   'country': 'GB'},
#  {'code': 'BRS',
#   'name': 'Bristol Airport',
#   'latitude': 51.386757,
#   'longitude': -2.710659,
#   'time_zone': 'Europe/London',
#   'city_code': 'BRS',
#   'country': 'GB'},
#  {'code': 'BRT',
#   'name': 'Bathurst Island',
#   'latitude': -11.766667,
#   'longitude': 130.63333,
#   'time_zone': 'Australia/Darwin',
#   'city_code': 'BRT',
#   'country': 'AU'},
#  {'code': 'BRU',
#   'name': 'Brussels Airport',
#   'latitude': 50.89717,
#   'longitude': 4.483602,
#   'time_zone': 'Europe/Brussels',
#   'city_code': 'BRU',
#   'country': 'BE'},
#  {'code': 'BRV',
#   'name': 'Bremerhaven',
#   'latitude': 53.75,
#   'longitude': 8.916667,
#   'time_zone': 'Europe/Berlin',
#   'city_code': 'BRV',
#   'country': 'DE'},
#  {'code': 'BRW',
#   'name': 'Wiley Post-Will Rogers Memorial Airport',
#   'latitude': 71.288574,
#   'longitude': -156.77579,
#   'time_zone': 'America/Anchorage',
#   'city_code': 'BRW',
#   'country': 'US'},
#  {'code': 'BRX',
#   'name': 'Barahona',
#   'latitude': 18.216667,
#   'longitude': -71.11667,
#   'time_zone': 'America/Santo_Domingo',
#   'city_code': 'BRX',
#   'country': 'DO'},
#  {'code': 'BRY',
#   'name': 'Samuels Field',
#   'latitude': 37.816666,
#   'longitude': -85.46667,
#   'time_zone': 'America/New_York',
#   'city_code': 'BRY',
#   'country': 'US'},
#  {'code': 'BRZ',
#   'name': 'Borotou',
#   'latitude': 8.766667,
#   'longitude': -7.5,
#   'time_zone': 'Europe/Rome',
#   'city_code': 'BRZ',
#   'country': 'IT'},
#  {'code': 'BSA',
#   'name': 'Bossaso',
#   'latitude': 11.283333,
#   'longitude': 49.15,
#   'time_zone': 'Africa/Mogadishu',
#   'city_code': 'BSA',
#   'country': 'SO'},
#  {'code': 'BSB',
#   'name': 'Brasilia International Airport',
#   'latitude': -15.869807,
#   'longitude': -47.921486,
#   'time_zone': 'America/Sao_Paulo',
#   'city_code': 'BSB',
#   'country': 'BR'},
#  {'code': 'BSC',
#   'name': 'Bahia Solano',
#   'latitude': 6.183333,
#   'longitude': -77.4,
#   'time_zone': 'America/Bogota',
#   'city_code': 'BSC',
#   'country': 'CO'},
#  {'code': 'BSD',
#   'name': 'Baoshan Airport',
#   'latitude': 25.055182,
#   'longitude': 99.16143,
#   'time_zone': 'Asia/Shanghai',
#   'city_code': 'BSD',
#   'country': 'CN'},
#  {'code': 'BSE',
#   'name': 'Sematan',
#   'latitude': 1.8,
#   'longitude': 109.76667,
#   'time_zone': 'Asia/Kuching',
#   'city_code': 'BSE',
#   'country': 'MY'},
#  {'code': 'BSF',
#   'name': 'Bradshaw AAF',
#   'latitude': 21.383333,
#   'longitude': -157.75,
#   'time_zone': 'Pacific/Honolulu',
#   'city_code': 'BSF',
#   'country': 'US'},
#  {'code': 'BSG',
#   'name': 'Bata Airport',
#   'latitude': 1.906667,
#   'longitude': 9.802222,
#   'time_zone': 'Africa/Malabo',
#   'city_code': 'BSG',
#   'country': 'GQ'},
#  {'code': 'BSH',
#   'name': 'Brighton',
#   'latitude': 50.816666,
#   'longitude': -0.116667,
#   'time_zone': 'Europe/London',
#   'city_code': 'BSH',
#   'country': 'GB'},
#  {'code': 'BSI',
#   'name': 'Blairsville',
#   'latitude': 40.45,
#   'longitude': -79.28333,
#   'time_zone': 'America/New_York',
#   'city_code': 'BSI',
#   'country': 'US'},
#  {'code': 'BSJ',
#   'name': 'Bairnsdale',
#   'latitude': -37.833332,
#   'longitude': 147.63333,
#   'time_zone': 'Australia/Melbourne',
#   'city_code': 'BSJ',
#   'country': 'AU'},
#  ...]

# %%
class rapid_Location_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://location-api.p.rapidapi.com/api/countries"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def CountryList(self):
        
        self.search_url = self.base_url

        self.response = requests.get(self.search_url,headers=self.headers)
        print(self.response.url)
        return self.response.json()
    
    def getCountryListdetails(self,jsonObj):
        
        return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_Location_Api(credentials['rapidapi_key'],credentials['rapidapi_host5'])
    v = app.CountryList()
    CountryList = app.getCountryListdetails(v)

# %%
CountryList
# Out:
# {'message': 'Endpoint/api/countries does not exist'}

# %%
class rapid_IATACodes_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://iatacodes-iatacodes-v1.p.rapidapi.com/api/v5/airports"
        self.base_url1 = "https://iatacodes-iatacodes-v1.p.rapidapi.com/api/v5/cities"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def browse_airports(self,api_key):
        self.api_key = api_key
        
        self.search_url = self.base_url
        
        self.params = {
            'api_key' : "{}".format(self.api_key)            
            }

        self.response = requests.get(self.search_url,headers=self.headers,params=self.params)
        print(self.response.url)
        return self.response.json()
    
    def browse_cities(self,api_key):
        self.api_key = api_key
        
        self.search_url1 = self.base_url1
        
        self.params = {
            'api_key' : "{}".format(self.api_key)            
            }

        self.response = requests.get(self.search_url1,headers=self.headers,params=self.params)
        print(self.response.url)
        return self.response.json()
    
    
    def getAirportsdetails(self,jsonObj):
        
        return jsonObj
    
    def getCitydetails(self,jsonObj):
        
        return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_IATACodes_Api(credentials['rapidapi_key'],credentials['rapidapi_host6'])
    v = app.browse_airports('4f382d39-3b81-47c4-8d1c-278d4a441b9a')
    AirportList = app.getAirportsdetails(v)
# Out:
# https://iatacodes-iatacodes-v1.p.rapidapi.com/api/v5/airports?api_key=4f382d39-3b81-47c4-8d1c-278d4a441b9a

# %%
AirportList
# Out:
# {'request': {'lang': 'en',
#   'currency': 'USD',
#   'time': 47,
#   'id': 1605697114558,
#   'server': 'production',
#   'host': 'airlabs.co',
#   'pid': 6230,
#   'key': {'id': 16859,
#    'api_key': '4f382d39-3b81-47c4-8d1c-278d4a441b9a',
#    'type': 'free',
#    'trial_price': None,
#    'expired': None,
#    'registered': '2020-11-18T03:56:42.000Z',
#    'limits_by_hour': 2500,
#    'limits_by_minute': 250,
#    'demo_methods': [],
#    'usage_by_hour': 4,
#    'usage_by_minute': 1},
#   'params': {'lang': 'en'},
#   'version': 5,
#   'method': 'airports',
#   'client': {'country_code': 'IN',
#    'country': 'India',
#    'city': 'Hyderabad',
#    'lat': 17.3753,
#    'lng': 78.4744,
#    'ip': '49.206.52.196',
#    'device': {'type': 'phone'},
#    'agent': {'browser': 'unknown', 'os': 'unknown', 'platform': 'unknown'}}},
#  'response': [{'code': 'AAA', 'name': 'Anaa'},
#   {'code': 'AAB', 'name': 'Arrabury'},
#   {'code': 'AAC', 'name': 'El Arish International Airport'},
#   {'code': 'AAE', 'name': 'Les Salines'},
#   {'code': 'AAF', 'name': 'Apalachicola Regional'},
#   {'code': 'AAG', 'name': 'Arapoti'},
#   {'code': 'AAH', 'name': 'Aachen/Merzbruck'},
#   {'code': 'AAI', 'name': 'Arraias'},
#   {'code': 'AAJ', 'name': 'Cayana Airstrip'},
#   {'code': 'AAK', 'name': 'Aranuka'},
#   {'code': 'AAL', 'name': 'Aalborg'},
#   {'code': 'AAM', 'name': 'Mala Mala'},
#   {'code': 'AAN', 'name': 'Al Ain'},
#   {'code': 'AAO', 'name': 'Anaco'},
#   {'code': 'AAQ', 'name': 'Anapa'},
#   {'code': 'AAR', 'name': 'Aarhus Airport'},
#   {'code': 'AAS', 'name': 'Apalapsili'},
#   {'code': 'AAT', 'name': 'Altay'},
#   {'code': 'AAU', 'name': 'Asau'},
#   {'code': 'AAV', 'name': 'Allah Valley'},
#   {'code': 'AAW', 'name': 'Abbottabad'},
#   {'code': 'AAX', 'name': 'Araxa'},
#   {'code': 'AAY', 'name': 'Al Ghaydah'},
#   {'code': 'AAZ', 'name': 'Quetzaltenango'},
#   {'code': 'ABA', 'name': 'Abakan'},
#   {'code': 'ABB', 'name': 'RAF Station'},
#   {'code': 'ABC', 'name': 'Los Llanos'},
#   {'code': 'ABD', 'name': 'Abadan'},
#   {'code': 'ABE', 'name': 'Lehigh Valley International'},
#   {'code': 'ABF', 'name': 'Abaiang'},
#   {'code': 'ABG', 'name': 'Abingdon'},
#   {'code': 'ABH', 'name': 'Alpha'},
#   {'code': 'ABI', 'name': 'Municipal'},
#   {'code': 'ABJ', 'name': 'Felix Houphouet Boigny'},
#   {'code': 'ABK', 'name': 'Kabri Dar'},
#   {'code': 'ABL', 'name': 'Ambler'},
#   {'code': 'ABM', 'name': 'Bamaga Injinoo'},
#   {'code': 'ABN', 'name': 'Albina'},
#   {'code': 'ABO', 'name': 'Aboisso'},
#   {'code': 'ABP', 'name': 'Atkamba'},
#   {'code': 'ABQ', 'name': 'Albuquerque International'},
#   {'code': 'ABR', 'name': 'Municipal'},
#   {'code': 'ABS', 'name': 'Abu Simbel'},
#   {'code': 'ABT', 'name': 'Al-Aqiq'},
#   {'code': 'ABU', 'name': 'Atambua'},
#   {'code': 'ABV', 'name': 'Nnamdi Azikiwe International Airport'},
#   {'code': 'ABW', 'name': 'Abau'},
#   {'code': 'ABX', 'name': 'Albury'},
#   {'code': 'ABY', 'name': 'Dougherty County'},
#   {'code': 'ABZ', 'name': 'Dyce'},
#   {'code': 'ACA', 'name': 'General Juan N. Alvarez International'},
#   {'code': 'ACB', 'name': 'Antrim County'},
#   {'code': 'ACC', 'name': 'Kotoka'},
#   {'code': 'ACD', 'name': 'Acandi'},
#   {'code': 'ACE', 'name': 'Lanzarote'},
#   {'code': 'ACH', 'name': 'Altenrhein'},
#   {'code': 'ACI', 'name': 'The Blaye'},
#   {'code': 'ACJ', 'name': 'Anuradhapura'},
#   {'code': 'ACK', 'name': 'Nantucket Memorial'},
#   {'code': 'ACL', 'name': 'Aguaclara'},
#   {'code': 'ACM', 'name': 'Arica'},
#   {'code': 'ACN', 'name': 'International'},
#   {'code': 'ACP', 'name': 'Sahand'},
#   {'code': 'ACR', 'name': 'Araracuara'},
#   {'code': 'ACS', 'name': 'Achinsk'},
#   {'code': 'ACT', 'name': 'Municipal'},
#   {'code': 'ACU', 'name': 'Achutupo'},
#   {'code': 'ACV', 'name': 'Arcata'},
#   {'code': 'ACX', 'name': 'Xingyi'},
#   {'code': 'ACY', 'name': 'Atlantic City International'},
#   {'code': 'ACZ', 'name': 'Zabol Airport'},
#   {'code': 'ADA', 'name': 'Adana'},
#   {'code': 'ADB', 'name': 'Adnan Menderes Airport'},
#   {'code': 'ADC', 'name': 'Andakombe'},
#   {'code': 'ADD', 'name': 'Bole International'},
#   {'code': 'ADE', 'name': 'International'},
#   {'code': 'ADF', 'name': 'Adiyaman'},
#   {'code': 'ADG', 'name': 'Lenawee County'},
#   {'code': 'ADH', 'name': 'Aldan'},
#   {'code': 'ADI', 'name': 'Arandis'},
#   {'code': 'ADJ', 'name': 'Marka International Airport'},
#   {'code': 'ADK', 'name': 'Adak Island Ns'},
#   {'code': 'ADL', 'name': 'Adelaide International Airport'},
#   {'code': 'ADM', 'name': 'Ardmore Municipal Airport'},
#   {'code': 'ADN', 'name': 'Andes'},
#   {'code': 'ADO', 'name': 'Andamooka'},
#   {'code': 'ADP', 'name': 'Ampara'},
#   {'code': 'ADQ', 'name': 'Kodiak Airport'},
#   {'code': 'ADR', 'name': 'Andrews'},
#   {'code': 'ADS', 'name': 'Addison Airport'},
#   {'code': 'ADT', 'name': 'Ada Municipal'},
#   {'code': 'ADU', 'name': 'Ardabil'},
#   {'code': 'ADW', 'name': 'Andrews AFB'},
#   {'code': 'ADX', 'name': 'Leuchars'},
#   {'code': 'ADY', 'name': 'Alldays'},
#   {'code': 'ADZ', 'name': 'San Andres Island'},
#   {'code': 'AEA', 'name': 'Abemama Atoll'},
#   {'code': 'AEB', 'name': 'Youjiang'},
#   {'code': 'AED', 'name': 'Aleneva'},
#   {'code': 'AEE', 'name': 'Adareil'},
#   {'code': 'AEG', 'name': 'Aek Godang'},
#   {'code': 'AEH', 'name': 'Abéché'},
#   {'code': 'AEI', 'name': 'Algeciras'},
#   {'code': 'AEK', 'name': 'Aseki'},
#   {'code': 'AEL', 'name': 'Albert Lea'},
#   {'code': 'AEO', 'name': 'Aioun El Atrouss'},
#   {'code': 'AEP', 'name': 'Aeroparque Jorge Newbery'},
#   {'code': 'AER', 'name': 'Sochi/Adler International Airport'},
#   {'code': 'AES', 'name': 'Vigra'},
#   {'code': 'AET', 'name': 'Allakaket'},
#   {'code': 'AEU', 'name': 'Abu Musa'},
#   {'code': 'AEX', 'name': 'Alexandria International'},
#   {'code': 'AEY', 'name': 'Akureyri'},
#   {'code': 'AFA', 'name': 'San Rafael'},
#   {'code': 'AFD', 'name': 'Port Alfred'},
#   {'code': 'AFF', 'name': 'USAF Academy Airstrip'},
#   {'code': 'AFI', 'name': 'Amalfi'},
#   {'code': 'AFK', 'name': 'Kondavattavan Tank'},
#   {'code': 'AFL', 'name': 'Alta Floresta'},
#   {'code': 'AFN', 'name': 'Municipal'},
#   {'code': 'AFO', 'name': 'Municipal'},
#   {'code': 'AFR', 'name': 'Afore'},
#   {'code': 'AFS', 'name': 'Zarafshan'},
#   {'code': 'AFT', 'name': 'Afutara Aerodrome'},
#   {'code': 'AFW', 'name': 'Fort Worth Alliance'},
#   {'code': 'AFY', 'name': 'Afyon'},
#   {'code': 'AFZ', 'name': 'Sabzevar'},
#   {'code': 'AGA', 'name': 'Agadir Almassira'},
#   {'code': 'AGB', 'name': 'Augsburg - Muehlhausen'},
#   {'code': 'AGC', 'name': 'Allegheny County'},
#   {'code': 'AGD', 'name': 'Anggi'},
#   {'code': 'AGE', 'name': 'Flugplatz'},
#   {'code': 'AGF', 'name': 'La Garenne'},
#   {'code': 'AGG', 'name': 'Angoram'},
#   {'code': 'AGH', 'name': 'Angelholm'},
#   {'code': 'AGI', 'name': 'Wageningen'},
#   {'code': 'AGJ', 'name': 'Aguni'},
#   {'code': 'AGK', 'name': 'Kagua'},
#   {'code': 'AGL', 'name': 'Wanigela'},
#   {'code': 'AGM', 'name': 'Tasiilaq'},
#   {'code': 'AGN', 'name': 'Angoon'},
#   {'code': 'AGO', 'name': 'Municipal'},
#   {'code': 'AGP', 'name': 'Pablo Ruiz Picasso'},
#   {'code': 'AGR', 'name': 'Kheria'},
#   {'code': 'AGS', 'name': 'Bush Field'},
#   {'code': 'AGT', 'name': 'Alejo Garcia'},
#   {'code': 'AGU', 'name': 'Aguascalients'},
#   {'code': 'AGV', 'name': 'Acarigua'},
#   {'code': 'AGW', 'name': 'Agnew'},
#   {'code': 'AGX', 'name': 'Agatti Island'},
#   {'code': 'AGZ', 'name': 'Aggeneys'},
#   {'code': 'AHA', 'name': 'Naha AFB'},
#   {'code': 'AHB', 'name': 'Abha'},
#   {'code': 'AHC', 'name': 'Amedee AAF'},
#   {'code': 'AHD', 'name': 'Downtown'},
#   {'code': 'AHE', 'name': 'Ahe Airport'},
#   {'code': 'AHF', 'name': 'Municipal'},
#   {'code': 'AHH', 'name': 'Municipal'},
#   {'code': 'AHI', 'name': 'Amahai'},
#   {'code': 'AHL', 'name': 'Aishalton'},
#   {'code': 'AHM', 'name': 'Sumner Parker Field'},
#   {'code': 'AHN', 'name': 'Athens-Ben Epps'},
#   {'code': 'AHO', 'name': 'Fertilia'},
#   {'code': 'AHS', 'name': 'Ahuas'},
#   {'code': 'AHU', 'name': 'Charif Al Idrissi'},
#   {'code': 'AHW', 'name': 'Saih Rawl'},
#   {'code': 'AHY', 'name': 'Ambatolahy'},
#   {'code': 'AHZ', 'name': 'Alpe D Huez'},
#   {'code': 'AIA', 'name': 'Alliance'},
#   {'code': 'AIB', 'name': 'Anita Bay'},
#   {'code': 'AIC', 'name': 'Airok'},
#   {'code': 'AID', 'name': 'Municipal'},
#   {'code': 'AIE', 'name': 'Aiome'},
#   {'code': 'AIF', 'name': 'Assis'},
#   {'code': 'AIG', 'name': 'Yalinga'},
#   {'code': 'AIH', 'name': 'Aiambak'},
#   {'code': 'AII', 'name': 'Alisabieh'},
#   {'code': 'AIK', 'name': 'Municipal'},
#   {'code': 'AIL', 'name': 'Ailigandi'},
#   {'code': 'AIM', 'name': 'Ailuk Island'},
#   {'code': 'AIN', 'name': 'Wainwright'},
#   {'code': 'AIO', 'name': 'Municipal'},
#   {'code': 'AIP', 'name': 'Ailinglapalap Island'},
#   {'code': 'AIR', 'name': 'Aripuana'},
#   {'code': 'AIS', 'name': 'Arorae Island'},
#   {'code': 'AIT', 'name': 'Aitutaki'},
#   {'code': 'AIU', 'name': 'Atiu Island'},
#   {'code': 'AIV', 'name': 'George Downer'},
#   {'code': 'AIW', 'name': 'Ai-ais'},
#   {'code': 'AIZ', 'name': 'Lee C Fine Memorial'},
#   {'code': 'AJA', 'name': 'Campo Dell Oro'},
#   {'code': 'AJF', 'name': 'Jouf'},
#   {'code': 'AJI', 'name': 'Agri'},
#   {'code': 'AJJ', 'name': 'Akjoujt'},
#   {'code': 'AJK', 'name': 'Araak'},
#   {'code': 'AJL', 'name': 'Aizawl'},
#   {'code': 'AJN', 'name': 'Ouani'},
#   {'code': 'AJR', 'name': 'Arvidsjaur'},
#   {'code': 'AJS', 'name': 'Abreojos'},
#   {'code': 'AJU', 'name': 'Santa Maria'},
#   {'code': 'AJY', 'name': 'Agades'},
#   {'code': 'AKA', 'name': 'Ankang'},
#   {'code': 'AKB', 'name': 'Atka'},
#   {'code': 'AKC', 'name': 'Fulton International'},
#   {'code': 'AKD', 'name': 'Akola'},
#   {'code': 'AKE', 'name': 'Akieni'},
#   {'code': 'AKF', 'name': 'Kufrah'},
#   {'code': 'AKG', 'name': 'Anguganak'},
#   {'code': 'AKH', 'name': 'Prince Sultan Air Base'},
#   {'code': 'AKI', 'name': 'Akiak'},
#   {'code': 'AKJ', 'name': 'Asahikawa'},
#   {'code': 'AKK', 'name': 'Akhiok SPB'},
#   {'code': 'AKL', 'name': 'Auckland International'},
#   {'code': 'AKM', 'name': 'Zakouma'},
#   {'code': 'AKN', 'name': 'King Salmon'},
#   {'code': 'AKO', 'name': 'Colorado Plains Regional Airport'},
#   {'code': 'AKP', 'name': 'Anaktuvuk'},
#   {'code': 'AKQ', 'name': 'Gunung Batin'},
#   {'code': 'AKR', 'name': 'Akure'},
#   {'code': 'AKS', 'name': "Gwaunaru'u"},
#   {'code': 'AKT', 'name': 'Raf Akrotiri'},
#   {'code': 'AKU', 'name': 'Aksu'},
#   {'code': 'AKV', 'name': 'Akulivik'},
#   {'code': 'AKW', 'name': 'Aghajari'},
#   {'code': 'AKX', 'name': 'Aktyubinsk'},
#   {'code': 'AKY', 'name': 'Civil'},
#   {'code': 'ALA', 'name': 'Almaty'},
#   {'code': 'ALB', 'name': 'Albany International'},
#   {'code': 'ALC', 'name': 'Alicante El Altet'},
#   {'code': 'ALD', 'name': 'Alerta'},
#   {'code': 'ALE', 'name': 'Alpine'},
#   {'code': 'ALF', 'name': 'Alta'},
#   {'code': 'ALG', 'name': 'Houari Boumediene'},
#   {'code': 'ALH', 'name': 'Albany'},
#   {'code': 'ALI', 'name': 'International'},
#   {'code': 'ALJ', 'name': 'Kortdoorn'},
#   {'code': 'ALK', 'name': 'Asela'},
#   {'code': 'ALL', 'name': 'Albenga'},
#   {'code': 'ALM', 'name': 'Municipal'},
#   {'code': 'ALN', 'name': 'Alton'},
#   {'code': 'ALO', 'name': 'Waterloo'},
#   {'code': 'ALP', 'name': 'Nejrab'},
#   {'code': 'ALQ', 'name': 'Federal'},
#   {'code': 'ALR', 'name': 'Alexandra'},
#   {'code': 'ALS', 'name': 'Municipal'},
#   {'code': 'ALT', 'name': 'Alenquer'},
#   {'code': 'ALU', 'name': 'Alula'},
#   {'code': 'ALW', 'name': 'Walla Walla'},
#   {'code': 'ALX', 'name': 'Thomas C Russell Field'},
#   {'code': 'ALY', 'name': 'El Nohza'},
#   {'code': 'ALZ', 'name': 'Alitak SPB'},
#   {'code': 'AMA', 'name': 'Rick Husband Amarillo International'},
#   {'code': 'AMB', 'name': 'Ambilobe'},
#   {'code': 'AMC', 'name': 'Am Timan'},
#   {'code': 'AMD', 'name': 'Ahmedabad'},
#   {'code': 'AME', 'name': 'Alto Molocue'},
#   {'code': 'AMF', 'name': 'Ama'},
#   {'code': 'AMG', 'name': 'Amboin'},
#   {'code': 'AMH', 'name': 'Arba Mintch'},
#   {'code': 'AMJ', 'name': 'Almenara'},
#   {'code': 'AMK', 'name': 'Animas Airpark'},
#   {'code': 'AMM', 'name': 'Queen Alia International'},
#   {'code': 'AMN', 'name': 'Gratiot Community'},
#   {'code': 'AMO', 'name': 'Mao'},
#   {'code': 'AMP', 'name': 'Ampanihy'},
#   {'code': 'AMQ', 'name': 'Pattimura'},
#   {'code': 'AMR', 'name': 'Arno'},
#   {'code': 'AMS', 'name': 'Schiphol'},
#   {'code': 'AMT', 'name': 'Amata'},
#   {'code': 'AMU', 'name': 'Amanab'},
#   {'code': 'AMV', 'name': 'Amderma'},
#   {'code': 'AMW', 'name': 'Ames'},
#   {'code': 'AMX', 'name': 'Ammaroo'},
#   {'code': 'AMY', 'name': 'Ambatomainty'},
#   {'code': 'AMZ', 'name': 'Ardmore'},
#   {'code': 'ANA', 'name': 'John Wayne International'},
#   {'code': 'ANB', 'name': 'Anniston Metropolitan'},
#   {'code': 'ANC', 'name': 'Ted Stevens Anchorage International Airport'},
#   {'code': 'AND', 'name': 'Anderson'},
#   {'code': 'ANE', 'name': 'Marce'},
#   {'code': 'ANF', 'name': 'Cerro Moreno'},
#   {'code': 'ANG', 'name': 'Brie-Champniers'},
#   {'code': 'ANI', 'name': 'Aniak'},
#   {'code': 'ANJ', 'name': 'Zanaga'},
#   {'code': 'ANK', 'name': 'Etimesgut'},
#   {'code': 'ANL', 'name': 'Andulo'},
#   {'code': 'ANM', 'name': 'Antsirabato'},
#   {'code': 'ANN', 'name': 'Annette Island'},
#   {'code': 'ANO', 'name': 'Angoche'},
#   {'code': 'ANP', 'name': 'Lee'},
#   {'code': 'ANQ', 'name': 'Tri-State Steuben County'},
#   {'code': 'ANR', 'name': 'Deurne/ Antwerp Airport'},
#   {'code': 'ANS', 'name': 'Andahuaylas'},
#   {'code': 'ANT', 'name': 'St Anton'},
#   {'code': 'ANU', 'name': 'V. C. Bird International'},
#   {'code': 'ANV', 'name': 'Anvik'},
#   {'code': 'ANW', 'name': 'Ainsworth'},
#   {'code': 'ANX', 'name': 'Andøya Lufthavn, Andenes'},
#   {'code': 'ANY', 'name': 'Anthony'},
#   {'code': 'ANZ', 'name': 'Angus Downs'},
#   {'code': 'AOB', 'name': 'Annanberg'},
#   {'code': 'AOC', 'name': 'Altenburg Nobitz'},
#   {'code': 'AOD', 'name': 'Abou Deia'},
#   {'code': 'AOE', 'name': 'Anadolu University'},
#   {'code': 'AOG', 'name': 'Anshan'},
#   {'code': 'AOH', 'name': 'Allen County'},
#   {'code': 'AOI', 'name': 'Falconara'},
#   {'code': 'AOJ', 'name': 'Aomori'},
#   {'code': 'AOK', 'name': 'Karpathos'},
#   {'code': 'AOL', 'name': 'Paso De Los Libres'},
#   {'code': 'AOM', 'name': 'Adam'},
#   {'code': 'AON', 'name': 'Arona'},
#   {'code': 'AOO', 'name': 'Martinsburg'},
#   {'code': 'AOP', 'name': 'Andoas'},
#   {'code': 'AOR', 'name': 'Alor Setar'},
#   {'code': 'AOS', 'name': 'Amook'},
#   {'code': 'AOT', 'name': 'Corrado Gex'},
#   {'code': 'AOU', 'name': 'Attopeu'},
#   {'code': 'APA', 'name': 'Arapahoe Co'},
#   {'code': 'APB', 'name': 'Apolo'},
#   {'code': 'APC', 'name': 'Napa County'},
#   {'code': 'APE', 'name': 'San Juan Aposento'},
#   {'code': 'APF', 'name': 'Naples'},
#   {'code': 'APG', 'name': 'Phillips AAF'},
#   {'code': 'APH', 'name': 'Camp A P Hill'},
#   {'code': 'API', 'name': 'Apiay'},
#   {'code': 'APK', 'name': 'Apataki'},
#   {'code': 'APL', 'name': 'Nampula'},
#   {'code': 'APN', 'name': 'Alpena County Regional'},
#   {'code': 'APO', 'name': 'Apartado'},
#   {'code': 'APP', 'name': 'Asapa'},
#   {'code': 'APQ', 'name': 'Arapiraca'},
#   {'code': 'APR', 'name': 'April River'},
#   {'code': 'APS', 'name': 'Anapolis'},
#   {'code': 'APT', 'name': 'Marion County'},
#   {'code': 'APU', 'name': 'Apucarana'},
#   {'code': 'APV', 'name': 'Apple Valley'},
#   {'code': 'APW', 'name': 'Faleolo'},
#   {'code': 'APX', 'name': 'Arapongas'},
#   {'code': 'APY', 'name': 'Alto Parnaiba'},
#   {'code': 'APZ', 'name': 'Zapala'},
#   {'code': 'AQA', 'name': 'Araraquara'},
#   {'code': 'AQB', 'name': 'Quiche Airport'},
#   {'code': 'AQG', 'name': 'Anqing'},
#   {'code': 'AQI', 'name': 'Qaisumah'},
#   {'code': 'AQJ', 'name': 'King Hussein International'},
#   {'code': 'AQM', 'name': 'Ariquemes'},
#   {'code': 'AQP', 'name': 'Rodriguez Ballon'},
#   {'code': 'AQY', 'name': 'Alyeska'},
#   {'code': 'ARA', 'name': 'Acadiana Regional'},
#   {'code': 'ARB', 'name': 'Municipal'},
#   {'code': 'ARC', 'name': 'Arctic Village'},
#   {'code': 'ARD', 'name': 'Alor Island'},
#   {'code': 'ARE', 'name': 'Arecibo'},
#   {'code': 'ARF', 'name': 'Acaricuara'},
#   {'code': 'ARG', 'name': 'Walnut Ridge'},
#   {'code': 'ARH', 'name': 'Arkhangelsk'},
#   {'code': 'ARI', 'name': 'Chacalluta'},
#   {'code': 'ARJ', 'name': 'Arso'},
#   {'code': 'ARK', 'name': 'Arusha'},
#   {'code': 'ARL', 'name': 'Arly'},
#   {'code': 'ARM', 'name': 'Armidale'},
#   {'code': 'ARN', 'name': 'Arlanda'},
#   {'code': 'ARO', 'name': 'Arboletas'},
#   {'code': 'ARP', 'name': 'Aragip'},
#   {'code': 'ARQ', 'name': 'Arauquita'},
#   {'code': 'ARR', 'name': 'Alto Rio Senguerr'},
#   {'code': 'ARS', 'name': 'Aragarcas'},
#   {'code': 'ART', 'name': 'Watertown'},
#   {'code': 'ARU', 'name': 'Aracatuba'},
#   {'code': 'ARV', 'name': 'Noble F. Lee'},
#   {'code': 'ARW', 'name': 'Arad'},
#   {'code': 'ARY', 'name': 'Ararat'},
#   {'code': 'ARZ', 'name': "N'zeto"},
#   {'code': 'ASA', 'name': 'Assab International'},
#   {'code': 'ASB', 'name': 'Ashgabat'},
#   {'code': 'ASC', 'name': 'Ascension'},
#   {'code': 'ASD', 'name': 'Andros Town'},
#   {'code': 'ASE', 'name': 'Aspen'},
#   {'code': 'ASF', 'name': 'Astrakhan'},
#   {'code': 'ASG', 'name': 'Ashburton'},
#   {'code': 'ASH', 'name': 'Boire Field'},
#   {'code': 'ASI', 'name': 'Wideawake Field'},
#   {'code': 'ASJ', 'name': 'Amami'},
#   {'code': 'ASK', 'name': 'Yamoussoukro'},
#   {'code': 'ASL', 'name': 'Harrison County'},
#   {'code': 'ASM', 'name': 'Yohannes IV'},
#   {'code': 'ASN', 'name': 'Talladega'},
#   {'code': 'ASO', 'name': 'Asosa'},
#   {'code': 'ASP', 'name': 'Alice Springs'},
#   {'code': 'ASQ', 'name': 'Austin'},
#   {'code': 'ASR', 'name': 'Erkilet International Airport'},
#   {'code': 'AST', 'name': 'Astoria'},
#   {'code': 'ASU', 'name': 'Silvio Pettirossi'},
#   {'code': 'ASV', 'name': 'Amboseli'},
#   {'code': 'ASW', 'name': 'Aswan'},
#   {'code': 'ASX', 'name': 'Ashland'},
#   {'code': 'ASY', 'name': 'Ashley'},
#   {'code': 'ASZ', 'name': 'Asirim'},
#   {'code': 'ATA', 'name': 'Anta'},
#   {'code': 'ATB', 'name': 'Atbara'},
#   {'code': 'ATC', 'name': "Arthur's Town"},
#   {'code': 'ATD', 'name': 'Atoifi'},
#   {'code': 'ATE', 'name': 'Antlers'},
#   {'code': 'ATF', 'name': 'Chachoan'},
#   {'code': 'ATG', 'name': 'Attock'},
#   {'code': 'ATH',
#    'name': 'Athens International Airport "Eleftherios Venizelos"'},
#   {'code': 'ATI', 'name': 'Artigas'},
#   {'code': 'ATJ', 'name': 'Antsirabe'},
#   {'code': 'ATK', 'name': 'Atqasuk'},
#   {'code': 'ATL', 'name': 'Hartsfield-jackson Atlanta International'},
#   {'code': 'ATM', 'name': 'Altamira'},
#   {'code': 'ATN', 'name': 'Namatanai'},
#   {'code': 'ATO', 'name': 'Ohio University'},
#   {'code': 'ATP', 'name': 'Airstrip'},
#   {'code': 'ATQ', 'name': 'Raja Sansi International Airport'},
#   {'code': 'ATR', 'name': 'Mouakchott'},
#   {'code': 'ATS', 'name': 'Artesia'},
#   {'code': 'ATT', 'name': 'Atmautluak'},
#   {'code': 'ATV', 'name': 'Ati'},
#   {'code': 'ATW', 'name': 'Outagamie County'},
#   {'code': 'ATX', 'name': 'Atbasar'},
#   {'code': 'ATY', 'name': 'Watertown'},
#   {'code': 'ATZ', 'name': 'Assiut'},
#   {'code': 'AUA', 'name': 'Reina Beatrix'},
#   {'code': 'AUB', 'name': 'Itauba'},
#   {'code': 'AUC', 'name': 'Arauca'},
#   {'code': 'AUD', 'name': 'Augustus Downs'},
#   {'code': 'AUE', 'name': 'Abu Rudeis'},
#   {'code': 'AUF', 'name': 'Auxerre Branches'},
#   {'code': 'AUG', 'name': 'Augusta'},
#   {'code': 'AUH', 'name': 'Abu Dhabi International'},
#   {'code': 'AUI', 'name': 'Aua Island'},
#   {'code': 'AUJ', 'name': 'Ambunti'},
#   {'code': 'AUK', 'name': 'Alakanuk'},
#   {'code': 'AUL', 'name': 'Aur Island'},
#   {'code': 'AUM', 'name': 'Austin'},
#   {'code': 'AUN', 'name': 'Auburn'},
#   {'code': 'AUO', 'name': 'Auburn-Opelika'},
#   {'code': 'AUP', 'name': 'Agaun'},
#   {'code': 'AUQ', 'name': 'Atuona'},
#   {'code': 'AUR', 'name': 'Aurillac'},
#   {'code': 'AUS', 'name': 'Austin-bergstrom International'},
#   {'code': 'AUT', 'name': 'Atauro'},
#   {'code': 'AUU', 'name': 'Aurukun Mission'},
#   {'code': 'AUV', 'name': 'Aumo'},
#   {'code': 'AUW', 'name': 'Municipal'},
#   {'code': 'AUX', 'name': 'Araguaina'},
#   {'code': 'AUY', 'name': 'Aneityum'},
#   {'code': 'AUZ', 'name': 'Municipal Airport'},
#   {'code': 'AVA', 'name': 'An Shun/Huang Guo Shu'},
#   {'code': 'AVB', 'name': 'Aviano'},
#   {'code': 'AVG', 'name': 'Auvergne'},
#   {'code': 'AVI', 'name': 'Maximo Gomez'},
#   {'code': 'AVK', 'name': 'Arvaikheer'},
#   {'code': 'AVL', 'name': 'Asheville Regional Airport'},
#   {'code': 'AVN', 'name': 'Avignon-Caumont'},
#   {'code': 'AVO', 'name': 'Municipal'},
#   {'code': 'AVP', 'name': 'Wilkes-Barre/Scranton International Airport'},
#   {'code': 'AVU', 'name': 'Avu Avu'},
#   {'code': 'AVV', 'name': 'Avalon'},
#   {'code': 'AVW', 'name': 'Avra Valley'},
#   {'code': 'AVX', 'name': 'Avalon Bay'},
#   {'code': 'AWA', 'name': 'Awassa'},
#   {'code': 'AWB', 'name': 'Awaba'},
#   {'code': 'AWD', 'name': 'Aniwa'},
#   {'code': 'AWE', 'name': 'Alowe'},
#   {'code': 'AWK', 'name': 'Wake Island'},
#   {'code': 'AWM', 'name': 'Municipal'},
#   {'code': 'AWN', 'name': 'Alton Downs'},
#   {'code': 'AWP', 'name': 'Austral Downs'},
#   {'code': 'AWZ', 'name': 'Ahwaz'},
#   {'code': 'AXA', 'name': 'Wallblake'},
#   {'code': 'AXB', 'name': 'Alexandria Bay'},
#   {'code': 'AXC', 'name': 'Aramac'},
#   {'code': 'AXD', 'name': 'Dimokritos'},
#   {'code': 'AXE', 'name': 'Xanxere'},
#   {'code': 'AXG', 'name': 'Algona'},
#   {'code': 'AXK', 'name': 'Ataq'},
#   {'code': 'AXL', 'name': 'Alexandria'},
#   {'code': 'AXM', 'name': 'El Eden'},
#   {'code': 'AXN', 'name': 'Alexandria'},
#   {'code': 'AXP', 'name': 'Springpoint Airport'},
#   {'code': 'AXR', 'name': 'Arutua'},
#   {'code': 'AXS', 'name': 'Municipal'},
#   {'code': 'AXT', 'name': 'Akita'},
#   {'code': 'AXU', 'name': 'Axum'},
#   {'code': 'AXV', 'name': 'Neil Armstrong'},
#   {'code': 'AXX', 'name': 'Angel Fire'},
#   {'code': 'AYA', 'name': 'Ayapel'},
#   {'code': 'AYC', 'name': 'Ayacucho'},
#   {'code': 'AYD', 'name': 'Alroy Downs'},
#   {'code': 'AYG', 'name': 'Yaguara'},
#   {'code': 'AYI', 'name': 'Yari'},
#   {'code': 'AYK', 'name': 'Arkalyk'},
#   {'code': 'AYL', 'name': 'Anthony Lagoon'},
#   {'code': 'AYN', 'name': 'Anyang'},
#   {'code': 'AYO', 'name': 'Ayolas'},
#   {'code': 'AYP', 'name': 'Yanamilla'},
#   {'code': 'AYQ', 'name': 'Connellan'},
#   {'code': 'AYR', 'name': 'Ayr'},
#   {'code': 'AYS', 'name': 'Ware County'},
#   {'code': 'AYT', 'name': 'Antalya'},
#   {'code': 'AYU', 'name': 'Aiyura'},
#   {'code': 'AYW', 'name': 'Ayawasi'},
#   {'code': 'AYY', 'name': 'Arugam Bay SPB'},
#   {'code': 'AZA', 'name': 'Williams Gateway'},
#   {'code': 'AZB', 'name': 'Amazon Bay'},
#   {'code': 'AZD', 'name': 'Yazd'},
#   {'code': 'AZG', 'name': 'Apatzingan'},
#   {'code': 'AZI', 'name': 'Bateen'},
#   {'code': 'AZL', 'name': 'Fazenda Tucunare'},
#   {'code': 'AZN', 'name': 'Andizhan'},
#   {'code': 'AZO', 'name': 'Kalamazoo/Battle Creek International'},
#   {'code': 'AZP', 'name': 'Atizapan'},
#   {'code': 'AZR', 'name': 'Adrar'},
#   {'code': 'AZS', 'name': 'Samaná El Catey International'},
#   {'code': 'AZT', 'name': 'Zapatoca'},
#   {'code': 'AZZ', 'name': 'Ambriz'},
#   {'code': 'BAA', 'name': 'Bialla'},
#   {'code': 'BAB', 'name': 'Beale AFB'},
#   {'code': 'BAC', 'name': 'Barranca De Upia'},
#   {'code': 'BAD', 'name': 'Barksdale AFB'},
#   {'code': 'BAE', 'name': 'Barcelonnette'},
#   {'code': 'BAF', 'name': 'Barnes'},
#   {'code': 'BAG', 'name': 'Loakan'},
#   {'code': 'BAH', 'name': 'Bahrain International'},
#   {'code': 'BAI', 'name': 'Buenos Aires'},
#   {'code': 'BAJ', 'name': 'Bali'},
#   {'code': 'BAL', 'name': 'Batman'},
#   {'code': 'BAM', 'name': 'Lander County'},
#   {'code': 'BAN', 'name': 'Basongo'},
#   {'code': 'BAO', 'name': 'Udorn'},
#   {'code': 'BAQ', 'name': 'E Cortissoz'},
#   {'code': 'BAR', 'name': 'Baker AAF'},
#   {'code': 'BAS', 'name': 'Balalae'},
#   {'code': 'BAT', 'name': 'Airport Chafei Amsei'},
#   {'code': 'BAU', 'name': 'Bauru'},
#   {'code': 'BAV', 'name': 'Baotou'},
#   {'code': 'BAW', 'name': 'Biawonque'},
#   {'code': 'BAX', 'name': 'Barnaul'},
#   {'code': 'BAY', 'name': 'Baia Mare'},
#   {'code': 'BAZ', 'name': 'Barbelos'},
#   {'code': 'BBA', 'name': 'Teniente Vidal'},
#   {'code': 'BBB', 'name': 'Municipal'},
#   {'code': 'BBC', 'name': 'Bay City'},
#   {'code': 'BBD', 'name': 'Curtis Field'},
#   {'code': 'BBF', 'name': 'Burlington'},
#   {'code': 'BBG', 'name': 'Butaritari'},
#   {'code': 'BBH', 'name': 'Barth'},
#   {'code': 'BBI', 'name': 'Bhubaneswar'},
#   {'code': 'BBJ', 'name': 'Bitburg Air Base'},
#   {'code': 'BBK', 'name': 'Kasane'},
#   {'code': 'BBM', 'name': 'Battambang'},
#   {'code': 'BBN', 'name': 'Bario'},
#   {'code': 'BBO', 'name': 'Berbera'},
#   {'code': 'BBP', 'name': 'Bembridge'},
#   {'code': 'BBQ', 'name': 'Barbuda'},
#   {'code': 'BBR', 'name': 'Baillif'},
#   {'code': 'BBS', 'name': 'Blackbushe'},
#   {'code': 'BBT', 'name': 'Berberati'},
#   {'code': 'BBU', 'name': 'Baneasa'},
#   {'code': 'BBV', 'name': 'Hkg'},
#   {'code': 'BBW', 'name': 'Broken Bow'},
#   {'code': 'BBX', 'name': 'Wings Field'},
#   {'code': 'BBY', 'name': 'Bambari'},
#   {'code': 'BBZ', 'name': 'Zambezi'},
#   {'code': 'BCA', 'name': 'Baracoa'},
#   {'code': 'BCB', 'name': 'Virginia Tech'},
#   {'code': 'BCC', 'name': 'Bear Creek'},
#   {'code': 'BCD', 'name': 'Bacolod'},
#   {'code': 'BCE', 'name': 'Bryce'},
#   {'code': 'BCF', 'name': 'Bouca'},
#   {'code': 'BCG', 'name': 'Bemichi'},
#   {'code': 'BCH', 'name': 'Cakung International'},
#   {'code': 'BCI', 'name': 'Barcaldine'},
#   {'code': 'BCK', 'name': 'Bolwarra'},
#   {'code': 'BCL', 'name': 'Barra Colorado'},
#   {'code': 'BCM', 'name': 'Bacau'},
#   {'code': 'BCN', 'name': 'El Prat De Llobregat'},
#   {'code': 'BCO', 'name': 'Jinka'},
#   {'code': 'BCP', 'name': 'Bambu'},
#   {'code': 'BCQ', 'name': 'Brack'},
#   {'code': 'BCR', 'name': 'Boca Do Acre'},
#   {'code': 'BCS', 'name': 'Southern Seaplane'},
#   {'code': 'BCT', 'name': 'Public'},
#   {'code': 'BCU', 'name': 'Bauchi'},
#   {'code': 'BCV', 'name': 'Belmopan'},
#   {'code': 'BCW', 'name': 'Benguera Island'},
#   {'code': 'BCX', 'name': 'Beloreck'},
#   {'code': 'BCY', 'name': 'Bulchi'},
#   {'code': 'BCZ', 'name': 'Bickerton Island'},
#   {'code': 'BDA', 'name': 'L. F. Wade International'},
#   {'code': 'BDB', 'name': 'Bundaberg'},
#   {'code': 'BDC', 'name': 'Barra Do Corda'},
#   {'code': 'BDD', 'name': 'Badu Island'},
#   {'code': 'BDE', 'name': 'Baudette'},
#   {'code': 'BDF', 'name': 'Rinkenberger'},
#   {'code': 'BDG', 'name': 'Blanding'},
#   {'code': 'BDH', 'name': 'Bandar Lengeh'},
#   {'code': 'BDI', 'name': 'Bird Island'},
#   {'code': 'BDJ', 'name': 'Sjamsudin Noor'},
#   {'code': 'BDK', 'name': 'Bondoukou'},
#   {'code': 'BDL', 'name': 'Bradley International'},
#   {'code': 'BDM', 'name': 'Bandirma'},
#   {'code': 'BDN', 'name': 'Talhar'},
#   {'code': 'BDO', 'name': 'Husein Sastranegara'},
#   {'code': 'BDP', 'name': 'Bhadrapur'},
#   {'code': 'BDQ', 'name': 'Vadodara'},
#   {'code': 'BDR', 'name': 'Igor I. Sikorsky Memorial'},
#   {'code': 'BDS', 'name': 'Papola Casale'},
#   {'code': 'BDT', 'name': 'Gbadolite'},
#   {'code': 'BDU', 'name': 'Bardufoss'},
#   {'code': 'BDV', 'name': 'Moba'},
#   {'code': 'BDW', 'name': 'Bedford Downs'},
#   {'code': 'BDX', 'name': 'Broadus'},
#   {'code': 'BDY', 'name': 'State'},
#   {'code': 'BDZ', 'name': 'Baindoung'},
#   {'code': 'BEB', 'name': 'Benbecula'},
#   {'code': 'BEC', 'name': 'Beech'},
#   {'code': 'BED', 'name': 'Hanscom Field'},
#   {'code': 'BEE', 'name': 'Beagle Bay'},
#   {'code': 'BEF', 'name': 'Bluefields'},
#   {'code': 'BEG', 'name': 'Belgrade Nikola Tesla'},
#   {'code': 'BEH', 'name': 'Ross Field'},
#   {'code': 'BEI', 'name': 'Beica'},
#   {'code': 'BEJ', 'name': 'Kalimaru'},
#   {'code': 'BEK', 'name': 'Bareli'},
#   {'code': 'BEL', 'name': 'Val De Cans'},
#   {'code': 'BEN', 'name': 'Benina International'},
#   {'code': 'BEO', 'name': 'Belmont'},
#   {'code': 'BEP', 'name': 'Bellary'},
#   {'code': 'BEQ', 'name': 'Honington'},
#   {'code': 'BES', 'name': 'Brest Lesquin'},
#   {'code': 'BET', 'name': 'Bethel Airport'},
#   {'code': 'BEU', 'name': 'Bedourie'},
#   {'code': 'BEV', 'name': 'Beer Sheba'},
#   {'code': 'BEW', 'name': 'Beira'},
#   {'code': 'BEX', 'name': 'Benson (RAF Station)'},
#   {'code': 'BEY', 'name': 'Beirut Rafic Hariri Airport'},
#   {'code': 'BEZ', 'name': 'Beru'},
#   {'code': 'BFA', 'name': 'Bahia Negra'},
#   {'code': 'BFB', 'name': 'Blue Fox Bay'},
#   {'code': 'BFC', 'name': 'Bloomfield'},
#   {'code': 'BFD', 'name': 'Bradford'},
#   {'code': 'BFE', 'name': 'Bielefeld'},
#   {'code': 'BFF', 'name': 'Western Neb. Regional'},
#   {'code': 'BFG', 'name': 'Bullfrog Basin'},
#   {'code': 'BFH', 'name': 'Bacacheri'},
#   {'code': 'BFI', 'name': 'Boeing Field/King County International Airport'},
#   {'code': 'BFK', 'name': 'Buffalo Municipal Airport'},
#   {'code': 'BFL', 'name': 'Meadows Field'},
#   {'code': 'BFM', 'name': 'Mobile Downtown'},
#   {'code': 'BFN', 'name': 'Bloemfontein'},
#   {'code': 'BFO', 'name': 'Buffalo Range'},
#   {'code': 'BFP', 'name': 'Beaver Falls'},
#   {'code': 'BFQ', 'name': 'Bahia Pinas'},
#   {'code': 'BFR', 'name': 'Virgil I Grissom Municipalcipal'},
#   {'code': 'BFS', 'name': 'Aldergrove International Airport'},
#   {'code': 'BFT', 'name': 'County'},
#   {'code': 'BFU', 'name': 'Bengbu'},
#   {'code': 'BFV', 'name': 'Buri Ram'},
#   {'code': 'BFW', 'name': 'Sidi Belabbes'},
#   {'code': 'BFX', 'name': 'Bafoussam'},
#   {'code': 'BGA', 'name': 'Palo Negro'},
#   {'code': 'BGB', 'name': 'Booue'},
#   {'code': 'BGC', 'name': 'Braganca'},
#   {'code': 'BGD', 'name': 'Borger'},
#   {'code': 'BGE', 'name': 'Decatur County'},
#   {'code': 'BGF', 'name': 'Bangui'},
#   {'code': 'BGG', 'name': 'Bongouanou'},
#   {'code': 'BGH', 'name': 'Abbaye'},
#   {'code': 'BGI', 'name': 'Grantley Adams International'},
#   {'code': 'BGJ', 'name': 'Borgarfjordur Eystri'},
#   {'code': 'BGK', 'name': 'Big Creek'},
#   {'code': 'BGL', 'name': 'Baglung'},
#   {'code': 'BGM', 'name': 'Greater Binghamton'},
#   {'code': 'BGO', 'name': 'Bergen Airport, Flesland'},
#   {'code': 'BGP', 'name': 'Bongo'},
#   {'code': 'BGQ', 'name': 'Big Lake'},
#   {'code': 'BGR', 'name': 'Bangor International Airport'},
#   {'code': 'BGS', 'name': 'Webb AFB'},
#   {'code': 'BGT', 'name': 'Bagdad'},
#   {'code': 'BGU', 'name': 'Bangassou'},
#   {'code': 'BGV', 'name': 'Bento Goncalves'},
#   {'code': 'BGW', 'name': 'Baghdad International'},
#   {'code': 'BGX', 'name': 'Airport Cmdt. Gustavo Kraemer'},
#   {'code': 'BGY', 'name': 'Bergamo - Orio al Serio'},
#   {'code': 'BGZ', 'name': 'Braga'},
#   {'code': 'BHA', 'name': 'Bahia De Caraquez'},
#   {'code': 'BHB', 'name': 'Bar Harbor'},
#   {'code': 'BHC', 'name': 'Bhurban Heliport'},
#   {'code': 'BHD', 'name': 'George Best Belfast City'},
#   {'code': 'BHE', 'name': 'Woodbourne Air Station'},
#   {'code': 'BHF', 'name': 'Bahia Cupica'},
#   {'code': 'BHG', 'name': 'Brus Laguna'},
#   {'code': 'BHH', 'name': 'Bisha'},
#   {'code': 'BHI', 'name': 'Comandante Espora'},
#   {'code': 'BHJ', 'name': 'Rudra Mata'},
#   {'code': 'BHK', 'name': 'Bukhara'},
#   {'code': 'BHL', 'name': 'Bahia Angeles'},
#   {'code': 'BHM', 'name': 'Birmingham'},
#   {'code': 'BHN', 'name': 'Beihan'},
#   {'code': 'BHO', 'name': 'Bhopal'},
#   {'code': 'BHP', 'name': 'Bhojpur'},
#   {'code': 'BHQ', 'name': 'Broken Hill'},
#   {'code': 'BHR', 'name': 'Bharatpur Airport'},
#   {'code': 'BHS', 'name': 'Raglan'},
#   {'code': 'BHT', 'name': 'Brighton Downs'},
#   {'code': 'BHU', 'name': 'Bhavnagar'},
#   {'code': 'BHV', 'name': 'Bahawalpur'},
#   {'code': 'BHW', 'name': 'Bhagatanwala Airport'},
#   {'code': 'BHX', 'name': 'Birmingham International Airport'},
#   {'code': 'BHY', 'name': 'Beihai'},
#   {'code': 'BIA', 'name': 'Poretta'},
#   {'code': 'BIB', 'name': 'Baidoa'},
#   {'code': 'BIC', 'name': 'Big Creek'},
#   {'code': 'BID', 'name': 'Block Island'},
#   {'code': 'BIE', 'name': 'Beatrice'},
#   {'code': 'BIF', 'name': 'Biggs AAF'},
#   {'code': 'BIG', 'name': 'Intermediate Field'},
#   {'code': 'BIH', 'name': 'Bishop'},
#   {'code': 'BII', 'name': 'Enyu Airfield'},
#   {'code': 'BIK', 'name': 'Frans Kaisepo'},
#   {'code': 'BIL', 'name': 'Billings'},
#   {'code': 'BIM', 'name': 'International'},
#   {'code': 'BIN', 'name': 'Bamiyan'},
#   {'code': 'BIO', 'name': 'Bilbao'},
#   {'code': 'BIP', 'name': 'Bulimba'},
#   {'code': 'BIQ', 'name': 'Biarritz Parme'},
#   {'code': 'BIR', 'name': 'Biratnagar'},
#   {'code': 'BIS', 'name': 'Bismarck'},
#   {'code': 'BIT', 'name': 'Baitadi'},
#   {'code': 'BIU', 'name': 'Bildudalur'},
#   {'code': 'BIV', 'name': 'Bria'},
#   {'code': 'BIW', 'name': 'Billiluna'},
#   {'code': 'BIX', 'name': 'Keesler AFB'},
#   {'code': 'BIY', 'name': 'Bisho'},
#   {'code': 'BJA', 'name': 'Bejaia'},
#   {'code': 'BJB', 'name': 'Bojnord'},
#   {'code': 'BJC', 'name': 'Jeffco'},
#   {'code': 'BJD', 'name': 'Bakkafjordur'},
#   {'code': 'BJE', 'name': 'Baleela'},
#   {'code': 'BJF', 'name': 'Batsfjord'},
#   {'code': 'BJG', 'name': 'Bolaang'},
#   {'code': 'BJH', 'name': 'Bajhang'},
#   {'code': 'BJI', 'name': 'Bemidji'},
#   {'code': 'BJJ', 'name': 'Wayne County'},
#   {'code': 'BJK', 'name': 'Benjina'},
#   {'code': 'BJL', 'name': 'Yundum International'},
#   {'code': 'BJM', 'name': 'International'},
#   {'code': 'BJN', 'name': 'Bajone'},
#   {'code': 'BJO', 'name': 'Bermejo'},
#   {'code': 'BJP', 'name': 'Braganca Paulista'},
#   {'code': 'BJQ', 'name': 'Bahja'},
#   {'code': 'BJR', 'name': 'Bahar Dar'},
#   {'code': 'BJT', 'name': 'Bentota River'},
#   {'code': 'BJU', 'name': 'Bajura Airport'},
#   {'code': 'BJV', 'name': 'Milas'},
#   {'code': 'BJW', 'name': 'Bajawa'},
#   {'code': 'BJX', 'name': 'Del Bajío International'},
#   {'code': 'BJY', 'name': 'Batajnica'},
#   {'code': 'BJZ', 'name': 'Talaveral La Real'},
#   {'code': 'BKB', 'name': 'Bikaner'},
#   {'code': 'BKC', 'name': 'Buckland'},
#   {'code': 'BKD', 'name': 'Stephens County'},
#   {'code': 'BKE', 'name': 'Baker'},
#   {'code': 'BKF', 'name': 'Lake Brooks SPB'},
#   {'code': 'BKG', 'name': 'Branson'},
#   {'code': 'BKH', 'name': 'Barking Sands PMRF'},
#   {'code': 'BKI', 'name': 'Kota-Kinabalu International Airport'},
#   {'code': 'BKJ', 'name': 'Boke'},
#   {'code': 'BKK', 'name': 'Suvarnabhumi International'},
#   {'code': 'BKL', 'name': 'Burke Lakefront'},
#   {'code': 'BKM', 'name': 'Bakalalan'},
#   {'code': 'BKO', 'name': 'Bamako'},
#   {'code': 'BKP', 'name': 'Barkly Downs'},
#   {'code': 'BKQ', 'name': 'Blackall'},
#   {'code': 'BKR', 'name': 'Bokoro'},
#   {'code': 'BKS', 'name': 'Padangkemiling'},
#   {'code': 'BKT', 'name': 'Blackstone AAF'},
#   {'code': 'BKU', 'name': 'Betioky'},
#   {'code': 'BKW', 'name': 'Beckley'},
#   {'code': 'BKX', 'name': 'Brookings'},
#   {'code': 'BKY', 'name': 'Kavumu'},
#   {'code': 'BKZ', 'name': 'Bukoba'},
#   {'code': 'BLA', 'name': 'Gen J A Anzoategui'},
#   {'code': 'BLB', 'name': 'Balboa'},
#   {'code': 'BLC', 'name': 'Bamenda'},
#   {'code': 'BLD', 'name': 'Boulder City'},
#   {'code': 'BLE', 'name': 'Dala Airport'},
#   {'code': 'BLF', 'name': 'Princeton'},
#   {'code': 'BLG', 'name': 'Belaga'},
#   {'code': 'BLH', 'name': 'Blythe'},
#   {'code': 'BLI', 'name': 'Bellingham'},
#   {'code': 'BLJ', 'name': 'Batna'},
#   {'code': 'BLK', 'name': 'Blackpool Airport'},
#   {'code': 'BLL', 'name': 'Billund'},
#   {'code': 'BLM', 'name': 'Monmouth Executive Airport'},
#   {'code': 'BLN', 'name': 'Benalla'},
#   {'code': 'BLO', 'name': 'Blonduos'},
#   {'code': 'BLP', 'name': 'Bellavista'},
#   {'code': 'BLQ', 'name': 'Guglielmo Marconi'},
#   {'code': 'BLR', 'name': 'Bangalore International Airport'},
#   {'code': 'BLS', 'name': 'Bollon'},
#   {'code': 'BLT', 'name': 'Blackwater'},
#   {'code': 'BLU', 'name': 'Blue Canyon'},
#   {'code': 'BLV', 'name': 'Belleville'},
#   {'code': 'BLX', 'name': 'Belluno'},
#   {'code': 'BLY', 'name': 'Belmullet'},
#   {'code': 'BLZ', 'name': 'Chileka'},
#   {'code': 'BMA', 'name': 'Bromma'},
#   {'code': 'BMB', 'name': 'Bumba'},
#   {'code': 'BMC', 'name': 'Brigham City'},
#   {'code': 'BMD', 'name': 'Belo'},
#   {'code': 'BME', 'name': 'Broome'},
#   {'code': 'BMF', 'name': 'Bakouma'},
#   {'code': 'BMG', 'name': 'Bloomington'},
#   {'code': 'BMH', 'name': 'Bomai'},
#   {'code': 'BMI',
#    'name': 'Central Illinois Regional Airport at Bloomington-Normal'},
#   {'code': 'BMJ', 'name': 'Baramita'},
#   {'code': 'BMK', 'name': 'Borkum'},
#   {'code': 'BML', 'name': 'Berlin Municipal Airport'},
#   {'code': 'BMM', 'name': 'Bitam'},
#   {'code': 'BMN', 'name': 'Bamerny'},
#   {'code': 'BMO', 'name': 'Bhamo'},
#   {'code': 'BMP', 'name': 'Brampton Island'},
#   {'code': 'BMQ', 'name': 'Bamburi'},
#   {'code': 'BMR', 'name': 'Baltrum'},
#   {'code': 'BMS', 'name': 'Brumado'},
#   {'code': 'BMT', 'name': 'Beaumont Municipalcipal'},
#   {'code': 'BMU', 'name': 'Bima'},
#   {'code': 'BMV', 'name': 'Phung-Duc'},
#   {'code': 'BMW', 'name': 'Bordj Badji Mokhtar'},
#   {'code': 'BMX', 'name': 'Big Mountain'},
#   {'code': 'BMY', 'name': 'Belep Island'},
#   {'code': 'BMZ', 'name': 'Bamu'},
#   {'code': 'BNA', 'name': 'Nashville International'},
#   {'code': 'BNB', 'name': 'Boende'},
#   {'code': 'BNC', 'name': 'Beni'},
#   {'code': 'BND', 'name': 'Bandar Abbas'},
#   {'code': 'BNE', 'name': 'Brisbane International'},
#   {'code': 'BNF', 'name': 'Warm Spring Bay SPB'},
#   {'code': 'BNG', 'name': 'Banning'},
#   {'code': 'BNH', 'name': 'Barnes'},
#   {'code': 'BNI', 'name': 'Benin City'},
#   {'code': 'BNK', 'name': 'Ballina Byron Gateway'},
#   {'code': 'BNL', 'name': 'Barnwell Regional'},
#   {'code': 'BNM', 'name': 'Bodinumu'},
#   {'code': 'BNN', 'name': 'Bronnoy'},
#   {'code': 'BNO', 'name': 'Burns'},
#   {'code': 'BNP', 'name': 'Bannu'},
#   {'code': 'BNR', 'name': 'Banfora'},
#   {'code': 'BNS', 'name': 'Barinas'},
#   {'code': 'BNT', 'name': 'Bundi'},
#   {'code': 'BNU', 'name': 'Blumenau'},
#   {'code': 'BNW', 'name': 'Boone'},
#   {'code': 'BNX', 'name': 'Banja Luka'},
#   {'code': 'BNY', 'name': 'Bellona'},
#   {'code': 'BOA', 'name': 'Boma'},
#   {'code': 'BOB', 'name': 'Motu Mute'},
#   {'code': 'BOC', 'name': 'Bocas Del Toro'},
#   {'code': 'BOD', 'name': 'Mérignac'},
#   {'code': 'BOE', 'name': 'Boundji'},
#   {'code': 'BOF', 'name': 'Bolling AFB'},
#   {'code': 'BOG', 'name': 'El Nuevo Dorado International'},
#   {'code': 'BOH', 'name': 'Bournemouth International'},
#   {'code': 'BOI', 'name': 'Boise Air Terminal/Gowen Field'},
#   {'code': 'BOJ', 'name': 'Bourgas'},
#   {'code': 'BOK', 'name': 'Brookings State'},
#   {'code': 'BOL', 'name': 'Ballykelly'},
#   {'code': 'BOM',
#    'name': 'Chhatrapati Shivaji International (Sahar International)'},
#   {'code': 'BON', 'name': 'Flamingo International'},
#   {'code': 'BOO', 'name': 'Bodo'},
#   {'code': 'BOP', 'name': 'Bouar'},
#   {'code': 'BOS', 'name': 'Logan International'},
#   {'code': 'BOT', 'name': 'Boset'},
#   {'code': 'BOU', 'name': 'Bourges'},
#   {'code': 'BOV', 'name': 'Boang'},
#   {'code': 'BOW', 'name': 'Bartow'},
#   {'code': 'BOX', 'name': 'Borroloola'},
#   {'code': 'BOY', 'name': 'Borgo'},
#   {'code': 'BOZ', 'name': 'Bozoum'},
#   {'code': 'BPB', 'name': 'Boridi'},
#   {'code': 'BPC', 'name': 'Bamenda'},
#   {'code': 'BPD', 'name': 'Bapi'},
#   {'code': 'BPE', 'name': 'Bagan'},
#   {'code': 'BPF', 'name': 'Batuna Aerodrome'},
#   {'code': 'BPG', 'name': 'Barra Do Garcas'},
#   {'code': 'BPH', 'name': 'Bislig'},
#   {'code': 'BPI', 'name': 'Big Piney-marbleton'},
#   {'code': 'BPK', 'name': 'Biangabip'},
#   {'code': 'BPL', 'name': 'Alashankou'},
#   {'code': 'BPM', 'name': 'Begumpet'},
#   {'code': 'BPO', 'name': "Bo'ao Railway Station"},
#   {'code': 'BPS', 'name': 'Porto Seguro'},
#   {'code': 'BPT', 'name': 'Jefferson County'},
#   {'code': 'BPU', 'name': 'Beppu'},
#   {'code': 'BPX', 'name': 'Bangda'},
#   {'code': 'BPY', 'name': 'Besalampy'},
#   {'code': 'BQA', 'name': 'Baler'},
#   {'code': 'BQB', 'name': 'Bussellton'},
#   {'code': 'BQE', 'name': 'Bubaque'},
#   {'code': 'BQG', 'name': 'Bogorodskoye'},
#   {'code': 'BQH', 'name': 'Biggin Hill'},
#   {'code': 'BQI', 'name': 'Bagani'},
#   {'code': 'BQJ', 'name': 'Batagay'},
#   {'code': 'BQK', 'name': 'Glynco Jetport'},
#   {'code': 'BQL', 'name': 'Boulia'},
#   {'code': 'BQN', 'name': 'Borinquen'},
#   {'code': 'BQO', 'name': 'Bouna'},
#   {'code': 'BQQ', 'name': 'Barra'},
#   {'code': 'BQS', 'name': 'Blagoveschensk'},
#   {'code': 'BQT', 'name': 'Brest'},
#   {'code': 'BQU', 'name': 'J. F. Mitchell'},
#   {'code': 'BQV', 'name': 'Bartlett SPB'},
#   {'code': 'BQW', 'name': 'Balgo Hills'},
#   {'code': 'BRA', 'name': 'Barreiras'},
#   {'code': 'BRB', 'name': 'Barreirinhas'},
#   {'code': 'BRC', 'name': 'International'},
#   {'code': 'BRD', 'name': 'Brainerd Lakes Regional'},
#   {'code': 'BRE', 'name': 'Bremen'},
#   {'code': 'BRF', 'name': 'Bradford'},
#   {'code': 'BRH', 'name': 'Brahman'},
#   {'code': 'BRI', 'name': 'Palese'},
#   {'code': 'BRJ', 'name': 'Bright'},
#   {'code': 'BRK', 'name': 'Bourke'},
#   {'code': 'BRL', 'name': 'Burlington'},
#   {'code': 'BRM', 'name': 'Barquisimeto'},
#   {'code': 'BRN', 'name': 'Belp'},
#   {'code': 'BRO', 'name': 'South Padre Is. International'},
#   {'code': 'BRP', 'name': 'Biaru'},
#   {'code': 'BRQ', 'name': 'Turany'},
#   {'code': 'BRR', 'name': 'North Bay'},
#   {'code': 'BRS', 'name': 'Bristol'},
#   {'code': 'BRT', 'name': 'Bathurst Island'},
#   {'code': 'BRU', 'name': 'Brussels Airport'},
#   {'code': 'BRV', 'name': 'Bremerhaven'},
#   {'code': 'BRW', 'name': 'Wiley Post/W.Rogers M'},
#   {'code': 'BRX', 'name': 'Barahona'},
#   {'code': 'BRY', 'name': 'Samuels Field'},
#   {'code': 'BRZ', 'name': 'Borotou'},
#   {'code': 'BSA', 'name': 'Bossaso'},
#   {'code': 'BSB', 'name': 'Presidente Juscelino Kubitschek'},
#   {'code': 'BSC', 'name': 'Bahia Solano'},
#   {'code': 'BSD', 'name': 'Baoshan'},
#   {'code': 'BSE', 'name': 'Sematan'},
#   {'code': 'BSF', 'name': 'Bradshaw AAF'},
#   {'code': 'BSG', 'name': 'Bata'},
#   {'code': 'BSH', 'name': 'Brighton'},
#   {'code': 'BSI', 'name': 'Blairsville'},
#   {'code': 'BSJ', 'name': 'Bairnsdale'},
#   {'code': 'BSK', 'name': 'Mohamed Boudiaf'},
#   {'code': 'BSL', 'name': 'Euroairport Swiss'},
#   {'code': 'BSM', 'name': 'Bishe-kola'},
#   {'code': 'BSN', 'name': 'Bossangoa'},
#   {'code': 'BSO', 'name': 'Basco'},
#   {'code': 'BSP', 'name': 'Bensbach'},
#   {'code': 'BSQ', 'name': 'Bisbee Municipal Airport'},
#   {'code': 'BSR', 'name': 'International'},
#   {'code': 'BSS', 'name': 'Balsas'},
#   {'code': 'BST', 'name': 'Bost'},
#   {'code': 'BSU', 'name': 'Basankusu'},
#   {'code': 'BSV', 'name': 'Besakoa'},
#   {'code': 'BSW', 'name': 'Boswell Bay'},
#   {'code': 'BSX', 'name': 'Bassein'},
#   {'code': 'BSY', 'name': 'Bardera'},
#   {'code': 'BSZ', 'name': 'Bartletts'},
#   {'code': 'BTA', 'name': 'Yaoundé'},
#   {'code': 'BTB', 'name': 'Betou'},
#   {'code': 'BTC', 'name': 'Batticaloa'},
#   {'code': 'BTD', 'name': 'Brunette Downs'},
#   {'code': 'BTE', 'name': 'Bonthe'},
#   {'code': 'BTF', 'name': 'Salt Lake Skypark'},
#   {'code': 'BTG', 'name': 'Batangafo'},
#   {'code': 'BTH', 'name': 'Hang Nadim'},
#   {'code': 'BTI', 'name': 'Barter Island'},
#   {'code': 'BTJ', 'name': 'Sultan Iskandarmuda Airport'},
#   {'code': 'BTK', 'name': 'Bratsk'},
#   {'code': 'BTL', 'name': 'WK Kellogg Regional'},
#   {'code': 'BTM', 'name': 'Bert Mooney Airport'},
#   {'code': 'BTN', 'name': 'Bennettsville'},
#   {'code': 'BTO', 'name': 'Botopasie'},
#   {'code': 'BTP', 'name': 'Butler County - Kenny Scholter Field'},
#   {'code': 'BTQ', 'name': 'Butare'},
#   {'code': 'BTR', 'name': 'Ryan'},
#   {'code': 'BTS', 'name': 'M. R. Štefánika'},
#   {'code': 'BTT', 'name': 'Bettles'},
#   {'code': 'BTU', 'name': 'Bintulu'},
#   {'code': 'BTV', 'name': 'Burlington International'},
#   {'code': 'BTW', 'name': 'Batu Licin'},
#   {'code': 'BTX', 'name': 'Betoota'},
#   {'code': 'BTY', 'name': 'Beatty'},
#   {'code': 'BUA', 'name': 'Buka'},
#   {'code': 'BUB', 'name': 'Municipal'},
#   {'code': 'BUC', 'name': 'Burketown'},
#   {'code': 'BUD', 'name': 'Liszt Ferenc International'},
#   {'code': 'BUF', 'name': 'Buffalo Niagara International'},
#   {'code': 'BUG', 'name': 'Gen V Deslandes'},
#   {'code': 'BUI', 'name': 'Bokondini'},
#   ...],
#  'terms': 'Unauthorised access is prohibited and punishable by law. Re-sale of data is strictly prohibited unless approved by AirLabs.Co. Full terms on https://airlabs.co/terms.html'}

# %%
if __name__ == '__main__':
    app = rapid_IATACodes_Api(credentials['rapidapi_key'],credentials['rapidapi_host6'])
    v = app.browse_cities('4f382d39-3b81-47c4-8d1c-278d4a441b9a')
    CityList = app.getCitydetails(v)
# Out:
# https://iatacodes-iatacodes-v1.p.rapidapi.com/api/v5/cities?api_key=4f382d39-3b81-47c4-8d1c-278d4a441b9a

# %%
CityList
# Out:
# {'request': {'lang': 'en',
#   'currency': 'USD',
#   'time': 56,
#   'id': 1605697154964,
#   'server': 'production',
#   'host': 'airlabs.co',
#   'pid': 6285,
#   'key': {'id': 16859,
#    'api_key': '4f382d39-3b81-47c4-8d1c-278d4a441b9a',
#    'type': 'free',
#    'trial_price': None,
#    'expired': None,
#    'registered': '2020-11-18T03:56:42.000Z',
#    'limits_by_hour': 2500,
#    'limits_by_minute': 250,
#    'demo_methods': [],
#    'usage_by_hour': 5,
#    'usage_by_minute': 2},
#   'params': {'lang': 'en'},
#   'version': 5,
#   'method': 'cities',
#   'client': {'country_code': 'IN',
#    'country': 'India',
#    'city': 'Hyderabad',
#    'lat': 17.3753,
#    'lng': 78.4744,
#    'ip': '49.206.52.196',
#    'device': {'type': 'phone'},
#    'agent': {'browser': 'unknown', 'os': 'unknown', 'platform': 'unknown'}}},
#  'response': [{'code': 'AAA', 'country_code': 'PF', 'name': 'Anaa'},
#   {'code': 'AAB', 'country_code': 'AU', 'name': 'Arrabury'},
#   {'code': 'AAC', 'country_code': 'EG', 'name': 'El Arish'},
#   {'code': 'AAE', 'country_code': 'DZ', 'name': 'Annaba'},
#   {'code': 'AAF', 'country_code': 'US', 'name': 'Apalachicola'},
#   {'code': 'AAG', 'country_code': 'BR', 'name': 'Arapoti'},
#   {'code': 'AAH', 'country_code': 'DE', 'name': 'Aachen'},
#   {'code': 'AAI', 'country_code': 'BR', 'name': 'Arraias'},
#   {'code': 'AAJ', 'country_code': 'SR', 'name': 'Awaradam'},
#   {'code': 'AAK', 'country_code': 'KI', 'name': 'Aranuka'},
#   {'code': 'AAL', 'country_code': 'DK', 'name': 'Aalborg'},
#   {'code': 'AAM', 'country_code': 'ZA', 'name': 'Mala Mala'},
#   {'code': 'AAN', 'country_code': 'AE', 'name': 'Al Ain'},
#   {'code': 'AAO', 'country_code': 'VE', 'name': 'Anaco'},
#   {'code': 'AAQ', 'country_code': 'RU', 'name': 'Anapa'},
#   {'code': 'AAR', 'country_code': 'DK', 'name': 'Aarhus'},
#   {'code': 'AAS', 'country_code': 'ID', 'name': 'Apalapsili'},
#   {'code': 'AAT', 'country_code': 'CN', 'name': 'Altay'},
#   {'code': 'AAU', 'country_code': 'WS', 'name': 'Asau'},
#   {'code': 'AAV', 'country_code': 'PH', 'name': 'Surallah'},
#   {'code': 'AAW', 'country_code': 'PK', 'name': 'Abbottabad'},
#   {'code': 'AAX', 'country_code': 'BR', 'name': 'Araxa'},
#   {'code': 'AAY', 'country_code': 'YE', 'name': 'Al Ghaydah'},
#   {'code': 'AAZ', 'country_code': 'GT', 'name': 'Quetzaltenango'},
#   {'code': 'ABA', 'country_code': 'RU', 'name': 'Abakan'},
#   {'code': 'ABB', 'country_code': 'NG', 'name': 'Asaba'},
#   {'code': 'ABC', 'country_code': 'ES', 'name': 'Albacete'},
#   {'code': 'ABD', 'country_code': 'IR', 'name': 'Abadan'},
#   {'code': 'ABE', 'country_code': 'US', 'name': 'Allentown'},
#   {'code': 'ABF', 'country_code': 'KI', 'name': 'Abaiang'},
#   {'code': 'ABG', 'country_code': 'AU', 'name': 'Abingdon'},
#   {'code': 'ABH', 'country_code': 'AU', 'name': 'Alpha'},
#   {'code': 'ABI', 'country_code': 'US', 'name': 'Abilene'},
#   {'code': 'ABJ', 'country_code': 'CI', 'name': 'Abidjan'},
#   {'code': 'ABK', 'country_code': 'ET', 'name': 'Kabri Dar'},
#   {'code': 'ABL', 'country_code': 'US', 'name': 'Ambler'},
#   {'code': 'ABM', 'country_code': 'AU', 'name': 'Bamaga'},
#   {'code': 'ABN', 'country_code': 'SR', 'name': 'Albina'},
#   {'code': 'ABO', 'country_code': 'CI', 'name': 'Aboisso'},
#   {'code': 'ABP', 'country_code': 'PG', 'name': 'Atkamba'},
#   {'code': 'ABQ', 'country_code': 'US', 'name': 'Albuquerque'},
#   {'code': 'ABR', 'country_code': 'US', 'name': 'Aberdeen'},
#   {'code': 'ABS', 'country_code': 'EG', 'name': 'Abu Simbel'},
#   {'code': 'ABT', 'country_code': 'SA', 'name': 'Al-Baha'},
#   {'code': 'ABU', 'country_code': 'ID', 'name': 'Atambua'},
#   {'code': 'ABV', 'country_code': 'NG', 'name': 'Abuja'},
#   {'code': 'ABW', 'country_code': 'PG', 'name': 'Abau'},
#   {'code': 'ABX', 'country_code': 'AU', 'name': 'Albury'},
#   {'code': 'ABY', 'country_code': 'US', 'name': 'Albany'},
#   {'code': 'ABZ', 'country_code': 'GB', 'name': 'Aberdeen'},
#   {'code': 'ACA', 'country_code': 'MX', 'name': 'Acapulco'},
#   {'code': 'ACB', 'country_code': 'US', 'name': 'Bellaire'},
#   {'code': 'ACC', 'country_code': 'GH', 'name': 'Accra'},
#   {'code': 'ACD', 'country_code': 'CO', 'name': 'Acandi'},
#   {'code': 'ACE', 'country_code': 'ES', 'name': 'Arrecife'},
#   {'code': 'ACH', 'country_code': 'CH', 'name': 'Altenrhein'},
#   {'code': 'ACI', 'country_code': 'GG', 'name': 'Alderney'},
#   {'code': 'ACJ', 'country_code': 'LK', 'name': 'Anuradhapura'},
#   {'code': 'ACK', 'country_code': 'US', 'name': 'Nantucket'},
#   {'code': 'ACL', 'country_code': 'CO', 'name': 'Aguaclara'},
#   {'code': 'ACM', 'country_code': 'CO', 'name': 'Arica'},
#   {'code': 'ACN', 'country_code': 'MX', 'name': 'Acuna'},
#   {'code': 'ACP', 'country_code': 'IR', 'name': 'Sahand'},
#   {'code': 'ACR', 'country_code': 'CO', 'name': 'Araracuara'},
#   {'code': 'ACS', 'country_code': 'RU', 'name': 'Achinsk'},
#   {'code': 'ACT', 'country_code': 'US', 'name': 'Waco'},
#   {'code': 'ACU', 'country_code': 'PA', 'name': 'Achutupo'},
#   {'code': 'ACV', 'country_code': 'US', 'name': 'Arcata'},
#   {'code': 'ACX', 'country_code': 'CN', 'name': 'Xingyi'},
#   {'code': 'ACZ', 'country_code': 'IR', 'name': 'Zabol'},
#   {'code': 'ADA', 'country_code': 'TR', 'name': 'Adana'},
#   {'code': 'ADC', 'country_code': 'PG', 'name': 'Andakombe'},
#   {'code': 'ADD', 'country_code': 'ET', 'name': 'Addis Ababa'},
#   {'code': 'ADE', 'country_code': 'YE', 'name': 'Aden'},
#   {'code': 'ADF', 'country_code': 'TR', 'name': 'Adiyaman'},
#   {'code': 'ADG', 'country_code': 'US', 'name': 'Adrian'},
#   {'code': 'ADH', 'country_code': 'RU', 'name': 'Aldan'},
#   {'code': 'ADI', 'country_code': 'NA', 'name': 'Arandis'},
#   {'code': 'ADK', 'country_code': 'US', 'name': 'Adak Island'},
#   {'code': 'ADL', 'country_code': 'AU', 'name': 'Adelaide'},
#   {'code': 'ADM', 'country_code': 'US', 'name': 'Ardmore'},
#   {'code': 'ADN', 'country_code': 'CO', 'name': 'Andes'},
#   {'code': 'ADO', 'country_code': 'AU', 'name': 'Andamooka'},
#   {'code': 'ADP', 'country_code': 'LK', 'name': 'Ampara'},
#   {'code': 'ADQ', 'country_code': 'US', 'name': 'Kodiak'},
#   {'code': 'ADR', 'country_code': 'US', 'name': 'Andrews'},
#   {'code': 'ADT', 'country_code': 'US', 'name': 'Ada'},
#   {'code': 'ADU', 'country_code': 'IR', 'name': 'Ardabil'},
#   {'code': 'ADW', 'country_code': 'US', 'name': 'Camp Springs'},
#   {'code': 'ADX', 'country_code': 'GB', 'name': 'St Andrews'},
#   {'code': 'ADY', 'country_code': 'ZA', 'name': 'Alldays'},
#   {'code': 'ADZ', 'country_code': 'CO', 'name': 'San Andres Island'},
#   {'code': 'AEA', 'country_code': 'KI', 'name': 'Abemama Atoll'},
#   {'code': 'AEB', 'country_code': 'CN', 'name': 'Baise'},
#   {'code': 'AED', 'country_code': 'US', 'name': 'Aleneva'},
#   {'code': 'AEE', 'country_code': 'SS', 'name': 'Adareil'},
#   {'code': 'AEG', 'country_code': 'ID', 'name': 'Aek Godang'},
#   {'code': 'AEH', 'country_code': 'TD', 'name': 'Abéché'},
#   {'code': 'AEI', 'country_code': 'ES', 'name': 'Algeciras'},
#   {'code': 'AEK', 'country_code': 'PG', 'name': 'Aseki'},
#   {'code': 'AEL', 'country_code': 'US', 'name': 'Albert Lea'},
#   {'code': 'AEO', 'country_code': 'MR', 'name': 'Aioun El Atrouss'},
#   {'code': 'AER', 'country_code': 'RU', 'name': 'Sochi'},
#   {'code': 'AES', 'country_code': 'NO', 'name': 'Aalesund'},
#   {'code': 'AET', 'country_code': 'US', 'name': 'Allakaket'},
#   {'code': 'AEU', 'country_code': 'IR', 'name': 'Abu Musa'},
#   {'code': 'AEX', 'country_code': 'US', 'name': 'Alexandria'},
#   {'code': 'AEY', 'country_code': 'IS', 'name': 'Akureyri'},
#   {'code': 'AFA', 'country_code': 'AR', 'name': 'San Rafael'},
#   {'code': 'AFD', 'country_code': 'ZA', 'name': 'Port Alfred'},
#   {'code': 'AFI', 'country_code': 'CO', 'name': 'Amalfi'},
#   {'code': 'AFL', 'country_code': 'BR', 'name': 'Alta Floresta'},
#   {'code': 'AFN', 'country_code': 'US', 'name': 'Jaffrey'},
#   {'code': 'AFO', 'country_code': 'US', 'name': 'Afton'},
#   {'code': 'AFR', 'country_code': 'PG', 'name': 'Afore'},
#   {'code': 'AFS', 'country_code': 'UZ', 'name': 'Zarafshan'},
#   {'code': 'AFT', 'country_code': 'SB', 'name': 'Afutara'},
#   {'code': 'AFY', 'country_code': 'TR', 'name': 'Afyon'},
#   {'code': 'AFZ', 'country_code': 'IR', 'name': 'Sabzevar'},
#   {'code': 'AGA', 'country_code': 'MA', 'name': 'Agadir'},
#   {'code': 'AGD', 'country_code': 'ID', 'name': 'Anggi'},
#   {'code': 'AGE', 'country_code': 'DE', 'name': 'Wangerooge'},
#   {'code': 'AGF', 'country_code': 'FR', 'name': 'Agen'},
#   {'code': 'AGG', 'country_code': 'PG', 'name': 'Angoram'},
#   {'code': 'AGH', 'country_code': 'SE', 'name': 'Angelholm'},
#   {'code': 'AGI', 'country_code': 'SR', 'name': 'Wageningen'},
#   {'code': 'AGJ', 'country_code': 'JP', 'name': 'Aguni'},
#   {'code': 'AGK', 'country_code': 'PG', 'name': 'Kagua'},
#   {'code': 'AGL', 'country_code': 'PG', 'name': 'Wanigela'},
#   {'code': 'AGM', 'country_code': 'GL', 'name': 'Tasiilaq'},
#   {'code': 'AGN', 'country_code': 'US', 'name': 'Angoon'},
#   {'code': 'AGO', 'country_code': 'US', 'name': 'Magnolia'},
#   {'code': 'AGP', 'country_code': 'ES', 'name': 'Malaga'},
#   {'code': 'AGQ', 'country_code': 'GR', 'name': 'Agrinion'},
#   {'code': 'AGR', 'country_code': 'IN', 'name': 'Agra'},
#   {'code': 'AGS', 'country_code': 'US', 'name': 'Augusta'},
#   {'code': 'AGT', 'country_code': 'PY', 'name': 'Ciudad Del Este'},
#   {'code': 'AGU', 'country_code': 'MX', 'name': 'Aguascalientes'},
#   {'code': 'AGV', 'country_code': 'VE', 'name': 'Acarigua'},
#   {'code': 'AGW', 'country_code': 'AU', 'name': 'Agnew'},
#   {'code': 'AGX', 'country_code': 'IN', 'name': 'Agatti Island'},
#   {'code': 'AGZ', 'country_code': 'ZA', 'name': 'Aggeneys'},
#   {'code': 'AHB', 'country_code': 'SA', 'name': 'Abha'},
#   {'code': 'AHC', 'country_code': 'US', 'name': 'Herlong'},
#   {'code': 'AHE', 'country_code': 'PF', 'name': 'Ahe'},
#   {'code': 'AHF', 'country_code': 'US', 'name': 'Arapahoe'},
#   {'code': 'AHH', 'country_code': 'US', 'name': 'Amery'},
#   {'code': 'AHI', 'country_code': 'ID', 'name': 'Amahai'},
#   {'code': 'AHL', 'country_code': 'GY', 'name': 'Aishalton'},
#   {'code': 'AHM', 'country_code': 'US', 'name': 'Ashland'},
#   {'code': 'AHN', 'country_code': 'US', 'name': 'Athens'},
#   {'code': 'AHO', 'country_code': 'IT', 'name': 'Alghero'},
#   {'code': 'AHS', 'country_code': 'HN', 'name': 'Ahuas'},
#   {'code': 'AHT', 'country_code': 'US', 'name': 'Amchitka'},
#   {'code': 'AHU', 'country_code': 'MA', 'name': 'Al Hoceima'},
#   {'code': 'AHW', 'country_code': 'OM', 'name': 'Saih Rawl'},
#   {'code': 'AHY', 'country_code': 'MG', 'name': 'Ambatolahy'},
#   {'code': 'AHZ', 'country_code': 'FR', 'name': 'Alpe D Huez'},
#   {'code': 'AIA', 'country_code': 'US', 'name': 'Alliance'},
#   {'code': 'AIB', 'country_code': 'US', 'name': 'Anita Bay'},
#   {'code': 'AIC', 'country_code': 'MH', 'name': 'Airok'},
#   {'code': 'AID', 'country_code': 'US', 'name': 'Anderson'},
#   {'code': 'AIE', 'country_code': 'PG', 'name': 'Aiome'},
#   {'code': 'AIF', 'country_code': 'BR', 'name': 'Assis'},
#   {'code': 'AIG', 'country_code': 'CF', 'name': 'Yalinga'},
#   {'code': 'AIH', 'country_code': 'PG', 'name': 'Aiambak'},
#   {'code': 'AII', 'country_code': 'DJ', 'name': 'Alisabieh'},
#   {'code': 'AIK', 'country_code': 'US', 'name': 'Aiken'},
#   {'code': 'AIL', 'country_code': 'PA', 'name': 'Ailigandi'},
#   {'code': 'AIM', 'country_code': 'MH', 'name': 'Ailuk Island'},
#   {'code': 'AIN', 'country_code': 'US', 'name': 'Wainwright'},
#   {'code': 'AIO', 'country_code': 'US', 'name': 'Atlantic'},
#   {'code': 'AIP', 'country_code': 'MH', 'name': 'Ailinglapalap Island'},
#   {'code': 'AIR', 'country_code': 'BR', 'name': 'Aripuana'},
#   {'code': 'AIS', 'country_code': 'KI', 'name': 'Arorae Island'},
#   {'code': 'AIT', 'country_code': 'CK', 'name': 'Aitutaki'},
#   {'code': 'AIU', 'country_code': 'CK', 'name': 'Atiu Island'},
#   {'code': 'AIV', 'country_code': 'US', 'name': 'Aliceville'},
#   {'code': 'AIW', 'country_code': 'NA', 'name': 'Ai-ais'},
#   {'code': 'AIY', 'country_code': 'US', 'name': 'Atlantic City'},
#   {'code': 'AIZ', 'country_code': 'US', 'name': 'Kaiser'},
#   {'code': 'AJA', 'country_code': 'FR', 'name': 'Ajaccio'},
#   {'code': 'AJF', 'country_code': 'SA', 'name': 'Sakaka Al Jouf'},
#   {'code': 'AJI', 'country_code': 'TR', 'name': 'Agri'},
#   {'code': 'AJJ', 'country_code': 'MR', 'name': 'Akjoujt'},
#   {'code': 'AJK', 'country_code': 'IR', 'name': 'Araak'},
#   {'code': 'AJL', 'country_code': 'IN', 'name': 'Aizawl'},
#   {'code': 'AJN', 'country_code': 'KM', 'name': 'Anjouan'},
#   {'code': 'AJR', 'country_code': 'SE', 'name': 'Arvidsjaur'},
#   {'code': 'AJS', 'country_code': 'MX', 'name': 'Abreojos'},
#   {'code': 'AJU', 'country_code': 'BR', 'name': 'Aracaju'},
#   {'code': 'AJY', 'country_code': 'NE', 'name': 'Agades'},
#   {'code': 'AKA', 'country_code': 'CN', 'name': 'Ankang'},
#   {'code': 'AKB', 'country_code': 'US', 'name': 'Atka'},
#   {'code': 'AKD', 'country_code': 'IN', 'name': 'Akola'},
#   {'code': 'AKE', 'country_code': 'GA', 'name': 'Akieni'},
#   {'code': 'AKF', 'country_code': 'LY', 'name': 'Kufrah'},
#   {'code': 'AKG', 'country_code': 'PG', 'name': 'Anguganak'},
#   {'code': 'AKH', 'country_code': 'SA', 'name': 'Al Kharj'},
#   {'code': 'AKI', 'country_code': 'US', 'name': 'Akiak'},
#   {'code': 'AKJ', 'country_code': 'JP', 'name': 'Asahikawa'},
#   {'code': 'AKK', 'country_code': 'US', 'name': 'Akhiok'},
#   {'code': 'AKL', 'country_code': 'NZ', 'name': 'Auckland'},
#   {'code': 'AKM', 'country_code': 'TD', 'name': 'Zakouma'},
#   {'code': 'AKN', 'country_code': 'US', 'name': 'King Salmon'},
#   {'code': 'AKO', 'country_code': 'US', 'name': 'Akron'},
#   {'code': 'AKP', 'country_code': 'US', 'name': 'Anaktuvuk'},
#   {'code': 'AKQ', 'country_code': 'ID', 'name': 'Astraksetra'},
#   {'code': 'AKR', 'country_code': 'NG', 'name': 'Akure'},
#   {'code': 'AKS', 'country_code': 'SB', 'name': 'Auki'},
#   {'code': 'AKT', 'country_code': 'CY', 'name': 'Akrotiri'},
#   {'code': 'AKU', 'country_code': 'CN', 'name': 'Aksu'},
#   {'code': 'AKV', 'country_code': 'CA', 'name': 'Akulivik'},
#   {'code': 'AKW', 'country_code': 'IR', 'name': 'Aghajari'},
#   {'code': 'AKX', 'country_code': 'KZ', 'name': 'Aktyubinsk'},
#   {'code': 'AKY', 'country_code': 'MM', 'name': 'Sittwe'},
#   {'code': 'ALA', 'country_code': 'KZ', 'name': 'Almaty'},
#   {'code': 'ALB', 'country_code': 'US', 'name': 'Albany'},
#   {'code': 'ALC', 'country_code': 'ES', 'name': 'Alicante'},
#   {'code': 'ALD', 'country_code': 'PE', 'name': 'Alerta'},
#   {'code': 'ALE', 'country_code': 'US', 'name': 'Alpine'},
#   {'code': 'ALF', 'country_code': 'NO', 'name': 'Alta'},
#   {'code': 'ALG', 'country_code': 'DZ', 'name': 'Algiers'},
#   {'code': 'ALH', 'country_code': 'AU', 'name': 'Albany'},
#   {'code': 'ALI', 'country_code': 'US', 'name': 'Alice'},
#   {'code': 'ALJ', 'country_code': 'ZA', 'name': 'Alexander Bay'},
#   {'code': 'ALK', 'country_code': 'ET', 'name': 'Asela'},
#   {'code': 'ALL', 'country_code': 'IT', 'name': 'Albenga'},
#   {'code': 'ALM', 'country_code': 'US', 'name': 'Alamogordo'},
#   {'code': 'ALN', 'country_code': 'US', 'name': 'Alton'},
#   {'code': 'ALO', 'country_code': 'US', 'name': 'Waterloo'},
#   {'code': 'ALP', 'country_code': 'SY', 'name': 'Aleppo'},
#   {'code': 'ALQ', 'country_code': 'BR', 'name': 'Alegrete'},
#   {'code': 'ALR', 'country_code': 'NZ', 'name': 'Alexandra'},
#   {'code': 'ALS', 'country_code': 'US', 'name': 'Alamosa'},
#   {'code': 'ALT', 'country_code': 'BR', 'name': 'Alenquer'},
#   {'code': 'ALU', 'country_code': 'SO', 'name': 'Alula'},
#   {'code': 'ALW', 'country_code': 'US', 'name': 'Walla Walla'},
#   {'code': 'ALX', 'country_code': 'US', 'name': 'Alexander City'},
#   {'code': 'ALY', 'country_code': 'EG', 'name': 'Alexandria'},
#   {'code': 'ALZ', 'country_code': 'US', 'name': 'Alitak'},
#   {'code': 'AMA', 'country_code': 'US', 'name': 'Amarillo'},
#   {'code': 'AMB', 'country_code': 'MG', 'name': 'Ambilobe'},
#   {'code': 'AMC', 'country_code': 'TD', 'name': 'Am Timan'},
#   {'code': 'AMD', 'country_code': 'IN', 'name': 'Ahmedabad'},
#   {'code': 'AME', 'country_code': 'MZ', 'name': 'Alto Molocue'},
#   {'code': 'AMF', 'country_code': 'PG', 'name': 'Ama'},
#   {'code': 'AMG', 'country_code': 'PG', 'name': 'Amboin'},
#   {'code': 'AMH', 'country_code': 'ET', 'name': 'Arba Mintch'},
#   {'code': 'AMI', 'country_code': 'ID', 'name': 'Mataram'},
#   {'code': 'AMJ', 'country_code': 'BR', 'name': 'Almenara'},
#   {'code': 'AML', 'country_code': 'PA', 'name': 'Puerto Armuellas'},
#   {'code': 'AMM', 'country_code': 'JO', 'name': 'Amman'},
#   {'code': 'AMN', 'country_code': 'US', 'name': 'Alma'},
#   {'code': 'AMO', 'country_code': 'TD', 'name': 'Mao'},
#   {'code': 'AMP', 'country_code': 'MG', 'name': 'Ampanihy'},
#   {'code': 'AMQ', 'country_code': 'ID', 'name': 'Ambon'},
#   {'code': 'AMR', 'country_code': 'MH', 'name': 'Arno'},
#   {'code': 'AMS', 'country_code': 'NL', 'name': 'Amsterdam'},
#   {'code': 'AMT', 'country_code': 'AU', 'name': 'Amata'},
#   {'code': 'AMU', 'country_code': 'PG', 'name': 'Amanab'},
#   {'code': 'AMV', 'country_code': 'RU', 'name': 'Amderma'},
#   {'code': 'AMW', 'country_code': 'US', 'name': 'Ames'},
#   {'code': 'AMX', 'country_code': 'AU', 'name': 'Ammaroo'},
#   {'code': 'AMY', 'country_code': 'MG', 'name': 'Ambatomainty'},
#   {'code': 'AMZ', 'country_code': 'NZ', 'name': 'Ardmore'},
#   {'code': 'ANA', 'country_code': 'US', 'name': 'Anaheim'},
#   {'code': 'ANB', 'country_code': 'US', 'name': 'Anniston'},
#   {'code': 'ANC', 'country_code': 'US', 'name': 'Anchorage'},
#   {'code': 'AND', 'country_code': 'US', 'name': 'Anderson'},
#   {'code': 'ANE', 'country_code': 'FR', 'name': 'Angers'},
#   {'code': 'ANF', 'country_code': 'CL', 'name': 'Antofagasta'},
#   {'code': 'ANG', 'country_code': 'FR', 'name': 'Angouleme'},
#   {'code': 'ANH', 'country_code': 'SB', 'name': 'Anuha Island Resort'},
#   {'code': 'ANI', 'country_code': 'US', 'name': 'Aniak'},
#   {'code': 'ANJ', 'country_code': 'CG', 'name': 'Zanaga'},
#   {'code': 'ANK', 'country_code': 'TR', 'name': 'Ankara'},
#   {'code': 'ANL', 'country_code': 'AO', 'name': 'Andulo'},
#   {'code': 'ANM', 'country_code': 'MG', 'name': 'Antalaha'},
#   {'code': 'ANN', 'country_code': 'US', 'name': 'Annette Island'},
#   {'code': 'ANO', 'country_code': 'MZ', 'name': 'Angoche'},
#   {'code': 'ANP', 'country_code': 'US', 'name': 'Annapolis'},
#   {'code': 'ANQ', 'country_code': 'US', 'name': 'Angola'},
#   {'code': 'ANR', 'country_code': 'BE', 'name': 'Antwerp'},
#   {'code': 'ANS', 'country_code': 'PE', 'name': 'Andahuaylas'},
#   {'code': 'ANT', 'country_code': 'AT', 'name': 'St Anton'},
#   {'code': 'ANU', 'country_code': 'AG', 'name': "St. John's"},
#   {'code': 'ANV', 'country_code': 'US', 'name': 'Anvik'},
#   {'code': 'ANW', 'country_code': 'US', 'name': 'Ainsworth'},
#   {'code': 'ANX', 'country_code': 'NO', 'name': 'Andenes'},
#   {'code': 'ANY', 'country_code': 'US', 'name': 'Anthony'},
#   {'code': 'ANZ', 'country_code': 'AU', 'name': 'Angus Downs'},
#   {'code': 'AOA', 'country_code': 'PG', 'name': 'Aroa'},
#   {'code': 'AOB', 'country_code': 'PG', 'name': 'Annanberg'},
#   {'code': 'AOC', 'country_code': 'DE', 'name': 'Altenburg'},
#   {'code': 'AOD', 'country_code': 'TD', 'name': 'Abou Deia'},
#   {'code': 'AOG', 'country_code': 'CN', 'name': 'Anshan'},
#   {'code': 'AOH', 'country_code': 'US', 'name': 'Lima'},
#   {'code': 'AOI', 'country_code': 'IT', 'name': 'Ancona'},
#   {'code': 'AOJ', 'country_code': 'JP', 'name': 'Aomori'},
#   {'code': 'AOK', 'country_code': 'GR', 'name': 'Karpathos'},
#   {'code': 'AOL', 'country_code': 'AR', 'name': 'Paso De Los Libres'},
#   {'code': 'AOM', 'country_code': 'OM', 'name': 'Adam'},
#   {'code': 'AON', 'country_code': 'PG', 'name': 'Arona'},
#   {'code': 'AOO', 'country_code': 'US', 'name': 'Martinsburg'},
#   {'code': 'AOP', 'country_code': 'PE', 'name': 'Andoas'},
#   {'code': 'AOR', 'country_code': 'MY', 'name': 'Alor Setar'},
#   {'code': 'AOS', 'country_code': 'US', 'name': 'Amook'},
#   {'code': 'AOT', 'country_code': 'IT', 'name': 'Aosta'},
#   {'code': 'AOU', 'country_code': 'LA', 'name': 'Attopeu'},
#   {'code': 'APB', 'country_code': 'BO', 'name': 'Apolo'},
#   {'code': 'APC', 'country_code': 'US', 'name': 'Napa'},
#   {'code': 'APE', 'country_code': 'PE', 'name': 'San Juan Aposento'},
#   {'code': 'APF', 'country_code': 'US', 'name': 'Naples'},
#   {'code': 'APG', 'country_code': 'US', 'name': 'Aberdeen'},
#   {'code': 'APH', 'country_code': 'US', 'name': 'Bowling Green'},
#   {'code': 'API', 'country_code': 'CO', 'name': 'Apiay'},
#   {'code': 'APK', 'country_code': 'PF', 'name': 'Apataki'},
#   {'code': 'APL', 'country_code': 'MZ', 'name': 'Nampula'},
#   {'code': 'APN', 'country_code': 'US', 'name': 'Alpena'},
#   {'code': 'APO', 'country_code': 'CO', 'name': 'Apartado'},
#   {'code': 'APP', 'country_code': 'PG', 'name': 'Asapa'},
#   {'code': 'APQ', 'country_code': 'BR', 'name': 'Arapiraca'},
#   {'code': 'APR', 'country_code': 'PG', 'name': 'April River'},
#   {'code': 'APS', 'country_code': 'BR', 'name': 'Anapolis'},
#   {'code': 'APT', 'country_code': 'US', 'name': 'Jasper'},
#   {'code': 'APU', 'country_code': 'BR', 'name': 'Apucarana'},
#   {'code': 'APV', 'country_code': 'US', 'name': 'Apple Valley'},
#   {'code': 'APW', 'country_code': 'WS', 'name': 'Apia'},
#   {'code': 'APX', 'country_code': 'BR', 'name': 'Arapongas'},
#   {'code': 'APY', 'country_code': 'BR', 'name': 'Alto Parnaiba'},
#   {'code': 'APZ', 'country_code': 'AR', 'name': 'Zapala'},
#   {'code': 'AQA', 'country_code': 'BR', 'name': 'Araraquara'},
#   {'code': 'AQB', 'country_code': 'GT', 'name': 'Quiche'},
#   {'code': 'AQG', 'country_code': 'CN', 'name': 'Anqing'},
#   {'code': 'AQI', 'country_code': 'SA', 'name': 'Qaisumah'},
#   {'code': 'AQJ', 'country_code': 'JO', 'name': 'Aqaba'},
#   {'code': 'AQM', 'country_code': 'BR', 'name': 'Ariquemes'},
#   {'code': 'AQP', 'country_code': 'PE', 'name': 'Arequipa'},
#   {'code': 'AQS', 'country_code': 'FJ', 'name': 'Saqani'},
#   {'code': 'AQY', 'country_code': 'US', 'name': 'Alyeska'},
#   {'code': 'ARA', 'country_code': 'US', 'name': 'New Iberia'},
#   {'code': 'ARB', 'country_code': 'US', 'name': 'Ann Arbor'},
#   {'code': 'ARC', 'country_code': 'US', 'name': 'Arctic Village'},
#   {'code': 'ARD', 'country_code': 'ID', 'name': 'Alor Island'},
#   {'code': 'ARE', 'country_code': 'PR', 'name': 'Arecibo'},
#   {'code': 'ARF', 'country_code': 'CO', 'name': 'Acaricuara'},
#   {'code': 'ARG', 'country_code': 'US', 'name': 'Walnut Ridge'},
#   {'code': 'ARH', 'country_code': 'RU', 'name': 'Arkhangelsk'},
#   {'code': 'ARI', 'country_code': 'CL', 'name': 'Arica'},
#   {'code': 'ARJ', 'country_code': 'ID', 'name': 'Arso'},
#   {'code': 'ARK', 'country_code': 'TZ', 'name': 'Arusha'},
#   {'code': 'ARL', 'country_code': 'BF', 'name': 'Arly'},
#   {'code': 'ARM', 'country_code': 'AU', 'name': 'Armidale'},
#   {'code': 'ARO', 'country_code': 'CO', 'name': 'Arboletas'},
#   {'code': 'ARP', 'country_code': 'PG', 'name': 'Aragip'},
#   {'code': 'ARQ', 'country_code': 'CO', 'name': 'Arauquita'},
#   {'code': 'ARR', 'country_code': 'AR', 'name': 'Alto Rio Senguerr'},
#   {'code': 'ARS', 'country_code': 'BR', 'name': 'Aragarcas'},
#   {'code': 'ART', 'country_code': 'US', 'name': 'Watertown'},
#   {'code': 'ARU', 'country_code': 'BR', 'name': 'Aracatuba'},
#   {'code': 'ARV', 'country_code': 'US', 'name': 'Minocqua'},
#   {'code': 'ARW', 'country_code': 'RO', 'name': 'Arad'},
#   {'code': 'ARX', 'country_code': 'US', 'name': 'Neptune'},
#   {'code': 'ARY', 'country_code': 'AU', 'name': 'Ararat'},
#   {'code': 'ARZ', 'country_code': 'AO', 'name': "N'zeto"},
#   {'code': 'ASA', 'country_code': 'ER', 'name': 'Assab'},
#   {'code': 'ASB', 'country_code': 'TM', 'name': 'Ashgabat'},
#   {'code': 'ASC', 'country_code': 'BO', 'name': 'Ascension'},
#   {'code': 'ASD', 'country_code': 'BS', 'name': 'Andros Town'},
#   {'code': 'ASE', 'country_code': 'US', 'name': 'Aspen'},
#   {'code': 'ASF', 'country_code': 'RU', 'name': 'Astrakhan'},
#   {'code': 'ASG', 'country_code': 'NZ', 'name': 'Ashburton'},
#   {'code': 'ASH', 'country_code': 'US', 'name': 'Nashua'},
#   {'code': 'ASI', 'country_code': 'SH', 'name': 'Georgetown'},
#   {'code': 'ASJ', 'country_code': 'JP', 'name': 'Amami'},
#   {'code': 'ASK', 'country_code': 'CI', 'name': 'Yamoussoukro'},
#   {'code': 'ASL', 'country_code': 'US', 'name': 'Marshall'},
#   {'code': 'ASM', 'country_code': 'ER', 'name': 'Asmara'},
#   {'code': 'ASN', 'country_code': 'US', 'name': 'Talladega'},
#   {'code': 'ASO', 'country_code': 'ET', 'name': 'Asosa'},
#   {'code': 'ASP', 'country_code': 'AU', 'name': 'Alice Springs'},
#   {'code': 'ASQ', 'country_code': 'US', 'name': 'Austin'},
#   {'code': 'ASR', 'country_code': 'TR', 'name': 'Kayseri'},
#   {'code': 'AST', 'country_code': 'US', 'name': 'Astoria'},
#   {'code': 'ASU', 'country_code': 'PY', 'name': 'Asuncion'},
#   {'code': 'ASV', 'country_code': 'KE', 'name': 'Amboseli'},
#   {'code': 'ASW', 'country_code': 'EG', 'name': 'Aswan'},
#   {'code': 'ASX', 'country_code': 'US', 'name': 'Ashland'},
#   {'code': 'ASY', 'country_code': 'US', 'name': 'Ashley'},
#   {'code': 'ASZ', 'country_code': 'PG', 'name': 'Asirim'},
#   {'code': 'ATA', 'country_code': 'PE', 'name': 'Anta'},
#   {'code': 'ATB', 'country_code': 'SD', 'name': 'Atbara'},
#   {'code': 'ATC', 'country_code': 'BS', 'name': "Arthur's Town"},
#   {'code': 'ATD', 'country_code': 'SB', 'name': 'Atoifi'},
#   {'code': 'ATE', 'country_code': 'US', 'name': 'Antlers'},
#   {'code': 'ATF', 'country_code': 'EC', 'name': 'Ambato'},
#   {'code': 'ATG', 'country_code': 'PK', 'name': 'Attock'},
#   {'code': 'ATH', 'country_code': 'GR', 'name': 'Athens'},
#   {'code': 'ATI', 'country_code': 'UY', 'name': 'Artigas'},
#   {'code': 'ATJ', 'country_code': 'MG', 'name': 'Antsirabe'},
#   {'code': 'ATK', 'country_code': 'US', 'name': 'Atqasuk'},
#   {'code': 'ATL', 'country_code': 'US', 'name': 'Atlanta'},
#   {'code': 'ATM', 'country_code': 'BR', 'name': 'Altamira'},
#   {'code': 'ATN', 'country_code': 'PG', 'name': 'Namatanai'},
#   {'code': 'ATO', 'country_code': 'US', 'name': 'Athens'},
#   {'code': 'ATP', 'country_code': 'PG', 'name': 'Aitape'},
#   {'code': 'ATQ', 'country_code': 'IN', 'name': 'Amritsar'},
#   {'code': 'ATR', 'country_code': 'MR', 'name': 'Atar'},
#   {'code': 'ATS', 'country_code': 'US', 'name': 'Artesia'},
#   {'code': 'ATT', 'country_code': 'US', 'name': 'Atmautluak'},
#   {'code': 'ATU', 'country_code': 'US', 'name': 'Attu Island'},
#   {'code': 'ATV', 'country_code': 'TD', 'name': 'Ati'},
#   {'code': 'ATW', 'country_code': 'US', 'name': 'Appleton'},
#   {'code': 'ATX', 'country_code': 'KZ', 'name': 'Atbasar'},
#   {'code': 'ATY', 'country_code': 'US', 'name': 'Watertown'},
#   {'code': 'ATZ', 'country_code': 'EG', 'name': 'Assiut'},
#   {'code': 'AUA', 'country_code': 'AW', 'name': 'Aruba'},
#   {'code': 'AUB', 'country_code': 'BR', 'name': 'Itauba'},
#   {'code': 'AUC', 'country_code': 'CO', 'name': 'Arauca'},
#   {'code': 'AUD', 'country_code': 'AU', 'name': 'Augustus Downs'},
#   {'code': 'AUE', 'country_code': 'EG', 'name': 'Abu Rudeis'},
#   {'code': 'AUF', 'country_code': 'FR', 'name': 'Auxerre'},
#   {'code': 'AUG', 'country_code': 'US', 'name': 'Augusta'},
#   {'code': 'AUH', 'country_code': 'AE', 'name': 'Abu Dhabi'},
#   {'code': 'AUI', 'country_code': 'PG', 'name': 'Aua Island'},
#   {'code': 'AUJ', 'country_code': 'PG', 'name': 'Ambunti'},
#   {'code': 'AUK', 'country_code': 'US', 'name': 'Alakanuk'},
#   {'code': 'AUL', 'country_code': 'MH', 'name': 'Aur Island'},
#   {'code': 'AUM', 'country_code': 'US', 'name': 'Austin'},
#   {'code': 'AUN', 'country_code': 'US', 'name': 'Auburn'},
#   {'code': 'AUO', 'country_code': 'US', 'name': 'Auburn'},
#   {'code': 'AUP', 'country_code': 'PG', 'name': 'Agaun'},
#   {'code': 'AUQ', 'country_code': 'PF', 'name': 'Atuona'},
#   {'code': 'AUR', 'country_code': 'FR', 'name': 'Aurillac'},
#   {'code': 'AUS', 'country_code': 'US', 'name': 'Austin'},
#   {'code': 'AUT', 'country_code': 'ID', 'name': 'Atauro'},
#   {'code': 'AUU', 'country_code': 'AU', 'name': 'Aurukun Mission'},
#   {'code': 'AUV', 'country_code': 'PG', 'name': 'Aumo'},
#   {'code': 'AUW', 'country_code': 'US', 'name': 'Wausau'},
#   {'code': 'AUX', 'country_code': 'BR', 'name': 'Araguaina'},
#   {'code': 'AUY', 'country_code': 'VU', 'name': 'Aneityum'},
#   {'code': 'AUZ', 'country_code': 'US', 'name': 'Aurora'},
#   {'code': 'AVA', 'country_code': 'CN', 'name': 'An Shun'},
#   {'code': 'AVB', 'country_code': 'IT', 'name': 'Aviano'},
#   {'code': 'AVG', 'country_code': 'AU', 'name': 'Auvergne'},
#   {'code': 'AVI', 'country_code': 'CU', 'name': 'Ciego De Avila'},
#   {'code': 'AVK', 'country_code': 'MN', 'name': 'Arvaikheer'},
#   {'code': 'AVL', 'country_code': 'US', 'name': 'Fletcher'},
#   {'code': 'AVN', 'country_code': 'FR', 'name': 'Avignon'},
#   {'code': 'AVO', 'country_code': 'US', 'name': 'Avon Park'},
#   {'code': 'AVP', 'country_code': 'US', 'name': 'Wilkes-Barre'},
#   {'code': 'AVU', 'country_code': 'SB', 'name': 'Avu Avu'},
#   {'code': 'AVX', 'country_code': 'US', 'name': 'Avalon'},
#   {'code': 'AWA', 'country_code': 'ET', 'name': 'Awassa'},
#   {'code': 'AWB', 'country_code': 'PG', 'name': 'Awaba'},
#   {'code': 'AWD', 'country_code': 'VU', 'name': 'Aniwa'},
#   {'code': 'AWE', 'country_code': 'GA', 'name': 'Alowe'},
#   {'code': 'AWK', 'country_code': 'UM', 'name': 'Wake Island'},
#   {'code': 'AWM', 'country_code': 'US', 'name': 'West Memphis'},
#   {'code': 'AWN', 'country_code': 'AU', 'name': 'Alton Downs'},
#   {'code': 'AWP', 'country_code': 'AU', 'name': 'Austral Downs'},
#   {'code': 'AWR', 'country_code': 'PG', 'name': 'Awar'},
#   {'code': 'AWZ', 'country_code': 'IR', 'name': 'Ahwaz'},
#   {'code': 'AXA', 'country_code': 'AI', 'name': 'Anguilla'},
#   {'code': 'AXB', 'country_code': 'US', 'name': 'Alexandria Bay'},
#   {'code': 'AXC', 'country_code': 'AU', 'name': 'Aramac'},
#   {'code': 'AXD', 'country_code': 'GR', 'name': 'Alexandroupolis'},
#   {'code': 'AXE', 'country_code': 'BR', 'name': 'Xanxere'},
#   {'code': 'AXG', 'country_code': 'US', 'name': 'Algona'},
#   {'code': 'AXK', 'country_code': 'YE', 'name': 'Ataq'},
#   {'code': 'AXL', 'country_code': 'AU', 'name': 'Alexandria'},
#   {'code': 'AXM', 'country_code': 'CO', 'name': 'Armenia'},
#   {'code': 'AXN', 'country_code': 'US', 'name': 'Alexandria'},
#   {'code': 'AXP', 'country_code': 'BS', 'name': 'Spring Point'},
#   {'code': 'AXR', 'country_code': 'PF', 'name': 'Arutua'},
#   {'code': 'AXT', 'country_code': 'JP', 'name': 'Akita'},
#   {'code': 'AXU', 'country_code': 'ET', 'name': 'Axum'},
#   {'code': 'AXV', 'country_code': 'US', 'name': 'Wapakoneta'},
#   {'code': 'AXX', 'country_code': 'US', 'name': 'Angel Fire'},
#   {'code': 'AYA', 'country_code': 'CO', 'name': 'Ayapel'},
#   {'code': 'AYC', 'country_code': 'CO', 'name': 'Ayacucho'},
#   {'code': 'AYD', 'country_code': 'AU', 'name': 'Alroy Downs'},
#   {'code': 'AYE', 'country_code': 'US', 'name': 'Fort Devens'},
#   {'code': 'AYG', 'country_code': 'CO', 'name': 'Yaguara'},
#   {'code': 'AYI', 'country_code': 'CO', 'name': 'Yari'},
#   {'code': 'AYK', 'country_code': 'KZ', 'name': 'Arkalyk'},
#   {'code': 'AYL', 'country_code': 'AU', 'name': 'Anthony Lagoon'},
#   {'code': 'AYN', 'country_code': 'CN', 'name': 'Anyang'},
#   {'code': 'AYO', 'country_code': 'PY', 'name': 'Ayolas'},
#   {'code': 'AYP', 'country_code': 'PE', 'name': 'Ayacucho'},
#   {'code': 'AYQ', 'country_code': 'AU', 'name': 'Ayers Rock'},
#   {'code': 'AYR', 'country_code': 'AU', 'name': 'Ayr'},
#   {'code': 'AYS', 'country_code': 'US', 'name': 'Waycross'},
#   {'code': 'AYT', 'country_code': 'TR', 'name': 'Antalya'},
#   {'code': 'AYU', 'country_code': 'PG', 'name': 'Aiyura'},
#   {'code': 'AYW', 'country_code': 'ID', 'name': 'Ayawasi'},
#   {'code': 'AYY', 'country_code': 'LK', 'name': 'Pothuvil'},
#   {'code': 'AYZ', 'country_code': 'US', 'name': 'Amityville'},
#   {'code': 'AZB', 'country_code': 'PG', 'name': 'Amazon Bay'},
#   {'code': 'AZD', 'country_code': 'IR', 'name': 'Yazd'},
#   {'code': 'AZG', 'country_code': 'MX', 'name': 'Apatzingan'},
#   {'code': 'AZL', 'country_code': 'BR', 'name': 'Sapezal'},
#   {'code': 'AZN', 'country_code': 'UZ', 'name': 'Andizhan'},
#   {'code': 'AZO', 'country_code': 'US', 'name': 'Kalamazoo'},
#   {'code': 'AZR', 'country_code': 'DZ', 'name': 'Adrar'},
#   {'code': 'AZS', 'country_code': 'DO', 'name': 'El Catey'},
#   {'code': 'AZT', 'country_code': 'CO', 'name': 'Zapatoca'},
#   {'code': 'AZZ', 'country_code': 'AO', 'name': 'Ambriz'},
#   {'code': 'BAA', 'country_code': 'PG', 'name': 'Bialla'},
#   {'code': 'BAC', 'country_code': 'CO', 'name': 'Barranca De Upia'},
#   {'code': 'BAE', 'country_code': 'FR', 'name': 'Barcelonnette'},
#   {'code': 'BAF', 'country_code': 'US', 'name': 'Westfield'},
#   {'code': 'BAG', 'country_code': 'PH', 'name': 'Baguio'},
#   {'code': 'BAH', 'country_code': 'BH', 'name': 'Manama'},
#   {'code': 'BAI', 'country_code': 'CR', 'name': 'Buenos Aires'},
#   {'code': 'BAJ', 'country_code': 'PG', 'name': 'Bali'},
#   {'code': 'BAK', 'country_code': 'AZ', 'name': 'Baku'},
#   {'code': 'BAL', 'country_code': 'TR', 'name': 'Batman'},
#   {'code': 'BAM', 'country_code': 'US', 'name': 'Battle Mountain'},
#   {'code': 'BAN', 'country_code': 'CD', 'name': 'Basongo'},
#   {'code': 'BAO', 'country_code': 'TH', 'name': 'Ban Mak Khaen'},
#   {'code': 'BAP', 'country_code': 'PG', 'name': 'Baibara'},
#   {'code': 'BAQ', 'country_code': 'CO', 'name': 'Barranquilla'},
#   {'code': 'BAR', 'country_code': 'US', 'name': 'Baker Island'},
#   {'code': 'BAS', 'country_code': 'SB', 'name': 'Balalae'},
#   {'code': 'BAT', 'country_code': 'BR', 'name': 'Barretos'},
#   {'code': 'BAV', 'country_code': 'CN', 'name': 'Baotou'},
#   {'code': 'BAW', 'country_code': 'GA', 'name': 'Biawonque'},
#   {'code': 'BAX', 'country_code': 'RU', 'name': 'Barnaul'},
#   {'code': 'BAY', 'country_code': 'RO', 'name': 'Baia Mare'},
#   {'code': 'BAZ', 'country_code': 'BR', 'name': 'Barbelos'},
#   {'code': 'BBA', 'country_code': 'CL', 'name': 'Balmaceda'},
#   {'code': 'BBB', 'country_code': 'US', 'name': 'Benson'},
#   {'code': 'BBC', 'country_code': 'US', 'name': 'Bay City'},
#   {'code': 'BBD', 'country_code': 'US', 'name': 'Brady'},
#   {'code': 'BBF', 'country_code': 'US', 'name': 'Burlington'},
#   {'code': 'BBG', 'country_code': 'KI', 'name': 'Butaritari'},
#   {'code': 'BBH', 'country_code': 'DE', 'name': 'Barth'},
#   {'code': 'BBI', 'country_code': 'IN', 'name': 'Bhubaneswar'},
#   {'code': 'BBJ', 'country_code': 'DE', 'name': 'Bitburg'},
#   {'code': 'BBK', 'country_code': 'BW', 'name': 'Kasane'},
#   {'code': 'BBM', 'country_code': 'KH', 'name': 'Battambang'},
#   {'code': 'BBN', 'country_code': 'MY', 'name': 'Bario'},
#   {'code': 'BBO', 'country_code': 'SO', 'name': 'Berbera'},
#   {'code': 'BBP', 'country_code': 'GB', 'name': 'Bembridge'},
#   {'code': 'BBQ', 'country_code': 'AG', 'name': 'Barbuda'},
#   {'code': 'BBR', 'country_code': 'GP', 'name': 'Basse Terre'},
#   {'code': 'BBS', 'country_code': 'GB', 'name': 'Yateley'},
#   {'code': 'BBT', 'country_code': 'CF', 'name': 'Berberati'},
#   {'code': 'BBV', 'country_code': 'CI', 'name': 'Bereby'},
#   {'code': 'BBW', 'country_code': 'US', 'name': 'Broken Bow'},
#   {'code': 'BBX', 'country_code': 'US', 'name': 'Blue Bell'},
#   {'code': 'BBY', 'country_code': 'CF', 'name': 'Bambari'},
#   {'code': 'BBZ', 'country_code': 'ZM', 'name': 'Zambezi'},
#   {'code': 'BCA', 'country_code': 'CU', 'name': 'Baracoa'},
#   {'code': 'BCB', 'country_code': 'US', 'name': 'Blacksburg'},
#   {'code': 'BCC', 'country_code': 'US', 'name': 'Bear Creek'},
#   {'code': 'BCD', 'country_code': 'PH', 'name': 'Bacolod'},
#   {'code': 'BCE', 'country_code': 'US', 'name': 'Bryce'},
#   {'code': 'BCF', 'country_code': 'CF', 'name': 'Bouca'},
#   {'code': 'BCG', 'country_code': 'GY', 'name': 'Bemichi'},
#   {'code': 'BCH', 'country_code': 'TL', 'name': 'Baucau'},
#   {'code': 'BCI', 'country_code': 'AU', 'name': 'Barcaldine'},
#   {'code': 'BCJ', 'country_code': 'US', 'name': 'Baca Grande'},
#   {'code': 'BCK', 'country_code': 'AU', 'name': 'Bolwarra'},
#   {'code': 'BCL', 'country_code': 'CR', 'name': 'Barra Colorado'},
#   {'code': 'BCM', 'country_code': 'RO', 'name': 'Bacau'},
#   {'code': 'BCN', 'country_code': 'ES', 'name': 'Barcelona'},
#   {'code': 'BCO', 'country_code': 'ET', 'name': 'Jinka'},
#   {'code': 'BCP', 'country_code': 'PG', 'name': 'Bambu'},
#   {'code': 'BCQ', 'country_code': 'LY', 'name': 'Brack'},
#   {'code': 'BCR', 'country_code': 'BR', 'name': 'Boca Do Acre'},
#   {'code': 'BCS', 'country_code': 'US', 'name': 'Belle Chasse'},
#   {'code': 'BCT', 'country_code': 'US', 'name': 'Boca Raton'},
#   {'code': 'BCU', 'country_code': 'NG', 'name': 'Bauchi'},
#   {'code': 'BCV', 'country_code': 'BZ', 'name': 'Belmopan'},
#   {'code': 'BCW', 'country_code': 'MZ', 'name': 'Benguera Island'},
#   {'code': 'BCX', 'country_code': 'RU', 'name': 'Beloreck'},
#   {'code': 'BCY', 'country_code': 'ET', 'name': 'Bulchi'},
#   {'code': 'BCZ', 'country_code': 'AU', 'name': 'Bickerton Island'},
#   {'code': 'BDA', 'country_code': 'BM', 'name': 'St. George'},
#   {'code': 'BDB', 'country_code': 'AU', 'name': 'Bundaberg'},
#   {'code': 'BDC', 'country_code': 'BR', 'name': 'Barra Do Corda'},
#   {'code': 'BDD', 'country_code': 'AU', 'name': 'Badu Island'},
#   {'code': 'BDE', 'country_code': 'US', 'name': 'Baudette'},
#   {'code': 'BDF', 'country_code': 'US', 'name': 'Bradford'},
#   {'code': 'BDG', 'country_code': 'US', 'name': 'Blanding'},
#   {'code': 'BDH', 'country_code': 'IR', 'name': 'Bandar Lengeh'},
#   {'code': 'BDI', 'country_code': 'SC', 'name': 'Bird Island'},
#   {'code': 'BDJ', 'country_code': 'ID', 'name': 'Banjarmasin'},
#   {'code': 'BDK', 'country_code': 'CI', 'name': 'Bondoukou'},
#   {'code': 'BDL', 'country_code': 'US', 'name': 'Windsor Locks'},
#   {'code': 'BDM', 'country_code': 'TR', 'name': 'Bandirma'},
#   {'code': 'BDN', 'country_code': 'PK', 'name': 'Badin'},
#   {'code': 'BDO', 'country_code': 'ID', 'name': 'Bandung'},
#   {'code': 'BDP', 'country_code': 'NP', 'name': 'Bhadrapur'},
#   {'code': 'BDQ', 'country_code': 'IN', 'name': 'Vadodara'},
#   {'code': 'BDR', 'country_code': 'US', 'name': 'Bridgeport'},
#   {'code': 'BDS', 'country_code': 'IT', 'name': 'Brindisi'},
#   {'code': 'BDT', 'country_code': 'CD', 'name': 'Gbadolite'},
#   {'code': 'BDU', 'country_code': 'NO', 'name': 'Bardufoss'},
#   {'code': 'BDV', 'country_code': 'CD', 'name': 'Moba'},
#   {'code': 'BDW', 'country_code': 'AU', 'name': 'Bedford Downs'},
#   {'code': 'BDX', 'country_code': 'US', 'name': 'Broadus'},
#   {'code': 'BDY', 'country_code': 'US', 'name': 'Bandon'},
#   {'code': 'BDZ', 'country_code': 'PG', 'name': 'Baindoung'},
#   {'code': 'BEA', 'country_code': 'PG', 'name': 'Bereina'},
#   {'code': 'BEB', 'country_code': 'GB', 'name': 'Benbecula'},
#   {'code': 'BED', 'country_code': 'US', 'name': 'Bedford'},
#   {'code': 'BEE', 'country_code': 'AU', 'name': 'Beagle Bay'},
#   {'code': 'BEF', 'country_code': 'NI', 'name': 'Bluefields'},
#   {'code': 'BEG', 'country_code': 'RS', 'name': 'Belgrade'},
#   {'code': 'BEH', 'country_code': 'US', 'name': 'Benton Harbor'},
#   {'code': 'BEI', 'country_code': 'ET', 'name': 'Beica'},
#   {'code': 'BEJ', 'country_code': 'ID', 'name': 'Tanjung Redep'},
#   {'code': 'BEK', 'country_code': 'IN', 'name': 'Bareli'},
#   {'code': 'BEL', 'country_code': 'BR', 'name': 'Belem'},
#   {'code': 'BEN', 'country_code': 'LY', 'name': 'Benghazi'},
#   {'code': 'BEP', 'country_code': 'IN', 'name': 'Bellary'},
#   {'code': 'BEQ', 'country_code': 'GB', 'name': 'Bury St Edmunds'},
#   {'code': 'BER', 'country_code': 'DE', 'name': 'Berlin'},
#   {'code': 'BES', 'country_code': 'FR', 'name': 'Brest'},
#   {'code': 'BET', 'country_code': 'US', 'name': 'Bethel'},
#   {'code': 'BEU', 'country_code': 'AU', 'name': 'Bedourie'},
#   {'code': 'BEV', 'country_code': 'IL', 'name': 'Beer Sheba'},
#   {'code': 'BEW', 'country_code': 'MZ', 'name': 'Beira'},
#   {'code': 'BEX', 'country_code': 'GB', 'name': 'Benson'},
#   {'code': 'BEY', 'country_code': 'LB', 'name': 'Beirut'},
#   {'code': 'BEZ', 'country_code': 'KI', 'name': 'Beru'},
#   {'code': 'BFA', 'country_code': 'PY', 'name': 'Bahia Negra'},
#   {'code': 'BFB', 'country_code': 'US', 'name': 'Blue Fox Bay'},
#   {'code': 'BFC', 'country_code': 'AU', 'name': 'Bloomfield'},
#   {'code': 'BFD', 'country_code': 'US', 'name': 'Bradford'},
#   {'code': 'BFE', 'country_code': 'DE', 'name': 'Bielefeld'},
#   {'code': 'BFF', 'country_code': 'US', 'name': 'Scottsbluff'},
#   {'code': 'BFG', 'country_code': 'US', 'name': 'Bullfrog Basin'},
#   {'code': 'BFH', 'country_code': 'BR', 'name': 'Curitiba.'},
#   {'code': 'BFL', 'country_code': 'US', 'name': 'Bakersfield'},
#   {'code': 'BFN', 'country_code': 'ZA', 'name': 'Bloemfontein'},
#   {'code': 'BFO', 'country_code': 'ZW', 'name': 'Buffalo Range'},
#   {'code': 'BFP', 'country_code': 'US', 'name': 'Beaver Falls'},
#   {'code': 'BFQ', 'country_code': 'PA', 'name': 'Bahia Pinas'},
#   {'code': 'BFR', 'country_code': 'US', 'name': 'Bedford'},
#   {'code': 'BFS', 'country_code': 'GB', 'name': 'Belfast'},
#   {'code': 'BFT', 'country_code': 'US', 'name': 'Beaufort'},
#   {'code': 'BFU', 'country_code': 'CN', 'name': 'Bengbu'},
#   {'code': 'BFV', 'country_code': 'TH', 'name': 'Buri Ram'},
#   {'code': 'BFW', 'country_code': 'DZ', 'name': 'Sidi Belabbes'},
#   {'code': 'BFX', 'country_code': 'CM', 'name': 'Bafoussam'},
#   {'code': 'BGA', 'country_code': 'CO', 'name': 'Bucaramanga'},
#   {'code': 'BGB', 'country_code': 'GA', 'name': 'Booue'},
#   {'code': 'BGC', 'country_code': 'PT', 'name': 'Braganca'},
#   {'code': 'BGD', 'country_code': 'US', 'name': 'Borger'},
#   {'code': 'BGE', 'country_code': 'US', 'name': 'Bainbridge'},
#   {'code': 'BGF', 'country_code': 'CF', 'name': 'Bangui'},
#   {'code': 'BGG', 'country_code': 'TR', 'name': 'Bongouanou'},
#   {'code': 'BGH', 'country_code': 'MR', 'name': 'Boghe'},
#   {'code': 'BGI', 'country_code': 'BB', 'name': 'Bridgetown'},
#   {'code': 'BGJ', 'country_code': 'IS', 'name': 'Borgarfjordur Eystri'},
#   {'code': 'BGK', 'country_code': 'BZ', 'name': 'Big Creek'},
#   {'code': 'BGL', 'country_code': 'NP', 'name': 'Baglung'},
#   {'code': 'BGM', 'country_code': 'US', 'name': 'Binghamton'},
#   {'code': 'BGO', 'country_code': 'NO', 'name': 'Bergen'},
#   {'code': 'BGP', 'country_code': 'GA', 'name': 'Bongo'},
#   {'code': 'BGQ', 'country_code': 'US', 'name': 'Big Lake'},
#   {'code': 'BGR', 'country_code': 'US', 'name': 'Bangor'},
#   {'code': 'BGT', 'country_code': 'US', 'name': 'Bagdad'},
#   {'code': 'BGU', 'country_code': 'CF', 'name': 'Bangassou'},
#   {'code': 'BGV', 'country_code': 'BR', 'name': 'Bento Goncalves'},
#   {'code': 'BGW', 'country_code': 'IQ', 'name': 'Baghdad'},
#   {'code': 'BGX', 'country_code': 'BR', 'name': 'Bage'},
#   {'code': 'BGZ', 'country_code': 'PT', 'name': 'Braga'},
#   {'code': 'BHA', 'country_code': 'EC', 'name': 'Bahia De Caraquez'},
#   {'code': 'BHB', 'country_code': 'US', 'name': 'Bar Harbor'},
#   {'code': 'BHC', 'country_code': 'PK', 'name': 'Bhurban'},
#   {'code': 'BHE', 'country_code': 'NZ', 'name': 'Blenheim'},
#   {'code': 'BHF', 'country_code': 'CO', 'name': 'Bahia Cupica'},
#   {'code': 'BHG', 'country_code': 'HN', 'name': 'Brus Laguna'},
#   {'code': 'BHH', 'country_code': 'SA', 'name': 'Bisha'},
#   {'code': 'BHI', 'country_code': 'AR', 'name': 'Bahia Blanca'},
#   {'code': 'BHJ', 'country_code': 'IN', 'name': 'Bhuj'},
#   {'code': 'BHK', 'country_code': 'UZ', 'name': 'Bukhara'},
#   {'code': 'BHL', 'country_code': 'MX', 'name': 'Bahia Angeles'},
#   {'code': 'BHM', 'country_code': 'US', 'name': 'Birmingham'},
#   {'code': 'BHN', 'country_code': 'YE', 'name': 'Beihan'},
#   {'code': 'BHO', 'country_code': 'IN', 'name': 'Bhopal'},
#   {'code': 'BHP', 'country_code': 'NP', 'name': 'Bhojpur'},
#   {'code': 'BHQ', 'country_code': 'AU', 'name': 'Broken Hill'},
#   {'code': 'BHR', 'country_code': 'NP', 'name': 'Bharatpur'},
#   {'code': 'BHS', 'country_code': 'AU', 'name': 'Bathurst'},
#   {'code': 'BHT', 'country_code': 'AU', 'name': 'Brighton Downs'},
#   {'code': 'BHU', 'country_code': 'IN', 'name': 'Bhavnagar'},
#   {'code': 'BHV', 'country_code': 'PK', 'name': 'Bahawalpur'},
#   {'code': 'BHX', 'country_code': 'GB', 'name': 'Birmingham'},
#   {'code': 'BHY', 'country_code': 'CN', 'name': 'Beihai'},
#   {'code': 'BHZ', 'country_code': 'BR', 'name': 'Belo Horizonte'},
#   {'code': 'BIA', 'country_code': 'FR', 'name': 'Bastia'},
#   {'code': 'BIB', 'country_code': 'SO', 'name': 'Baidoa'},
#   {'code': 'BIC', 'country_code': 'US', 'name': 'Big Creek'},
#   {'code': 'BID', 'country_code': 'US', 'name': 'Block Island'},
#   {'code': 'BIE', 'country_code': 'US', 'name': 'Beatrice'},
#   {'code': 'BIG', 'country_code': 'US', 'name': 'Big Delta'},
#   {'code': 'BIH', 'country_code': 'US', 'name': 'Bishop'},
#   {'code': 'BII', 'country_code': 'MH', 'name': 'Bikini Atoll'},
#   {'code': 'BIJ', 'country_code': 'PG', 'name': 'Biliau'},
#   {'code': 'BIK', 'country_code': 'ID', 'name': 'Biak'},
#   {'code': 'BIL', 'country_code': 'US', 'name': 'Billings'},
#   {'code': 'BIM', 'country_code': 'BS', 'name': 'Bimini'},
#   {'code': 'BIN', 'country_code': 'AF', 'name': 'Bamiyan'},
#   {'code': 'BIO', 'country_code': 'ES', 'name': 'Bilbao'},
#   {'code': 'BIP', 'country_code': 'AU', 'name': 'Bulimba'},
#   {'code': 'BIQ', 'country_code': 'FR', 'name': 'Biarritz'},
#   {'code': 'BIR', 'country_code': 'NP', 'name': 'Biratnagar'},
#   {'code': 'BIS', 'country_code': 'US', 'name': 'Bismarck'},
#   {'code': 'BIT', 'country_code': 'NP', 'name': 'Baitadi'},
#   {'code': 'BIU', 'country_code': 'IS', 'name': 'Bildudalur'},
#   {'code': 'BIV', 'country_code': 'CF', 'name': 'Bria'},
#   {'code': 'BIW', 'country_code': 'AU', 'name': 'Billiluna'},
#   {'code': 'BIX', 'country_code': 'US', 'name': 'Biloxi'},
#   {'code': 'BIY', 'country_code': 'ZA', 'name': 'Bisho'},
#   {'code': 'BIZ', 'country_code': 'PG', 'name': 'Bimin'},
#   {'code': 'BJA', 'country_code': 'DZ', 'name': 'Bejaia'},
#   {'code': 'BJB', 'country_code': 'IR', 'name': 'Bojnord'},
#   {'code': 'BJC', 'country_code': 'US', 'name': 'Broomfield'},
#   {'code': 'BJD', 'country_code': 'IS', 'name': 'Bakkafjordur'},
#   {'code': 'BJE', 'country_code': 'SD', 'name': 'Baleela'},
#   {'code': 'BJF', 'country_code': 'NO', 'name': 'Batsfjord'},
#   {'code': 'BJG', 'country_code': 'ID', 'name': 'Bolaang'},
#   {'code': 'BJH', 'country_code': 'NP', 'name': 'Bajhang'},
#   {'code': 'BJI', 'country_code': 'US', 'name': 'Bemidji'},
#   {'code': 'BJJ', 'country_code': 'US', 'name': 'Wooster'},
#   {'code': 'BJK', 'country_code': 'ID', 'name': 'Benjina'},
#   {'code': 'BJL', 'country_code': 'GM', 'name': 'Banjul'},
#   {'code': 'BJM', 'country_code': 'BI', 'name': 'Bujumbura'},
#   {'code': 'BJN', 'country_code': 'MZ', 'name': 'Bajone'},
#   {'code': 'BJO', 'country_code': 'BO', 'name': 'Bermejo'},
#   {'code': 'BJP', 'country_code': 'BR', 'name': 'Braganca Paulista'},
#   {'code': 'BJQ', 'country_code': 'OM', 'name': 'Bahja'},
#   {'code': 'BJR', 'country_code': 'ET', 'name': 'Bahar Dar'},
#   {'code': 'BJS', 'country_code': 'CN', 'name': 'Beijing'},
#   {'code': 'BJT', 'country_code': 'LK', 'name': 'Bentota River'},
#   {'code': 'BJU', 'country_code': 'NP', 'name': 'Bajura'},
#   {'code': 'BJV', 'country_code': 'TR', 'name': 'Milas'},
#   {'code': 'BJW', 'country_code': 'ID', 'name': 'Bajawa'},
#   {'code': 'BJX', 'country_code': 'MX', 'name': 'León'},
#   {'code': 'BJZ', 'country_code': 'ES', 'name': 'Badajoz'},
#   {'code': 'BKB', 'country_code': 'IN', 'name': 'Bikaner'},
#   {'code': 'BKC', 'country_code': 'US', 'name': 'Buckland'},
#   {'code': 'BKD', 'country_code': 'US', 'name': 'Breckenridge'},
#   {'code': 'BKE', 'country_code': 'US', 'name': 'Baker'},
#   {'code': 'BKF', 'country_code': 'US', 'name': 'Katmai National Park'},
#   {'code': 'BKG', 'country_code': 'US', 'name': 'Branson'},
#   {'code': 'BKH', 'country_code': 'US', 'name': 'Kekaha'},
#   {'code': 'BKI', 'country_code': 'MY', 'name': 'Kota-Kinabalu'},
#   {'code': 'BKJ', 'country_code': 'GN', 'name': 'Boke'},
#   {'code': 'BKK', 'country_code': 'TH', 'name': 'Bangkok'},
#   {'code': 'BKM', 'country_code': 'MY', 'name': 'Bakalalan'},
#   {'code': 'BKO', 'country_code': 'ML', 'name': 'Bamako'},
#   {'code': 'BKP', 'country_code': 'AU', 'name': 'Barkly Downs'},
#   {'code': 'BKQ', 'country_code': 'AU', 'name': 'Blackall'},
#   {'code': 'BKR', 'country_code': 'TD', 'name': 'Bokoro'},
#   {'code': 'BKS', 'country_code': 'ID', 'name': 'Bengkulu'},
#   {'code': 'BKT', 'country_code': 'US', 'name': 'Blackstone'},
#   {'code': 'BKU', 'country_code': 'MG', 'name': 'Betioky'},
#   {'code': 'BKW', 'country_code': 'US', 'name': 'Beckley'},
#   {'code': 'BKX', 'country_code': 'US', 'name': 'Brookings'},
#   {'code': 'BKY', 'country_code': 'CD', 'name': 'Bukavu'},
#   {'code': 'BKZ', 'country_code': 'TZ', 'name': 'Bukoba'},
#   {'code': 'BLA', 'country_code': 'VE', 'name': 'Barcelona'},
#   {'code': 'BLB', 'country_code': 'PA', 'name': 'Balboa'},
#   {'code': 'BLC', 'country_code': 'CM', 'name': 'Bali'},
#   {'code': 'BLE', 'country_code': 'SE', 'name': 'Borlange'},
#   {'code': 'BLF', 'country_code': 'US', 'name': 'Princeton'},
#   {'code': 'BLG', 'country_code': 'MY', 'name': 'Belaga'},
#   {'code': 'BLH', 'country_code': 'US', 'name': 'Blythe'},
#   {'code': 'BLI', 'country_code': 'US', 'name': 'Bellingham'},
#   {'code': 'BLJ', 'country_code': 'DZ', 'name': 'Batna'},
#   {'code': 'BLK', 'country_code': 'GB', 'name': 'Blackpool'},
#   {'code': 'BLL', 'country_code': 'DK', 'name': 'Billund'},
#   {'code': 'BLM', 'country_code': 'US', 'name': 'Belmar - Farmingdale'},
#   {'code': 'BLN', 'country_code': 'AU', 'name': 'Benalla'},
#   {'code': 'BLO', 'country_code': 'IS', 'name': 'Blonduos'},
#   {'code': 'BLP', 'country_code': 'PE', 'name': 'Bellavista'},
#   {'code': 'BLQ', 'country_code': 'IT', 'name': 'Bologna'},
#   {'code': 'BLR', 'country_code': 'IN', 'name': 'Bangalore'},
#   {'code': 'BLS', 'country_code': 'AU', 'name': 'Bollon'},
#   {'code': 'BLT', 'country_code': 'AU', 'name': 'Blackwater'},
#   {'code': 'BLU', 'country_code': 'US', 'name': 'Blue Canyon'},
#   {'code': 'BLV', 'country_code': 'US', 'name': 'Belleville'},
#   {'code': 'BLW', 'country_code': 'US', 'name': 'Waimanalo'},
#   {'code': 'BLX', 'country_code': 'IT', 'name': 'Belluno'},
#   {'code': 'BLY', 'country_code': 'IE', 'name': 'Belmullet'},
#   {'code': 'BLZ', 'country_code': 'MW', 'name': 'Blantyre'},
#   {'code': 'BMB', 'country_code': 'CD', 'name': 'Bumba'},
#   {'code': 'BMC', 'country_code': 'US', 'name': 'Brigham City'},
#   {'code': 'BMD', 'country_code': 'MG', 'name': 'Belo'},
#   {'code': 'BME', 'country_code': 'AU', 'name': 'Broome'},
#   {'code': 'BMF', 'country_code': 'CF', 'name': 'Bakouma'},
#   {'code': 'BMG', 'country_code': 'US', 'name': 'Bloomington'},
#   {'code': 'BMH', 'country_code': 'PG', 'name': 'Bomai'},
#   {'code': 'BMI', 'country_code': 'US', 'name': 'Bloomington'},
#   {'code': 'BMJ', 'country_code': 'GY', 'name': 'Baramita'},
#   {'code': 'BMK', 'country_code': 'DE', 'name': 'Borkum'},
#   {'code': 'BML', 'country_code': 'US', 'name': 'Berlin'},
#   {'code': 'BMM', 'country_code': 'GA', 'name': 'Bitam'},
#   {'code': 'BMN', 'country_code': 'IQ', 'name': 'Bamerny'},
#   {'code': 'BMO', 'country_code': 'MM', 'name': 'Bhamo'},
#   {'code': 'BMP', 'country_code': 'AU', 'name': 'Brampton Island'},
#   {'code': 'BMQ', 'country_code': 'KE', 'name': 'Bamburi'},
#   {'code': 'BMR', 'country_code': 'DE', 'name': 'Baltrum Island'},
#   {'code': 'BMS', 'country_code': 'BR', 'name': 'Brumado'},
#   {'code': 'BMU', 'country_code': 'ID', 'name': 'Bima'},
#   {'code': 'BMV', 'country_code': 'VN', 'name': 'Banmethuot'},
#   {'code': 'BMW', 'country_code': 'DZ', 'name': 'Bordj Badji Mokhtar'},
#   {'code': 'BMX', 'country_code': 'US', 'name': 'Big Mountain'},
#   {'code': 'BMY', 'country_code': 'NC', 'name': 'Belep Island'},
#   {'code': 'BMZ', 'country_code': 'PG', 'name': 'Bamu'},
#   {'code': 'BNA', 'country_code': 'US', 'name': 'Nashville'},
#   {'code': 'BNB', 'country_code': 'CD', 'name': 'Boende'},
#   {'code': 'BNC', 'country_code': 'CD', 'name': 'Beni'},
#   {'code': 'BND', 'country_code': 'IR', 'name': 'Bandar Abbas'},
#   {'code': 'BNE', 'country_code': 'AU', 'name': 'Brisbane'},
#   {'code': 'BNF', 'country_code': 'US', 'name': 'Baranof'},
#   {'code': 'BNG', 'country_code': 'US', 'name': 'Banning'},
#   {'code': 'BNI', 'country_code': 'NG', 'name': 'Benin City'},
#   {'code': 'BNK', 'country_code': 'AU', 'name': 'Ballina'},
#   {'code': 'BNL', 'country_code': 'US', 'name': 'Barnwell'},
#   {'code': 'BNM', 'country_code': 'PG', 'name': 'Bodinumu'},
#   {'code': 'BNN', 'country_code': 'NO', 'name': 'Bronnoysund'},
#   {'code': 'BNO', 'country_code': 'US', 'name': 'Burns'},
#   {'code': 'BNP', 'country_code': 'PK', 'name': 'Bannu'},
#   {'code': 'BNQ', 'country_code': 'PH', 'name': 'Baganga'},
#   {'code': 'BNR', 'country_code': 'BF', 'name': 'Banfora'},
#   {'code': 'BNS', 'country_code': 'VE', 'name': 'Barinas'},
#   {'code': 'BNT', 'country_code': 'PG', 'name': 'Bundi'},
#   {'code': 'BNU', 'country_code': 'BR', 'name': 'Blumenau'},
#   {'code': 'BNV', 'country_code': 'PG', 'name': 'Boana'},
#   {'code': 'BNW', 'country_code': 'US', 'name': 'Boone'},
#   {'code': 'BNX', 'country_code': 'BA', 'name': 'Banja Luka'},
#   {'code': 'BNY', 'country_code': 'SB', 'name': 'Bellona'},
#   {'code': 'BNZ', 'country_code': 'PG', 'name': 'Banz'},
#   {'code': 'BOA', 'country_code': 'CD', 'name': 'Boma'},
#   {'code': 'BOB', 'country_code': 'PF', 'name': 'Bora Bora'},
#   {'code': 'BOC', 'country_code': 'PA', 'name': 'Bocas Del Toro'},
#   {'code': 'BOD', 'country_code': 'FR', 'name': 'Bordeaux'},
#   {'code': 'BOE', 'country_code': 'CG', 'name': 'Boundji'},
#   {'code': 'BOG', 'country_code': 'CO', 'name': 'Bogota'},
#   {'code': 'BOH', 'country_code': 'GB', 'name': 'Bournemouth'},
#   {'code': 'BOI', 'country_code': 'US', 'name': 'Boise'},
#   {'code': 'BOJ', 'country_code': 'BG', 'name': 'Bourgas'},
#   {'code': 'BOK', 'country_code': 'US', 'name': 'Brookings'},
#   {'code': 'BOL', 'country_code': 'GB', 'name': 'Ballykelly'},
#   {'code': 'BOM', 'country_code': 'IN', 'name': 'Mumbai'},
#   {'code': 'BON', 'country_code': 'BQ', 'name': 'Kralendijk'},
#   {'code': 'BOO', 'country_code': 'NO', 'name': 'Bodo'},
#   {'code': 'BOP', 'country_code': 'CF', 'name': 'Bouar'},
#   {'code': 'BOQ', 'country_code': 'PG', 'name': 'Boku'},
#   {'code': 'BOS', 'country_code': 'US', 'name': 'Boston'},
#   {'code': 'BOT', 'country_code': 'PG', 'name': 'Boset'},
#   {'code': 'BOU', 'country_code': 'FR', 'name': 'Bourges'},
#   {'code': 'BOV', 'country_code': 'PG', 'name': 'Boang'},
#   {'code': 'BOW', 'country_code': 'US', 'name': 'Bartow'},
#   {'code': 'BOX', 'country_code': 'AU', 'name': 'Borroloola'},
#   {'code': 'BOY', 'country_code': 'BF', 'name': 'Bobo Dioulasso'},
#   {'code': 'BOZ', 'country_code': 'CF', 'name': 'Bozoum'},
#   {'code': 'BPA', 'country_code': 'US', 'name': 'Bethpage'},
#   {'code': 'BPB', 'country_code': 'PG', 'name': 'Boridi'},
#   {'code': 'BPC', 'country_code': 'CM', 'name': 'Bamenda'},
#   {'code': 'BPD', 'country_code': 'PG', 'name': 'Bapi'},
#   {'code': 'BPE', 'country_code': 'MM', 'name': 'Bagan'},
#   {'code': 'BPF', 'country_code': 'SB', 'name': 'Batuna'},
#   {'code': 'BPG', 'country_code': 'BR', 'name': 'Barra Do Garcas'},
#   {'code': 'BPH', 'country_code': 'PH', 'name': 'Bislig'},
#   {'code': 'BPI', 'country_code': 'US', 'name': 'Big Piney'},
#   {'code': 'BPK', 'country_code': 'PG', 'name': 'Biangabip'},
#   {'code': 'BPL', 'country_code': 'CN', 'name': 'Bole'},
#   {'code': 'BPN', 'country_code': 'ID', 'name': 'Balikpapan'},
#   {'code': 'BPO', 'country_code': 'CN', 'name': "Bo'ao"},
#   {'code': 'BPS', 'country_code': 'BR', 'name': 'Porto Seguro'},
#   {'code': 'BPT', 'country_code': 'US', 'name': 'Beaumont'},
#   {'code': 'BPU', 'country_code': 'JP', 'name': 'Beppu'},
#   {'code': 'BPX', 'country_code': 'CN', 'name': 'Bangda'},
#   {'code': 'BPY', 'country_code': 'MG', 'name': 'Besalampy'},
#   {'code': 'BQA', 'country_code': 'PH', 'name': 'Baler'},
#   {'code': 'BQB', 'country_code': 'AU', 'name': 'Bussellton'},
#   {'code': 'BQE', 'country_code': 'GW', 'name': 'Bubaque'},
#   {'code': 'BQG', 'country_code': 'RU', 'name': 'Bogorodskoye'},
#   {'code': 'BQI', 'country_code': 'NA', 'name': 'Bagani'},
#   {'code': 'BQJ', 'country_code': 'RU', 'name': 'Batagay'},
#   {'code': 'BQL', 'country_code': 'AU', 'name': 'Boulia'},
#   {'code': 'BQN', 'country_code': 'PR', 'name': 'Aguadilla'},
#   {'code': 'BQO', 'country_code': 'CI', 'name': 'Bouna'},
#   {'code': 'BQQ', 'country_code': 'BR', 'name': 'Barra'},
#   {'code': 'BQS', 'country_code': 'RU', 'name': 'Blagoveschensk'},
#   {'code': 'BQT', 'country_code': 'BY', 'name': 'Brest'},
#   {'code': 'BQU', 'country_code': 'VC', 'name': 'Bequia'},
#   {'code': 'BQW', 'country_code': 'AU', 'name': 'Balgo Hills'},
#   {'code': 'BRA', 'country_code': 'BR', 'name': 'Barreiras'},
#   {'code': 'BRB', 'country_code': 'BR', 'name': 'Barreirinhas'},
#   {'code': 'BRC', 'country_code': 'AR', 'name': 'San Carlos DeBariloche'},
#   {'code': 'BRD', 'country_code': 'US', 'name': 'Brainerd'},
#   {'code': 'BRE', 'country_code': 'DE', 'name': 'Bremen'},
#   {'code': 'BRG', 'country_code': 'US', 'name': 'Whitesburg'},
#   {'code': 'BRH', 'country_code': 'PG', 'name': 'Brahman'},
#   {'code': 'BRI', 'country_code': 'IT', 'name': 'Bari'},
#   {'code': 'BRJ', 'country_code': 'AU', 'name': 'Bright'},
#   {'code': 'BRK', 'country_code': 'AU', 'name': 'Bourke'},
#   {'code': 'BRL', 'country_code': 'US', 'name': 'Burlington'},
#   {'code': 'BRM', 'country_code': 'VE', 'name': 'Barquisimeto'},
#   {'code': 'BRN', 'country_code': 'CH', 'name': 'Berne'},
#   {'code': 'BRO', 'country_code': 'US', 'name': 'Brownsville'},
#   {'code': 'BRP', 'country_code': 'PG', 'name': 'Biaru'},
#   {'code': 'BRQ', 'country_code': 'CZ', 'name': 'Brno'},
#   {'code': 'BRR', 'country_code': 'GB', 'name': 'Barra'},
#   {'code': 'BRS', 'country_code': 'GB', 'name': 'Bristol'},
#   {'code': 'BRT', 'country_code': 'AU', 'name': 'Bathurst Island'},
#   {'code': 'BRU', 'country_code': 'BE', 'name': 'Brussels'},
#   {'code': 'BRV', 'country_code': 'DE', 'name': 'Bremerhaven'},
#   {'code': 'BRW', 'country_code': 'US', 'name': 'Barrow'},
#   {'code': 'BRX', 'country_code': 'DO', 'name': 'Barahona'},
#   {'code': 'BRY', 'country_code': 'US', 'name': 'Bardstown'},
#   {'code': 'BRZ', 'country_code': 'IT', 'name': 'Borotou'},
#   {'code': 'BSA', 'country_code': 'SO', 'name': 'Bossaso'},
#   {'code': 'BSB', 'country_code': 'BR', 'name': 'Brasilia'},
#   {'code': 'BSC', 'country_code': 'CO', 'name': 'Bahia Solano'},
#   {'code': 'BSD', 'country_code': 'CN', 'name': 'Baoshan'},
#   {'code': 'BSE', 'country_code': 'MY', 'name': 'Sematan'},
#   {'code': 'BSF', 'country_code': 'US', 'name': 'Pohakuloa'},
#   {'code': 'BSG', 'country_code': 'GQ', 'name': 'Bata'},
#   {'code': 'BSH', 'country_code': 'GB', 'name': 'Brighton'},
#   {'code': 'BSI', 'country_code': 'US', 'name': 'Blairsville'},
#   {'code': 'BSJ', 'country_code': 'AU', 'name': 'Bairnsdale'},
#   {'code': 'BSK', 'country_code': 'DZ', 'name': 'Biskra'},
#   {'code': 'BSM', 'country_code': 'IR', 'name': 'Bishe-kola'},
#   {'code': 'BSN', 'country_code': 'CF', 'name': 'Bossangoa'},
#   {'code': 'BSO', 'country_code': 'PH', 'name': 'Basco'},
#   {'code': 'BSP', 'country_code': 'PG', 'name': 'Bensbach'},
#   {'code': 'BSQ', 'country_code': 'US', 'name': 'Bisbee'},
#   {'code': 'BSR', 'country_code': 'IQ', 'name': 'Basra'},
#   {'code': 'BSS', 'country_code': 'BR', 'name': 'Balsas'},
#   {'code': 'BST', 'country_code': 'AF', 'name': 'Bost'},
#   {'code': 'BSU', 'country_code': 'CD', 'name': 'Basankusu'},
#   {'code': 'BSV', 'country_code': 'MG', 'name': 'Besakoa'},
#   {'code': 'BSW', 'country_code': 'US', 'name': 'Boswell Bay'},
#   {'code': 'BSX', 'country_code': 'MM', 'name': 'Bassein'},
#   {'code': 'BSY', 'country_code': 'SO', 'name': 'Bardera'},
#   {'code': 'BSZ', 'country_code': 'US', 'name': 'Bartletts'},
#   {'code': 'BTA', 'country_code': 'CM', 'name': 'Yaoundé'},
#   {'code': 'BTB', 'country_code': 'CG', 'name': 'Betou'},
#   {'code': 'BTC', 'country_code': 'LK', 'name': 'Batticaloa'},
#   {'code': 'BTD', 'country_code': 'AU', 'name': 'Brunette Downs'},
#   {'code': 'BTE', 'country_code': 'SL', 'name': 'Bonthe'},
#   {'code': 'BTF', 'country_code': 'US', 'name': 'Bountiful'},
#   {'code': 'BTG', 'country_code': 'CF', 'name': 'Batangafo'},
#   {'code': 'BTH', 'country_code': 'ID', 'name': 'Batam'},
#   {'code': 'BTI', 'country_code': 'US', 'name': 'Barter Island'},
#   {'code': 'BTJ', 'country_code': 'ID', 'name': 'Banda Aceh'},
#   {'code': 'BTK', 'country_code': 'RU', 'name': 'Bratsk'},
#   {'code': 'BTL', 'country_code': 'US', 'name': 'Battle Creek'},
#   {'code': 'BTM', 'country_code': 'US', 'name': 'Butte'},
#   {'code': 'BTN', 'country_code': 'US', 'name': 'Bennettsville'},
#   {'code': 'BTO', 'country_code': 'SR', 'name': 'Botopasie'},
#   {'code': 'BTP', 'country_code': 'US', 'name': 'Butler'},
#   {'code': 'BTQ', 'country_code': 'RW', 'name': 'Butare'},
#   {'code': 'BTR', 'country_code': 'US', 'name': 'Baton Rouge'},
#   {'code': 'BTS', 'country_code': 'SK', 'name': 'Bratislava'},
#   {'code': 'BTT', 'country_code': 'US', 'name': 'Bettles'},
#   {'code': 'BTU', 'country_code': 'MY', 'name': 'Bintulu'},
#   {'code': 'BTV', 'country_code': 'US', 'name': 'Burlington'},
#   {'code': 'BTW', 'country_code': 'ID', 'name': 'Batu Licin'},
#   {'code': 'BTX', 'country_code': 'AU', 'name': 'Betoota'},
#   {'code': 'BTY', 'country_code': 'US', 'name': 'Beatty'},
#   {'code': 'BUA', 'country_code': 'PG', 'name': 'Buka'},
#   {'code': 'BUB', 'country_code': 'US', 'name': 'Burwell'},
#   {'code': 'BUC', 'country_code': 'AU', 'name': 'Burketown'},
#   {'code': 'BUD', 'country_code': 'HU', 'name': 'Budapest'},
#   {'code': 'BUE', 'country_code': 'AR', 'name': 'Buenos Aires'},
#   {'code': 'BUF', 'country_code': 'US', 'name': 'Buffalo'},
#   {'code': 'BUG', 'country_code': 'AO', 'name': 'Benguela'},
#   {'code': 'BUH', 'country_code': 'RO', 'name': 'Bucharest'},
#   {'code': 'BUI', 'country_code': 'ID', 'name': 'Bokondini'},
#   {'code': 'BUJ', 'country_code': 'DZ', 'name': 'Boussaada'},
#   {'code': 'BUK', 'country_code': 'YE', 'name': 'Albuq'},
#   {'code': 'BUL', 'country_code': 'PG', 'name': 'Bulolo'},
#   {'code': 'BUM', 'country_code': 'US', 'name': 'Butler'},
#   {'code': 'BUN', 'country_code': 'CO', 'name': 'Buenaventura'},
#   {'code': 'BUO', 'country_code': 'SO', 'name': 'Burao'},
#   {'code': 'BUP', 'country_code': 'IN', 'name': 'Bhatinda'},
#   {'code': 'BUQ', 'country_code': 'ZW', 'name': 'Bulawayo'},
#   {'code': 'BUR', 'country_code': 'US', 'name': 'Burbank'},
#   {'code': 'BUS', 'country_code': 'GE', 'name': 'Batumi'},
#   {'code': 'BUV', 'country_code': 'UY', 'name': 'Bella Union'},
#   {'code': 'BUW', 'country_code': 'ID', 'name': 'Baubau'},
#   {'code': 'BUX', 'country_code': 'CD', 'name': 'Bunia'},
#   {'code': 'BUY', 'country_code': 'AU', 'name': 'Bunbury'},
#   {'code': 'BUZ', 'country_code': 'IR', 'name': 'Bushehr'},
#   {'code': 'BVB', 'country_code': 'BR', 'name': 'Boa Vista'},
#   {'code': 'BVC', 'country_code': 'CV', 'name': 'Boa Vista'},
#   {'code': 'BVD', 'country_code': 'US', 'name': 'Beaver Inlet'},
#   ...],
#  'terms': 'Unauthorised access is prohibited and punishable by law. Re-sale of data is strictly prohibited unless approved by AirLabs.Co. Full terms on https://airlabs.co/terms.html'}

# %%
r = requests.get("https://distancecalculator.globefeed.com/Distance_Between_Countries_Result.asp?fromplace=India&toplace=France")

soup = BeautifulSoup(r.text, 'html.parser')
#print(soup)
Distances = soup.find(id="straightDist")
#print(Distances)
jsonStr = Distances.text
jsonData = jsonStr.split()
Dist_kM = float(jsonData[1])
Dist_Miles = float(jsonData[3])
Dist_NM = float(jsonData[6])
FlighTime = soup.find(id="estDistance")
jsonStr = FlighTime.text
jsonData = jsonStr.split()
FlightTime_Hr = float(jsonData[3])
FlightSpeed_mph = float(jsonData[10].split('m')[0])

# %%
Dist_kM
# Out:
# 7368.55

# %%
r = requests.get("https://www.budgetyourtrip.com/Zimbabwe")
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup.find('title').text.split()[4]
# Out:
# 'Average'

# %%
currency = soup.find_all('script', type='text/javascript')

# %%
currency = re.sub('[^A-Za-z0-9]+', '  ', str(currency[4]))

# %%
currency.split()[6]
# Out:
# 'ZMK'

# %%
scripts = soup.find_all('li', class_='cost-tile cost-tile-main smaller-text-size')

# %%
scripts
# Out:
# [<li class="cost-tile cost-tile-main smaller-text-size">
#  <div class="cost-tile-label">
#  										Average Daily Cost
#  										<span class="cost-tile-label-description">
#  											Per person, per day
#  										</span>
#  </div>
#  <div class="cost-tile-value">
#  <span class="symbol">ZMK</span><span class="curvalue">6,811,582</span>
#  </div>
#  </li>]

# %%
#Average Cost
int(re.sub('[^0-9]+', '', scripts[0].text.split('\n')[8]))
# Out:
# 6811582

# %%
scripts_2 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-accommodation cost-tile-category-1')

# %%
#Average Hotel or hostel for one person
int(re.sub('[^0-9]+', '', scripts_2[0].text.split('\n')[7]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-154-55f083ef5341> in <module>
#       1 #Average Hotel or hostel for one person
# ----> 2 int(re.sub('[^0-9]+', '', scripts_2[0].text.split('\n')[7]))
#
# IndexError: list index out of range

# %%
#Average Typical double-occupancy room
int(re.sub('[^0-9]+', '',scripts_2[1].text.split('\n')[8]))
# Out:
# 2377

# %%
scripts_3 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-food cost-tile-category-4')

# %%
#Average Food Cost per day
int(re.sub('[^0-9]+', '', scripts_3[0].text.split('\n')[7]))
# Out:
# 150

# %%
scripts_4 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-transportation cost-tile-category-3')

# %%
#Average Transportation Cost per day
int(re.sub('[^0-9]+', '', scripts_4[0].text.split('\n')[7]))
# Out:
# 243

# %%
scripts_5 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-entertainment cost-tile-category-6')

# %%
#Average Entertainment Cost per day
int(re.sub('[^0-9]+', '', scripts_5[0].text.split('\n')[7]))
# Out:
# 429

# %%
scripts_6 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-tips-and-handouts cost-tile-category-13')

# %%
#Average Tip Cost per day
int(re.sub('[^0-9]+', '', scripts_6[0].text.split('\n')[7]))
# Out:
# 66

# %%
scripts_7 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-scams-robberies-and-mishaps cost-tile-category-11')

# %%
#Average Scam/Robbery Cost per day
int(re.sub('[^0-9]+', '', scripts_7[0].text.split('\n')[5]))
# Out:
# 93

# %%
scripts_8 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-alcohol cost-tile-category-12')

# %%
#Average Alcohol Cost per day
int(re.sub('[^0-9]+', '', scripts_8[0].text.split('\n')[7]))
# Out:
# 230

# %%
scripts_9 = soup.find_all('li', class_='cost-tile cost-tile-category cost-tile-category-water cost-tile-category-5')

# %%
#Average Water Cost per day
int(re.sub('[^0-9]+', '', scripts_9[0].text.split('\n')[7]))
# Out:
# 32

# %%
scripts_10 = soup.find_all('div', class_='textcontent budget-page-content')

# %%
scripts_10[0].text
# Out:
# '\nIndia On a Budget\n\n\nBikaner, India\n\r\n\t\t\t\t\t\t\t\tIndia is one of the world\'s most affordable and impressive destinations. It is a country of extremes. From its vibrant colors, rich scents, and strong flavors, to its strong spirituality and welcoming people, India truly has something for everyone. It\'s a country where poverty sits next to wealth, beauty is intertwined with filth, and structure is found amidst chaos. It has cities, like Varanasi, where religion and spirituality touch its very essence. It has natural beauty that is unsurpassed elsewhere but it also has a growing economy that is becoming an influential force in the world. The eager friendliness of the people is endearing, and the food is unforgettable. \n\r\nIndia\'s vast size as well as its dramatic diversity from south to north and east to west, make it a country easiest visited over the course of several trips. It can be challenging to see the entire country, even with many weeks to explore. In the north you\'ll find the culturally and historically rich areas of Delhi, Varanasi, Rajasthan, and Agra (with the Taj Mahal). In the south you\'ll find the more rural and absolutely beautiful areas, with a more laid back feel and some of the country\'s best food. Wherever you go, it truly is Incredible India!\n\r\nTravel costs in India are some of the lowest in the world. Budget travelers flock here because they can stretch there money in unexpected ways. Cheap hotels can cost as little as a few dollars in some places and filling meals can be purchased for equally as cheap. The best way to ensure you get a good deal is to negotiate hard, and rarely make reservations. Unless you\'re traveling during a peak time period when hotels and transportation fill up, you likely don\'t need advanced reservations. The one exception to this is the trains. Some train trips should be booked weeks in advance, while others can be booked the day before. It\'s almost always possible to show up in a town without reservations and you can get a good deal. For comfort and peace of mind, reservations in larger cities such as Mumbai or Delhi are recommended.At A GlanceIndia is a large country with both rural and urban areas. If you\'re spending an extended amount of time in the country you\'ll probably be surprised to find that prices are actually cheaper in many cities than they are in rural areas. This is in large part because of the limited competition that exists in the more remote areas. There are few hotels and restaurants when you\'re well out of town, so you can expect to pay a little more. Prices are still incredibly low though, so wherever you go in India, you\'re likely to get a good deal.\n\nThe Indian population is incredibly welcoming. Prior to visiting India you\'ll probably hear many stories about the scams and ripoffs that can happen. While these do exist, do not let them intimidate you. The vast majority of the population will go out of their way to make you feel welcome. Strangers will help you negotiate a rickshaw and families will invite you into their home.\n\nRestaurants in large cities are often well overstaffed. Particularly at the higher end restaurants, don\'t be surprised to find a herd of people waiting on you. They\'ll stand attentively by while you read over the menu or enjoy your meal. It can be a little intrusive at first, but don\'t let it get to you. They are just hoping to make your experience as enjoyable as possible, and happy to be employed.\n\nIt\'s easy to find budget accommodation in India for little more than a few bucks. If you want comfort and style, you don\'t have to spend much more to stay at a very nice and modern place. This is true in most cities around the country. If the place seems empty you can probably talk the price down even further as well, so do not hesitate to negotiate. If you just show up at a hotel or guesthouse, make sure you check out the room, bed, and bathroom before committing to a price.\n\nTransportation aroun ...

# %%
re.sub('[^A-Za-z0-9]+', ' ', scripts_10[0].text)
# Out:
# ' India On a Budget Bikaner India India is one of the world s most affordable and impressive destinations It is a country of extremes From its vibrant colors rich scents and strong flavors to its strong spirituality and welcoming people India truly has something for everyone It s a country where poverty sits next to wealth beauty is intertwined with filth and structure is found amidst chaos It has cities like Varanasi where religion and spirituality touch its very essence It has natural beauty that is unsurpassed elsewhere but it also has a growing economy that is becoming an influential force in the world The eager friendliness of the people is endearing and the food is unforgettable India s vast size as well as its dramatic diversity from south to north and east to west make it a country easiest visited over the course of several trips It can be challenging to see the entire country even with many weeks to explore In the north you ll find the culturally and historically rich areas of Delhi Varanasi Rajasthan and Agra with the Taj Mahal In the south you ll find the more rural and absolutely beautiful areas with a more laid back feel and some of the country s best food Wherever you go it truly is Incredible India Travel costs in India are some of the lowest in the world Budget travelers flock here because they can stretch there money in unexpected ways Cheap hotels can cost as little as a few dollars in some places and filling meals can be purchased for equally as cheap The best way to ensure you get a good deal is to negotiate hard and rarely make reservations Unless you re traveling during a peak time period when hotels and transportation fill up you likely don t need advanced reservations The one exception to this is the trains Some train trips should be booked weeks in advance while others can be booked the day before It s almost always possible to show up in a town without reservations and you can get a good deal For comfort and peace of mind reservations in larger cities such as Mumbai or Delhi are recommended At A GlanceIndia is a large country with both rural and urban areas If you re spending an extended amount of time in the country you ll probably be surprised to find that prices are actually cheaper in many cities than they are in rural areas This is in large part because of the limited competition that exists in the more remote areas There are few hotels and restaurants when you re well out of town so you can expect to pay a little more Prices are still incredibly low though so wherever you go in India you re likely to get a good deal The Indian population is incredibly welcoming Prior to visiting India you ll probably hear many stories about the scams and ripoffs that can happen While these do exist do not let them intimidate you The vast majority of the population will go out of their way to make you feel welcome Strangers will help you negotiate a rickshaw and families will invite you into their home Restaurants in large cities are often well overstaffed Particularly at the higher end restaurants don t be surprised to find a herd of people waiting on you They ll stand attentively by while you read over the menu or enjoy your meal It can be a little intrusive at first but don t let it get to you They are just hoping to make your experience as enjoyable as possible and happy to be employed It s easy to find budget accommodation in India for little more than a few bucks If you want comfort and style you don t have to spend much more to stay at a very nice and modern place This is true in most cities around the country If the place seems empty you can probably talk the price down even further as well so do not hesitate to negotiate If you just show up at a hotel or guesthouse make sure you check out the room bed and bathroom before committing to a price Transportation around India can often be difficult especially for long distances Several popular options are available including flights buses trains and hiring a c ...

# %%
#Currency Converter

# %%
class rapid_Currency_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://currency-converter5.p.rapidapi.com/currency/convert"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def CurrencyConverter(self,original,to):
        
        self.search_url = self.base_url
        self.original = original
        self.to = to
        
        self.params = {
            'original' : "{}".format(self.original),
            'to' : "{}".format(self.to)
            }
        
        
        self.response = requests.get(self.search_url,headers=self.headers,params=self.params)
        print(self.response.url)
        return self.response.json()
    
    def getCurrencydetails(self,jsonObj):
        
        return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_Currency_Api(credentials['rapidapi_key'],credentials['rapidapi_host7'])
    v = app.CurrencyConverter('INR','USD')
    Currency_Details = app.getCurrencydetails(v)
# Out:
# https://currency-converter5.p.rapidapi.com/currency/convert?original=INR&to=USD

# %%
Currency_Details
# Out:
# {'amount': '1.0000',
#  'base_currency_code': 'EUR',
#  'base_currency_name': 'Euro',
#  'rates': {'USD': {'currency_name': 'US Dollar',
#    'rate': '1.2239',
#    'rate_for_amount': '1.2239'}},
#  'status': 'success',
#  'updated_date': '2020-12-18'}

# %%
class rapid_Currency2_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://currency-converter13.p.rapidapi.com/convert"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def CurrencyConverter2(self,original,to,amount):
        
        self.search_url = self.base_url
        self.original = original
        self.to = to
        self.amount = amount
        
        self.params = {
            'original' : "{}".format(self.original),
            'to' : "{}".format(self.to),
            'amount' : "{}".format(self.amount)            
            }
        
        
        self.response = requests.get(self.search_url,headers=self.headers,params=self.params)
        print(self.response.url)
        return self.response.json()
    
    def getCurrencydetails2(self,jsonObj):
        
        return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_Currency2_Api(credentials['rapidapi_key'],credentials['rapidapi_host8'])
    v = app.CurrencyConverter2('USD','INR','1')
    Currency_Details = app.getCurrencydetails2(v)
# Out:
# https://currency-converter13.p.rapidapi.com/convert?original=USD&to=INR&amount=1

# %%
Currency_Details
# Out:
# {'message': 'Missing required parameters'}

# %%
class rapid_Currency3_Api():

    def __init__(self,rapidapi_key,rapidapi_host):
        self.rapidapi_key = rapidapi_key
        self.rapidapi_host = rapidapi_host
        self.base_url = "https://currencyscoop.p.rapidapi.com/latest"
        # the api key is passed in the header of the url
        self.headers = {"x-rapidapi-key":"{}".format(self.rapidapi_key),
                       "x-rapidapi-host":"{}".format(self.rapidapi_host)}
        
    def CurrencyConverter3(self):
        
        self.search_url = self.base_url
        
        self.response = requests.get(self.search_url,headers=self.headers)
        print(self.response.url)
        return self.response.json()
    
    def getCurrencydetails3(self,jsonObj):
        
        return jsonObj

# %%
if __name__ == '__main__':
    app = rapid_Currency3_Api(credentials['rapidapi_key'],credentials['rapidapi_host9'])
    v = app.CurrencyConverter3()
    Currency_Details = app.getCurrencydetails3(v)
# Out:
# https://currencyscoop.p.rapidapi.com/latest

# %%
Currency_Details
# Out:
# {'meta': {'code': 200,
#   'disclaimer': 'Usage subject to terms: https://currencyscoop.com/terms'},
#  'response': {'date': '2020-12-20T18:28:40Z',
#   'base': 'USD',
#   'rates': {'USD': 1,
#    'EUR': 0.81601283,
#    'GBP': 0.7395215,
#    'INR': 73.55949598,
#    'AUD': 1.31231968,
#    'CAD': 1.27822813,
#    'SGD': 1.32874953,
#    'CHF': 0.88336735,
#    'MYR': 4.04045179,
#    'JPY': 103.35004948,
#    'CNY': 6.53520278,
#    'NZD': 1.40055633,
#    'THB': 29.86684744,
#    'HUF': 291.63239864,
#    'AED': 3.6725,
#    'HKD': 7.75242526,
#    'MXN': 19.94865149,
#    'ZAR': 14.53453817,
#    'PHP': 48.0975405,
#    'SEK': 8.23592344,
#    'IDR': 14147.83354225,
#    'SAR': 3.75,
#    'BRL': 5.08714742,
#    'TRY': 7.62519838,
#    'KES': 111.44771044,
#    'KRW': 1099.98585418,
#    'EGP': 15.6170819,
#    'IQD': 1190.23955952,
#    'NOK': 8.58658218,
#    'KWD': 0.30504922,
#    'RUB': 73.18500528,
#    'DKK': 6.07042575,
#    'PKR': 159.97221858,
#    'ILS': 3.23951051,
#    'PLN': 3.64646488,
#    'QAR': 3.64,
#    'XAU': 0.00053145,
#    'OMR': 0.3845,
#    'COP': 3418.32660607,
#    'CLP': 725.21969624,
#    'TWD': 28.20336228,
#    'ARS': 82.68668624,
#    'CZK': 21.32984657,
#    'VND': 23221.1442451,
#    'MAD': 8.87623256,
#    'JOD': 0.709,
#    'BHD': 0.376,
#    'XOF': 535.26932397,
#    'LKR': 187.69979235,
#    'UAH': 27.93515162,
#    'NGN': 379.95866962,
#    'TND': 2.68851677,
#    'UGX': 3654.06792766,
#    'RON': 3.97112348,
#    'BDT': 84.81530263,
#    'PEN': 3.59683192,
#    'GEL': 3.28459995,
#    'XAF': 535.26932397,
#    'FJD': 2.04549981,
#    'VEF': 9.9875,
#    'VES': 1058425.0635055,
#    'BYN': 2.50500011,
#    'HRK': 6.15525237,
#    'UZS': 10462.99813026,
#    'BGN': 1.59598238,
#    'DZD': 132.41761433,
#    'IRR': 42025.2824099,
#    'DOP': 58.19014509,
#    'ISK': 127.74765566,
#    'XAG': 0.03874877,
#    'CRC': 607.45436408,
#    'SYP': 512.79353199,
#    'LYD': 1.33890483,
#    'JMD': 142.59470952,
#    'MUR': 39.69993361,
#    'GHS': 5.82220642,
#    'AOA': 650.25133189,
#    'UYU': 42.39232129,
#    'AFN': 77.13002687,
#    'LBP': 1507.50003882,
#    'XPF': 97.37623247,
#    'TTD': 6.80633808,
#    'TZS': 2317.49871437,
#    'ALL': 100.84851419,
#    'XCD': 2.70000005,
#    'GTQ': 7.79602776,
#    'NPR': 118.24688912,
#    'BOB': 6.89502426,
#    'ZWD': 361.89999379,
#    'BBD': 2,
#    'CUC': 1,
#    'LAK': 9270.81343971,
#    'BND': 1.32874953,
#    'BWP': 10.78372576,
#    'HNL': 24.15346058,
#    'PYG': 6996.02555788,
#    'ETB': 38.47952675,
#    'NAD': 14.53453817,
#    'PGK': 3.5149996,
#    'SDG': 55.11249913,
#    'MOP': 7.98499802,
#    'NIO': 34.90024522,
#    'BMD': 1,
#    'KZT': 419.61718744,
#    'PAB': 1,
#    'BAM': 1.59598238,
#    'GYD': 210.04988727,
#    'YER': 249.33000664,
#    'MGA': 3939.92559057,
#    'KYD': 0.82000408,
#    'MZN': 74.53892754,
#    'RSD': 95.94166747,
#    'SCR': 21.86798047,
#    'AMD': 481.61794347,
#    'SBD': 8.03538609,
#    'AZN': 1.69999522,
#    'SLL': 10076.05405601,
#    'TOP': 2.25479571,
#    'BZD': 2.01530542,
#    'MWK': 766.78113942,
#    'GMD': 51.74943627,
#    'BIF': 1938.84420068,
#    'SOS': 584.07090294,
#    'HTG': 73.09970536,
#    'GNF': 9992.54556101,
#    'MVR': 15.6699991,
#    'MNT': 2855.21843991,
#    'CDF': 1970.98007773,
#    'STN': 20.05006292,
#    'TJS': 11.30000014,
#    'KPW': 900.000009,
#    'MMK': 1347.85367107,
#    'LSL': 14.53453817,
#    'LRD': 161.29513802,
#    'KGS': 83.14796465,
#    'GIP': 0.7395215,
#    'XPT': 0.00096262,
#    'MDL': 17.13549994,
#    'CUP': 26.49999997,
#    'KHR': 4032.62717999,
#    'MKD': 50.27999901,
#    'VUV': 108.22257249,
#    'MRU': 38.29596277,
#    'ANG': 1.78750017,
#    'SZL': 14.53453817,
#    'CVE': 89.98173506,
#    'SRD': 14.08000017,
#    'XPD': 0.00042455,
#    'SVC': 8.75,
#    'BSD': 1,
#    'XDR': 0.69253518,
#    'RWF': 969.980839,
#    'AWG': 1.79,
#    'DJF': 177.99965554,
#    'BTN': 73.55949598,
#    'KMF': 401.45200372,
#    'WST': 2.5542892,
#    'SPL': 0.16666667,
#    'ERN': 14.99999999,
#    'FKP': 0.7395215,
#    'SHP': 0.7395215,
#    'JEP': 0.7395215,
#    'TMT': 3.50999998,
#    'TVD': 1.31231968,
#    'IMP': 0.7395215,
#    'GGP': 0.7395215,
#    'ZMW': 21.18098245}}}

# %%
list(Currency_Details['response']['rates'].keys())
# Out:
# ['USD',
#  'EUR',
#  'GBP',
#  'INR',
#  'AUD',
#  'CAD',
#  'SGD',
#  'CHF',
#  'MYR',
#  'JPY',
#  'CNY',
#  'NZD',
#  'THB',
#  'HUF',
#  'AED',
#  'HKD',
#  'MXN',
#  'ZAR',
#  'PHP',
#  'SEK',
#  'IDR',
#  'SAR',
#  'BRL',
#  'TRY',
#  'KES',
#  'KRW',
#  'EGP',
#  'IQD',
#  'NOK',
#  'KWD',
#  'RUB',
#  'DKK',
#  'PKR',
#  'ILS',
#  'PLN',
#  'QAR',
#  'XAU',
#  'OMR',
#  'COP',
#  'CLP',
#  'TWD',
#  'ARS',
#  'CZK',
#  'VND',
#  'MAD',
#  'JOD',
#  'BHD',
#  'XOF',
#  'LKR',
#  'UAH',
#  'NGN',
#  'TND',
#  'UGX',
#  'RON',
#  'BDT',
#  'PEN',
#  'GEL',
#  'XAF',
#  'FJD',
#  'VEF',
#  'VES',
#  'BYN',
#  'HRK',
#  'UZS',
#  'BGN',
#  'DZD',
#  'IRR',
#  'DOP',
#  'ISK',
#  'XAG',
#  'CRC',
#  'SYP',
#  'LYD',
#  'JMD',
#  'MUR',
#  'GHS',
#  'AOA',
#  'UYU',
#  'AFN',
#  'LBP',
#  'XPF',
#  'TTD',
#  'TZS',
#  'ALL',
#  'XCD',
#  'GTQ',
#  'NPR',
#  'BOB',
#  'ZWD',
#  'BBD',
#  'CUC',
#  'LAK',
#  'BND',
#  'BWP',
#  'HNL',
#  'PYG',
#  'ETB',
#  'NAD',
#  'PGK',
#  'SDG',
#  'MOP',
#  'NIO',
#  'BMD',
#  'KZT',
#  'PAB',
#  'BAM',
#  'GYD',
#  'YER',
#  'MGA',
#  'KYD',
#  'MZN',
#  'RSD',
#  'SCR',
#  'AMD',
#  'SBD',
#  'AZN',
#  'SLL',
#  'TOP',
#  'BZD',
#  'MWK',
#  'GMD',
#  'BIF',
#  'SOS',
#  'HTG',
#  'GNF',
#  'MVR',
#  'MNT',
#  'CDF',
#  'STN',
#  'TJS',
#  'KPW',
#  'MMK',
#  'LSL',
#  'LRD',
#  'KGS',
#  'GIP',
#  'XPT',
#  'MDL',
#  'CUP',
#  'KHR',
#  'MKD',
#  'VUV',
#  'MRU',
#  'ANG',
#  'SZL',
#  'CVE',
#  'SRD',
#  'XPD',
#  'SVC',
#  'BSD',
#  'XDR',
#  'RWF',
#  'AWG',
#  'DJF',
#  'BTN',
#  'KMF',
#  'WST',
#  'SPL',
#  'ERN',
#  'FKP',
#  'SHP',
#  'JEP',
#  'TMT',
#  'TVD',
#  'IMP',
#  'GGP',
#  'ZMW']
