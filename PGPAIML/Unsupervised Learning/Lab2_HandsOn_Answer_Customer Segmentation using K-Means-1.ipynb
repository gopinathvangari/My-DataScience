# %% [markdown]
# ### Collect Data
#
# https://archive.ics.uci.edu/ml/datasets/Online+Retail

# %% [markdown]
# ### Load Data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
df = pd.read_excel('Online Retail.xlsx')

# %% [markdown]
# Check dataset details

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Remove missing values from the dataset

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (406829, 8)

# %%
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ### Explore & Visualize Dataset

# %% [markdown]
# Number of Unique customers

# %%
len(df.CustomerID.unique())
# Out:
# 4372

# %% [markdown]
# Geograhic information

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada',
#        'Unspecified', 'Brazil', 'USA', 'European Community', 'Bahrain',
#        'Malta', 'RSA'], dtype=object)

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(y='Country', data=df)

# %% [markdown]
# Lets remove Non-UK records as enough Geographic details about other countries/region is not available.

# %%
df = df[df.Country.isin(['United Kingdom'])]

# %%
df.shape
# Out:
# (361878, 8)

# %%
df.Country.unique()
# Out:
# array(['United Kingdom'], dtype=object)

# %% [markdown]
# Number of Unique Products

# %%
len(df.StockCode.unique())
# Out:
# 3661

# %% [markdown]
# Invoice Date Range

# %%
df.InvoiceDate.min(), df.InvoiceDate.max()
# Out:
# (Timestamp('2010-12-01 08:26:00'), Timestamp('2011-12-09 12:49:00'))

# %% [markdown]
# ### Remove Invoices for 'Returns'

# %% [markdown]
# Number of Returned invoices

# %%
df.InvoiceNo.str.startswith('C').sum()
# Out:
# 7533

# %% [markdown]
# Remove these invoices from the dataset

# %%
df = df[~df.InvoiceNo.str.startswith('C').fillna(False)]

# %%
df.shape
# Out:
# (354345, 8)

# %% [markdown]
# ### Build a Customer Dataset

# %%
cust_df = pd.DataFrame(df.CustomerID.unique(), columns=['CustomerID'])

# %%
cust_df.columns
# Out:
# Index(['CustomerID'], dtype='object')

# %% [markdown]
# ### Recency of Purchase

# %%
df['Recency'] = (pd.datetime(2011,12,10) - pd.to_datetime(df['InvoiceDate'])).dt.days

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Recency
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom      373
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      373
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom      373
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      373
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      373

# %%
recency_df = df.groupby('CustomerID', as_index=False).agg({'Recency':'min'})

# %%
recency_df.shape
# Out:
# (3921, 2)

# %%
cust_df = cust_df.merge(recency_df, left_on='CustomerID', right_on='CustomerID')

# %%
cust_df.shape
# Out:
# (3921, 2)

# %%
cust_df
# Out:
#       CustomerID  Recency
# 0        17850.0      372
# 1        13047.0       31
# 2        13748.0       95
# 3        15100.0      333
# 4        15291.0       25
# 5        14688.0        7
# 6        17809.0       16
# 7        15311.0        0
# 8        16098.0       87
# 9        18074.0      373
# 10       17420.0       50
# 11       16029.0       38
# 12       16250.0      261
# 13       17511.0        2
# 14       13705.0        7
# 15       13747.0      373
# 16       13408.0        1
# 17       13767.0        2
# 18       17924.0       11
# 19       13448.0       16
# 20       15862.0        8
# 21       15513.0       33
# 22       16218.0       29
# 23       14045.0      109
# 24       14307.0       88
# 25       17908.0      373
# 26       17920.0        4
# 27       12838.0       33
# 28       13255.0        9
# 29       16583.0      373
# ...          ...      ...
# 3891     13560.0        7
# 3892     15539.0        7
# 3893     13017.0        7
# 3894     18174.0        7
# 3895     13153.0        5
# 3896     15773.0        5
# 3897     17936.0        5
# 3898     16535.0        5
# 3899     16988.0        5
# 3900     15097.0        4
# 3901     18015.0        4
# 3902     16597.0        4
# 3903     13790.0        4
# 3904     14219.0        4
# 3905     17383.0        4
# 3906     15992.0        3
# 3907     15318.0        3
# 3908     17914.0        3
# 3909     16528.0        3
# 3910     16569.0        3
# 3911     14578.0        3
# 3912     16000.0        2
# 3913     15195.0        2
# 3914     14087.0        2
# 3915     14204.0        2
# 3916     15471.0        2
# 3917     13436.0        1
# 3918     15520.0        1
# 3919     13298.0        1
# 3920     14569.0        1
#
# [3921 rows x 2 columns]

# %% [markdown]
# ### Frequency of Invoices

# %%
frequency_df = df.groupby('CustomerID', as_index=False).agg({'InvoiceNo':'count'})

# %%
frequency_df.shape
# Out:
# (3921, 2)

# %%
frequency_df
# Out:
#       CustomerID  InvoiceNo
# 0        12346.0          1
# 1        12747.0        103
# 2        12748.0       4596
# 3        12749.0        199
# 4        12820.0         59
# 5        12821.0          6
# 6        12822.0         46
# 7        12823.0          5
# 8        12824.0         25
# 9        12826.0         91
# 10       12827.0         25
# 11       12828.0         56
# 12       12829.0         11
# 13       12830.0         38
# 14       12831.0          9
# 15       12832.0         27
# 16       12833.0         24
# 17       12834.0         18
# 18       12836.0        175
# 19       12837.0         12
# 20       12838.0        123
# 21       12839.0        314
# 22       12840.0        113
# 23       12841.0        420
# 24       12842.0         34
# 25       12843.0        103
# 26       12844.0         52
# 27       12845.0         27
# 28       12847.0         91
# 29       12849.0         51
# ...          ...        ...
# 3891     18242.0         78
# 3892     18245.0        175
# 3893     18246.0          4
# 3894     18248.0         47
# 3895     18249.0          8
# 3896     18250.0         21
# 3897     18251.0         16
# 3898     18252.0         98
# 3899     18255.0          6
# 3900     18257.0        118
# 3901     18259.0         42
# 3902     18260.0        134
# 3903     18261.0         21
# 3904     18262.0         13
# 3905     18263.0         61
# 3906     18265.0         46
# 3907     18268.0          1
# 3908     18269.0          7
# 3909     18270.0         11
# 3910     18272.0        166
# 3911     18273.0          3
# 3912     18274.0         11
# 3913     18276.0         14
# 3914     18277.0          8
# 3915     18278.0          9
# 3916     18280.0         10
# 3917     18281.0          7
# 3918     18282.0         12
# 3919     18283.0        756
# 3920     18287.0         70
#
# [3921 rows x 2 columns]

# %%
cust_df = cust_df.merge(frequency_df, left_on='CustomerID', right_on='CustomerID')

# %%
cust_df.shape
# Out:
# (3921, 3)

# %%
cust_df
# Out:
#       CustomerID  Recency  InvoiceNo
# 0        17850.0      372        297
# 1        13047.0       31        172
# 2        13748.0       95         28
# 3        15100.0      333          3
# 4        15291.0       25        103
# 5        14688.0        7        327
# 6        17809.0       16         61
# 7        15311.0        0       2379
# 8        16098.0       87         67
# 9        18074.0      373         13
# 10       17420.0       50         30
# 11       16029.0       38        242
# 12       16250.0      261         24
# 13       17511.0        2        963
# 14       13705.0        7         28
# 15       13747.0      373          1
# 16       13408.0        1        478
# 17       13767.0        2        368
# 18       17924.0       11         31
# 19       13448.0       16        195
# 20       15862.0        8        147
# 21       15513.0       33        308
# 22       16218.0       29         84
# 23       14045.0      109          6
# 24       14307.0       88        180
# 25       17908.0      373         58
# 26       17920.0        4        696
# 27       12838.0       33        123
# 28       13255.0        9         13
# 29       16583.0      373         14
# ...          ...      ...        ...
# 3891     13560.0        7         33
# 3892     15539.0        7         41
# 3893     13017.0        7          1
# 3894     18174.0        7          1
# 3895     13153.0        5         15
# 3896     15773.0        5         10
# 3897     17936.0        5         77
# 3898     16535.0        5         31
# 3899     16988.0        5          7
# 3900     15097.0        4         25
# 3901     18015.0        4         46
# 3902     16597.0        4          7
# 3903     13790.0        4         45
# 3904     14219.0        4          7
# 3905     17383.0        4         51
# 3906     15992.0        3          3
# 3907     15318.0        3         33
# 3908     17914.0        3         80
# 3909     16528.0        3         17
# 3910     16569.0        3          5
# 3911     14578.0        3         24
# 3912     16000.0        2          9
# 3913     15195.0        2          1
# 3914     14087.0        2         69
# 3915     14204.0        2         44
# 3916     15471.0        2         77
# 3917     13436.0        1         12
# 3918     15520.0        1         18
# 3919     13298.0        1          2
# 3920     14569.0        1         12
#
# [3921 rows x 3 columns]

# %% [markdown]
# ### Monetary Value of Purchases

# %% [markdown]
# Calculate total purchase price for each invoice

# %%
df['Sales'] = df['Quantity'] * df['UnitPrice']

# %%
monetary_df =  df.groupby('CustomerID', as_index=False).agg({'Sales':'sum'})

# %%
monetary_df
# Out:
#       CustomerID     Sales
# 0        12346.0  77183.60
# 1        12747.0   4196.01
# 2        12748.0  33719.73
# 3        12749.0   4090.88
# 4        12820.0    942.34
# 5        12821.0     92.72
# 6        12822.0    948.88
# 7        12823.0   1759.50
# 8        12824.0    397.12
# 9        12826.0   1474.72
# 10       12827.0    430.15
# 11       12828.0   1018.71
# 12       12829.0    293.00
# 13       12830.0   6814.64
# 14       12831.0    215.05
# 15       12832.0    383.03
# 16       12833.0    417.38
# 17       12834.0    312.38
# 18       12836.0   2612.86
# 19       12837.0    134.10
# 20       12838.0    683.13
# 21       12839.0   5591.42
# 22       12840.0   2726.77
# 23       12841.0   4022.35
# 24       12842.0   1118.99
# 25       12843.0   1702.26
# 26       12844.0    325.96
# 27       12845.0    354.09
# 28       12847.0    871.54
# 29       12849.0   1050.89
# ...          ...       ...
# 3891     18242.0   2232.49
# 3892     18245.0   2567.06
# 3893     18246.0    596.10
# 3894     18248.0    804.02
# 3895     18249.0     95.34
# 3896     18250.0    349.27
# 3897     18251.0   4314.72
# 3898     18252.0    526.67
# 3899     18255.0    103.30
# 3900     18257.0   2337.63
# 3901     18259.0   2338.60
# 3902     18260.0   2643.20
# 3903     18261.0    324.24
# 3904     18262.0    149.48
# 3905     18263.0   1213.16
# 3906     18265.0    801.51
# 3907     18268.0     25.50
# 3908     18269.0    168.60
# 3909     18270.0    283.15
# 3910     18272.0   3078.58
# 3911     18273.0    204.00
# 3912     18274.0    175.92
# 3913     18276.0    335.86
# 3914     18277.0    110.38
# 3915     18278.0    173.90
# 3916     18280.0    180.60
# 3917     18281.0     80.82
# 3918     18282.0    178.05
# 3919     18283.0   2094.88
# 3920     18287.0   1837.28
#
# [3921 rows x 2 columns]

# %%
cust_df = cust_df.merge(monetary_df, left_on='CustomerID', right_on='CustomerID')

# %%
cust_df
# Out:
#       CustomerID  Recency  InvoiceNo     Sales
# 0        17850.0      372        297   5391.21
# 1        13047.0       31        172   3237.54
# 2        13748.0       95         28    948.25
# 3        15100.0      333          3    876.00
# 4        15291.0       25        103   4668.30
# 5        14688.0        7        327   5630.87
# 6        17809.0       16         61   5411.91
# 7        15311.0        0       2379  60767.90
# 8        16098.0       87         67   2005.63
# 9        18074.0      373         13    489.60
# 10       17420.0       50         30    598.83
# 11       16029.0       38        242  81024.84
# 12       16250.0      261         24    389.44
# 13       17511.0        2        963  91062.38
# 14       13705.0        7         28    711.86
# 15       13747.0      373          1     79.60
# 16       13408.0        1        478  28117.04
# 17       13767.0        2        368  17220.36
# 18       17924.0       11         31   2962.50
# 19       13448.0       16        195   3539.37
# 20       15862.0        8        147    832.88
# 21       15513.0       33        308  14758.22
# 22       16218.0       29         84   3084.68
# 23       14045.0      109          6   1659.75
# 24       14307.0       88        180   2995.72
# 25       17908.0      373         58    243.28
# 26       17920.0        4        696   4204.10
# 27       12838.0       33        123    683.13
# 28       13255.0        9         13    399.51
# 29       16583.0      373         14    233.45
# ...          ...      ...        ...       ...
# 3891     13560.0        7         33    174.37
# 3892     15539.0        7         41    538.46
# 3893     13017.0        7          1    204.00
# 3894     18174.0        7          1    104.00
# 3895     13153.0        5         15    486.22
# 3896     15773.0        5         10    635.68
# 3897     17936.0        5         77    389.84
# 3898     16535.0        5         31    593.75
# 3899     16988.0        5          7    126.12
# 3900     15097.0        4         25    248.08
# 3901     18015.0        4         46    120.03
# 3902     16597.0        4          7     90.04
# 3903     13790.0        4         45    348.80
# 3904     14219.0        4          7     89.94
# 3905     17383.0        4         51    199.29
# 3906     15992.0        3          3     41.99
# 3907     15318.0        3         33    312.62
# 3908     17914.0        3         80    336.43
# 3909     16528.0        3         17    244.41
# 3910     16569.0        3          5    124.20
# 3911     14578.0        3         24    168.63
# 3912     16000.0        2          9  12393.70
# 3913     15195.0        2          1   3861.00
# 3914     14087.0        2         69    194.42
# 3915     14204.0        2         44    161.03
# 3916     15471.0        2         77    469.48
# 3917     13436.0        1         12    196.89
# 3918     15520.0        1         18    343.50
# 3919     13298.0        1          2    360.00
# 3920     14569.0        1         12    227.39
#
# [3921 rows x 4 columns]

# %% [markdown]
# ### Standardize the data

# %%
import numpy as np

# %%
cust_df['Recency_log'] = np.log(cust_df.Recency+0.1)
cust_df['Monetary_log'] = np.log(cust_df.Sales + 0.1)
cust_df['Frequency_log'] = np.log(cust_df.InvoiceNo)

# %%
sns.pointplot(x='Frequency_log', y='Monetary_log', hue='Recency_log', data=cust_df, palette='spring')

# %% [markdown]
# ### Applying K-Means

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=2, #Number of clusters
            n_init=10, #How many times KMeans will be run with random centoid starts
            max_iter=300) #Maximum iterations

# %%
km.fit(cust_df[['Recency_log', 'Frequency_log', 'Monetary_log']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# Add cluster information to Dataframe

# %%
cust_df['k_2'] = km.predict(cust_df[['Recency_log', 'Frequency_log', 'Monetary_log']])

# %% [markdown]
# ### Exploring 2 Clusters

# %% [markdown]
# Centroids

# %%
km.cluster_centers_
# Out:
# array([[4.5795832 , 2.87650421, 5.81682425],
#        [2.53445158, 4.75405176, 7.54986817]])

# %% [markdown]
# Visualize Clusters

# %%
sns.scatterplot(x='Frequency_log', y='Monetary_log', hue='k_2', data=cust_df, palette='spring')
plt.scatter(km.cluster_centers_[:,1], km.cluster_centers_[:,2], s=100, marker='s', c='red', alpha=0.7, label='Centroids')

# %% [markdown]
# Sum of Squared Error (SSE)

# %%
km.inertia_
# Out:
# 12012.481469767372

# %% [markdown]
# What does 2 Clusters tell us about the dataset

# %%
cust_df.groupby('k_2').agg({'Sales':'median', 
                            'InvoiceNo':'median', 
                            'Recency':'median'})
# Out:
#        Sales  InvoiceNo  Recency
# k_2
# 0     337.04         20      108
# 1    1799.70        113       16

# %% [markdown]
# ### How many Clusters to use?

# %%
#Initial a list to track SSE for KMeans with different K
sse_df = pd.DataFrame(columns=['K','SSE'])

for i in range(2,11):
    
    #Initialize KMeans
    km = KMeans(n_clusters=i, n_init=10, max_iter=300)
    
    #Fit on the data
    km.fit(cust_df[['Recency_log', 'Frequency_log', 'Monetary_log']])
    
    #Add cluster information for each record in dataframe
    cust_df['k_' + str(i)] = km.predict(cust_df[['Recency_log', 'Frequency_log', 'Monetary_log']])
    
    #Track K and SSE information in sse_df
    sse_df.loc[sse_df.shape[0]] = [i, km.inertia_]

# %%
cust_df.head()
# Out:
#    CustomerID  Recency  InvoiceNo    Sales  Recency_log  Monetary_log  \
# 0     17850.0      372        297  5391.21     5.919163      8.592544
# 1     13047.0       31        172  3237.54     3.437208      8.082600
# 2     13748.0       95         28   948.25     4.554929      6.854724
# 3     15100.0      333          3   876.00     5.808443      6.775480
# 4     15291.0       25        103  4668.30     3.222868      8.448572
#
#    Frequency_log  k_2  k_3  k_4  k_5  k_6  k_7  k_8  k_9  k_10
# 0       5.693732    1    1    1    1    3    5    1    1     6
# 1       5.147494    1    1    1    1    5    0    5    5     6
# 2       3.332205    0    1    1    2    3    5    1    1     9
# 3       1.098612    0    0    2    3    4    2    6    4     3
# 4       4.634729    1    1    1    1    5    0    5    5     6

# %% [markdown]
# Visualize K vs SSE

# %%
sns.lineplot(x='K', y='SSE', data=sse_df)

# %% [markdown]
# Visualize clusters with K=5

# %%
sns.scatterplot(x='Frequency_log', y='Monetary_log', hue='k_5', data=cust_df, palette='spring')
print(cust_df.groupby('k_5').agg({'Sales':'median', 'InvoiceNo':'median', 'Recency':'median'}))
# Out:
#         Sales  InvoiceNo  Recency
# k_5
# 0    3264.525        195        3
# 1    1823.600        115       28
# 2     546.810         34      129
# 3     172.290          8      186
# 4     384.080         27       19
