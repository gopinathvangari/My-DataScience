# %% [markdown]
# ### Load Gensim Library

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.16.2)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.11.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.8.1)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.2.1)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.49.0)
# Requirement already satisfied: bz2file in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (0.98)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.18.4)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (1.9.130)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.6)
# Requirement already satisfied: botocore<1.13.0,>=1.12.130 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (1.12.130)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.2.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.9.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.130->boto3->smart-open>=1.2.1->gensim) (2.5.3)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.130->boto3->smart-open>=1.2.1->gensim) (0.14)

# %%
import gensim
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# ### Load Text Data

# %%
import pandas as pd
df = pd.read_csv('/gdrive/My Drive/AI-ML/unlabeledTrainData.tsv.zip', header=0, delimiter="\t", quoting=3)

print('Number of examples in Dataset: ', df.shape)
df.head()
# Out:
# Number of examples in Dataset:  (50000, 2)
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %% [markdown]
# ### Function to Clean up data

# %%
import re, string

def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

# %% [markdown]
# ### Clean the Data using routine above

# %%
df['clean_review'] = df['review'].apply(clean_str)
df.head()
# Out:
#           id                                             review  \
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...
#
#                                         clean_review
# 0  watching time chasers it obvious that it was m...
# 1  i saw this film about years ago and remember i...
# 2  minor spoilers br br in new york joan barnard ...
# 3  i went to see this film with a great deal of e...
# 4  yes i agree with everyone on this site this mo...

# %% [markdown]
# ### Convert Review to a Word List

# %%
#List to hold all words in each review
documents = []

#Iterate over each review
for doc in df['clean_review']:
    documents.append(doc.split(' '))

print(len(documents))
print(documents[0])
# Out:
# 50000
# ['watching', 'time', 'chasers', 'it', 'obvious', 'that', 'it', 'was', 'made', 'by', 'a', 'bunch', 'of', 'friends', 'maybe', 'they', 'were', 'sitting', 'around', 'one', 'day', 'in', 'film', 'school', 'and', 'said', 'hey', 'let', 's', 'pool', 'our', 'money', 'together', 'and', 'make', 'a', 'really', 'bad', 'movie', 'or', 'something', 'like', 'that', 'what', 'ever', 'they', 'said', 'they', 'still', 'ended', 'up', 'making', 'a', 'really', 'bad', 'movie', 'dull', 'story', 'bad', 'script', 'lame', 'acting', 'poor', 'cinematography', 'bottom', 'of', 'the', 'barrel', 'stock', 'music', 'etc', 'all', 'corners', 'were', 'cut', 'except', 'the', 'one', 'that', 'would', 'have', 'prevented', 'this', 'film', 's', 'release', 'life', 's', 'like', 'that']

# %% [markdown]
# ### Build the Model

# %%
#Build the model
model = gensim.models.Word2Vec(documents, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPUs
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2019-04-13 07:01:26,248 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-04-13 07:01:26,250 : INFO : collecting all words and their counts
# 2019-04-13 07:01:26,251 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-04-13 07:01:26,850 : INFO : PROGRESS: at sentence #10000, processed 2399440 words, keeping 51654 word types
# 2019-04-13 07:01:27,496 : INFO : PROGRESS: at sentence #20000, processed 4835846 words, keeping 69077 word types
# 2019-04-13 07:01:28,097 : INFO : PROGRESS: at sentence #30000, processed 7267977 words, keeping 81515 word types
# 2019-04-13 07:01:28,709 : INFO : PROGRESS: at sentence #40000, processed 9669772 words, keeping 91685 word types
# 2019-04-13 07:01:29,331 : INFO : collected 100479 word types from a corpus of 12084660 raw words and 50000 sentences
# 2019-04-13 07:01:29,332 : INFO : Loading a fresh vocabulary
# 2019-04-13 07:01:29,835 : INFO : effective_min_count=10 retains 28322 unique words (28% of original 100479, drops 72157)
# 2019-04-13 07:01:29,836 : INFO : effective_min_count=10 leaves 11910457 word corpus (98% of original 12084660, drops 174203)
# 2019-04-13 07:01:29,938 : INFO : deleting the raw counts dictionary of 100479 items
# 2019-04-13 07:01:29,943 : INFO : sample=0.001 downsamples 49 most-common words
# 2019-04-13 07:01:29,944 : INFO : downsampling leaves estimated 8817283 word corpus (74.0% of prior 11910457)
# 2019-04-13 07:01:30,068 : INFO : estimated required memory for 28322 words and 50 dimensions: 25489800 bytes
# 2019-04-13 07:01:30,069 : INFO : resetting layer weights
# 2019-04-13 07:01:30,350 : INFO : training model with 4 workers on 28322 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-04-13 07:01:31,364 : INFO : EPOCH 1 - PROGRESS: at 5.82% examples, 512034 words/s, in_qsize 8, out_qsize 0
# 2019-04-13 07:01:32,382 : INFO : EPOCH 1 - PROGRESS: at 12.06% examples, 521447 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:01:33,384 : INFO : EPOCH 1 - PROGRESS: at 18.13% examples, 523754 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:01:34,388 : INFO : EPOCH 1 - PROGRESS: at 24.21% examples, 526641 words/s, in_qsize 6, out_qsize 1
# 2019-04-13 07:01:35,416 : INFO : EPOCH 1 - PROGRESS: at 30.32% examples, 525831 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:01:36,431 : INFO : EPOCH 1 - PROGRESS: at 36.49% examples, 527387 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:01:37,445 : INFO : EPOCH 1 - PROGRESS: at 42.32% examples, 526672 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:01:38,457 : INFO : EPOCH 1 - PROGRESS: at 48.30% examples, 526279 words/s, in_qsize 6, out_qsize 1
# 2019-04-13 07:01:39,459 : INFO : EPOCH 1 - PROGRESS: at 54.31% examples, 526817 words/s, in_qsize 6, out_qsize 1
# 2019-04-13 07:01:40,463 : INFO : EPOCH 1 - PROGRESS: at 60.18% examples, 526399 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07
words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:03,906 : INFO : EPOCH 10 - PROGRESS: at 11.98% examples, 520419 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:04,911 : INFO : EPOCH 10 - PROGRESS: at 17.97% examples, 521289 words/s, in_qsize 8, out_qsize 1
# 2019-04-13 07:04:05,935 : INFO : EPOCH 10 - PROGRESS: at 24.13% examples, 524623 words/s, in_qsize 8, out_qsize 1
# 2019-04-13 07:04:06,938 : INFO : EPOCH 10 - PROGRESS: at 30.25% examples, 525538 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:07,955 : INFO : EPOCH 10 - PROGRESS: at 36.32% examples, 525900 words/s, in_qsize 6, out_qsize 1
# 2019-04-13 07:04:08,956 : INFO : EPOCH 10 - PROGRESS: at 42.41% examples, 529368 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:09,973 : INFO : EPOCH 10 - PROGRESS: at 48.36% examples, 528430 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:10,976 : INFO : EPOCH 10 - PROGRESS: at 54.38% examples, 528638 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:11,988 : INFO : EPOCH 10 - PROGRESS: at 60.26% examples, 527642 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:12,997 : INFO : EPOCH 10 - PROGRESS: at 66.23% examples, 527490 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:14,006 : INFO : EPOCH 10 - PROGRESS: at 72.33% examples, 527343 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:15,008 : INFO : EPOCH 10 - PROGRESS: at 78.36% examples, 527477 words/s, in_qsize 6, out_qsize 1
# 2019-04-13 07:04:16,021 : INFO : EPOCH 10 - PROGRESS: at 84.41% examples, 527165 words/s, in_qsize 6, out_qsize 1
# 2019-04-13 07:04:17,030 : INFO : EPOCH 10 - PROGRESS: at 90.60% examples, 527554 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:18,056 : INFO : EPOCH 10 - PROGRESS: at 96.56% examples, 527189 words/s, in_qsize 7, out_qsize 0
# 2019-04-13 07:04:18,595 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-13 07:04:18,600 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-13 07:04:18,601 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-13 07:04:18,606 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-13 07:04:18,611 : INFO : EPOCH - 10 : training on 12084660 raw words (8817253 effective words) took 16.7s, 527373 effective words/s
# 2019-04-13 07:04:18,613 : INFO : training on a 120846600 raw words (88169510 effective words) took 168.3s, 524001 effective words/s

# %% [markdown]
# # Exploring the model

# %% [markdown]
# ### How many words in the model

# %%
#Model size
model.wv.syn0.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.
# (28322, 50)

# %%
# Vocablury of the model
model.wv.vocab
# Out:
# {'watching': <gensim.models.keyedvectors.Vocab at 0x7fda01803550>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fda018037b8>,
#  'chasers': <gensim.models.keyedvectors.Vocab at 0x7fda017f4e80>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7fda017f4c88>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x7fda017f4fd0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9c18>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9c88>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9940>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9ac8>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9b38>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9ba8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9b70>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9b00>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9cc0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9cf8>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9d30>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9d68>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9da0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9dd8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9e10>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9e48>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9e80>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9eb8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9ef0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9f28>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9f60>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9f98>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7fd9da0a9fd0>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7fd9da049048>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7fd9da049080>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7fd9da0490b8>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7fd9da0490f0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7fd9da049128>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7fd9da049160>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7fd9da049198>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7fd9da0491d0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7fd9da049208>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7fd9da049240>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7fd9da049278>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7fd9da0492b0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7fd9da0492e8>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fd9da049320>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x7fd9da049358>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7fd9da049390>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7fd9da0493c8>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x7fd9da049400>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7fd9da049438>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x7fd9da049470>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x7fd9da0494a8>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x7fd9da0494e0>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7fd9da049518>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x7fd9da049550>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7fd9da049588>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7fd9da0495c0>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x7fd9da0495f8>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7fd9da049630>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7fd9da049668>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7fd9da0496a0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7fd9da0496d8>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x7fd9da049710>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7fd9da049748>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7fd9da049780>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fd9da0497b8>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7fd9da0497f0>,
#  'prevented': <gensim.models.keyedvectors.Vocab at 0x7fd9da049828>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7fd9da049860>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7fd9da049898>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fd9da0498d0>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7fd9da049908>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7fd9da049940>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7fd9da049978>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7fd9da0499b0>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7fd9da0499e8>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7fd9da049a20>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7fd9da049a58>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7fd9da049a90>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7fd9da049ac8>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x7fd9da049b00>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7fd9da049b38>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7fd9da049b70>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7fd9da049ba8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7fd9da049be0>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7fd9da049c18>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x7fd9da049c50>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7fd9da049c88>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7fd9da049cc0>,
#  'breaks': <gensim.models.keyedvectors.Vocab at 0x7fd9da049cf8>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7fd9da049d30>,
#  'nurses': <gensim.models.keyedvectors.Vocab at 0x7fd9da049d68>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7fd9da049da0>,
#  'rapes': <gensim.models.keyedvectors.Vocab at 0x7fd9da049dd8>,
#  'tortures': <gensim.models.keyedvectors.Vocab at 0x7fd9da049e10>,
#  'kills': <gensim.models.keyedvectors.Vocab at 0x7fd9da049e48>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7fd9da049e80>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7fd9da049eb8>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x7fd9da049ef0>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7fd9da049f28>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7fd9da049f60>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7fd9da049f98>,
#  'saves': <gensim.models.keyedvectors.Vocab at 0x7fd9da049fd0>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b048>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b080>,
#  'shocking': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b0b8>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b0f0>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b128>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b160>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b198>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b1d0>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b208>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b240>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b278>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b2b0>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b2e8>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b320>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b358>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b390>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b3c8>,
#  'obscene': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b400>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b438>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b470>,
#  'spoilers': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b4a8>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b4e0>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b518>,
#  'joan': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b550>,
#  'barnard': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b588>,
#  'elvire': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b5c0>,
#  'audrey': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b5f8>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b630>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b668>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b6a0>,
#  'arthur': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b6d8>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b710>,
#  'saxon': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b748>,
#  'mysteriously': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b780>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b7b8>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b7f0>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b828>,
#  'searching': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b860>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b898>,
#  'etruscan': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b8d0>,
#  'tomb': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b908>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b940>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b978>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b9b0>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x7fd9da04b9e8>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7fd9da04ba20>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7fd9da04ba58>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7fd9da04ba90>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bac8>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bb00>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bb38>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bb70>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bba8>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bbe0>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bc18>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bc50>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bc88>,
#  'maggots': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bcc0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bcf8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bd30>,
#  'shootings': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bd68>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bda0>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bdd8>,
#  'realizes': <gensim.models.keyedvectors.Vocab at 0x7fd9da04be10>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7fd9da04be48>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7fd9da04be80>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x7fd9da04beb8>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bef0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bf28>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bf60>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bf98>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x7fd9da04bfd0>,
#  'detective': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f048>,
#  'narcotic': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f080>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f0b8>,
#  'ends': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f0f0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f128>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f160>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f198>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f1d0>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f208>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f240>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f278>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f2b0>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f2e8>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f320>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f358>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f390>,
#  'displeasure': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f3c8>,
#  'wasting': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f400>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f438>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f470>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f4a8>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f4e0>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f518>,
#  'thriller': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f550>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f588>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f5c0>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f5f8>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f630>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f668>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f6a0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f6d8>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f710>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f748>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f780>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f7b8>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f7f0>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f828>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f860>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f898>,
#  'credits': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f8d0>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f908>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f940>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f978>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f9b0>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7fd9da04f9e8>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fa20>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fa58>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fa90>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fac8>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fb00>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fb38>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fb70>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fba8>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fbe0>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fc18>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fc50>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fc88>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fcc0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fcf8>,
#  'desire': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fd30>,
#  'curiosity': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fd68>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fda0>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fdd8>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fe10>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fe48>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fe80>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7fd9da04feb8>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7fd9da04fef0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7fd9da04ff28>,
#  'navigate': <gensim.models.keyedvectors.Vocab at 0x7fd9da04ff60>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7fd9da04ff98>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x7fd9da04ffd0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7fd9da051048>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7fd9da051080>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7fd9da0510b8>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7fd9da0510f0>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7fd9da051128>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7fd9da051160>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7fd9da051198>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7fd9da0511d0>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7fd9da051208>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7fd9da051240>,
#  'mist': <gensim.models.keyedvectors.Vocab at 0x7fd9da051278>,
#  'rio': <gensim.models.keyedvectors.Vocab at 0x7fd9da0512b0>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x7fd9da0512e8>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7fd9da051320>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7fd9da051358>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7fd9da051390>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7fd9da0513c8>,
#  'excitement': <gensim.models.keyedvectors.Vocab at 0x7fd9da051400>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7fd9da051438>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7fd9da051470>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7fd9da0514a8>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7fd9da0514e0>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7fd9da051518>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7fd9da051550>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x7fd9da051588>,
#  'stinks': <gensim.models.keyedvectors.Vocab at 0x7fd9da0515c0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7fd9da0515f8>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7fd9da051630>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7fd9da051668>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7fd9da0516a0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fd9da0516d8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7fd9da051710>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7fd9da051748>,
#  'walked': <gensim.models.keyedvectors.Vocab at 0x7fd9da051780>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7fd9da0517b8>,
#  'pub': <gensim.models.keyedvectors.Vocab at 0x7fd9da0517f0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fd9da051828>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7fd9da051860>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7fd9da051898>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7fd9da0518d0>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x7fd9da051908>,
#  'balcony': <gensim.models.keyedvectors.Vocab at 0x7fd9da051940>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7fd9da051978>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7fd9da0519b0>,
#  'helicopter': <gensim.models.keyedvectors.Vocab at 0x7fd9da0519e8>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x7fd9da051a20>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7fd9da051a58>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7fd9da051a90>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7fd9da051ac8>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7fd9da051b00>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7fd9da051b38>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7fd9da051b70>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7fd9da051ba8>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7fd9da051be0>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7fd9da051c18>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x7fd9da051c50>,
#  'reporters': <gensim.models.keyedvectors.Vocab at 0x7fd9da051c88>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7fd9da051cc0>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7fd9da051cf8>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7fd9da051d30>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7fd9da051d68>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x7fd9da051da0>,
#  'jumping': <gensim.models.keyedvectors.Vocab at 0x7fd9da051dd8>,
#  'encouraging': <gensim.models.keyedvectors.Vocab at 0x7fd9da051e10>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x7fd9da051e48>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7fd9da051e80>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x7fd9da051eb8>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7fd9da051ef0>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x7fd9da051f28>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7fd9da051f60>,
#  'broadcasts': <gensim.models.keyedvectors.Vocab at 0x7fd9da051f98>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7fd9da051fd0>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7fd9da054048>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7fd9da054080>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x7fd9da0540b8>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7fd9da0540f0>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x7fd9da054128>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7fd9da054160>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x7fd9da054198>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fd9da0541d0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7fd9da054208>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7fd9da054240>,
#  'microphone': <gensim.models.keyedvectors.Vocab at 0x7fd9da054278>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x7fd9da0542b0>,
#  'transmitter': <gensim.models.keyedvectors.Vocab at 0x7fd9da0542e8>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7fd9da054320>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7fd9da054358>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7fd9da054390>,
#  'utterly': <gensim.models.keyedvectors.Vocab at 0x7fd9da0543c8>,
#  'derivative': <gensim.models.keyedvectors.Vocab at 0x7fd9da054400>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7fd9da054438>,
#  'existent': <gensim.models.keyedvectors.Vocab at 0x7fd9da054470>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fd9da0544a8>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7fd9da0544e0>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7fd9da054518>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7fd9da054550>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7fd9da054588>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7fd9da0545c0>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7fd9da0545f8>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x7fd9da054630>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7fd9da054668>,
#  'compares': <gensim.models.keyedvectors.Vocab at 0x7fd9da0546a0>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7fd9da0546d8>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7fd9da054710>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7fd9da054748>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x7fd9da054780>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7fd9da0547b8>,
#  'packaging': <gensim.models.keyedvectors.Vocab at 0x7fd9da0547f0>,
#  'intentionally': <gensim.models.keyedvectors.Vocab at 0x7fd9da054828>,
#  'misleading': <gensim.models.keyedvectors.Vocab at 0x7fd9da054860>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7fd9da054898>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7fd9da0548d0>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x7fd9da054908>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7fd9da054940>,
#  'retitled': <gensim.models.keyedvectors.Vocab at 0x7fd9da054978>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7fd9da0549b0>,
#  'goofy': <gensim.models.keyedvectors.Vocab at 0x7fd9da0549e8>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7fd9da054a20>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x7fd9da054a58>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7fd9da054a90>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7fd9da054ac8>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7fd9da054b00>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x7fd9da054b38>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7fd9da054b70>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7fd9da054ba8>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7fd9da054be0>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7fd9da054c18>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x7fd9da054c50>,
#  'rodney': <gensim.models.keyedvectors.Vocab at 0x7fd9da054c88>,
#  'dangerfield': <gensim.models.keyedvectors.Vocab at 0x7fd9da054cc0>,
#  'comedians': <gensim.models.keyedvectors.Vocab at 0x7fd9da054cf8>,
#  'hbo': <gensim.models.keyedvectors.Vocab at 0x7fd9da054d30>,
#  'featured': <gensim.models.keyedvectors.Vocab at 0x7fd9da054d68>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7fd9da054da0>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7fd9da054dd8>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x7fd9da054e10>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x7fd9da054e48>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7fd9da054e80>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7fd9da054eb8>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7fd9da054ef0>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x7fd9da054f28>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7fd9da054f60>,
#  'carrey': <gensim.models.keyedvectors.Vocab at 0x7fd9da054f98>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x7fd9da054fd0>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7fd9da058048>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x7fd9da058080>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7fd9da0580b8>,
#  'lacking': <gensim.models.keyedvectors.Vocab at 0x7fd9da0580f0>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7fd9da058128>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7fd9da058160>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7fd9da058198>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x7fd9da0581d0>,
#  'comedian': <gensim.models.keyedvectors.Vocab at 0x7fd9da058208>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7fd9da058240>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7fd9da058278>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7fd9da0582b0>,
#  'janet': <gensim.models.keyedvectors.Vocab at 0x7fd9da0582e8>,
#  'talented': <gensim.models.keyedvectors.Vocab at 0x7fd9da058320>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7fd9da058358>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7fd9da058390>,
#  'beware': <gensim.models.keyedvectors.Vocab at 0x7fd9da0583c8>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x7fd9da058400>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x7fd9da058438>,
#  'jennifer': <gensim.models.keyedvectors.Vocab at 0x7fd9da058470>,
#  'ehle': <gensim.models.keyedvectors.Vocab at 0x7fd9da0584a8>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x7fd9da0584e0>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7fd9da058518>,
#  'prejudice': <gensim.models.keyedvectors.Vocab at 0x7fd9da058550>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x7fd9da058588>,
#  'northam': <gensim.models.keyedvectors.Vocab at 0x7fd9da0585c0>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7fd9da0585f8>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7fd9da058630>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7fd9da058668>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x7fd9da0586a0>,
#  'caliber': <gensim.models.keyedvectors.Vocab at 0x7fd9da0586d8>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7fd9da058710>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7fd9da058748>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7fd9da058780>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x7fd9da0587b8>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x7fd9da0587f0>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x7fd9da058828>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7fd9da058860>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7fd9da058898>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x7fd9da0588d0>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x7fd9da058908>,
#  'disappointment': <gensim.models.keyedvectors.Vocab at 0x7fd9da058940>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7fd9da058978>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7fd9da0589b0>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7fd9da0589e8>,
#  'flick': <gensim.models.keyedvectors.Vocab at 0x7fd9da058a20>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7fd9da058a58>,
#  'scenes': <gensim.models.keyedvectors.Vocab at 0x7fd9da058a90>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7fd9da058ac8>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7fd9da058b00>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x7fd9da058b38>,
#  'tenderness': <gensim.models.keyedvectors.Vocab at 0x7fd9da058b70>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7fd9da058ba8>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x7fd9da058be0>,
#  'consisted': <gensim.models.keyedvectors.Vocab at 0x7fd9da058c18>,
#  'hackneyed': <gensim.models.keyedvectors.Vocab at 0x7fd9da058c50>,
#  'unsubtle': <gensim.models.keyedvectors.Vocab at 0x7fd9da058c88>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7fd9da058cc0>,
#  'cinematic': <gensim.models.keyedvectors.Vocab at 0x7fd9da058cf8>,
#  'lust': <gensim.models.keyedvectors.Vocab at 0x7fd9da058d30>,
#  'voracious': <gensim.models.keyedvectors.Vocab at 0x7fd9da058d68>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7fd9da058da0>,
#  'mouthed': <gensim.models.keyedvectors.Vocab at 0x7fd9da058dd8>,
#  'kissing': <gensim.models.keyedvectors.Vocab at 0x7fd9da058e10>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7fd9da058e48>,
#  'porn': <gensim.models.keyedvectors.Vocab at 0x7fd9da058e80>,
#  'humping': <gensim.models.keyedvectors.Vocab at 0x7fd9da058eb8>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x7fd9da058ef0>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7fd9da058f28>,
#  'originality': <gensim.models.keyedvectors.Vocab at 0x7fd9da058f60>,
#  'tasteless': <gensim.models.keyedvectors.Vocab at 0x7fd9da058f98>,
#  'awful': <gensim.models.keyedvectors.Vocab at 0x7fd9da058fd0>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d048>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d080>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d0b8>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d0f0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d128>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d160>,
#  'effeminate': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d198>,
#  'appearance': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d1d0>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d208>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d240>,
#  'aren': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d278>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d2b0>,
#  'masculine': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d2e8>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d320>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d358>,
#  'hollywood': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d390>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d3c8>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d400>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d438>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d470>,
#  'imaginative': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d4a8>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d4e0>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d518>,
#  'amy': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d550>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d588>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d5c0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d5f8>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d630>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d668>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d6a0>,
#  'publisher': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d6d8>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d710>,
#  'guiding': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d748>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d780>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d7b8>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d7f0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d828>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d860>,
#  'sarandon': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d898>,
#  'plays': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d8d0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d908>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d940>,
#  'sadistic': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d978>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d9b0>,
#  'billy': <gensim.models.keyedvectors.Vocab at 0x7fd9da05d9e8>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x7fd9da05da20>,
#  'thorton': <gensim.models.keyedvectors.Vocab at 0x7fd9da05da58>,
#  'chubby': <gensim.models.keyedvectors.Vocab at 0x7fd9da05da90>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dac8>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fd9da05db00>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7fd9da05db38>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x7fd9da05db70>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dba8>,
#  'actress': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dbe0>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dc18>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dc50>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dc88>,
#  'gown': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dcc0>,
#  'wears': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dcf8>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dd30>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dd68>,
#  'festival': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dda0>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x7fd9da05ddd8>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7fd9da05de10>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7fd9da05de48>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x7fd9da05de80>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7fd9da05deb8>,
#  'stale': <gensim.models.keyedvectors.Vocab at 0x7fd9da05def0>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7fd9da05df28>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fd9da05df60>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x7fd9da05df98>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fd9da05dfd0>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f048>,
#  'adopts': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f080>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f0b8>,
#  'contradicts': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f0f0>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f128>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f160>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f198>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f1d0>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f208>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f240>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f278>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f2b0>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f2e8>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f320>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f358>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f390>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f3c8>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f400>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f438>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f470>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f4a8>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f4e0>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f518>,
#  'northwest': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f550>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f588>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f5c0>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f5f8>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f630>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f668>,
#  'harlan': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f6a0>,
#  'knowles': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f6d8>,
#  'lance': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f710>,
#  'henriksen': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f748>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f780>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f7b8>,
#  'ragtag': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f7f0>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f828>,
#  'execute': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f860>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f898>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f8d0>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f908>,
#  'oy': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f940>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f978>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f9b0>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x7fd9da05f9e8>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fa20>,
#  'genre': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fa58>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fa90>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fac8>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fb00>,
#  'suffers': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fb38>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fb70>,
#  'flaws': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fba8>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fbe0>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fc18>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fc50>,
#  'jonas': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fc88>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fcc0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fcf8>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fd30>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fd68>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fda0>,
#  'aka': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fdd8>,
#  'sasquatch': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fe10>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fe48>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fe80>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7fd9da05feb8>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7fd9da05fef0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7fd9da05ff28>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7fd9da05ff60>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7fd9da05ff98>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x7fd9da05ffd0>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7fd9da063048>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7fd9da063080>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fd9da0630b8>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7fd9da0630f0>,
#  'improvise': <gensim.models.keyedvectors.Vocab at 0x7fd9da063128>,
#  'sequiturs': <gensim.models.keyedvectors.Vocab at 0x7fd9da063160>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7fd9da063198>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7fd9da0631d0>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7fd9da063208>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x7fd9da063240>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x7fd9da063278>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7fd9da0632b0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7fd9da0632e8>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x7fd9da063320>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7fd9da063358>,
#  'crib': <gensim.models.keyedvectors.Vocab at 0x7fd9da063390>,
#  'blair': <gensim.models.keyedvectors.Vocab at 0x7fd9da0633c8>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x7fd9da063400>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7fd9da063438>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x7fd9da063470>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x7fd9da0634a8>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x7fd9da0634e0>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x7fd9da063518>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x7fd9da063550>,
#  'exposition': <gensim.models.keyedvectors.Vocab at 0x7fd9da063588>,
#  'dialogue': <gensim.models.keyedvectors.Vocab at 0x7fd9da0635c0>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x7fd9da0635f8>,
#  'subtler': <gensim.models.keyedvectors.Vocab at 0x7fd9da063630>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7fd9da063668>,
#  'saccharine': <gensim.models.keyedvectors.Vocab at 0x7fd9da0636a0>,
#  'subtexts': <gensim.models.keyedvectors.Vocab at 0x7fd9da0636d8>,
#  'costume': <gensim.models.keyedvectors.Vocab at 0x7fd9da063710>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7fd9da063748>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7fd9da063780>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x7fd9da0637b8>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x7fd9da0637f0>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x7fd9da063828>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7fd9da063860>,
#  'trudging': <gensim.models.keyedvectors.Vocab at 0x7fd9da063898>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7fd9da0638d0>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7fd9da063908>,
#  'chris': <gensim.models.keyedvectors.Vocab at 0x7fd9da063940>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7fd9da063978>,
#  'stereotype': <gensim.models.keyedvectors.Vocab at 0x7fd9da0639b0>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x7fd9da0639e8>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7fd9da063a20>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7fd9da063a58>,
#  'exploring': <gensim.models.keyedvectors.Vocab at 0x7fd9da063a90>,
#  'relationships': <gensim.models.keyedvectors.Vocab at 0x7fd9da063ac8>,
#  'lair': <gensim.models.keyedvectors.Vocab at 0x7fd9da063b00>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7fd9da063b38>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7fd9da063b70>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7fd9da063ba8>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x7fd9da063be0>,
#  'corpse': <gensim.models.keyedvectors.Vocab at 0x7fd9da063c18>,
#  'decorations': <gensim.models.keyedvectors.Vocab at 0x7fd9da063c50>,
#  'ala': <gensim.models.keyedvectors.Vocab at 0x7fd9da063c88>,
#  'primitive': <gensim.models.keyedvectors.Vocab at 0x7fd9da063cc0>,
#  'jeepers': <gensim.models.keyedvectors.Vocab at 0x7fd9da063cf8>,
#  'creepers': <gensim.models.keyedvectors.Vocab at 0x7fd9da063d30>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x7fd9da063d68>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7fd9da063da0>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7fd9da063dd8>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7fd9da063e10>,
#  'frightening': <gensim.models.keyedvectors.Vocab at 0x7fd9da063e48>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7fd9da063e80>,
#  'missteps': <gensim.models.keyedvectors.Vocab at 0x7fd9da063eb8>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7fd9da063ef0>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x7fd9da063f28>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7fd9da063f60>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x7fd9da063f98>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7fd9da063fd0>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7fd9da067048>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7fd9da067080>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7fd9da0670b8>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7fd9da0670f0>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x7fd9da067128>,
#  'screens': <gensim.models.keyedvectors.Vocab at 0x7fd9da067160>,
#  'snippets': <gensim.models.keyedvectors.Vocab at 0x7fd9da067198>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7fd9da0671d0>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7fd9da067208>,
#  'unspecified': <gensim.models.keyedvectors.Vocab at 0x7fd9da067240>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7fd9da067278>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x7fd9da0672b0>,
#  'irrelevant': <gensim.models.keyedvectors.Vocab at 0x7fd9da0672e8>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x7fd9da067320>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7fd9da067358>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x7fd9da067390>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7fd9da0673c8>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7fd9da067400>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7fd9da067438>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7fd9da067470>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7fd9da0674a8>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7fd9da0674e0>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7fd9da067518>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7fd9da067550>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7fd9da067588>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7fd9da0675c0>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7fd9da0675f8>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x7fd9da067630>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7fd9da067668>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7fd9da0676a0>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fd9da0676d8>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7fd9da067710>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7fd9da067748>,
#  'pointless': <gensim.models.keyedvectors.Vocab at 0x7fd9da067780>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x7fd9da0677b8>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7fd9da0677f0>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7fd9da067828>,
#  'justify': <gensim.models.keyedvectors.Vocab at 0x7fd9da067860>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7fd9da067898>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7fd9da0678d0>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x7fd9da067908>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7fd9da067940>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7fd9da067978>,
#  'mancini': <gensim.models.keyedvectors.Vocab at 0x7fd9da0679b0>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7fd9da0679e8>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x7fd9da067a20>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7fd9da067a58>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7fd9da067a90>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7fd9da067ac8>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x7fd9da067b00>,
#  'motif': <gensim.models.keyedvectors.Vocab at 0x7fd9da067b38>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x7fd9da067b70>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x7fd9da067ba8>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7fd9da067be0>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x7fd9da067c18>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7fd9da067c50>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x7fd9da067c88>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x7fd9da067cc0>,
#  'insists': <gensim.models.keyedvectors.Vocab at 0x7fd9da067cf8>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7fd9da067d30>,
#  'blurry': <gensim.models.keyedvectors.Vocab at 0x7fd9da067d68>,
#  'cam': <gensim.models.keyedvectors.Vocab at 0x7fd9da067da0>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7fd9da067dd8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7fd9da067e10>,
# ...
#  'every': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a208>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a240>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a278>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a2b0>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a2e8>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a320>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a358>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a390>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a3c8>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a400>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a438>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a470>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a4a8>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a4e0>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a518>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a550>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a588>,
#  'directing': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a5c0>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a5f8>,
#  'manages': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a630>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a668>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a6a0>,
#  'cliches': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a6d8>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a710>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a748>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a780>,
#  'suspense': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a7b8>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a7f0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a828>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a860>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a898>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a8d0>,
#  'masterpiece': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a908>,
#  'fashioned': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a940>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a978>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a9b0>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7fd9da06a9e8>,
#  'thoroughly': <gensim.models.keyedvectors.Vocab at 0x7fd9da06aa20>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x7fd9da06aa58>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x7fd9da06aa90>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x7fd9da06aac8>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ab00>,
#  'predictable': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ab38>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ab70>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x7fd9da06aba8>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7fd9da06abe0>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ac18>,
#  'gang': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ac50>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ac88>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7fd9da06acc0>,
#  'stations': <gensim.models.keyedvectors.Vocab at 0x7fd9da06acf8>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ad30>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ad68>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ada0>,
#  'policeman': <gensim.models.keyedvectors.Vocab at 0x7fd9da06add8>,
#  'teenagers': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ae10>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ae48>,
#  'cliche': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ae80>,
#  'imaginable': <gensim.models.keyedvectors.Vocab at 0x7fd9da06aeb8>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x7fd9da06aef0>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x7fd9da06af28>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x7fd9da06af60>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x7fd9da06af98>,
#  'jr': <gensim.models.keyedvectors.Vocab at 0x7fd9da06afd0>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d048>,
#  'laughs': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d080>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d0b8>,
#  'ain': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d0f0>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d128>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d160>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d198>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d1d0>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d208>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d240>,
#  'sickened': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d278>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d2b0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d2e8>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d320>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d358>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d390>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d3c8>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d400>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d438>,
#  'abu': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d470>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d4a8>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d4e0>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d518>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d550>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d588>,
#  'stimulation': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d5c0>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d5f8>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d630>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d668>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d6a0>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d6d8>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d710>,
#  'guard': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d748>,
#  'reserves': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d780>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d7b8>,
#  'roughly': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d7f0>,
#  'abuses': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d828>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d860>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d898>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d8d0>,
#  'stepped': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d908>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d940>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d978>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d9b0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7fd9da06d9e8>,
#  'sarcastic': <gensim.models.keyedvectors.Vocab at 0x7fd9da06da20>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x7fd9da06da58>,
#  'commentary': <gensim.models.keyedvectors.Vocab at 0x7fd9da06da90>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dac8>,
#  'enemy': <gensim.models.keyedvectors.Vocab at 0x7fd9da06db00>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7fd9da06db38>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x7fd9da06db70>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dba8>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dbe0>,
#  'humanitarian': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dc18>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dc50>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dc88>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dcc0>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dcf8>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dd30>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dd68>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dda0>,
#  'overwhelmed': <gensim.models.keyedvectors.Vocab at 0x7fd9da06ddd8>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x7fd9da06de10>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7fd9da06de48>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x7fd9da06de80>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7fd9da06deb8>,
#  'mocks': <gensim.models.keyedvectors.Vocab at 0x7fd9da06def0>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7fd9da06df28>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7fd9da06df60>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x7fd9da06df98>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x7fd9da06dfd0>,
#  'villages': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1048>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1080>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff10b8>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff10f0>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1128>,
#  'landing': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1160>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1198>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff11d0>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1208>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1240>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1278>,
#  'unscrupulous': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff12b0>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff12e8>,
#  'occupation': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1320>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1358>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1390>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff13c8>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1400>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1438>,
#  'mayhem': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1470>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff14a8>,
#  'disservice': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff14e0>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1518>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1550>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1588>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff15c0>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff15f8>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1630>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1668>,
#  'personnel': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff16a0>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff16d8>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1710>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1748>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1780>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff17b8>,
#  'harm': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff17f0>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1828>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1860>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1898>,
#  'wage': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff18d0>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1908>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1940>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1978>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff19b0>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff19e8>,
#  'visitor': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1a20>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1a58>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1a90>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1ac8>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1b00>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1b38>,
#  'accepts': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1b70>,
#  'lieu': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1ba8>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1be0>,
#  'ged': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1c18>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1c50>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1c88>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1cc0>,
#  'undergraduate': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1cf8>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1d30>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1d68>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1da0>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1dd8>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1e10>,
#  'elfen': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1e48>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1e80>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1eb8>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1ef0>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1f28>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1f60>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1f98>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff1fd0>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6048>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6080>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff60b8>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff60f0>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6128>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6160>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6198>,
#  'coherently': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff61d0>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6208>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6240>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6278>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff62b0>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff62e8>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6320>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6358>,
#  'anime': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6390>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff63c8>,
#  'shines': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6400>,
#  'narrative': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6438>,
#  'enthralled': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6470>,
#  'weaving': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff64a8>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff64e0>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6518>,
#  'gory': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6550>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6588>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff65c0>,
#  'contrasting': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff65f8>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6630>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6668>,
#  'emotive': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff66a0>,
#  'bloodshed': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff66d8>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6710>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6748>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff6780>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff67b8>,
#  'viewer': <gensim.models.keyedvectors.Vocab at 0x7fd9d9ff67f0>,
#  ...}

# %% [markdown]
# ### Get an embedding for a word

# %%
model.wv['flower']
# Out:
# array([ 0.7568026 , -0.18180634, -0.17753159, -0.67494357, -1.5582796 ,
#         0.08646239,  0.6238796 , -0.17049365,  1.2921526 , -0.87824315,
#         0.95820993, -1.087397  ,  0.87916046, -0.57581604,  0.5137825 ,
#        -0.11233454, -0.18431784, -1.3852475 ,  0.41678172, -0.0754873 ,
#        -0.47281814,  0.8488433 , -0.10011446,  1.1238286 ,  0.7669508 ,
#        -0.10805985,  0.54498583, -0.9058127 ,  0.4636573 ,  0.91139543,
#        -0.8717332 ,  0.74897826,  0.37250862,  1.152637  ,  0.87119037,
#        -0.02884753, -0.29983905, -0.2240433 , -0.24067906, -1.3407695 ,
#        -0.3668513 , -0.89341813,  0.32513633, -0.35597268,  0.69412   ,
#         0.24599057, -0.48554245,  0.61435413,  1.3205293 , -0.41895688],
#       dtype=float32)

# %% [markdown]
# ### Finding Words which have similar meaning

# %%
model.wv.most_similar('great')
# Out:
# 2019-04-13 07:07:56,529 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('fantastic', 0.8930344581604004),
#  ('terrific', 0.8748549222946167),
#  ('wonderful', 0.8648861646652222),
#  ('good', 0.8316959142684937),
#  ('fine', 0.829056441783905),
#  ('brilliant', 0.8062900304794312),
#  ('superb', 0.7853832840919495),
#  ('perfect', 0.7718095183372498),
#  ('nice', 0.7465071678161621),
#  ('amazing', 0.743908703327179)]

# %% [markdown]
# ### Find the word which is not like others

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'kitchen'

# %% [markdown]
# ### Saving the model

# %%
model.save('word2vec-movie-50')
# Out:
# 2019-04-13 07:19:25,328 : INFO : saving Word2Vec object under word2vec-movie-50, separately None
# 2019-04-13 07:19:25,330 : INFO : not storing attribute vectors_norm
# 2019-04-13 07:19:25,333 : INFO : not storing attribute cum_table
# 2019-04-13 07:19:25,334 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-04-13 07:19:25,575 : INFO : saved word2vec-movie-50

# %%
#Load model from memory
model = gensim.models.Word2Vec.load('word2vec-movie-50')

# %% [markdown]
# 1. Equation king + man = queen + ?
# 2. In this case there may not be enough data for this equation

# %%
model.most_similar(positive=['king','man'], negative=['queen'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('soldier', 0.5443345308303833),
#  ('enforcer', 0.5437442660331726),
#  ('master', 0.5365206003189087),
#  ('scientist', 0.5275171399116516),
#  ('toulon', 0.5243131518363953),
#  ('joker', 0.5217767357826233),
#  ('buio', 0.5210888385772705),
#  ('vet', 0.511581540107727),
#  ('batman', 0.5082988739013672),
#  ('yakuza', 0.5009059906005859)]
