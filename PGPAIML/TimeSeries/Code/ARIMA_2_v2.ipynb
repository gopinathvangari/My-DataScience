# %%
# !wget -nc https://lazyprogrammer.me/course_files/airline_passengers.csv
# Out:
# --2020-08-08 20:50:50--  https://lazyprogrammer.me/course_files/airline_passengers.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.31.81.48, 104.31.80.48, 172.67.213.166, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.31.81.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2036 (2.0K) [text/csv]
# Saving to: ‘airline_passengers.csv’
#
# airline_passengers. 100%[===================>]   1.99K  --.-KB/s    in 0s
#
# 2020-08-08 20:50:51 (34.9 MB/s) - ‘airline_passengers.csv’ saved [2036/2036]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.4.0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.9.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.26.11)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (63.4.1)
# Requirement already satisfied: packaging>=17.1 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=17.1->pmdarima) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.4 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp39-cp39-macosx_10_9_x86_64.whl (656 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 656.2/656.2 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %%
df = pd.read_csv('/Users/gopinathvangari/Work/Career/Mission AI/Time Series Analysis/Data/airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
df['LogPassengers'] = np.log(df['Passengers'])

# %%
Ntest = 12
train = df.iloc[:-Ntest]
test = df.iloc[-Ntest:]

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(train['Passengers'],
                      trace=True,
                      suppress_warnings=True,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=1.46 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=1022.234, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=906.857, Time=0.37 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=963.555, Time=0.41 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=1192.711, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=907.180, Time=0.06 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=908.543, Time=3.95 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.81 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=907.120, Time=0.41 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=11.07 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=1021.611, Time=0.29 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=906.396, Time=0.56 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=906.075, Time=0.08 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=906.713, Time=0.48 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=905.686, Time=0.09 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=906.124, Time=0.69 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=906.388, Time=0.62 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=906.035, Time=1.02 sec
#  ARIMA(4,0,0)(0,1,0)[12] intercept   : AIC=907.453, Time=0.17 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(3,0,1)(0,1,0)[12] intercept   : AIC=907.583, Time=0.16 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=906.399, Time=0.12 sec
#  ARIMA(4,0,1)(0,1,0)[12] intercept   : AIC=909.320, Time=0.26 sec
#  ARIMA(3,0,0)(0,1,0)[12]             : AIC=911.907, Time=0.06 sec
#
# Best model:  ARIMA(3,0,0)(0,1,0)[12] intercept
# Total fit time: 24.029 seconds
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  132
# Model:             SARIMAX(3, 0, 0)x(0, 1, 0, 12)   Log Likelihood                -447.843
# Date:                            Tue, 30 Jan 2024   AIC                            905.686
# Time:                                    08:03:41   BIC                            919.623
# Sample:                                01-01-1949   HQIC                           911.346
#                                      - 12-01-1959
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.5341      2.007      2.757      0.006       1.600       9.468
# ar.L1          0.7049      0.095      7.393      0.000       0.518       0.892
# ar.L2          0.2574      0.131      1.968      0.049       0.001       0.514
# ar.L3         -0.1434      0.107     -1.338      0.181      -0.354       0.067
# sigma2       101.0969     12.818      7.887      0.000      75.974     126.220
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.83
# Prob(Q):                              0.96   Prob(JB):                         0.24
# Heteroskedasticity (H):               1.41   Skew:                            -0.14
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_pred, confint = model.predict(n_periods=Ntest, return_conf_int=True)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(test.index, test['Passengers'], label='data')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
train_pred = model.predict_in_sample(start=0, end=-1)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.index, df['Passengers'], label='data')
ax.plot(train.index, train_pred, label='fitted')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
logmodel = pm.auto_arima(train['LogPassengers'],
                      trace=True,
                      suppress_warnings=True,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-438.248, Time=0.99 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-317.949, Time=0.05 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-433.027, Time=0.60 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-383.189, Time=0.55 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-134.983, Time=0.02 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-444.326, Time=1.40 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-414.783, Time=0.36 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-442.330, Time=17.72 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-436.716, Time=1.14 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=inf, Time=15.64 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-445.571, Time=1.00 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-414.732, Time=0.29 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-442.114, Time=1.17 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-443.413, Time=11.61 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-436.648, Time=1.00 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=inf, Time=13.80 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-416.893, Time=0.74 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-447.285, Time=0.82 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-416.167, Time=0.16 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-444.938, Time=1.01 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-445.290, Time=11.33 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-439.765, Time=1.08 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=11.62 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-442.847, Time=0.75 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-446.332, Time=1.36 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-327.548, Time=0.37 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-448.051, Time=0.96 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-417.188, Time=0.20 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-445.200, Time=0.96 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-446.059, Time=16.52 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-440.423, Time=0.86 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=12.88 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-446.264, Time=0.92 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-444.359, Time=1.15 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-440.546, Time=0.89 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 132.020 seconds

# %%
logmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  132
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 12)   Log Likelihood                 229.026
# Date:                              Tue, 30 Jan 2024   AIC                           -448.051
# Time:                                      08:08:28   BIC                           -434.114
# Sample:                                  01-01-1949   HQIC                          -442.391
#                                        - 12-01-1959
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0192      0.009      2.147      0.032       0.002       0.037
# ar.L1          0.6006      0.083      7.280      0.000       0.439       0.762
# ar.L2          0.2420      0.085      2.857      0.004       0.076       0.408
# ma.S.L12      -0.5676      0.105     -5.428      0.000      -0.773      -0.363
# sigma2         0.0012      0.000      8.195      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 6.05
# Prob(Q):                              0.99   Prob(JB):                         0.05
# Heteroskedasticity (H):               0.36   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_pred_log, confint = logmodel.predict(n_periods=Ntest, return_conf_int=True)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(test.index, test['LogPassengers'], label='data')
ax.plot(test.index, test_pred_log, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
train_pred_log = logmodel.predict_in_sample(start=0, end=-1)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.index, df['LogPassengers'], label='data')
ax.plot(train.index, train_pred_log, label='fitted')
ax.plot(test.index, test_pred_log, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
### forecast RMSE
def rmse(t, y):
  return np.sqrt(np.mean((t - y)**2))

# %%
print("Non-logged RMSE:", rmse(test['Passengers'], test_pred))
print("Logged RMSE:", rmse(test['Passengers'], np.exp(test_pred_log)))
# Out:
# Non-logged RMSE: 18.536468848484933
# Logged RMSE: 23.038937322566138

# %%
### non-seasonal
model = pm.auto_arima(train['LogPassengers'],
                      trace=True,
                      suppress_warnings=True,
                      d=0,
                      max_p=12, max_q=2, max_order=14,
                      stepwise=False,
                      seasonal=False)
# Out:
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=826.758, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-209.510, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-211.836, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-211.327, Time=0.15 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-207.022, Time=0.16 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-206.465, Time=0.14 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=-211.014, Time=0.19 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.23 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=-220.840, Time=0.24 sec
#  ARIMA(6,0,0)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(6,0,1)(0,0,0)[0]             : AIC=16.000, Time=0.07 sec
#  ARIMA(6,0,2)(0,0,0)[0]             : AIC=-219.592, Time=0.23 sec
#  ARIMA(7,0,0)(0,0,0)[0]             : AIC=inf, Time=0.21 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(7,0,1)(0,0,0)[0]             : AIC=-213.810, Time=0.34 sec
#  ARIMA(7,0,2)(0,0,0)[0]             : AIC=-235.948, Time=0.31 sec
#  ARIMA(8,0,0)(0,0,0)[0]             : AIC=inf, Time=0.26 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(8,0,1)(0,0,0)[0]             : AIC=-212.004, Time=0.62 sec
#  ARIMA(8,0,2)(0,0,0)[0]             : AIC=-238.960, Time=0.65 sec
#  ARIMA(9,0,0)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(9,0,1)(0,0,0)[0]             : AIC=-210.070, Time=0.63 sec
#  ARIMA(9,0,2)(0,0,0)[0]             : AIC=24.000, Time=0.41 sec
#  ARIMA(10,0,0)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(10,0,1)(0,0,0)[0]             : AIC=-237.268, Time=0.67 sec
#  ARIMA(10,0,2)(0,0,0)[0]             : AIC=26.000, Time=0.50 sec
#  ARIMA(11,0,0)(0,0,0)[0]             : AIC=inf, Time=0.46 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(11,0,1)(0,0,0)[0]             : AIC=-228.551, Time=0.76 sec
#  ARIMA(11,0,2)(0,0,0)[0]             : AIC=28.000, Time=0.51 sec
#  ARIMA(12,0,0)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(12,0,1)(0,0,0)[0]             : AIC=-260.615, Time=0.81 sec
#  ARIMA(12,0,2)(0,0,0)[0]             : AIC=-304.104, Time=0.85 sec
#
# Best model:  ARIMA(12,0,2)(0,0,0)[0]
# Total fit time: 11.997 seconds

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  132
# Model:              SARIMAX(12, 0, 2)   Log Likelihood                 167.052
# Date:                Tue, 30 Jan 2024   AIC                           -304.104
# Time:                        08:08:40   BIC                           -260.862
# Sample:                    01-01-1949   HQIC                          -286.533
#                          - 12-01-1959
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0288      0.084      0.341      0.733      -0.137       0.194
# ar.L2          0.2097      0.098      2.135      0.033       0.017       0.402
# ar.L3          0.1278      0.102      1.250      0.211      -0.073       0.328
# ar.L4         -0.1028      0.080     -1.278      0.201      -0.260       0.055
# ar.L5          0.0398      0.079      0.502      0.616      -0.116       0.195
# ar.L6          0.0689      0.081      0.853      0.394      -0.089       0.227
# ar.L7         -0.0371      0.088     -0.423      0.672      -0.209       0.135
# ar.L8         -0.1108      0.085     -1.297      0.195      -0.278       0.057
# ar.L9         -0.0051      0.080     -0.063      0.949      -0.162       0.152
# ar.L10         0.1060      0.077      1.379      0.168      -0.045       0.257
# ar.L11        -0.0733      0.082     -0.890      0.373      -0.235       0.088
# ar.L12         0.7479      0.083      9.047      0.000       0.586       0.910
# ma.L1          0.9901      0.097     10.177      0.000       0.799       1.181
# ma.L2          0.6341      0.084      7.522      0.000       0.469       0.799
# sigma2         0.0038      0.001      6.781      0.000       0.003       0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.70   Jarque-Bera (JB):                 1.24
# Prob(Q):                              0.05   Prob(JB):                         0.54
# Heteroskedasticity (H):               0.50   Skew:                             0.24
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_pred, confint = model.predict(n_periods=Ntest, return_conf_int=True)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(test.index, test['LogPassengers'], label='data')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
train_pred = model.predict_in_sample(start=1, end=-1)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.index, df['LogPassengers'], label='data')
ax.plot(train.index[1:], train_pred, label='fitted')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
rmse(test['Passengers'], np.exp(test_pred))
# Out:
# 57.20883173131196

# %%
### non-seasonal non-logged
model = pm.auto_arima(train['Passengers'],
                      trace=True,
                      suppress_warnings=True,
                      max_p=12, max_q=2, max_order=14,
                      stepwise=False,
                      seasonal=False)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1277.589, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1264.738, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1262.608, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1268.313, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1258.440, Time=0.06 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1263.896, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1218.683, Time=0.18 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1261.216, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=1254.439, Time=0.06 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=1245.588, Time=0.14 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=1256.151, Time=0.07 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=1247.185, Time=0.21 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(6,1,0)(0,0,0)[0] intercept   : AIC=1252.415, Time=0.09 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(6,1,1)(0,0,0)[0] intercept   : AIC=1246.387, Time=0.27 sec
#  ARIMA(6,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(7,1,0)(0,0,0)[0] intercept   : AIC=1252.659, Time=0.13 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(7,1,1)(0,0,0)[0] intercept   : AIC=1212.214, Time=0.36 sec
#  ARIMA(7,1,2)(0,0,0)[0] intercept   : AIC=1215.269, Time=0.31 sec
#  ARIMA(8,1,0)(0,0,0)[0] intercept   : AIC=1210.583, Time=0.30 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(8,1,1)(0,0,0)[0] intercept   : AIC=1178.134, Time=0.44 sec
#  ARIMA(8,1,2)(0,0,0)[0] intercept   : AIC=1180.440, Time=0.45 sec
#  ARIMA(9,1,0)(0,0,0)[0] intercept   : AIC=1206.774, Time=0.39 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(9,1,1)(0,0,0)[0] intercept   : AIC=1177.544, Time=0.40 sec
#  ARIMA(9,1,2)(0,0,0)[0] intercept   : AIC=1179.088, Time=0.45 sec
#  ARIMA(10,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(10,1,1)(0,0,0)[0] intercept   : AIC=1101.963, Time=0.48 sec
#  ARIMA(10,1,2)(0,0,0)[0] intercept   : AIC=1055.490, Time=0.59 sec
#  ARIMA(11,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.50 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(11,1,1)(0,0,0)[0] intercept   : AIC=1075.067, Time=0.54 sec
#  ARIMA(11,1,2)(0,0,0)[0] intercept   : AIC=1039.125, Time=0.62 sec
#  ARIMA(12,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(12,1,1)(0,0,0)[0] intercept   : AIC=1022.780, Time=0.65 sec
#  ARIMA(12,1,2)(0,0,0)[0] intercept   : AIC=1020.062, Time=0.68 sec
#
# Best model:  ARIMA(12,1,2)(0,0,0)[0] intercept
# Total fit time: 10.906 seconds

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  132
# Model:              SARIMAX(12, 1, 2)   Log Likelihood                -494.031
# Date:                Tue, 30 Jan 2024   AIC                           1020.062
# Time:                        08:08:52   BIC                           1066.065
# Sample:                    01-01-1949   HQIC                          1038.755
#                          - 12-01-1959
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      6.1064      3.022      2.020      0.043       0.183      12.030
# ar.L1         -0.0766      0.143     -0.536      0.592      -0.357       0.203
# ar.L2         -0.2993      0.142     -2.113      0.035      -0.577      -0.022
# ar.L3         -0.1341      0.117     -1.150      0.250      -0.363       0.094
# ar.L4         -0.2843      0.115     -2.481      0.013      -0.509      -0.060
# ar.L5         -0.0920      0.116     -0.791      0.429      -0.320       0.136
# ar.L6         -0.3053      0.112     -2.716      0.007      -0.526      -0.085
# ar.L7         -0.1007      0.124     -0.814      0.416      -0.343       0.142
# ar.L8         -0.3147      0.120     -2.623      0.009      -0.550      -0.080
# ar.L9         -0.0836      0.120     -0.695      0.487      -0.319       0.152
# ar.L10        -0.3178      0.129     -2.470      0.014      -0.570      -0.066
# ar.L11        -0.0756      0.130     -0.584      0.559      -0.330       0.178
# ar.L12         0.6367      0.126      5.060      0.000       0.390       0.883
# ma.L1         -0.0960      0.157     -0.610      0.542      -0.404       0.212
# ma.L2          0.2344      0.185      1.266      0.206      -0.129       0.597
# sigma2        97.8916     15.342      6.381      0.000      67.821     127.962
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                13.03
# Prob(Q):                              0.67   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.86   Skew:                            -0.19
# Prob(H) (two-sided):                  0.04   Kurtosis:                         4.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_pred, confint = model.predict(n_periods=Ntest, return_conf_int=True)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(test.index, test['Passengers'], label='data')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
rmse(test['Passengers'], test_pred)
# Out:
# 20.149854667503412
